# %% [markdown]
# # Bias Variance Tradeoff
#
# In this notebook we investigate the bias and variance of models. In the first section we'll investigate fitting functions of the form:
#
# $$f(x) = a + b * x^n$$
#
# to some cubic data with noise.

# %%
% matplotlib inline
import random

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
from sklearn import datasets, linear_model

# %% [markdown]
# ## Some helper functions
# The following functions will generate data and polynomial values.

# %%
def polynomials(X, degree=1):
    array = [X]
    y = X
    for i in range(2, int(degree + 1)):
        y = y * X
        array.append(y)
    return np.array(array).transpose()

def monomials(X, degree=1):
    y = np.array(X)
    y = np.power(X, degree)
    return np.array([y]).transpose()

def generate_data(func, a, b, n=100):
    data = []
    for _ in range(n):
        x = random.random() * (b - a)
        y = func(x)
        data.append((x, y))
    return list(sorted(data))

# %%
X = np.array(range(10))
polynomials(X, 3)
# Out:
# array([[  0,   0,   0],
#        [  1,   1,   1],
#        [  2,   4,   8],
#        [  3,   9,  27],
#        [  4,  16,  64],
#        [  5,  25, 125],
#        [  6,  36, 216],
#        [  7,  49, 343],
#        [  8,  64, 512],
#        [  9,  81, 729]])

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
# norm = np.random.normal(mu, sigma)

# Generate some data for the formula below
f = lambda x: 4 + 5 * x - 3 * x*x + 0.1 * x * x * x + np.random.normal(mu, sigma)
data = generate_data(f, 0, 2, n=20)

# %% [markdown]
# ## Fitting Polynomial Functions
#
# Here we fit try to fit our sample data with an increasing exponent:
#
# $$f(x) = 1 + b x^n$$
#
# None of these models are quite right because the data is generate from the function
#
# $$ \hat{f}(x) = 4 + 5 x - 3 x^2 + 0.1 x^3$$
#
# So each model is not quite right because one or more terms is missing. This will allow us to take a closer look at the bias-variance tradeoff.
#
# Let's start with $n = 1, 2, 3, 4$.

# %%
domain = np.array([x[0] for x in data])
Y = np.array([x[1] for x in data])


# from sklearn import linear_model
# regr = linear_model.LinearRegression()
# regr.fit(X, Y)

# yhat = regr.predict(X)
# sse = np.mean((np.mean(yhat) - Y) ** 2)
# var = np.var(yhat)
# bias = sse - var - 0.01


for i in range(1, 10): #take 10 shots at creating a model, so it tries functions of increasing orders
    X = monomials(domain, i) 
    # Create linear regression object and fit it to X and Y
    regr = linear_model.LinearRegression() #underlying model i want is linearreg from sklearn
    regr.fit(X,Y) # adjust the model for X input data in order to predict Y
    yhat = regr.predict(X) #using X as input, predict dependent variable Y (yhat is that predicted value)
    mse = np.mean((np.mean(yhat) -Y) ** 2) #take the difference of means (estimated - observed) for each point, square it...
    # then run the same thing again 10 times and take the average result of each of those calculations
    var = np.var(yhat) #variance function in numpy
    bias = sse - var - 0.01 #bias is all incorrectness not accounted for in variance, sum of squared error, and some random
    #unspecified random error term
    

    
    # The coefficients
    print('Coefficients: \n', regr.coef_)
    # Explained variance score: 1 is perfect prediction
    print('Variance score: %.2f' % regr.score(X, Y))

    # The mean square error
    print("Residual sum of squares: %.2f" % sse)

    print("Bias: {bias}".format(bias=bias))
    print("Variance: {var}".format(var=var))
        
    # Plot outputs
    plt.scatter(domain, Y,  color='black')
    plt.plot(domain, regr.predict(X), color='blue', linewidth=3)

    plt.title("n = " + str(i))

    plt.show()
# Out:
# ('Coefficients: \n', array([-0.51184378]))
# Variance score: 0.16
# Residual sum of squares: 0.42
# Bias: 0.345255839117
# Variance: 0.0654819967884
# ('Coefficients: \n', array([-0.37451862]))
# Variance score: 0.34
# Residual sum of squares: 0.42
# Bias: 0.267372517676
# Variance: 0.143365318229
# ('Coefficients: \n', array([-0.25129288]))
# Variance score: 0.50
# Residual sum of squares: 0.42
# Bias: 0.201445678461
# Variance: 0.209292157444
# ('Coefficients: \n', array([-0.15476835]))
# Variance score: 0.60
# Residual sum of squares: 0.42
# Bias: 0.157069726071
# Variance: 0.253668109835
# ('Coefficients: \n', array([-0.0897829]))
# Variance score: 0.66
# Residual sum of squares: 0.42
# Bias: 0.132169953645
# Variance: 0.27856788226
# ('Coefficients: \n', array([-0.05000452]))
# Variance score: 0.69
# Residual sum of squares: 0.42
# Bias: 0.121616986311
# Variance: 0.289120849595
# ('Coefficients: \n', array([-0.02709936]))
# Variance score: 0.69
# Residual sum of squares: 0.42
# Bias: 0.120412544758
# Variance: 0.290325291147
# ('Coefficients: \n', array([-0.01442801]))
# Variance score: 0.68
# Residual sum of squares: 0.42
# Bias: 0.124633063732
# Variance: 0.286104772173
# ('Coefficients: \n', array([-0.007598]))
# Variance score: 0.66
# Residual sum of squares: 0.42
# Bias: 0.131553622094
# Variance: 0.279184213811

# %% [markdown]
# It's important to note that the true measures of bias and variance are averaged over many fits to many samples from the same data source, and we're only looking at one instance here. Notice that the bias is at first decreasing as the exponent increases, but at $n=6$ we see the bias start to increase while the squared errors are basically unchanged. Let's make a plot of the bias as the exponent increases.

# %%
bs = [] #list of biases
vars_ = [] #list of variances
exps = np.arange(0, 100, 0.1)

for i in exps: #by increasing exps
    X = monomials(domain, i)
    # Create linear regression object
    regr = linear_model.LinearRegression()
    regr.fit(X, Y)
    # Calculate statistics
    yhat = regr.predict(X)
    sse = np.mean((np.mean(yhat) - Y) ** 2) #why not mean squared error - standard sq error
    var = np.var(yhat)
    bias = sse - var -0.01
    
    bs.append(bias)
    vars_.append(var)

#Plot the variance and bias
plt.plot(exps, bs, label="Bias")
plt.plot(exps, vars_, label="Variance")
ax = plt.gca()
ax.set_xlim([0,20])
ax.set_ylim([0,.5])

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, labels)

plt.show()

# %% [markdown]
# Just as in the conceptual diagram from the lesson, there's a spot where the bias is minimized around $n=5$.

# %% [markdown]
# # Variance
#
# Now let's try to fit the full polynomial as the degree increases, which will help us visualize variance error.
#
# **Check**: In the next code section, what changes when compared to the code above?

# %%
domain = np.array([x[0] for x in data])
Y = np.array([x[1] for x in data])

for i in range(1, 10):
    X = polynomials(domain, i) #why is domain included if still default [-1,1]? What's window?
    # Create linear regression object
    regr = linear_model.LinearRegression()
    regr.fit(X,Y)
    yhat = regr.predict(X)
    mse = np.mean((np.mean(yhat)-Y)**2)
    var = np.var(yhat)
    bias = var - sse - 0.01
    
    # The coefficients
    print('Coefficients: \n', regr.coef_)
    # Explained variance score: 1 is perfect prediction
    print('Variance score: %.2f' % regr.score(X, Y))

    # The mean square error
    print("Residual sum of squares: %.2f" % sse)

    print("Bias: {bias}".format(bias=bias))
    print("Variance: {var}".format(var=var))
        
    # Plot outputs
    plt.scatter(domain, Y,  color='black')
    plt.plot(domain, regr.predict(X), color='blue', linewidth=3)

    plt.title("n = " + str(i))

    plt.show()
# Out:
# ('Coefficients: \n', array([-0.51184378]))
# Variance score: 0.16
# Residual sum of squares: 0.42
# Bias: -0.365255839117
# Variance: 0.0654819967884
# ('Coefficients: \n', array([ 4.69755871, -2.64068932]))
# Variance score: 0.97
# Residual sum of squares: 0.42
# Bias: -0.0208602778235
# Variance: 0.409877558082
# ('Coefficients: \n', array([ 4.57690043, -2.50343058, -0.04458175]))
# Variance score: 0.97
# Residual sum of squares: 0.42
# Bias: -0.0208361057304
# Variance: 0.409901730175
# ('Coefficients: \n', array([ 4.70090497, -2.73928141,  0.12519586, -0.04087013]))
# Variance score: 0.97
# Residual sum of squares: 0.42
# Bias: -0.0208313640924
# Variance: 0.409906471813
# ('Coefficients: \n', array([ 6.63951531, -8.27355364,  6.85019867, -3.65769094,  0.7082118 ]))
# Variance score: 0.97
# Residual sum of squares: 0.42
# Bias: -0.0206496662186
# Variance: 0.410088169687
# ('Coefficients: \n', array([  4.08699364,   1.47669118, -10.40061614,  11.68815108,
#         -5.94005081,   1.11330085]))
# Variance score: 0.97
# Residual sum of squares: 0.42
# Bias: -0.020585913284
# Variance: 0.410151922621
# ('Coefficients: \n', array([  3.17264358,   5.81315798, -20.47578653,  24.34721619,
#        -14.69805584,   4.24638786,  -0.45196787]))
# Variance score: 0.97
# Residual sum of squares: 0.42
# Bias: -0.0205845316767
# Variance: 0.410153304229
# ('Coefficients: \n', array([ -100.95393661,   587.26252438, -1682.70596865,  2730.95174185,
#        -2621.84964333,  1471.89480445,  -446.01522177,    56.27047613]))
# Variance score: 0.98
# Residual sum of squares: 0.42
# Bias: -0.0182129590071
# Variance: 0.412524876898
# ('Coefficients: \n', array([  104.6283872 ,  -737.72360601,  2852.70147694, -6470.05264573,
#         8970.20259854, -7677.35753495,  3948.56542545, -1116.60140205,
#          133.21173763]))
# Variance score: 0.98
# Residual sum of squares: 0.42
# Bias: -0.0168756253909
# Variance: 0.413862210514

# %%
bs = []
vars = []
exps = np.arange(0, 12, .1)

for i in exps:
    X = polynomials(domain, i)
    # Create linear regression object
    
  
    regr = linear_model.LinearRegression()
    regr.fit(X, Y)
    yhat = regr.predict(X)
    mse = np.mean((np.mean(yhat) - Y) ** 2)
    var = np.var(yhat)
    bias = sse - var - 0.01
    bs.append(bias)
    vars.append(var)

plt.plot(exps, bs, label="Bias")
plt.plot(exps, vars, label="Variance")
ax = plt.gca()

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, labels)

plt.show()

# %% [markdown]
# Notice that the fits for $n = 2, 3, 4$ are pretty good. As the exponent increases, the best fit curve is overfitting the dataset, and the shape of the curve does not reflect what we know the underlying data to really look like. In this case we have error due to variance -- with too many parameters, our model is fitting the random variations in the data which we generally want to avoid.

# %% [markdown]
# # Guided Practice
#
# We've seen that as the complexity in our models change so too do the bias and variance. Let's investigate from another angle using linear regression. Rather than change the model, we'll change the underlying data to be drawn from a higher dimensional model.
#
# Your tasks are:
# * Fill in the code to fit a linear regression to the data
# * Investiage the bias and variance as the data source changes in complexity

# %%
#0.A: set data to x and y (observed), 0.B: (if relevant) create for loop with X = polynomials(domain(?), i) to try models with
#increasing number of terms, with increasing magnitude (see polynomial) 
#1: declare linear model, #2, fit with the training data, #3 use inputs to predict y, setting that equal to yhat
#4: calculate mse, variance and bias to evaluate your model, #5 put variance and bias in lists



vars = []
bias_list = []


for i in range(1, 7):
    # Generate some data
    f = lambda x: 1 - 2 * x + 3 * x ** i + np.random.normal(mu, sigma)
    data = generate_data(f, 0, 2, n=20)

    domain = np.array([x[0] for x in data])
    y = np.array([x[1] for x in data])

    x = np.array([domain]).transpose() #changing this to polynomial below
    # Create linear regression object
    regr = linear_model.LinearRegression()
    regr.fit(x,y)
    yhat= regr.predict(x)
   
    # Computer the errors
    
    mse = np.mean((np.mean(yhat) - y)**2)
    np.mean((np.mean(yhat)-Y)**2)
    var = np.var(yhat)
    bias = sse - var - 0.01
    
    # Plot outputs
    bias_list.append(bias)
    vars.append(var)

    plt.plot(bias_list, label="Bias")
    plt.plot(vars, label="Variance") 
    ax1 = plt.gca()

    handles, labels = ax.get_legend_handles_labels()
    ax1.legend(handles, labels)
    ax1.set_xlim(0,5)
    ax1.set_ylim(-5,5)
    plt.scatter(domain, y,  color='black')
    plt.plot(domain, yhat, color='blue', linewidth=3, label="Predicted Vals")
    plt.plot(domain, y, color='orange', linewidth=3, label="Observed Vals")
        
    plt.title("n = " + str(i))
    plt.show() 
    
    
     # The coefficients
    print('Coefficients: \n', regr.coef_)
    # Explained variance score: 1 is perfect prediction
    print('Variance score: %.2f' % regr.score(X, Y))

    # The mean square error
    print("Residual sum of squares: %.2f" % mse)

    print("Bias: {bias}".format(bias=bias))
    print("Variance: {var}".format(var=var))
# Out:
# ('Coefficients: \n', array([ 0.95486441]))
# Variance score: 0.96
# Residual sum of squares: 0.35
# Bias: 0.0655021930985
# Variance: 0.345235642807
# ('Coefficients: \n', array([ 4.27078048]))
# Variance score: -12.38
# Residual sum of squares: 5.78
# Bias: -4.58196138341
# Variance: 4.99269921932
# ('Coefficients: \n', array([ 8.13904826]))
# Variance score: -81.51
# Residual sum of squares: 29.26
# Bias: -23.4558469037
# Variance: 23.8665847396
# ('Coefficients: \n', array([ 17.6405464]))
# Variance score: -387.67
# Residual sum of squares: 131.51
# Bias: -95.0570679647
# Variance: 95.4678058006
# ('Coefficients: \n', array([ 32.12886499]))
# Variance score: -1368.44
# Residual sum of squares: 424.53
# Bias: -310.124694838
# Variance: 310.535432674
# ('Coefficients: \n', array([ 84.03874228]))
# Variance score: -8844.20
# Residual sum of squares: 3577.18
# Bias: -2317.53134552
# Variance: 2317.94208336

# %%
domain = np.array([x[0] for x in data])
Y = np.array([x[1] for x in data])

for i in range(1, 10):
    X = polynomials(domain, i) #why is domain included if still default [-1,1]? What's window?
    # Create linear regression object
    regr = linear_model.LinearRegression()
    regr.fit(X,Y)
    yhat = regr.predict(X)
    mse = np.mean((np.mean(yhat)-Y)**2)
    var = np.var(yhat)
    bias = var - sse - 0.01
    
    # The coefficients
    print('Coefficients: \n', regr.coef_)
    # Explained variance score: 1 is perfect prediction
    print('Variance score: %.2f' % regr.score(X, Y))

    # The mean square error
    print("Residual sum of squares: %.2f" % sse)

    print("Bias: {bias}".format(bias=bias))
    print("Variance: {var}".format(var=var))
        
    # Plot outputs
    plt.scatter(domain, Y,  color='black')
    plt.plot(domain, regr.predict(X), color='blue', linewidth=3)

    plt.title("n = " + str(i))

    plt.show()

# %%
#0.A: set data to x and y (observed), 0.B: (if relevant) create for loop with X = polynomials(domain(?), i) to try models with
#increasing number of terms, with increasing magnitude (see polynomial) 
#1: declare linear model, #2, fit with the training data, #3 use inputs to predict y, setting that equal to yhat
#4: calculate mse, variance and bias to evaluate your model, #5 put variance and bias in lists



vars = []
bias_list = []


for i in range(1, 7):
    # Generate some data
    f = lambda x: 1 - 2 * x + 3 * x ** i + np.random.normal(mu, sigma)
    data = generate_data(f, 0, 2, n=20)

    domain = np.array([x[0] for x in data]) #i don't get this line and how it works elsewhere in plot
    y = np.array([x[1] for x in data])

    x = polynomials(domain, i) #changed this from above, making the model more effective, but still have issues with 
    # Create linear regression object
    regr = linear_model.LinearRegression()
    regr.fit(x,y)
    yhat= regr.predict(x)
   
    # Computer the errors
    
    mse = np.mean((np.mean(yhat) - y)**2)
    var = np.var(yhat)
    bias = sse - var - 0.01
    
    # Plot outputs
    bias_list.append(bias)
    vars.append(var)

    plt.plot(bias, label="Bias")
    plt.plot(var, label="Variance") 
    ax1 = plt.gca()

    handles, labels = ax.get_legend_handles_labels()
    ax1.legend(handles, labels)
    ax1.set_xlim(0,5)
    ax1.set_ylim(-5,5)
    plt.scatter(domain, y,  color='black')
    plt.plot(domain, yhat, color='blue', linewidth=3, label="Predicted Vals")
    plt.plot(domain, y, color='orange', linewidth=1, label="Observed Vals")
        
    plt.title("n = " + str(i))
    plt.show() 
    
    
     # The coefficients
    print('Coefficients: \n', regr.coef_)
    # Explained variance score: 1 is perfect prediction
    print('Variance score: %.2f' % regr.score(x, y))

    # The mean square error
    print("Residual sum of squares: %.2f" % mse)

    print("Bias: {bias}".format(bias=bias_list))
    print("Variance: {var}".format(var=vars))
# Out:
# ('Coefficients: \n', array([ 1.01737133]))
# Variance score: 0.97
# Residual sum of squares: 0.29
# Bias: [0.12663398962167777]
# Variance: [0.28410384628366459]
# ('Coefficients: \n', array([-1.86541693,  3.00407414]))
# Variance score: 1.00
# Residual sum of squares: 3.21
# Bias: [0.12663398962167777, -2.7883666648394101]
# Variance: [0.28410384628366459, 3.1991045007447525]
# ('Coefficients: \n', array([-2.31491738,  0.44819818,  2.84539526]))
# Variance score: 1.00
# Residual sum of squares: 28.74
# Bias: [0.12663398962167777, -2.7883666648394101, -28.325681720642077]
# Variance: [0.28410384628366459, 3.1991045007447525, 28.736419556547418]
# ('Coefficients: \n', array([-1.6438549 , -0.37880114,  0.17925382,  2.965858  ]))
# Variance score: 1.00
# Residual sum of squares: 187.46
# Bias: [0.12663398962167777, -2.7883666648394101, -28.325681720642077, -187.03792008498141]
# Variance: [0.28410384628366459, 3.1991045007447525, 28.736419556547418, 187.44865792088677]
# ('Coefficients: \n', array([-0.07608772, -5.97728763,  7.77444913, -4.45833745,  3.9245384 ]))
# Variance score: 1.00
# Residual sum of squares: 468.05
# Bias: [0.12663398962167777, -2.7883666648394101, -28.325681720642077, -187.03792008498141, -467.63559309024714]
# Variance: [0.28410384628366459, 3.1991045007447525, 28.736419556547418, 187.44865792088677, 468.04633092615251]
# ('Coefficients: \n', array([  2.55358479, -14.09003171,  18.79006124, -12.25177604,
#          3.8831873 ,   2.51662913]))
# Variance score: 1.00
# Residual sum of squares: 3203.88
# Bias: [0.12663398962167777, -2.7883666648394101, -28.325681720642077, -187.03792008498141, -467.63559309024714, -3203.4622401069482]
# Variance: [0.28410384628366459, 3.1991045007447525, 28.736419556547418, 187.44865792088677, 468.04633092615251, 3203.8729779428531]

# %% [markdown]
# # Advanced Exercises
#
# Some functions, like $sin$ and $exp$ can be better fit with increasing large polynomials.
#
# * By modifying the above code, fit polynomials of degree $n$ as $n$ ranges from 1 to 10 to $sin$ on the interval $[0, 2 \pi]$.
# * Can you explain why the bias and variance continue to decrease as $n$ gets large?

# %%
import math
f = lambda x: math.sin(x) + np.random.normal(mu, sigma)
data = generate_data(f, 0, 2*3.14, n=100)

domain = np.array([x[0] for x in data])
Y = np.array([x[1] for x in data])

for i in range(1, 10):
    pass
    # Fit a polynomial of degree i to the data
    
    # Compute the errors

    # Plot outputs

# %% [markdown]
# ### Repeat the same exercise with the function
#
# $$ y = e^x $$
#
# You should again find that larger polynomials fit the data better.

# %% [markdown]
# ### A bad model for the exponential
#
# To see a model with high variance, try fitting the model:
#
# ```
# y = a sin(x) + b cos(x)
# ```
#
# to `y = e^x`. Does this model have more bias or variance?
