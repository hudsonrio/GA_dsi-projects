# %%
from __future__ import division, print_function

from IPython.core.display import HTML, Image

import pandas as pd
import numpy as np
import os
import random

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %matplotlib inline

# %% [markdown]
# # Plotting with Pandas

# %% [markdown]
# ## Agenda
# - Line plots
# - Bar plots
# - Scatter plots
# - Histograms
# - MPL object model

# %%
os.getcwd()
# Out:
# '/Users/HudsonCavanagh/dsi-projects/week02'

# %%
PATH = '/Users/HudsonCavanagh/dsi-projects/DSI-NYC-1/curriculum/week-02/5.3-pandas-plotting/assets/images/'

# %%
Image(PATH + 'pandas_plot.png')

# %% [markdown]
# ## Import our data

# %%
df = pd.DataFrame(np.random.randn(10, 4), 
                  columns=['col1', 'col2', 'col3', 'col4'],
                  index=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'])

# %%
df
# Out:
#        col1      col2      col3      col4
# a  0.519221 -0.546061 -0.658539 -0.794090
# b -0.036867  0.411962 -0.211068 -1.904354
# c -1.048221 -0.626312 -0.561006 -0.500489
# d  0.854339 -0.142000 -0.598036  1.948479
# e  1.404591  0.499429  1.308063 -0.804617
# f -0.667503 -1.880717  0.949237 -0.766990
# g  1.858737  1.177165 -0.132814  1.849689
# h  0.212570  0.304026 -0.170068 -1.343454
# i  0.248733 -0.517611  0.966282  0.705752
# j -0.464730  0.003311 -1.291487 -0.579726

# %% [markdown]
# ## Line plot - DataFrame

# %%
df.plot()

# %% [markdown]
# ### <ul> Line plots are the default plot in pandas

# %% [markdown]
# ## Line plot - Series

# %%
df['col1'].plot()

# %% [markdown]
# ## We can pass in parameters to change the dimensions and the size

# %%
df.plot(figsize=(16,8))

# %% [markdown]
# ### <ul>figsize(width, height)

# %% [markdown]
# ## We can change the color

# %%
df['col1'].plot(color='crimson', figsize=(16,8))

# %% [markdown]
# ## We can change the style - markers

# %%
df[['col1', 'col4']].plot(figsize=(16,8),\
                          style={'col1': ':r', 'col4': 'vb'})

# %% [markdown]
# ## E1. Using the df, create a line plot of col2 and col3. For col2 use a green o and for col3 use a blue dashed line. Set the width to 12 and the height to 8.

# %%
df[['col2', 'col3']].plot(figsize=(12,8), style={'col2': 'og', 'col3': '--b'}); #semi-colon kills the output

# %% [markdown]
# ## We can change the visible ticks and their size

# %%
df['col2'].plot(figsize=(16,4), color='purple', fontsize=14)

# %%
ticks_to_show = [x for x in range(len(df['col2'].index)) if x%2 == 0]
#charts can get overcrowded, this makes only every other tick show
df['col2'].plot(figsize=(16,4), color='purple', xticks=ticks_to_show, fontsize=16)

# %% [markdown]
# ## We can change the label rotation

# %%
df.plot(figsize=(16,8), fontsize=20, rot=-50, title='Big Rotated Labels - Tiny Title')

# %% [markdown]
# ### E2. Create a line chart with col4. Rotate the labels 90 degrees and give them a fontsize of 16. Set the color to dark orange. Set they title to "My Cool Plot". Set the figure size to 14 by 7.

# %%
df['col4'].plot(figsize=(14,7), fontsize=16, rot=-90, c='darkorange', title='My "cool" plot')

# %% [markdown]
# ## All the functionality of Matplotlib is available

# %%
fig = df.plot(figsize=(16,8), fontsize=20)
ax = plt.gca()

ax.set_title('Finally A Big Title!', fontsize=21, y=1.01)

# %% [markdown]
# #### E3. Create a plot using the full data frame. Set the figure size to 16 by 8. Give it any title you want with a fontsize of 22. Move the title so that it is in the the body of the graph. Set a y label  of "this is my y axis" and an x label equal to "this is my x axis". Give both labels a fontsize of 16. Rotate your x axis label - what you just created - 180 degrees.

# %%
fig = df.plot(figsize=(16,8), fontsize=20)
ax = plt.gca()

ax.set_title('Chart Chart Chart Chart', fontsize=22, y=-1)
ax.set_xlabel('my other upside down x label', fontsize=16, rotation=180)
#plt.xlabel('this is x axis (upside down)', fontsize=16, rotation=180)
#no clear reason why we should use one vs. the other
plt.ylabel('this is my y axis',  fontsize=16)

# %% [markdown]
# # Bar Plots

# %% [markdown]
# ## Series

# %%
df['col4'].plot(kind='bar', color='darkred', figsize=(16,8), fontsize=14)

# %% [markdown]
# ## Using matplotlib commands we can get fancy

# %%
fig = df.plot(kind='bar', figsize=(16,8))
ax = plt.gca()

# set the title
ax.set_title('Some Kinda Plot Thingy', fontsize=21, y=1.01)

# move the legend
ax.legend(loc=1)

# x-axis labels
ax.set_ylabel('Important y-axis info', fontsize=16)

# y-axis labels
ax.set_xlabel('Meaningless x-axis info', fontsize=16)

# %% [markdown]
# ## We can switch to horizontal bars...

# %%
df.plot(kind='barh', figsize=(8,16))

# %% [markdown]
# ## E4. Create a bar chart using col1 and col2. Give it a large title of your choosing. Move the legend to the lower-left corner.

# %%
df[['col1','col2']].plot()

# %%
fig1 = df[['col1','col2']].plot(figsize=(16,8), fontsize=20)
ax1 = plt.gca()

ax1.set_title('Chart Chart Chart Chart', fontsize=22, y=-1)
ax1.legend(loc=4)
ax1.set_xlabel('my other upside down x label', fontsize=16, rotation=90)
#plt.xlabel('this is x axis (upside down)', fontsize=16, rotation=180)
#no clear reason why we should use one vs. the other
plt.ylabel('this is my y axis',  fontsize=16)

# %% [markdown]
# ## E5. Do the same thing but with horizontal bars. Move the legend to the upper-right.

# %%
fig1 = df[['col1','col2']].plot(kind='barh', stacked=True, figsize=(16,8), fontsize=20)
ax1 = plt.gca()

ax1.set_title('Chart Chart Chart Chart', fontsize=22, y=.5)
ax1.legend(loc=1)
ax1.set_xlabel('my  x label', fontsize=16, rotation=-1)
#plt.xlabel('this is x axis (upside down)', fontsize=16, rotation=180)
#no clear reason why we should use one vs. the other
plt.ylabel('this is my y axis',  fontsize=16)

# %% [markdown]
# ## We can use stacked bars

# %%
df.plot(kind='bar', stacked=True, figsize=(16,8))

# %% [markdown]
# ## <ul> Must use on multiple columns

# %% [markdown]
# ## Stacked works on hbar too

# %%
df.plot(kind='barh', stacked=True, figsize=(16,8))

# %% [markdown]
# ## E6. Create a stacked bar chart using any two columns. Either vertical or horizontal.

# %%
df[['col2','col3']].plot(kind='bar', stacked=1, figsize=(16,10))

# %% [markdown]
# # Scatter Plots

# %%
df.plot(x='col3', y='col4', kind='scatter', color='knicksorange', figsize=(16,8), s=250)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-27f584493fb6> in <module>()
# ----> 1 df.plot(x='col3', y='col4', kind='scatter', color='knicksorange', figsize=(16,8), s=250)
#
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3669                           fontsize=fontsize, colormap=colormap, table=table,
#    3670                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3671                           sort_columns=sort_columns, **kwds)
#    3672     __call__.__doc__ = plot_frame.__doc__
#    3673
#
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2554                  yerr=yerr, xerr=xerr,
#    2555                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2556                  **kwds)
#    2557
#    2558
#
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2382         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2383
# -> 2384     plot_obj.generate()
#    2385     plot_obj.draw()
#    2386     return plot_obj.result
#
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in generate(self)
#     985         self._compute_plot_data()
#     986         self._setup_subplots()
# --> 987         self._make_plot()
#     988         self._add_table()
#     989         self._make_legend()
#
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _make_plot(self)
#    1557             label = None
#    1558         scatter = ax.scatter(data[x].values, data[y].values, c=c_values,
# -> 1559                              label=label, cmap=cmap, **self.kwds)
#    1560         if cb:
#    1561             img = ax.collections[0]
#
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
#    1814         if pre_doc is None:
#
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    3891                 offsets=offsets,
#    3892                 transOffset=kwargs.pop('transform', self.transData),
# -> 3893                 alpha=alpha
#    3894                 )
#    3895         collection.set_transform(mtransforms.IdentityTransform())
#
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/matplotlib/collections.pyc in __init__(self, paths, sizes, **kwargs)
#     829         """
#     830
# --> 831         Collection.__init__(self, **kwargs)
#     832         self.set_paths(paths)
#     833         self.set_sizes(sizes)
#
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/matplotlib/collections.pyc in __init__(self, edgecolors, facecolors, linewidths, linestyles, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, offset_position, zorder, **kwargs)
#     115
#     116         self.set_edgecolor(edgecolors)
# --> 117         self.set_facecolor(facecolors)
#     118         self.set_linewidth(linewidths)
#     119         self.set_linestyle(linestyles)
#
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/matplotlib/collections.pyc in set_facecolor(self, c)
#     610             c = mpl.rcParams['patch.facecolor']
#     611         self._facecolors_original = c
# --> 612         self._facecolors = mcolors.colorConverter.to_rgba_array(c, self._alpha)
#     613         self.stale = True
#     614
#
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/matplotlib/colors.pyc in to_rgba_array(self, c, alpha)
#     420             result = np.zeros((nc, 4), dtype=np.float)
#     421             for i, cc in enumerate(c):
# --> 422                 result[i] = self.to_rgba(cc, alpha)
#     423             return result
#     424
#
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/matplotlib/colors.pyc in to_rgba(self, arg, alpha)
#     374         except (TypeError, ValueError) as exc:
#     375             raise ValueError(
# --> 376                 'to_rgba: Invalid rgba arg "%s"\n%s' % (str(arg), exc))
#     377
#     378     def to_rgba_array(self, c, alpha=None):
#
# ValueError: to_rgba: Invalid rgba arg "knicksorange"
# to_rgb: Invalid rgb arg "knicksorange"
# could not convert string to float: knicksorange

# %% [markdown]
# ## E7. Create a scatter plot using the DataFrame below. Adjust the size of each point so that it is the value of the y variable to the 4th power. \*_hint_ think list comprehension.

# %%
sp_dict = {'x': [1,2,3,4,5], 'y': [2,5,3,9,12]}
sp = pd.DataFrame(sp_dict)
type(sp)

# %%
sp['z'] = sp['y']**3
#sp = sp.drop('y', axis=1, inplace=1)
sp.head()

# %%
sp.plot(kind='scatter', x='x', y='z', figsize=(16,12))

# %%
sp.plot(x='x', y='z', kind='scatter', s=[x**4 for x in sp['y']], color='orange', figsize=(16,12))

# %% [markdown]
# # Histograms

# %%
df.hist(figsize=(16,8));

# %% [markdown]
# ## Single historgram

# %%
norm = np.random.standard_normal(5000)

# %%
pd.Series(norm).hist(figsize=(16,4), bins=10)

# %% [markdown]
# ## Bins param adjusts the no. of bins

# %%
pd.Series(norm).hist(figsize=(16,4), bins=20)

# %% [markdown]
# ## E8. Create a histogram of the poisson distribution using the parameters 5 and 1 million. Set the bins to 20.

# %%
pois = np.random.poisson(lam=5, size=1000000)

# %%
pd.Series(pois).hist(figsize=(16,4), bins=20)

# %% [markdown]
# ## Understanding figures, subplots, and axes

# %% [markdown]
# <em style="font-size:26px">In matplotlib, the figure (an instance of the class plt.Figure) can be thought of as a single container which contains all the objects representing axes, graphics, text, labels, etc.
#
# The axes (an instance of the class plt.Axes) is what we see below: a bounding box with ticks and labels, which will eventually contain other plot elements.</em>

# %%
Image(PATH + 'subplots.png')

# %% [markdown]
# #### <ul> A 2 by 1 subplot arrangement

# %%
Image(PATH + 'subplots2.png')

# %% [markdown]
# #### A 2 by 2 arrangement

# %%
Image(PATH + 'axes.png')

# %%
Image(PATH + 'axes2.png')

# %% [markdown]
# ## Create an example

# %%
fig, axes = plt.subplots(2,3, figsize=(16,8))

axes_details = type(axes)
fig_details = type(fig)

# %%
fig_details

# %%
axes_details

# %%
axes.shape

# %%
axes[0]

# %%
axes[1]

# %%
axes[2]

# %% [markdown]
# ## Changing ticks on a subplot

# %%
fig, axes = plt.subplots(2,3, figsize=(16,8))

# change upper-left plot x ticks
axes[0][0].set_xticklabels([0,1,2,3,4,5], fontsize=16)

# change lower-right plot x ticks
axes[1][2].set_xticklabels(['a','b','c','d','e','f'], fontsize=16)

# %% [markdown]
# ## Setting titles

# %%
fig, axes = plt.subplots(2,2, figsize=(16,8))

# set title for bottom-right plot
axes[1][1].set_title('Hello From Row 2, Plot 2')

fig.suptitle('Hello From the Figure', fontsize=21)

# %% [markdown]
# ## Independent Exercise

# %% [markdown]
# - Create a plot that is 1 across and three long
# - Create a line 10 elements long with a postive slope in the first plot
# - Color it green
# - Give it a title
# - In the second plot, create a line (10 elements) with a negative slope
# - Give it a title
# - Color it red
# - In the last plot, plot both a line with an increasing slope and a decreasing slope
# - Give that a title as well
# - Finally, give the entire plot a main title
# - Now using those same negative and positive values, create a DataFrame from them
# - Using that DataFrame, create two scatterplots using pandas plotting one with a positive slope and one with a negative slope. Make sure to adjust the marker size so that the dots are large enough to view easily.
# - Now using subplots with matplotlib, draw both scatterplots on a single subplot
# - Using .set_xlim() change the scatter plot so that it starts at zero

# %% [markdown]
# ## Create a plot that is 1 across and 3 long

# %%
#ding = x for x in random.randint(1,20, size=10)
#dong = random.randint(10,100, size=10)
#random.randrange(start, stop[, step])

#def randomish(y):
   # list = []
   # for i in range(y):
   #     list.append(x for x in random.randrange(10,100,1))
   # return list


#ding = randomish(10)
#print(ding)




#type(axes)
#axes = plt.gca()
#axes[1][0].set_xticklabels([0,1,2,3,4,5], fontsize=16)

# %%
bing = pd.Series(random.sample(xrange(100), 10))
bong = pd.Series(random.sample(xrange(200), 10))

fig, axe = plt.subplots(3,1, figsize=(16,8))
axe[0].set_title('Hello From Row 1')

axe[1].set_title('Hello From Row 2')
axe[2].set_title('Hello From Row 3')
fig.suptitle('Hello From the Figure', fontsize=21)
axe[0].plot(bong, color='blue')
axe[2].plot((bing/bong), color='red')
axe[1].plot(bing, color='orange')
#plt.ylim(-100, 100)
#plt.xlim(-200, 200)
#axe.set_ylim(1,500)
#axe.set_xlim(1,500)

#data_df.plot(x='Compression Velocity', y='Compression Force', xticks=d['Compression Velocity'])

# %%
bing
# Out:
# 0    22
# 1    31
# 2    60
# 3    78
# 4    38
# 5    14
# 6     1
# 7     7
# 8    54
# 9    90
# dtype: int64

# %% [markdown]
# ## Plot a line with an increasing slope in the top subplot

# %%
plt.plot(x=range(50), y=x**2, kind='line', ax=axes[1])

# %% [markdown]
# ## Add a line with a negative slope

# %%
#axis.scatter(x=???, y=???, color=, s=100)

# %% [markdown]
# ## Add both to the last subplot

# %% [markdown]
# ## Add a title above all the plots

# %% [markdown]
# ## Create two scatter plots with those lines using pandas

# %%
lines = pd.DataFrame({'pos': pos_slope, 'neg': neg_slope})
lines

# %% [markdown]
# ## x is negative and y is positive

# %% [markdown]
# ## x is positive and y is negative

# %% [markdown]
# ## Create two scatter plots on the same subplot

# %% [markdown]
# ## Set the xlim
