# %%
#Python - Pandas
#Created by hedgefund guy to add capabilities of R to Python

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
# %matplotlib inline

os.getcwd()
# Out:
# '/Users/HudsonCavanagh/dsi-projects/week02'

# %%
df = pd.read_csv('/Users/HudsonCavanagh/dsi-projects/week02/salary.csv')

# %%
#df.head()
#can also use arguements to extend, same with tail() below:
df.head(20)
# Out:
#         sx         rk  yr         dg  yd     sl
# 0     male       full  25  doctorate  35  36350
# 1     male       full  13  doctorate  22  35350
# 2     male       full  10  doctorate  23  28200
# 3   female       full   7  doctorate  27  26775
# 4     male       full  19    masters  30  33696
# 5     male       full  16  doctorate  21  28516
# 6   female       full   0    masters  32  24900
# 7     male       full  16  doctorate  18  31909
# 8     male       full  13    masters  30  31850
# 9     male       full  13    masters  31  32850
# 10    male       full  12  doctorate  22  27025
# 11    male  associate  15  doctorate  19  24750
# 12    male       full   9  doctorate  17  28200
# 13    male  associate   9    masters  27  23712
# 14    male       full   9  doctorate  24  25748
# 15    male       full   7  doctorate  15  29342
# 16    male       full  13  doctorate  20  31114
# 17    male  associate  11    masters  14  24742
# 18    male  associate  10    masters  15  22906
# ...

# %%
df.tail()
# Out:
#         sx         rk  yr         dg  yd     sl
# 47  female  assistant   2  doctorate   2  15350
# 48    male  assistant   1  doctorate   1  16244
# 49  female  assistant   1  doctorate   1  16686
# 50  female  assistant   1  doctorate   1  15000
# 51  female  assistant   0  doctorate   2  20300

# %%
df.describe()
#ignores all non-numeric values
# Out:
#               yr         yd            sl
# count  52.000000  52.000000     52.000000
# mean    7.480769  16.115385  23797.653846
# std     5.507536  10.222340   5917.289154
# min     0.000000   1.000000  15000.000000
# 25%     3.000000   6.750000  18246.750000
# 50%     7.000000  15.500000  23719.000000
# 75%    11.000000  23.250000  27258.500000
# max    25.000000  35.000000  38045.000000

# %%
df.describe(percentiles=[.1,.2,.5,.8,.95])
# Out:
#               yr         yd            sl
# count  52.000000  52.000000     52.000000
# mean    7.480769  16.115385  23797.653846
# std     5.507536  10.222340   5917.289154
# min     0.000000   1.000000  15000.000000
# 10%     1.000000   2.100000  16518.600000
# 20%     2.200000   4.200000  17680.000000
# 50%     7.000000  15.500000  23719.000000
# 80%    11.800000  26.400000  28200.000000
# 95%    16.000000  31.450000  34440.300000
# max    25.000000  35.000000  38045.000000

# %%
df.count()
# Out:
# sx    52
# rk    52
# yr    52
# dg    52
# yd    52
# sl    52
# dtype: int64

# %%
df.mean()
# Out:
# yr        7.480769
# yd       16.115385
# sl    23797.653846
# dtype: float64

# %%
df.median()
# Out:
# yr        7.0
# yd       15.5
# sl    23719.0
# dtype: float64

# %%
df.max()
#df.min()
#for categorical variables, returns the first alphabetically, NOT the most frequent
# Out:
# sx       male
# rk       full
# yr         25
# dg    masters
# yd         35
# sl      38045
# dtype: object

# %%
df.info()
#this shows where null values are, which we will need to fill later
#
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52 entries, 0 to 51
# Data columns (total 6 columns):
# sx    52 non-null object
# rk    52 non-null object
# yr    52 non-null int64
# dg    52 non-null object
# yd    52 non-null int64
# sl    52 non-null int64
# dtypes: int64(3), object(3)
# memory usage: 2.8+ KB

# %%
#df.fillna('ffill') interpolation based na-filling

# %%
degree = df['dg'] 

means = df.groupby(degree).mean()
print(means)
# Out:
#                  yr         yd            sl
# dg
# doctorate  6.911765  12.558824  23500.352941
# masters    8.555556  22.833333  24359.222222

# %%
#list_of_cols = ['sx', 'yr', 'sl']
other_list_of_cols = x for x in df if 'c' in x
#use something like the above to filter a large number of column names
df[other_list_of_cols]
# Out:
#   File "<ipython-input-27-53ba7ca0913f>", line 2
#     other_list_of_cols = x for x in df if 'c' in x
#                              ^
# SyntaxError: invalid syntax

# %%
#first ten rows and columns 2:4
df.iloc[0:10, 2:24]
#many ways to do this, but this might be the best method to do so
# Out:
#    yr         dg  yd     sl
# 0  25  doctorate  35  36350
# 1  13  doctorate  22  35350
# 2  10  doctorate  23  28200
# 3   7  doctorate  27  26775
# 4  19    masters  30  33696
# 5  16  doctorate  21  28516
# 6   0    masters  32  24900
# 7  16  doctorate  18  31909
# 8  13    masters  30  31850
# 9  13    masters  31  32850

# %%
df.iloc[1,3]
#row 1, column 3 (returns one cell)
# Out:
# 'doctorate'

# %%
df['yr'].hist()
#various matplotlib functions work as well, as do parameters. Limited set however.

# %%
df['yr'].hist(figsize=10, color='orange')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-e789b20ead5f> in <module>()
# ----> 1 df['yr'].hist(figsize=10, color='orange')
#
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#    2889         # hack until the plotting interface is a bit more unified
#    2890         fig = kwds.pop('figure', plt.gcf() if plt.get_fignums() else
# -> 2891                        plt.figure(figsize=figsize))
#    2892         if (figsize is not None and tuple(figsize) !=
#    2893             tuple(fig.get_size_inches())):
#
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, **kwargs)
# ...

# %%
fig = df['yr'].hist(figsize=(12,8), color ='darkblue')

plt.style.use('fivethirtyeight')
ax = plt.gca()
ax.set_ylabel('Frequency', fontsize=14)
ax.set_xlabel('Years', fontsize=14)

fig.set_title('A Chart of stuff', y=1.01)
#last parameter moves the chart title up/ down

# %%
os.getcwd()
# Out:
# '/Users/HudsonCavanagh/dsi-projects/week02'

# %%
sw = pd.read_csv('/Users/HudsonCavanagh/dsi-projects/538data/star-wars-survey/StarWars.csv', encoding='latin1')

# %%
#sw.columns = ['RespondentID', 'seen6', 'fan_status'] - seems to only be able to name, not rename
sw.rename(columns={'Have you seen any of the 6 films in the Star Wars franchise?': 'seen6'}, inplace=True)
sw.rename(columns={'Do you consider yourself to be a fan of the Star Wars film franchise?': 'fan_status'}, inplace=True)
sw.rename(columns={'Lando Calrissian': 'lando_calrissian'}, inplace=True)

# %%
sw['fan_status'].describe()

#big3 = sw['seen6', 'fan_status', 'lando_calrissian']
# Out:
# count     837
# unique      3
# top       Yes
# freq      552
# Name: fan_status, dtype: object

# %%
sw['seen6'].describe()
# Out:
# count     1187
# unique       3
# top        Yes
# freq       936
# Name: seen6, dtype: object

# %%
sw.loc[:, 'RespondentID'] = sw['RespondentID'].astype('str')
#^ all rows, then indexing the column by name. The above converts respondent ID to a string
sw.describe()
# Out:
#         RespondentID seen6 fan_status  \
# count           1187  1187        837
# unique          1187     3          3
# top     3289498263.0   Yes        Yes
# freq               1   936        552
#
#        Which of the following Star Wars films have you seen? Please select all that apply.  \
# count                                                 674
# unique                                                  1
# top              Star Wars: Episode I  The Phantom Menace
# freq                                                  674
#
#                                          Unnamed: 4  \
# count                                           572
# unique                                            1
# top     Star Wars: Episode II  Attack of the Clones
# freq                                            572
#
#                                          Unnamed: 5  \
# count                                           551
# unique                                            1
# ...

# %%
pd.get_dummies(sw, prefix=['Have you seen any of the 6 films in the Star Wars franchise?', 'gender'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-fb81c9c2ed17> in <module>()
# ----> 1 pd.get_dummies(sw, prefix=['Have you seen any of the 6 films in the Star Wars franchise?', 'gender'])
#
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/pandas/core/reshape.pyc in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse)
#    1043                                      len(columns_to_encode)))
#    1044
# -> 1045         check_len(prefix, 'prefix')
#    1046         check_len(prefix_sep, 'prefix_sep')
#    1047         if isinstance(prefix, compat.string_types):
#
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/pandas/core/reshape.pyc in check_len(item, name)
#    1041                 if not len(item) == len(columns_to_encode):
#    1042                     raise ValueError(length_msg.format(name, len(item),
# ...

# %%
cols = [x for x in sw.columns if 'you' in x]
#quick filter of column headings

# %%
sw.loc[:,cols]
#similar to df.iloc(), but loc uses column name instead of index num
# Out:
#      Which of the following Star Wars films have you seen? Please select all that apply.  \
# 0              Star Wars: Episode I  The Phantom Menace
# 1              Star Wars: Episode I  The Phantom Menace
# 2                                                   NaN
# 3              Star Wars: Episode I  The Phantom Menace
# 4              Star Wars: Episode I  The Phantom Menace
# 5              Star Wars: Episode I  The Phantom Menace
# 6              Star Wars: Episode I  The Phantom Menace
# 7              Star Wars: Episode I  The Phantom Menace
# 8              Star Wars: Episode I  The Phantom Menace
# 9              Star Wars: Episode I  The Phantom Menace
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13             Star Wars: Episode I  The Phantom Menace
# 14             Star Wars: Episode I  The Phantom Menace
# ...

# %%
sw.iloc(:,1)
#similar to df.loc(), but iloc uses an index number

# %%
sw['YesNo'] = 1
#later we'll look into populating this dynamically

# %%
sw.head()
# Out:
#    RespondentID     seen6 fan_status  \
# 0           nan  Response   Response
# 1  3292879998.0       Yes        Yes
# 2  3292879538.0        No        NaN
# 3  3292765271.0       Yes         No
# 4  3292763116.0       Yes        Yes
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 0           Star Wars: Episode I  The Phantom Menace
# 1           Star Wars: Episode I  The Phantom Menace
# 2                                                NaN
# 3           Star Wars: Episode I  The Phantom Menace
# 4           Star Wars: Episode I  The Phantom Menace
#
#                                     Unnamed: 4  \
# 0  Star Wars: Episode II  Attack of the Clones
# 1  Star Wars: Episode II  Attack of the Clones
# 2                                          NaN
# 3  Star Wars: Episode II  Attack of the Clones
# 4  Star Wars: Episode II  Attack of the Clones
#
#                                     Unnamed: 5  \
# ...
