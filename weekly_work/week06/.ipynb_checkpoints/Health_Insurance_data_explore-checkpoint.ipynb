# %%
import pandas as pd
import numpy as np
import sklearn
import os

os.getcwd()
# Out:
# '/Users/HudsonCavanagh/GA_dsi-projects/weekly_work/week06'

# %%
rate = pd.read_csv('/Users/HudsonCavanagh/Documents/health_insurance_marketplace/kaggle_data/Rate.csv')
benefitscostsharing = pd.read_csv('/Users/HudsonCavanagh/Documents/health_insurance_marketplace/kaggle_data/BenefitsCostSharing.csv')
businessrules = pd.read_csv('/Users/HudsonCavanagh/Documents/health_insurance_marketplace/kaggle_data/BusinessRules.csv')
crosswalk15= pd.read_csv('/Users/HudsonCavanagh/Documents/health_insurance_marketplace/kaggle_data/Crosswalk2015.csv')
crosswalk16= pd.read_csv('/Users/HudsonCavanagh/Documents/health_insurance_marketplace/kaggle_data/Crosswalk2016.csv')
hashes = pd.read_csv('/Users/HudsonCavanagh/Documents/health_insurance_marketplace/kaggle_data/hashes.txt')
network = pd.read_csv('/Users/HudsonCavanagh/Documents/health_insurance_marketplace/kaggle_data/Network.csv')
plan_attributes = pd.read_csv('/Users/HudsonCavanagh/Documents/health_insurance_marketplace/kaggle_data/PlanAttributes.csv')
service_area = pd.read_csv('/Users/HudsonCavanagh/Documents/health_insurance_marketplace/kaggle_data/ServiceArea.csv')


pd.DataFrame(rate)

rate = pd.DataFrame(rate)
benefitscostsharing = pd.DataFrame(benefitscostsharing)
businessrules =  pd.DataFrame(businessrules)
crosswalk15= pd.DataFrame(crosswalk15)
crosswalk16= pd.DataFrame(crosswalk16)
hashes = pd.DataFrame(hashes)
network = pd.DataFrame(network)
plan_attributes = pd.DataFrame(plan_attributes)
service_area = pd.DataFrame(service_area)
# Out:
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2902: DtypeWarning: Columns (3,6,9,10,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2902: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ...

# %%
rate.head()
# Out:
#    BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0          2014        AK     21989       HIOS           6
# 1          2014        AK     21989       HIOS           6
# 2          2014        AK     21989       HIOS           6
# 3          2014        AK     21989       HIOS           6
# 4          2014        AK     21989       HIOS           6
#
#             ImportDate  IssuerId2  FederalTIN RateEffectiveDate  \
# 0  2014-03-19 07:06:49      21989  93-0438772        2014-01-01
# 1  2014-03-19 07:06:49      21989  93-0438772        2014-01-01
# 2  2014-03-19 07:06:49      21989  93-0438772        2014-01-01
# 3  2014-03-19 07:06:49      21989  93-0438772        2014-01-01
# 4  2014-03-19 07:06:49      21989  93-0438772        2014-01-01
#
#   RateExpirationDate    ...     IndividualRate IndividualTobaccoRate Couple  \
# 0         2014-12-31    ...              29.00                   NaN    NaN
# ...

# %%
benefitscostsharing.head()
# Out:
#                        BenefitName  BusinessYear CoinsInnTier1 CoinsInnTier2  \
# 0  Routine Dental Services (Adult)          2014           20%           NaN
# 1     Dental Check-Up for Children          2014           20%           NaN
# 2        Basic Dental Care - Child          2014           40%           NaN
# 3              Orthodontia - Child          2014           50%           NaN
# 4        Major Dental Care - Child          2014           50%           NaN
#
#   CoinsOutofNet CopayInnTier1 CopayInnTier2 CopayOutofNet  \
# 0           20%     No Charge           NaN     No Charge
# 1           20%     No Charge           NaN     No Charge
# 2           40%     No Charge           NaN     No Charge
# 3           50%     No Charge           NaN     No Charge
# 4           50%     No Charge           NaN     No Charge
#
#              EHBVarReason Exclusions     ...                  LimitUnit  \
# 0               Above EHB        NaN     ...           Dollars per Year
# ...

# %%
businessrules.head()
# businessrules['MarketCoverage'].value_counts()
# Out:
#    BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0          2014        AL     82285       HIOS           7
# 1          2014        AL     82285       HIOS           7
# 2          2014        AL     82285       HIOS           7
# 3          2014        AL     82285       HIOS           7
# 4          2014        AL     82285       HIOS           7
#
#             ImportDate  IssuerId2         TIN ProductId StandardComponentId  \
# 0  2014-01-21 08:29:49      82285  94-2761537       NaN      82285AL0010006
# 1  2014-01-21 08:29:49      82285  94-2761537       NaN      82285AL0020001
# 2  2014-01-21 08:29:49      82285  94-2761537       NaN      82285AL0020002
# 3  2014-01-21 08:29:49      82285  94-2761537       NaN      82285AL0020004
# 4  2014-01-21 08:29:49      82285  94-2761537       NaN      82285AL0020006
#
#        ...       DependentMaximumAgRule ChildrenOnlyContractMaxChildrenRule  \
# ...

# %%
print(crosswalk15.head())
# Out:
#   State DentalPlan     PlanID_2014  IssuerID_2014 MultistatePlan_2014  \
# 0    AK          Y  21989AK0010001          21989                   N
# 1    AK          Y  21989AK0010001          21989                   N
# 2    AK          Y  21989AK0010001          21989                   N
# 3    AK          Y  21989AK0010001          21989                   N
# 4    AK          Y  21989AK0010001          21989                   N
#
#   MetalLevel_2014  ChildAdultOnly_2014  FIPSCode  ZipCode  CrosswalkLevel  \
# 0             Low                    0      2013        0               1
# 1             Low                    0      2016        0               1
# 2             Low                    0      2020        0               1
# 3             Low                    0      2050        0               1
# 4             Low                    0      2060        0               1
#
#              ...                PlanID_2015 IssuerID_2015  \
# ...

# %%
crosswalk16.head()
# Out:
#   State DentalPlan     PlanID_2015  IssuerID_2015 MultistatePlan_2015  \
# 0    OR          N  10091OR0360004          10091                   N
# 1    OR          N  10091OR0360004          10091                   N
# 2    OR          N  10091OR0360004          10091                   N
# 3    OR          N  10091OR0360004          10091                   N
# 4    OR          N  10091OR0360004          10091                   N
#
#   MetalLevel_2015  ChildAdultOnly_2015  FIPSCode  ZipCode  CrosswalkLevel  \
# 0          Bronze                    0     41021        0               0
# 1          Bronze                    0     41037        0               0
# 2          Bronze                    0     41009        0               0
# 3          Bronze                    0     41023        0               0
# 4          Bronze                    0     41059        0               0
#
#              ...                PlanID_2016 IssuerID_2016  \
# ...

# %%
hashes.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ea5220c270db> in <module>()
# ----> 1 hashes.head()
#
# NameError: name 'hashes' is not defined

# %%
# network.head()

piv = pd.pivot_table(network, index='NetworkName')
# pd.pivot_table(data, values=None, index=None, columns=None, aggfunc='mean', fill_value=None, margins=False, dropna=True, margins_name='All')
biz_details = pd.merge(piv, rate, how='left', on='IssuerId')
# biz_details = pd.merge(biz_details, rate, how='left', on='IssuerId')
# biz_details.head()
by_state = pd.pivot_table(biz_details, index='StateCode', aggfunc='avg')

# %%
plan_attributes.head()

# %%
service_area.head()

# %%
# BenefitsCostSharing.csv
# BusinessRules.csv
# Crosswalk2015.csv
# Crosswalk2016.csv
# database.sqlite
# hashes.txt
# Network.csv
# PlanAttributes.csv
# Rate.csv
# raw
# ServiceArea.csv

# %%
import pandas as pd

er = pd.read_csv("/Users/HudsonCavanagh/Documents/health_insurance_marketplace/NHQR/cleaned_sub_er.csv")
er = er.rename(columns={'Unnamed: 0': "er_admits_substances"})

er.set_index("er_admits_substances", inplace=1)
# er.head(25)

age_list = ['0-17', '18-44', '45-64', '65-84', 'Total']
genders = ['Male', 'Female']
incomes =['First quartile (lowest income)', 'Second quartile', 'Third quartile', 'Fourth quartile [highest income]']
location_types = ['Large central metropolitan', 'Large fringe metropolitan', 'Medium metropolitan', 'Small metropolitan', 'Micropolitan', 'Noncore']
regions = ['Northeast', 'Midwest', 'South', 'West']



age_er = er.loc[['0-17', '18-44', '45-64', '65-84', 'Total'],:]
age_er
# Out:
# 2011    540.0
# 2010    510.2
# 2009    487.5
# 2008    457.7
# 2007    437.7
# Name: Total, dtype: object

# %%
import seaborn as sns

sns.regplot(age_er.index, age_er.values)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-ba326a6b2bcb> in <module>()
#       1 import seaborn as sns
#       2
# ----> 3 sns.regplot(age_er.index, age_er.values)
#
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/seaborn/linearmodels.pyc in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     772     scatter_kws["marker"] = marker
#     773     line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 774     plotter.plot(ax, scatter_kws, line_kws)
#     775     return ax
#     776
#
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/seaborn/linearmodels.pyc in plot(self, ax, scatter_kws, line_kws)
# ...
