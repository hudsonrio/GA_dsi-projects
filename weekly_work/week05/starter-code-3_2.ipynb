# %% [markdown]
# # SQL Lab
#
# In this lab we will learn how to use execute SQL from the ipython notebook and practice some queries on the [Northwind sample database](https://northwinddatabase.codeplex.com/) that we used in Lesson 3.1.
#
# You can access the data with this command:
#
#     psql -h dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com -p 5432 -U dsi_student northwind
#     password: gastudents

# %% [markdown]
# First of all let's install the ipython-sql extension. You can find instructions [here](https://github.com/catherinedevlin/ipython-sql).

# %%
# !pip install ipython-sql
# Out:
# Collecting ipython-sql
#   Downloading ipython-sql-0.3.6.tar.gz
# Collecting prettytable (from ipython-sql)
#   Downloading prettytable-0.7.2.zip
# Requirement already satisfied (use --upgrade to upgrade): ipython>=1.0 in /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages (from ipython-sql)
# Requirement already satisfied (use --upgrade to upgrade): sqlalchemy>=0.6.7 in /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages (from ipython-sql)
# Collecting sqlparse (from ipython-sql)
#   Downloading sqlparse-0.1.19.tar.gz (58kB)
#     100% |████████████████████████████████| 61kB 3.4MB/s
# Requirement already satisfied (use --upgrade to upgrade): six in /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages (from ipython-sql)
# Building wheels for collected packages: ipython-sql, prettytable, sqlparse
# done
#   Stored in directory: /Users/HudsonCavanagh/Library/Caches/pip/wheels/c1/43/06/1d23ebe4d5f622d90231c7e394d77944700340fd33426dcaff
# done
#   Stored in directory: /Users/HudsonCavanagh/Library/Caches/pip/wheels/b6/90/7b/1c22b89217d0eba6d5f406e562365ebee804f0d4595b2bdbcd
# done
#   Stored in directory: /Users/HudsonCavanagh/Library/Caches/pip/wheels/ef/22/36/1c3c229ebf514a0b534424314151526f782c20c378897bc141
# Successfully built ipython-sql prettytable sqlparse
# Installing collected packages: prettytable, sqlparse, ipython-sql
# Successfully installed ipython-sql-0.3.6 prettytable-0.7.2 sqlparse-0.1.19

# %% [markdown]
# Let's see if it works:

# %%
# %load_ext sql
conda install psycopg2
pip install ipython-sql
# Out:
#   File "<ipython-input-9-0dad4a773bd9>", line 2
#     conda install psycopg2
#                 ^
# SyntaxError: invalid syntax

# %%
# %%sql postgresql://dsi_student:gastudents@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
#
# select * from orders limit 5;
# Out:
# 5 rows affected.
# [(10248, u'VINET', 5, datetime.date(1996, 7, 4), datetime.date(1996, 8, 1), datetime.date(1996, 7, 16), 3, 32.38, u'Vins et alcools Chevalier', u"59 rue de l'Abbaye", u'Reims', None, u'51100', u'France'),
#  (10249, u'TOMSP', 6, datetime.date(1996, 7, 5), datetime.date(1996, 8, 16), datetime.date(1996, 7, 10), 1, 11.61, u'Toms Spezialit\xe4ten', u'Luisenstr. 48', u'M\xfcnster', None, u'44087', u'Germany'),
#  (10250, u'HANAR', 4, datetime.date(1996, 7, 8), datetime.date(1996, 8, 5), datetime.date(1996, 7, 12), 2, 65.83, u'Hanari Carnes', u'Rua do Pa\xe7o, 67', u'Rio de Janeiro', u'RJ', u'05454-876', u'Brazil'),
#  (10251, u'VICTE', 3, datetime.date(1996, 7, 8), datetime.date(1996, 8, 5), datetime.date(1996, 7, 15), 1, 41.34, u'Victuailles en stock', u'2, rue du Commerce', u'Lyon', None, u'69004', u'France'),
#  (10252, u'SUPRD', 4, datetime.date(1996, 7, 9), datetime.date(1996, 8, 6), datetime.date(1996, 7, 11), 2, 51.3, u'Supr\xeames d\xe9lices', u'Boulevard Tirou, 255', u'Charleroi', None, u'B-6000', u'Belgium')]

# %% [markdown]
# If this isn't working, then it's back to psql for now...

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1: Inspect the database
#
# If we were connected via console, it would be easy to list all tables using `\dt`. We can however access table information performing a query on the `information_schema.tables` table.
#
# ### 1.a: List Tables
#
# 1. write a `SELECT` statement that lists all the tables in the public schema of the `northwind` database, sorted alphabetically

# %%
# %%sql
# SELECT table_schema, table_name
# FROM information_schema.tables
# ORDER BY table_name DESC;
# Out:
# 172 rows affected.
# [(u'information_schema', u'view_table_usage'),
#  (u'information_schema', u'views'),
#  (u'information_schema', u'view_routine_usage'),
#  (u'information_schema', u'view_column_usage'),
#  (u'public', u'usstates'),
#  (u'information_schema', u'user_mappings'),
#  (u'information_schema', u'user_mapping_options'),
#  (u'information_schema', u'user_defined_types'),
#  (u'information_schema', u'usage_privileges'),
#  (u'information_schema', u'udt_privileges'),
#  (u'information_schema', u'triggers'),
#  (u'information_schema', u'triggered_update_columns'),
#  (u'public', u'territories'),
#  (u'information_schema', u'tables'),
#  (u'information_schema', u'table_privileges'),
#  (u'information_schema', u'table_constraints'),
#  (u'public', u'table1'),
#  (u'public', u'suppliers'),
#  (u'information_schema', u'sql_sizing_profiles'),
#  (u'information_schema', u'sql_sizing'),
#  (u'information_schema', u'sql_packages'),
#  (u'information_schema', u'sql_languages'),
#  (u'information_schema', u'sql_implementation_info'),
#  (u'information_schema', u'sql_features'),
#  (u'public', u'shippers_tmp'),
#  (u'public', u'shippers'),
#  (u'information_schema', u'sequences'),
#  (u'information_schema', u'schemata'),
#  (u'information_schema', u'routines'),
#  (u'information_schema', u'routine_privileges'),
#  (u'information_schema', u'role_usage_grants'),
#  (u'information_schema', u'role_udt_grants'),
#  (u'information_schema', u'role_table_grants'),
#  (u'information_schema', u'role_routine_grants'),
#  (u'information_schema', u'role_column_grants'),
#  (u'public', u'region'),
#  (u'information_schema', u'referential_constraints'),
#  (u'public', u'ratings'),
#  (u'public', u'products'),
#  (u'pg_catalog', u'pg_views'),
#  (u'pg_catalog', u'pg_user_mappings'),
#  (u'pg_catalog', u'pg_user'),
#  (u'pg_catalog', u'pg_type'),
#  (u'pg_catalog', u'pg_ts_template'),
#  (u'pg_catalog', u'pg_ts_parser'),
#  (u'pg_catalog', u'pg_ts_dict'),
#  (u'pg_catalog', u'pg_ts_config_map'),
#  (u'pg_catalog', u'pg_ts_config'),
#  (u'pg_catalog', u'pg_trigger'),
#  (u'pg_catalog', u'pg_timezone_names'),
#  (u'pg_catalog', u'pg_timezone_abbrevs'),
#  (u'pg_catalog', u'pg_tablespace'),
#  (u'pg_catalog', u'pg_tables'),
#  (u'pg_catalog', u'pg_stat_xact_user_tables'),
#  (u'pg_catalog', u'pg_stat_xact_user_functions'),
#  (u'pg_catalog', u'pg_stat_xact_sys_tables'),
#  (u'pg_catalog', u'pg_stat_xact_all_tables'),
#  (u'pg_catalog', u'pg_stat_user_tables'),
#  (u'pg_catalog', u'pg_stat_user_indexes'),
#  (u'pg_catalog', u'pg_stat_user_functions'),
#  (u'pg_catalog', u'pg_stat_sys_tables'),
#  (u'pg_catalog', u'pg_stat_sys_indexes'),
#  (u'pg_catalog', u'pg_stats'),
#  (u'pg_catalog', u'pg_stat_replication'),
#  (u'pg_catalog', u'pg_statio_user_tables'),
#  (u'pg_catalog', u'pg_statio_user_sequences'),
#  (u'pg_catalog', u'pg_statio_user_indexes'),
#  (u'pg_catalog', u'pg_statio_sys_tables'),
#  (u'pg_catalog', u'pg_statio_sys_sequences'),
#  (u'pg_catalog', u'pg_statio_sys_indexes'),
#  (u'pg_catalog', u'pg_statio_all_tables'),
#  (u'pg_catalog', u'pg_statio_all_sequences'),
#  (u'pg_catalog', u'pg_statio_all_indexes'),
#  (u'pg_catalog', u'pg_stat_database_conflicts'),
#  (u'pg_catalog', u'pg_stat_database'),
#  (u'pg_catalog', u'pg_stat_bgwriter'),
#  (u'pg_catalog', u'pg_stat_archiver'),
#  (u'pg_catalog', u'pg_stat_all_tables'),
#  (u'pg_catalog', u'pg_stat_all_indexes'),
#  (u'pg_catalog', u'pg_stat_activity'),
#  (u'pg_catalog', u'pg_shseclabel'),
#  (u'pg_catalog', u'pg_shdescription'),
#  (u'pg_catalog', u'pg_shdepend'),
#  (u'pg_catalog', u'pg_settings'),
#  (u'pg_catalog', u'pg_seclabels'),
#  (u'pg_catalog', u'pg_seclabel'),
#  (u'pg_catalog', u'pg_rules'),
#  (u'pg_catalog', u'pg_roles'),
#  (u'pg_catalog', u'pg_rewrite'),
#  (u'pg_catalog', u'pg_replication_slots'),
#  (u'pg_catalog', u'pg_range'),
#  (u'pg_catalog', u'pg_proc'),
#  (u'pg_catalog', u'pg_prepared_xacts'),
#  (u'pg_catalog', u'pg_prepared_statements'),
#  (u'pg_catalog', u'pg_pltemplate'),
#  (u'pg_catalog', u'pg_opfamily'),
#  (u'pg_catalog', u'pg_operator'),
#  (u'pg_catalog', u'pg_opclass'),
#  (u'pg_catalog', u'pg_namespace'),
#  (u'pg_catalog', u'pg_matviews'),
#  (u'pg_catalog', u'pg_locks'),
#  (u'pg_catalog', u'pg_largeobject_metadata'),
#  (u'pg_catalog', u'pg_language'),
#  (u'pg_catalog', u'pg_inherits'),
#  (u'pg_catalog', u'pg_indexes'),
#  (u'pg_catalog', u'pg_index'),
#  (u'pg_catalog', u'pg_group'),
#  (u'pg_catalog', u'pg_foreign_table'),
#  (u'pg_catalog', u'pg_foreign_server'),
#  (u'pg_catalog', u'pg_foreign_data_wrapper'),
#  (u'pg_catalog', u'pg_extension'),
#  (u'pg_catalog', u'pg_event_trigger'),
#  (u'pg_catalog', u'pg_enum'),
#  (u'pg_catalog', u'pg_description'),
#  (u'pg_catalog', u'pg_depend'),
#  (u'pg_catalog', u'pg_default_acl'),
#  (u'pg_catalog', u'pg_db_role_setting'),
#  (u'pg_catalog', u'pg_database'),
#  (u'pg_catalog', u'pg_cursors'),
#  (u'pg_catalog', u'pg_conversion'),
#  (u'pg_catalog', u'pg_constraint'),
#  (u'pg_catalog', u'pg_collation'),
#  (u'pg_catalog', u'pg_class'),
#  (u'pg_catalog', u'pg_cast'),
#  (u'pg_catalog', u'pg_available_extension_versions'),
#  (u'pg_catalog', u'pg_available_extensions'),
#  (u'pg_catalog', u'pg_auth_members'),
#  (u'pg_catalog', u'pg_attribute'),
#  (u'pg_catalog', u'pg_attrdef'),
#  (u'pg_catalog', u'pg_amproc'),
#  (u'pg_catalog', u'pg_amop'),
#  (u'pg_catalog', u'pg_am'),
#  (u'pg_catalog', u'pg_aggregate'),
#  (u'information_schema', u'parameters'),
#  (u'public', u'orders'),
#  (u'public', u'order_details'),
#  (u'public', u'movies'),
#  (u'information_schema', u'key_column_usage'),
#  (u'information_schema', u'information_schema_catalog_name'),
#  (u'information_schema', u'foreign_tables'),
#  (u'information_schema', u'foreign_table_options'),
#  (u'information_schema', u'foreign_servers'),
#  (u'information_schema', u'foreign_server_options'),
#  (u'information_schema', u'foreign_data_wrappers'),
#  (u'information_schema', u'foreign_data_wrapper_options'),
#  (u'information_schema', u'enabled_roles'),
#  (u'public', u'employeeterritories'),
#  (u'public', u'employees'),
#  (u'information_schema', u'element_types'),
#  (u'information_schema', u'domain_udt_usage'),
#  (u'information_schema', u'domains'),
#  (u'information_schema', u'domain_constraints'),
#  (u'information_schema', u'data_type_privileges'),
#  (u'public', u'customers'),
#  (u'public', u'customerdemographics'),
#  (u'public', u'customercustomerdemo'),
#  (u'information_schema', u'constraint_table_usage'),
#  (u'information_schema', u'constraint_column_usage'),
#  (u'information_schema', u'column_udt_usage'),
#  (u'information_schema', u'columns'),
#  (u'information_schema', u'column_privileges'),
#  (u'information_schema', u'column_options'),
#  (u'information_schema', u'column_domain_usage'),
#  (u'information_schema', u'collations'),
#  (u'information_schema', u'collation_character_set_applicability'),
#  (u'information_schema', u'check_constraints'),
#  (u'information_schema', u'check_constraint_routine_usage'),
#  (u'information_schema', u'character_sets'),
#  (u'public', u'categories'),
#  (u'information_schema', u'attributes'),
#  (u'information_schema', u'applicable_roles'),
#  (u'information_schema', u'administrable_role_authorizations')]

# %% [markdown]
# ### 1.b: Print Schemas
#
# The table `INFORMATION_SCHEMA.COLUMNS` contains schema information on each.
#
# Query it to display schemas of all the public tables. In particular we are interested in the column names and data types. Make sure you only include public schemas to avoid cluttering your results with a bunch of postgres related stuff.

# %%
# %%sql
# SELECT DISTINCT data_type from INFORMATION_SCHEMA.COLUMNS info
# WHERE info.table_catalog = 'northwind'
# LIMIT 10;
# Out:
# 10 rows affected.
# [(u'anyarray',),
#  (u'inet',),
#  (u'"char"',),
#  (u'timestamp with time zone',),
#  (u'xid',),
#  (u'name',),
#  (u'bytea',),
#  (u'character',),
#  (u'date',),
#  (u'double precision',)]

# %%
# %%sql
# SELECT * from INFORMATION_SCHEMA.COLUMNS info
# WHERE info.table_catalog = 'northwind'
# LIMIT 10;
# Out:
# 10 rows affected.
# [(u'northwind', u'pg_catalog', u'pg_type', u'typname', 1, None, u'NO', u'name', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, u'northwind', u'pg_catalog', u'name', None, None, None, None, u'1', u'NO', u'NO', None, None, None, None, None, None, u'NEVER', None, u'YES'),
#  (u'northwind', u'pg_catalog', u'pg_type', u'typnamespace', 2, None, u'NO', u'oid', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, u'northwind', u'pg_catalog', u'oid', None, None, None, None, u'2', u'NO', u'NO', None, None, None, None, None, None, u'NEVER', None, u'YES'),
#  (u'northwind', u'pg_catalog', u'pg_type', u'typowner', 3, None, u'NO', u'oid', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, u'northwind', u'pg_catalog', u'oid', None, None, None, None, u'3', u'NO', u'NO', None, None, None, None, None, None, u'NEVER', None, u'YES'),
#  (u'northwind', u'pg_catalog', u'pg_type', u'typlen', 4, None, u'NO', u'smallint', None, None, 16, 2, 0, None, None, None, None, None, None, None, None, None, None, None, None, u'northwind', u'pg_catalog', u'int2', None, None, None, None, u'4', u'NO', u'NO', None, None, None, None, None, None, u'NEVER', None, u'YES'),
#  (u'northwind', u'pg_catalog', u'pg_type', u'typbyval', 5, None, u'NO', u'boolean', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, u'northwind', u'pg_catalog', u'bool', None, None, None, None, u'5', u'NO', u'NO', None, None, None, None, None, None, u'NEVER', None, u'YES'),
#  (u'northwind', u'pg_catalog', u'pg_type', u'typtype', 6, None, u'NO', u'"char"', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, u'northwind', u'pg_catalog', u'char', None, None, None, None, u'6', u'NO', u'NO', None, None, None, None, None, None, u'NEVER', None, u'YES'),
#  (u'northwind', u'pg_catalog', u'pg_type', u'typcategory', 7, None, u'NO', u'"char"', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, u'northwind', u'pg_catalog', u'char', None, None, None, None, u'7', u'NO', u'NO', None, None, None, None, None, None, u'NEVER', None, u'YES'),
#  (u'northwind', u'pg_catalog', u'pg_type', u'typispreferred', 8, None, u'NO', u'boolean', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, u'northwind', u'pg_catalog', u'bool', None, None, None, None, u'8', u'NO', u'NO', None, None, None, None, None, None, u'NEVER', None, u'YES'),
#  (u'northwind', u'pg_catalog', u'pg_type', u'typisdefined', 9, None, u'NO', u'boolean', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, u'northwind', u'pg_catalog', u'bool', None, None, None, None, u'9', u'NO', u'NO', None, None, None, None, None, None, u'NEVER', None, u'YES'),
#  (u'northwind', u'pg_catalog', u'pg_type', u'typdelim', 10, None, u'NO', u'"char"', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, u'northwind', u'pg_catalog', u'char', None, None, None, None, u'10', u'NO', u'NO', None, None, None, None, None, None, u'NEVER', None, u'YES')]

# %% [markdown]
# ### 1.c: Table peek
#
# Another way of quickly looking at table information is to query the first few rows. Do this for a couple of tables, for example: `orders`, `products`, `usstates`. Display only the first 3 rows.

# %%
# %%sql
# SELECT * FROM products
# LIMIT 5;
# Out:
# 5 rows affected.
# [(1, u'Chai', 8, 1, u'10 boxes x 30 bags', 18.0, 39, 0, 10, 1),
#  (2, u'Chang', 1, 1, u'24 - 12 oz bottles', 19.0, 17, 40, 25, 1),
#  (3, u'Aniseed Syrup', 1, 2, u'12 - 550 ml bottles', 10.0, 13, 70, 25, 0),
#  (4, u"Chef Anton's Cajun Seasoning", 2, 2, u'48 - 6 oz jars', 22.0, 53, 0, 0, 0),
#  (5, u"Chef Anton's Gumbo Mix", 2, 2, u'36 boxes', 21.35, 0, 0, 0, 1)]

# %%
# %%sql
# SELECT * FROM order_details
# LIMIT 5;
# Out:
# 5 rows affected.
# [(10248, 11, 14.0, 12, 0.0),
#  (10248, 42, 9.8, 10, 0.0),
#  (10248, 72, 34.8, 5, 0.0),
#  (10249, 14, 18.6, 9, 0.0),
#  (10249, 51, 42.4, 40, 0.0)]

# %% [markdown]
# As you can see, some tables (like `usstates` or `region`) contain information that is probably less prone to change than other tables (like `orders` or `order_details`). This database is well organized to avoid unnecessary duplication. Let's start digging deeper in the data.

# %% [markdown]
# ## 2: Products
#
# What products is this company selling? The `products` and `categories` tables contain information to answer this question.
#
# Use a combination of SQL queries and Pandas merge to answer the following questions:
#
# - What categories of products is the company selling?
# - How many products per category does the catalog contain?
# - Let's focus only on products that have not been discontinued => how many products per category?
# - What are the most expensive 5 products (not discontinued)?
# - How many units of each of these 5 products are there in stock?
# - Draw a pie chart of the categories, with slices that have the size of the number of products in that category (use non discontinued products)

# %% [markdown]
# ### 2.a: What categories of products is the company selling?
#
# Remember that PostgreSQL is case sensitive.

# %%
# %%sql
# SELECT DISTINCT "ProductName" from products
# ORDER BY "ProductName" ASC;
# Out:
# 77 rows affected.
# [(u'Alice Mutton',),
#  (u'Aniseed Syrup',),
#  (u'Boston Crab Meat',),
#  (u'Camembert Pierrot',),
#  (u'Carnarvon Tigers',),
#  (u'Chai',),
#  (u'Chang',),
#  (u'Chartreuse verte',),
#  (u"Chef Anton's Cajun Seasoning",),
#  (u"Chef Anton's Gumbo Mix",),
#  (u'Chocolade',),
#  (u'C\xf4te de Blaye',),
#  (u'Escargots de Bourgogne',),
#  (u'Filo Mix',),
#  (u'Flotemysost',),
#  (u'Geitost',),
#  (u'Genen Shouyu',),
#  (u'Gnocchi di nonna Alice',),
#  (u'Gorgonzola Telino',),
#  (u"Grandma's Boysenberry Spread",),
#  (u'Gravad lax',),
#  (u'Guaran\xe1 Fant\xe1stica',),
#  (u'Gudbrandsdalsost',),
#  (u'Gula Malacca',),
#  (u'Gumb\xe4r Gummib\xe4rchen',),
#  (u"Gustaf's Kn\xe4ckebr\xf6d",),
#  (u'Ikura',),
#  (u'Inlagd Sill',),
#  (u'Ipoh Coffee',),
#  (u"Jack's New England Clam Chowder",),
#  (u'Konbu',),
#  (u'Lakkalik\xf6\xf6ri',),
#  (u'Laughing Lumberjack Lager',),
#  (u'Longlife Tofu',),
#  (u'Louisiana Fiery Hot Pepper Sauce',),
#  (u'Louisiana Hot Spiced Okra',),
#  (u'Manjimup Dried Apples',),
#  (u'Mascarpone Fabioli',),
#  (u'Maxilaku',),
#  (u'Mishi Kobe Niku',),
#  (u'Mozzarella di Giovanni',),
#  (u'Nord-Ost Matjeshering',),
#  (u'Northwoods Cranberry Sauce',),
#  (u'NuNuCa Nu\xdf-Nougat-Creme',),
#  (u'Original Frankfurter gr\xfcne So\xdfe',),
#  (u'Outback Lager',),
#  (u'P\xe2t\xe9 chinois',),
#  (u'Pavlova',),
#  (u'Perth Pasties',),
#  (u'Queso Cabrales',),
#  (u'Queso Manchego La Pastora',),
#  (u'Raclette Courdavault',),
#  (u'Ravioli Angelo',),
#  (u'Rh\xf6nbr\xe4u Klosterbier',),
#  (u'R\xf6d Kaviar',),
#  (u'Rogede sild',),
#  (u'R\xf6ssle Sauerkraut',),
#  (u'Sasquatch Ale',),
#  (u'Schoggi Schokolade',),
#  (u'Scottish Longbreads',),
#  (u'Singaporean Hokkien Fried Mee',),
#  (u"Sirop d'\xe9rable",),
#  (u"Sir Rodney's Marmalade",),
#  (u"Sir Rodney's Scones",),
#  (u'Spegesild',),
#  (u'Steeleye Stout',),
#  (u'Tarte au sucre',),
#  (u'Teatime Chocolate Biscuits',),
#  (u'Th\xfcringer Rostbratwurst',),
#  (u'Tofu',),
#  (u'Tourti\xe8re',),
#  (u'Tunnbr\xf6d',),
#  (u"Uncle Bob's Organic Dried Pears",),
#  (u'Valkoinen suklaa',),
#  (u'Vegie-spread',),
#  (u'Wimmers gute Semmelkn\xf6del',),
#  (u'Zaanse koeken',)]

# %%
# Out:
# 77 rows affected.
# [(u'Alice Mutton', u'Meat/Poultry'),
#  (u'Aniseed Syrup', u'Condiments'),
#  (u'Boston Crab Meat', u'Seafood'),
#  (u'Camembert Pierrot', u'Dairy Products'),
#  (u'Carnarvon Tigers', u'Seafood'),
#  (u'Chai', u'Beverages'),
#  (u'Chang', u'Beverages'),
#  (u'Chartreuse verte', u'Beverages'),
#  (u"Chef Anton's Cajun Seasoning", u'Condiments'),
#  (u"Chef Anton's Gumbo Mix", u'Condiments'),
#  (u'Chocolade', u'Confections'),
#  (u'C\xf4te de Blaye', u'Beverages'),
#  (u'Escargots de Bourgogne', u'Seafood'),
#  (u'Filo Mix', u'Grains/Cereals'),
#  (u'Flotemysost', u'Dairy Products'),
#  (u'Geitost', u'Dairy Products'),
#  (u'Genen Shouyu', u'Condiments'),
#  (u'Gnocchi di nonna Alice', u'Grains/Cereals'),
#  (u'Gorgonzola Telino', u'Dairy Products'),
#  (u"Grandma's Boysenberry Spread", u'Condiments'),
#  (u'Gravad lax', u'Seafood'),
#  (u'Guaran\xe1 Fant\xe1stica', u'Beverages'),
#  (u'Gudbrandsdalsost', u'Dairy Products'),
#  (u'Gula Malacca', u'Condiments'),
#  (u'Gumb\xe4r Gummib\xe4rchen', u'Confections'),
#  (u"Gustaf's Kn\xe4ckebr\xf6d", u'Grains/Cereals'),
#  (u'Ikura', u'Seafood'),
#  (u'Inlagd Sill', u'Seafood'),
#  (u'Ipoh Coffee', u'Beverages'),
#  (u"Jack's New England Clam Chowder", u'Seafood'),
#  (u'Konbu', u'Seafood'),
#  (u'Lakkalik\xf6\xf6ri', u'Beverages'),
#  (u'Laughing Lumberjack Lager', u'Beverages'),
#  (u'Longlife Tofu', u'Produce'),
#  (u'Louisiana Fiery Hot Pepper Sauce', u'Condiments'),
#  (u'Louisiana Hot Spiced Okra', u'Condiments'),
#  (u'Manjimup Dried Apples', u'Produce'),
#  (u'Mascarpone Fabioli', u'Dairy Products'),
#  (u'Maxilaku', u'Confections'),
#  (u'Mishi Kobe Niku', u'Meat/Poultry'),
#  (u'Mozzarella di Giovanni', u'Dairy Products'),
#  (u'Nord-Ost Matjeshering', u'Seafood'),
#  (u'Northwoods Cranberry Sauce', u'Condiments'),
#  (u'NuNuCa Nu\xdf-Nougat-Creme', u'Confections'),
#  (u'Original Frankfurter gr\xfcne So\xdfe', u'Condiments'),
#  (u'Outback Lager', u'Beverages'),
#  (u'P\xe2t\xe9 chinois', u'Meat/Poultry'),
#  (u'Pavlova', u'Confections'),
#  (u'Perth Pasties', u'Meat/Poultry'),
#  (u'Queso Cabrales', u'Dairy Products'),
#  (u'Queso Manchego La Pastora', u'Dairy Products'),
#  (u'Raclette Courdavault', u'Dairy Products'),
#  (u'Ravioli Angelo', u'Grains/Cereals'),
#  (u'Rh\xf6nbr\xe4u Klosterbier', u'Beverages'),
#  (u'R\xf6d Kaviar', u'Seafood'),
#  (u'Rogede sild', u'Seafood'),
#  (u'R\xf6ssle Sauerkraut', u'Produce'),
#  (u'Sasquatch Ale', u'Beverages'),
#  (u'Schoggi Schokolade', u'Confections'),
#  (u'Scottish Longbreads', u'Confections'),
#  (u'Singaporean Hokkien Fried Mee', u'Grains/Cereals'),
#  (u"Sirop d'\xe9rable", u'Condiments'),
#  (u"Sir Rodney's Marmalade", u'Confections'),
#  (u"Sir Rodney's Scones", u'Confections'),
#  (u'Spegesild', u'Seafood'),
#  (u'Steeleye Stout', u'Beverages'),
#  (u'Tarte au sucre', u'Confections'),
#  (u'Teatime Chocolate Biscuits', u'Confections'),
#  (u'Th\xfcringer Rostbratwurst', u'Meat/Poultry'),
#  (u'Tofu', u'Produce'),
#  (u'Tourti\xe8re', u'Meat/Poultry'),
#  (u'Tunnbr\xf6d', u'Grains/Cereals'),
#  (u"Uncle Bob's Organic Dried Pears", u'Produce'),
#  (u'Valkoinen suklaa', u'Confections'),
#  (u'Vegie-spread', u'Condiments'),
#  (u'Wimmers gute Semmelkn\xf6del', u'Grains/Cereals'),
#  (u'Zaanse koeken', u'Confections')]

# %%
# %%sql
# SELECT * FROM categories
# ORDER BY ASC;
# Out:
# (psycopg2.ProgrammingError) syntax error at or near "ASC"
# LINE 2: ORDER BY ASC;
#                  ^
#  [SQL: 'SELECT * FROM categories\nORDER BY ASC;']

# %% [markdown]
# ### 2.b: How many products per category does the catalog contain?
#
# Keep in mind that you can cast a %sql result to a pandas dataframe using the `.DataFrame()` method.

# %%
# %%sql
# SELECT "ProductName", "CategoryName" FROM products
# JOIN categories
# ON categories."CategoryID" = products."CategoryID"
# GROUP BY "ProductName", "CategoryName"
# ORDER BY "ProductName" ASC;
# Out:
# 77 rows affected.
# [(u'Alice Mutton', u'Meat/Poultry'),
#  (u'Aniseed Syrup', u'Condiments'),
#  (u'Boston Crab Meat', u'Seafood'),
#  (u'Camembert Pierrot', u'Dairy Products'),
#  (u'Carnarvon Tigers', u'Seafood'),
#  (u'Chai', u'Beverages'),
#  (u'Chang', u'Beverages'),
#  (u'Chartreuse verte', u'Beverages'),
#  (u"Chef Anton's Cajun Seasoning", u'Condiments'),
#  (u"Chef Anton's Gumbo Mix", u'Condiments'),
#  (u'Chocolade', u'Confections'),
#  (u'C\xf4te de Blaye', u'Beverages'),
#  (u'Escargots de Bourgogne', u'Seafood'),
#  (u'Filo Mix', u'Grains/Cereals'),
#  (u'Flotemysost', u'Dairy Products'),
#  (u'Geitost', u'Dairy Products'),
#  (u'Genen Shouyu', u'Condiments'),
#  (u'Gnocchi di nonna Alice', u'Grains/Cereals'),
#  (u'Gorgonzola Telino', u'Dairy Products'),
#  (u"Grandma's Boysenberry Spread", u'Condiments'),
#  (u'Gravad lax', u'Seafood'),
#  (u'Guaran\xe1 Fant\xe1stica', u'Beverages'),
#  (u'Gudbrandsdalsost', u'Dairy Products'),
#  (u'Gula Malacca', u'Condiments'),
#  (u'Gumb\xe4r Gummib\xe4rchen', u'Confections'),
#  (u"Gustaf's Kn\xe4ckebr\xf6d", u'Grains/Cereals'),
#  (u'Ikura', u'Seafood'),
#  (u'Inlagd Sill', u'Seafood'),
#  (u'Ipoh Coffee', u'Beverages'),
#  (u"Jack's New England Clam Chowder", u'Seafood'),
#  (u'Konbu', u'Seafood'),
#  (u'Lakkalik\xf6\xf6ri', u'Beverages'),
#  (u'Laughing Lumberjack Lager', u'Beverages'),
#  (u'Longlife Tofu', u'Produce'),
#  (u'Louisiana Fiery Hot Pepper Sauce', u'Condiments'),
#  (u'Louisiana Hot Spiced Okra', u'Condiments'),
#  (u'Manjimup Dried Apples', u'Produce'),
#  (u'Mascarpone Fabioli', u'Dairy Products'),
#  (u'Maxilaku', u'Confections'),
#  (u'Mishi Kobe Niku', u'Meat/Poultry'),
#  (u'Mozzarella di Giovanni', u'Dairy Products'),
#  (u'Nord-Ost Matjeshering', u'Seafood'),
#  (u'Northwoods Cranberry Sauce', u'Condiments'),
#  (u'NuNuCa Nu\xdf-Nougat-Creme', u'Confections'),
#  (u'Original Frankfurter gr\xfcne So\xdfe', u'Condiments'),
#  (u'Outback Lager', u'Beverages'),
#  (u'P\xe2t\xe9 chinois', u'Meat/Poultry'),
#  (u'Pavlova', u'Confections'),
#  (u'Perth Pasties', u'Meat/Poultry'),
#  (u'Queso Cabrales', u'Dairy Products'),
#  (u'Queso Manchego La Pastora', u'Dairy Products'),
#  (u'Raclette Courdavault', u'Dairy Products'),
#  (u'Ravioli Angelo', u'Grains/Cereals'),
#  (u'Rh\xf6nbr\xe4u Klosterbier', u'Beverages'),
#  (u'R\xf6d Kaviar', u'Seafood'),
#  (u'Rogede sild', u'Seafood'),
#  (u'R\xf6ssle Sauerkraut', u'Produce'),
#  (u'Sasquatch Ale', u'Beverages'),
#  (u'Schoggi Schokolade', u'Confections'),
#  (u'Scottish Longbreads', u'Confections'),
#  (u'Singaporean Hokkien Fried Mee', u'Grains/Cereals'),
#  (u"Sirop d'\xe9rable", u'Condiments'),
#  (u"Sir Rodney's Marmalade", u'Confections'),
#  (u"Sir Rodney's Scones", u'Confections'),
#  (u'Spegesild', u'Seafood'),
#  (u'Steeleye Stout', u'Beverages'),
#  (u'Tarte au sucre', u'Confections'),
#  (u'Teatime Chocolate Biscuits', u'Confections'),
#  (u'Th\xfcringer Rostbratwurst', u'Meat/Poultry'),
#  (u'Tofu', u'Produce'),
#  (u'Tourti\xe8re', u'Meat/Poultry'),
#  (u'Tunnbr\xf6d', u'Grains/Cereals'),
#  (u"Uncle Bob's Organic Dried Pears", u'Produce'),
#  (u'Valkoinen suklaa', u'Confections'),
#  (u'Vegie-spread', u'Condiments'),
#  (u'Wimmers gute Semmelkn\xf6del', u'Grains/Cereals'),
#  (u'Zaanse koeken', u'Confections')]

# %%
# %%sql
# SELECT COUNT(DISTINCT "ProductName"), "CategoryName" FROM products
# JOIN categories
# ON categories."CategoryID" = products."CategoryID"
# GROUP BY "ProductName", "CategoryName"
# ORDER BY "ProductName" ASC;
# Out:
# 77 rows affected.
# [(1L, u'Meat/Poultry'),
#  (1L, u'Condiments'),
#  (1L, u'Seafood'),
#  (1L, u'Dairy Products'),
#  (1L, u'Seafood'),
#  (1L, u'Beverages'),
#  (1L, u'Beverages'),
#  (1L, u'Beverages'),
#  (1L, u'Condiments'),
#  (1L, u'Condiments'),
#  (1L, u'Confections'),
#  (1L, u'Beverages'),
#  (1L, u'Seafood'),
#  (1L, u'Grains/Cereals'),
#  (1L, u'Dairy Products'),
#  (1L, u'Dairy Products'),
#  (1L, u'Condiments'),
#  (1L, u'Grains/Cereals'),
#  (1L, u'Dairy Products'),
#  (1L, u'Condiments'),
#  (1L, u'Seafood'),
#  (1L, u'Beverages'),
#  (1L, u'Dairy Products'),
#  (1L, u'Condiments'),
#  (1L, u'Confections'),
#  (1L, u'Grains/Cereals'),
#  (1L, u'Seafood'),
#  (1L, u'Seafood'),
#  (1L, u'Beverages'),
#  (1L, u'Seafood'),
#  (1L, u'Seafood'),
#  (1L, u'Beverages'),
#  (1L, u'Beverages'),
#  (1L, u'Produce'),
#  (1L, u'Condiments'),
#  (1L, u'Condiments'),
#  (1L, u'Produce'),
#  (1L, u'Dairy Products'),
#  (1L, u'Confections'),
#  (1L, u'Meat/Poultry'),
#  (1L, u'Dairy Products'),
#  (1L, u'Seafood'),
#  (1L, u'Condiments'),
#  (1L, u'Confections'),
#  (1L, u'Condiments'),
#  (1L, u'Beverages'),
#  (1L, u'Meat/Poultry'),
#  (1L, u'Confections'),
#  (1L, u'Meat/Poultry'),
#  (1L, u'Dairy Products'),
#  (1L, u'Dairy Products'),
#  (1L, u'Dairy Products'),
#  (1L, u'Grains/Cereals'),
#  (1L, u'Beverages'),
#  (1L, u'Seafood'),
#  (1L, u'Seafood'),
#  (1L, u'Produce'),
#  (1L, u'Beverages'),
#  (1L, u'Confections'),
#  (1L, u'Confections'),
#  (1L, u'Grains/Cereals'),
#  (1L, u'Condiments'),
#  (1L, u'Confections'),
#  (1L, u'Confections'),
#  (1L, u'Seafood'),
#  (1L, u'Beverages'),
#  (1L, u'Confections'),
#  (1L, u'Confections'),
#  (1L, u'Meat/Poultry'),
#  (1L, u'Produce'),
#  (1L, u'Meat/Poultry'),
#  (1L, u'Grains/Cereals'),
#  (1L, u'Produce'),
#  (1L, u'Confections'),
#  (1L, u'Condiments'),
#  (1L, u'Grains/Cereals'),
#  (1L, u'Confections')]

# %% [markdown]
# ### 2.c: How many not discontinued products per category?

# %% [markdown]
# ### 2.d: What are the most expensive 5 products (not discontinued)?

# %% [markdown]
# ### 2.e: How many units of each of these 5 products are there in stock?

# %% [markdown]
# ### 2.f: Pie Chart
#
# Use pandas to make a pie chart plot.

# %% [markdown]
# ## 3: Orders
#
# Now that we have a better understanding of products, let's start digging into orders.
#
# - How many orders in total?
# - How many orders per year
# - How many orders per quarter
# - Which country is receiving the most orders
# - Which country is receiving the least
# - What's the average shipping time (ShippedDate - OrderDate)
# - What customer is submitting the highest number of orders?
# - What customer is generating the highest revenue (need to pd.merge with order_details)
# - What fraction of the revenue is generated by the top 5 customers?

# %% [markdown]
# ### 3.a: How many orders in total?

# %% [markdown]
# ### 3.b: How many orders per year?

# %% [markdown]
# ### 3.c: How many orders per quarter?
#
# Make a line plot for these.

# %% [markdown]
# ### 3.d: Which country is receiving the most orders?

# %% [markdown]
# ### 3.e: Which country is receiving the least?

# %% [markdown]
# ### 3.f: What's the average shipping time (ShippedDate - OrderDate)?

# %% [markdown]
# ### 3.g: What customer is submitting the highest number of orders?

# %% [markdown]
# ### 3.h: What customer is generating the highest revenue (need to pd.merge with order_details)?

# %% [markdown]
# ### 3.i: What fraction of the revenue is generated by the top 5 customers?
#
# Compare that with the fraction represented by 5 customers over the total number of customers.

# %% [markdown]
# Wow!! 5.5% of the customers generate a third of the revenue!!

# %% [markdown]
# ## Bonus: Other tables
#
# Investigate the content of other tables. In particular lookt at the `suppliers`, `shippers` and `employees` tables.
