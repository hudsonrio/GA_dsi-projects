# %%
import pandas as pd

# %% [markdown]
# ### Categorical variables

# %%
# Let's use pandas to create Categorical Series. One way is by 
# specifying dtype="category" when constructing a Series:

s = pd.Series(["a","b","c","a"], dtype="category")
s
# Out:
# 0    a
# 1    b
# 2    c
# 3    a
# dtype: category
# Categories (3, object): [a, b, c]

# %%
# Another way is to convert an existing Series or column to a 
# category dtype:

df = pd.DataFrame({"A":["a","b","c","a"]})
df["B"] = df["A"].astype('category')
df
# Out:
#    A  B
# 0  a  a
# 1  b  b
# 2  c  c
# 3  a  a

# %%
# You can also pass a pandas.Categorical object to a Series 

raw_cat = pd.Categorical(["a","b","c","a"], categories=["b","c","d"],
                          ordered=False)

# %%
s = pd.Series(raw_cat)
s
# Out:
# 0    NaN
# 1      b
# 2      c
# 3    NaN
# dtype: category
# Categories (3, object): [b, c, d]

# %% [markdown]
# ### Dummy variables

# %%
# Let's use pd.get_dummies to convert categorical variables into dummy 
# variables. First let's create a small DataFrame with categorical variables. 

df = pd.DataFrame({'key': list('bbacab'), 'data1': range(6)})

# %%
df
# Out:
#    data1 key
# 0      0   b
# 1      1   b
# 2      2   a
# 3      3   c
# 4      4   a
# 5      5   b

# %%
# Now, let's convert the categorical variables into dummy variables. 

pd.get_dummies(df['key'])
# Out:
#    a  b  c
# 0  0  1  0
# 1  0  1  0
# 2  1  0  0
# 3  0  0  1
# 4  1  0  0
# 5  0  1  0

# %%
pd.concat([df.drop('key',axis=1),pd.get_dummies(df['key'])], axis = 1)
# Out:
#    data1  a  b  c
# 0      0  0  1  0
# 1      1  0  1  0
# 2      2  1  0  0
# 3      3  0  0  1
# 4      4  1  0  0
# 5      5  0  1  0

# %%
import os
os.getcwd()


crunch = pd.read_csv('/Users/HudsonCavanagh/Documents/crunchbase_monthly_export.csv')
cb = pd.DataFrame(crunch)
cb.head(50)
# Out:
#                            permalink                name  \
# 0     /organization/canal-do-credito    Canal do Credito
# 1              /organization/waywire            #waywire
# 2    /organization/tv-communications  &TV Communications
# 3      /organization/rock-your-paper   'Rock' Your Paper
# 4     /organization/in-touch-network   (In)Touch Network
# 5              /organization/n-plusn              #NAME?
# 6         /organization/club-domains       .Club Domains
# 7         /organization/fox-networks       .Fox Networks
# 8              /organization/0-6-com             0-6.com
# 9     /organization/004-technologies    004 Technologies
# 10              /organization/0xdata              0xdata
# 11         /organization/1-2-3-listo         1,2,3 Listo
# 12             /organization/1-4-all             1-4 All
# 13       /organization/1-800-dentist       1-800-DENTIST
# 14       /organization/1-800-doctors       1-800-DOCTORS
# 15    /organization/1-618-technology    1.618 Technology
# 16         /organization/10-20-media         10-20 Media
# 17          /organization/1000-corks          1000 Corks
# 18        /organization/1000-markets        1000 Markets
# 19   /organization/1000jobboersen-de   1000jobboersen.de
# 20        /organization/1000memories        1000memories
# 21     /organization/1000museums-com     1000museums.com
# 22          /organization/1001-menus          1001 Menus
# 23             /organization/1006-tv             1006.tv
# 24            /organization/100du-tv            100du.tv
# 25            /organization/100e-com            100e.com
# 26             /organization/100plus             100Plus
# 27            /organization/1010data            1010data
# 28        /organization/10bestthings        10BestThings
# 29               /organization/10sec               10sec
# 30  /organization/10seconds-software  10seconds Software
# 31               /organization/10six               10Six
# 32            /organization/10tracks            10tracks
# 33    /organization/10x-technologies    10X Technologies
# 34          /organization/10x10-room          10X10 Room
# 35   /organization/115-network-disks   115 network disks
# 36               /organization/117go               117go
# 37       /organization/11i-solutions       11i Solutions
# 38    /organization/12-star-survival    12 Star Survival
# 39             /organization/121cast             121cast
# 40            /organization/121nexus            121nexus
# 41           /organization/1234enter           1234ENTER
# 42      /organization/123contactform      123ContactForm
# 43           /organization/123people           123people
# 44                /organization/1248                1248
# 45               /organization/12bis               12Bis
# 46           /organization/12society           12Society
# 47   /organization/1366-technologies   1366 Technologies
# 48             /organization/139shop             139shop
# 49            /organization/13th-lab            13th Lab
#
#                            homepage_url  \
# 0      http://www.canaldocredito.com.br
# 1                http://www.waywire.com
# 2                 http://enjoyandtv.com
# 3          http://www.rockyourpaper.org
# 4         http://www.InTouchNetwork.com
# 5                      http://plusn.com
# 6                      http://nic.club/
# 7                 http://www.dotfox.com
# 8                    http://www.0-6.com
# 9     http://004gmbh.de/en/004-interact
# 10                http://www.0xdata.com
# 11              http://www.123listo.com
# 12                                  NaN
# 13           http://www.1800dentist.com
# 14               http://1800doctors.com
# 15                                  NaN
# 16            http://www.10-20media.com
# 17                 http://1000corks.com
# 18           http://www.1000markets.com
# 19         http://www.1000jobboersen.de
# 20              http://1000memories.com
# 21           http://www.1000museums.com
# 22                 http://1001menus.com
# 23                  http://www.1006.tv/
# 24                 http://www.100du.com
# 25                  http://www.100e.com
# 26               http://www.100plus.com
# 27              http://www.1010data.com
# 28              http://10bestthings.com
# 29                      https://10s.ec/
# 30     http://www.10secondsSoftware.com
# 31               http://10sixenergy.com
# 32                  http://10tracks.com
# 33           http://10xtechnologies.com
# 34                 http://10x10room.com
# 35                  http://www.115.com/
# 36                     http://117go.com
# 37          http://www.11isolutions.com
# 38        http://www.12starsurvival.com
# 39               http://www.121cast.com
# 40              http://www.121nexus.com
# 41          http://www.1234enter.com.br
# 42        http://www.123contactform.com
# 43                 http://123people.com
# 44  http://1248.io/index.php?page=index
# 45                     http://12bis.com
# 46             http://www.12Society.com
# 47              http://www.1366tech.com
# 48               http://www.139shop.com
# 49                   http://13thlab.com
#
#                                         category_list                market   \
# 0                |Credit|Technology|Services|Finance|                Credit
# 1          |Entertainment|Politics|Social Media|News|         Entertainment
# 2                                             |Games|                 Games
# 3                              |Publishing|Education|             Education
# 4   |Electronics|Guides|Coffee|Restaurants|Music|i...                  Apps
# 5                                          |Software|              Software
# 6                                          |Software|              Software
# 7                                       |Advertising|           Advertising
# 8                                       |Curated Web|           Curated Web
# 9                                          |Software|              Software
# 10                                        |Analytics|             Analytics
# 11                                       |E-Commerce|            E-Commerce
# 12                     |Entertainment|Games|Software|         Entertainment
# 13                              |Health and Wellness|   Health and Wellness
# 14                              |Health and Wellness|   Health and Wellness
# 15                                      |Real Estate|           Real Estate
# 16                                       |E-Commerce|            E-Commerce
# 17                                           |Search|                Search
# 18                      |Marketplaces|Art|E-Commerce|                   Art
# 19                                      |Curated Web|           Curated Web
# 20                                      |Curated Web|           Curated Web
# 21                                      |Curated Web|           Curated Web
# 22                     |Local Businesses|Restaurants|      Local Businesses
# 23                                      |Media|Games|                 Games
# 24                                      |Hospitality|           Hospitality
# 25                                        |Education|             Education
# 26                                        |Analytics|             Analytics
# 27                                         |Software|              Software
# 28                                      |Curated Web|           Curated Web
# 29       |Social Commerce|E-Commerce|Mobile Commerce|            E-Commerce
# 30            |Mobility|Enterprise Software|Software|   Enterprise Software
# 31                                                NaN                    NaN
# 32                                                NaN                    NaN
# 33                                    |Biotechnology|         Biotechnology
# 34                                         |Software|              Software
# 35                                        |Education|             Education
# 36                                                NaN                    NaN
# 37                              |Enterprise Software|   Enterprise Software
# 38                                           |Sports|                Sports
# 39                               |Audio|Music|Mobile|                 Audio
# 40  |Politics|Technology|Medical Devices|Pharmaceu...       Medical Devices
# 41  |Small and Medium Businesses|Education|Analyti...           Advertising
# 42                                  |SaaS|E-Commerce|            E-Commerce
# 43                                  |Software|Search|                Search
# 44                                         |Software|              Software
# 45                                                NaN                    NaN
# 46                                       |E-Commerce|            E-Commerce
# 47                                    |Manufacturing|         Manufacturing
# 48                                       |E-Commerce|            E-Commerce
# 49  |iPad|Games|Augmented Reality|Computer Vision|...     Augmented Reality
#
#     funding_total_usd      status country_code state_code  \
# 0             750,000         NaN          BRA        NaN
# 1           1,750,000    acquired          USA         NY
# 2           4,000,000   operating          USA         CA
# 3              40,000   operating          EST        NaN
# 4           1,500,000   operating          GBR        NaN
# 5             600,000   operating          USA         NY
# 6           7,000,000         NaN          USA         FL
# 7           4,912,393      closed          ARG        NaN
# 8           2,000,000   operating          NaN        NaN
# 9                 -     operating          USA         IL
# 10          1,700,000   operating          USA         CA
# 11             40,000   operating          CHL        NaN
# 12                -     operating          USA         NC
# 13                -     operating          USA         CA
# 14          1,750,000   operating          USA         NJ
# 15                -     operating          USA         FL
# 16          2,050,000   operating          USA         MD
# 17             40,000   operating          USA         OR
# 18            500,000    acquired          NaN        NaN
# 19                -     operating          DEU        NaN
# 20          2,535,000    acquired          USA         CA
# 21          4,462,651   operating          USA         WA
# 22          1,869,079   operating          FRA        NaN
# 23         10,000,000   operating          NaN        NaN
# 24          3,000,000   operating          NaN        NaN
# 25          3,000,000   operating          CHN        NaN
# 26          1,250,000    acquired          USA         CA
# 27         35,000,000   operating          USA         NY
# 28             50,000      closed          USA         OH
# 29          1,600,000         NaN          NaN        NaN
# 30            100,000   operating          AUS        NaN
# 31                -     operating          USA         NY
# 32             40,000         NaN          NaN        NaN
# 33          3,000,000   operating          USA         CA
# 34             77,500   operating          USA         MA
# 35                -     operating          NaN        NaN
# 36         20,000,000         NaN          CHN        NaN
# 37          1,800,000      closed          USA         AL
# 38                -     operating          NaN        NaN
# 39            270,000   operating          AUS        NaN
# 40            794,000   operating          USA         RI
# 41            650,267   operating          ITA        NaN
# 42                -     operating          ROU        NaN
# 43                -      acquired          AUT        NaN
# 44            378,812   operating          GBR        NaN
# 45            130,636   operating          FRA        NaN
# 46                -      acquired          USA         CA
# 47         66,450,000   operating          USA         MA
# 48                -     operating          CHN        NaN
# 49            700,000         NaN          SWE        NaN
#
#                    region               city  funding_rounds founded_at  \
# 0          Rio de Janeiro     Belo Horizonte               1        NaN
# 1           New York City           New York               1     6/1/12
# 2             Los Angeles        Los Angeles               2        NaN
# 3                 Tallinn            Tallinn               1   10/26/12
# 4                  London             London               1     4/1/11
# 5           New York City           New York               1     1/1/12
# 6          Ft. Lauderdale       Oakland Park               1   10/10/11
# 7            Buenos Aires       Buenos Aires               1        NaN
# 8                     NaN                NaN               1     1/1/07
# 9   Springfield, Illinois          Champaign               1     1/1/10
# 10            SF Bay Area      Mountain View               1     1/1/11
# 11               Santiago         Las Condes               1     1/1/12
# 12         North Carolina  Connellys Springs               1        NaN
# 13            Los Angeles        Los Angeles               1     1/1/86
# 14                 Newark             Iselin               1     1/1/84
# 15                Orlando            Orlando               1    12/7/13
# 16              Baltimore           Woodbine               4     1/1/01
# 17       Portland, Oregon        Lake Oswego               1     1/1/08
# 18                    NaN                NaN               1     1/1/09
# 19                 Berlin             Berlin               1        NaN
# 20            SF Bay Area      San Francisco               2     7/1/10
# 21                Seattle           Bellevue               4     1/1/08
# 22                  Paris              Paris               2   11/20/10
# 23                Beijing            Beijing               3     1/1/09
# 24                    NaN                NaN               2        NaN
# 25                Beijing            Beijing               1        NaN
# 26            SF Bay Area      San Francisco               2    9/16/11
# 27          New York City           New York               1     1/1/00
# 28              Cleveland          Cleveland               1     4/1/09
# 29                    NaN                NaN               1     7/8/13
# 30                 Sydney             Sydney               1     7/1/09
# 31          New York City           New York               1        NaN
# 32                    NaN                NaN               1        NaN
# 33            SF Bay Area            Oakland               1     1/1/12
# 34                 Boston          Lexington               1     1/1/10
# 35                    NaN                NaN               1        NaN
# 36               Shanghai           Shanghai               1    10/1/11
# 37             Huntsville         Huntsville               1        NaN
# 38                    NaN                NaN               1    7/17/13
# 39              Melbourne          Melbourne               2     2/1/12
# 40             Providence         Providence               6    10/7/11
# 41               Piemonte                Bra               2     1/1/12
# 42              Timisoara          Timisoara               1     1/1/08
# 43                 Vienna             Vienna               1     1/1/07
# 44                 London          Cambridge               1     1/1/13
# 45                  Paris              Paris               1     1/1/08
# 46            Los Angeles     West Hollywood               1     1/1/12
# 47                 Boston            Bedford               8     1/1/07
# 48                   Asia                NaN               1        NaN
# 49              Stockholm          Stockholm               1     1/1/10
#
#    founded_month founded_quarter  founded_year first_funding_at  \
# 0            NaN             NaN           NaN           1/1/10
# 1        2012-06         2012-Q2          2012          6/30/12
# 2            NaN             NaN           NaN           6/4/10
# 3        2012-10         2012-Q4          2012           8/9/12
# 4        2011-04         2011-Q2          2011           4/1/11
# 5        2012-01         2012-Q1          2012          8/29/12
# 6        2011-10         2011-Q4          2011          5/31/13
# 7            NaN             NaN           NaN          1/16/07
# 8        2007-01         2007-Q1          2007          3/19/08
# 9        2010-01         2010-Q1          2010          7/24/14
# 10       2011-01         2011-Q1          2011           1/3/13
# 11       2012-01         2012-Q1          2012          2/18/13
# 12           NaN             NaN           NaN          4/21/13
# 13       1986-01         1986-Q1          1986          8/19/10
# 14       1984-01         1984-Q1          1984           3/2/11
# 15       2013-12         2013-Q4          2013          1/22/14
# 16       2001-01         2001-Q1          2001          6/18/09
# 17       2008-01         2008-Q1          2008          8/23/11
# 18       2009-01         2009-Q1          2009          5/15/09
# 19           NaN             NaN           NaN          9/16/11
# 20       2010-07         2010-Q3          2010           1/1/10
# 21       2008-01         2008-Q1          2008         10/14/09
# 22       2010-11         2010-Q4          2010         12/27/12
# 23       2009-01         2009-Q1          2009           1/1/11
# 24           NaN             NaN           NaN           1/7/08
# 25           NaN             NaN           NaN           1/1/06
# 26       2011-09         2011-Q3          2011          11/2/11
# 27       2000-01         2000-Q1          2000           3/8/10
# 28       2009-04         2009-Q2          2009           4/1/09
# 29       2013-07         2013-Q3          2013           5/8/14
# 30       2009-07         2009-Q3          2009           7/1/10
# 31           NaN             NaN           NaN           2/1/13
# 32           NaN             NaN           NaN           3/1/13
# 33       2012-01         2012-Q1          2012          11/7/12
# 34       2010-01         2010-Q1          2010         10/12/11
# 35           NaN             NaN           NaN          11/1/11
# 36       2011-10         2011-Q4          2011          4/28/14
# 37           NaN             NaN           NaN          3/22/11
# 38       2013-07         2013-Q3          2013         10/17/13
# 39       2012-02         2012-Q1          2012           5/1/12
# 40       2011-10         2011-Q4          2011           2/6/12
# 41       2012-01         2012-Q1          2012           9/1/12
# 42       2008-01         2008-Q1          2008           1/1/10
# 43       2007-01         2007-Q1          2007           1/1/08
# 44       2013-01         2013-Q1          2013          3/18/14
# 45       2008-01         2008-Q1          2008          3/15/12
# 46       2012-01         2012-Q1          2012           4/5/12
# 47       2007-01         2007-Q1          2007          3/27/08
# 48           NaN             NaN           NaN           2/1/07
# 49       2010-01         2010-Q1          2010          6/15/12
#
#    last_funding_at  Unnamed: 18
# 0           1/1/10          NaN
# 1          6/30/12          NaN
# 2          9/23/10          NaN
# 3           8/9/12          NaN
# 4           4/1/11          NaN
# 5          8/29/12          NaN
# 6          5/31/13          NaN
# 7          1/16/07          NaN
# 8          3/19/08          NaN
# 9          7/24/14          NaN
# 10          1/3/13          NaN
# 11         2/18/13          NaN
# 12         4/21/13          NaN
# 13         8/19/10          NaN
# 14          3/2/11          NaN
# 15         1/22/14          NaN
# 16        12/28/11          NaN
# 17         8/23/11          NaN
# 18         5/15/09          NaN
# 19         9/16/11          NaN
# 20         2/16/11          NaN
# 21         1/15/14          NaN
# 22        11/13/13          NaN
# 23         7/31/14          NaN
# 24         8/13/10          NaN
# 25          1/1/06          NaN
# 26        11/30/11          NaN
# 27          3/8/10          NaN
# 28          4/1/09          NaN
# 29          5/8/14          NaN
# 30          7/1/10          NaN
# 31          2/1/13          NaN
# 32          3/1/13          NaN
# 33         11/7/12          NaN
# 34        10/12/11          NaN
# 35         11/1/11          NaN
# 36         4/28/14          NaN
# 37         3/22/11          NaN
# 38        10/17/13          NaN
# 39        11/13/12          NaN
# 40          1/1/14          NaN
# 41        11/22/13          NaN
# 42          1/1/10          NaN
# 43          1/1/08          NaN
# 44         3/18/14          NaN
# 45         3/15/12          NaN
# 46          4/5/12          NaN
# 47        12/12/13          NaN
# 48          2/1/07          NaN
# 49         6/15/12          NaN

# %%
market_dummy = pd.get_dummies(cb[' market '])
cb_market = pd.concat([cb, market_dummy], axis=1)

# pd.concat([df.drop('key',axis=1),pd.get_dummies(df['key'])], axis = 1)
cols = cb_market.columns
print(cols)
# Out:
# Index([u'permalink', u'name', u'homepage_url', u'category_list', u' market ',
#        u' funding_total_usd ', u'status', u'country_code', u'state_code',
#        u'region',
#        ...
#        u' Web Hosting ', u' Web Tools ', u' Weddings ', u' Wholesale ',
#        u' Wine And Spirits ', u' Wireless ', u' iOS ', u' iPad ', u' iPhone ',
#        u' mHealth '],
#       dtype='object', length=566)

# %%
cb_market['funding_total_usd'] = cb_market[' funding_total_usd '].apply(lambda x: str(x))
cb_market['funding_total_usd'] = cb_market['funding_total_usd'].apply(lambda x: x.strip(','))
cb_market['funding_total_usd'] = cb_market['funding_total_usd'].apply(lambda x: x.strip())
cb_market['funding_total_usd']

# cb_market['funding_total_usd'] = cb_market['funding_total_usd'].apply(lambda x: int(x))

# print(type(cb_market['funding_total_usd'][4]))
# Out:
# 0            750,000
# 1          1,750,000
# 2          4,000,000
# 3             40,000
# 4          1,500,000
# 5            600,000
# 6          7,000,000
# 7          4,912,393
# 8          2,000,000
# 9                  -
# 10         1,700,000
# 11            40,000
# 12                 -
# 13                 -
# 14         1,750,000
# 15                 -
# 16         2,050,000
# 17            40,000
# 18           500,000
# 19                 -
# 20         2,535,000
# 21         4,462,651
# 22         1,869,079
# 23        10,000,000
# 24         3,000,000
# 25         3,000,000
# 26         1,250,000
# 27        35,000,000
# 28            50,000
# 29         1,600,000
#             ...
# 44920        651,000
# 44921      3,500,000
# 44922        190,000
# 44923        100,000
# 44924        870,000
# 44925      3,845,100
# 44926     45,750,000
# 44927              -
# 44928      9,000,000
# 44929      3,384,225
# 44930        800,000
# 44931         75,000
# 44932     12,039,999
# 44933      2,257,464
# 44934     38,900,000
# 44935              -
# 44936              -
# 44937      3,805,520
# 44938    866,550,786
# 44939     25,000,000
# 44940     14,750,000
# 44941     34,275,015
# 44942     15,398,910
# 44943      1,510,500
# 44944      2,686,600
# 44945        120,000
# 44946      1,587,301
# 44947         71,525
# 44948      9,300,000
# 44949     45,000,000
# Name: funding_total_usd, dtype: object
