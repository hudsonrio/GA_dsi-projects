# %%
import matplotlib.pyplot as plt
from sklearn import metrics
import pandas as pd
import numpy as np
import os

% matplotlib inline
os.getcwd()
cost_of_living = pd.read_csv('/Users/HudsonCavanagh/GA_dsi-projects/projects/4th/cost_of_living_index.csv')
cost = pd.DataFrame(cost_of_living)
cost.head()
# Out:
#    Ranking                       City  Price Index
# 0        1      Palo Alto, California          277
# 1        2  San Francisco, California          272
# 2        3              New York City          269
# 3        4            Washington D.C.          258
# 4        5  Mountain View, California          257

# %%
import seaborn as sns

sns.distplot(cost['Price Index'])
