# %% [markdown]
# # Web Scraping for Indeed.com & Predicting Salaries

# %% [markdown]
# In this project, we will practice two major skills: collecting data by scraping a website and then building a binary predictor with Logistic Regression.
#
# We are going to collect salary information on data science jobs in a variety of markets. Then using the location, title and summary of the job we will attempt to predict the salary of the job. For job posting sites, this would be extraordinarily useful. While most listings DO NOT come with salary information (as you will see in this exercise), being to able extrapolate or predict the expected salaries from other listings can help guide negotiations.
#
# Normally, we could use regression for this task; however, we will convert this problem into classification and use Logistic Regression.
#
# - Question: Why would we want this to be a classification problem?
# - Answer: While more precision may be better, there is a fair amount of natural variance in job salaries - predicting a range be may be useful.
#
# Therefore, the first part of the assignment will be focused on scraping Indeed.com. In the second, we'll focus on using listings with salary information to build a model and predict additional salaries.

# %% [markdown]
# ### Scraping job listings from Indeed.com

# %% [markdown]
# We will be scraping job listings from Indeed.com using BeautifulSoup. Luckily, Indeed.com is a simple text page where we can easily find relevant entries.
#
# First, look at the source of an Indeed.com page: (http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10")
#
# Notice, each job listing is underneath a `div` tag with a class name of `result`. We can use BeautifulSoup to extract those.

# %% [markdown]
# #### Setup a request (using `requests`) to the URL below. Use BeautifulSoup to parse the page and extract all results (HINT: Look for div tags with class name result)

# %%
URL = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"

# %%
import requests
import bs4
from bs4 import BeautifulSoup
from __future__ import division, print_function

import requests
from bs4 import BeautifulSoup
from selenium import webdriver

import pandas as pd
import numpy as np

from IPython.core.display import HTML, Image

# %%
r = requests.get(URL)
indeed = BeautifulSoup(r.content, "lxml")

# %%
col_list = ['location', 'title', 'company', 'salary', 'description']

def prime_time(soup):
    location_list = []
    role_title_list = []
    company_list = []
    salaries = []
    summaries = []

    for t in soup.findAll("div", class_='result'):
#     url = t.find('a', 
#     url_list.append(url) #---- can return to this later
        location = t.find('span', class_='location').text # WORKS!
        location_list.append(location)
        title = t.find('a')['title'] # WORKS!
        role_title_list.append(title)
        company_name = t.find('span', class_='company').text
        company_name = company_name.strip('\n')
        company_list.append(company_name)
        salary = t.find('nobr' or 'sjcl')   #('nobr').next_sibling sjcl
        salaries.append(salary)
        summary = t.find('span', class_="summary").text
        summaries.append(summary)
    
    results = zip(location_list, role_title_list, company_list, salaries, summaries)
    results = pd.DataFrame(results)
    results.columns = col_list
    return(results)

# indeed_results = prime_time(indeed)
# indeed_output = pd.DataFrame(indeed_results)
# indeed_output.head()

# %% [markdown]
# Let's look at one result more closely. A single `result` looks like
#
# ```
# <div class=" row result" data-jk="2480d203f7e97210" data-tn-component="organicJob" id="p_2480d203f7e97210" itemscope="" itemtype="http://schema.org/JobPosting">
# <h2 class="jobtitle" id="jl_2480d203f7e97210">
# <a class="turnstileLink" data-tn-element="jobTitle" onmousedown="return rclk(this,jobmap[0],1);" rel="nofollow" target="_blank" title="AVP/Quantitative Analyst">AVP/Quantitative Analyst</a>
# </h2>
# <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
# <span itemprop="name">
# <a href="/cmp/Alliancebernstein?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=2480d203f7e97210&amp;jcid=b374f2a780e04789" target="_blank">
#     AllianceBernstein</a></span>
# </span>
# <tr>
# <td class="snip">
# <nobr>$117,500 - $127,500 a year</nobr>
# <div>
# <span class="summary" itemprop="description">
# C onduct quantitative and statistical research as well as portfolio management for various investment portfolios. Collaborate with Quantitative Analysts and</span>
# </div>
# </div>
# </td>
# </tr>
# </table>
# </div>
# ```
#
# While this has some more verbose elements removed, we can see that there is some structure to the above:
# - The salary is available in a `nobr` element inside of a `td` element with `class='snip`.
# - The title of a job is in a link with class set to `jobtitle` and a `data-tn-element="jobTitle`.
# - The location is set in a `span` with `class='location'`.
# - The company is set in a `span` with `class='company'`.

# %% [markdown]
# ### Write 4 functions to extract each item: location, company, job, and salary.
#
# example:
# ```python
# def extract_location_from_result(result):
#     return result.find ...
# ```
#
#
# - Make sure these functions are robust and can handle cases where the data/field may not be available.
# - Test the functions on the results above
# - Include any other features you may want to use later (e.g. summary, #of reviews...)

# %% [markdown]
# Now, to scale up our scraping, we need to accumulate more results. We can do this by examining the URL above.
#
# - "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"
#
# There are two query parameters here we can alter to collect more results, the `l=New+York` and the `start=10`. The first controls the location of the results (so we can try a different city). The second controls where in the results to start and gives 10 results (thus, we can keep incrementing by 10 to go further in the list).

# %% [markdown]
# ### Complete the following code to collect results from multiple cities and starting points.
# - Indeed.com only has salary information for an estimated 20% of job postings. You may want to add other cities to the list below to gather more data.
# - Remember to convert your salary to U.S. Dollars to match the other cities if the currency is different

# %%
import numpy as np

url_template_first = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l={}"
url_template = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l={}&start={}"

max_results_per_city = 100
col_list = ['location', 'title', 'company', 'salary', 'description']
sample_vals = [np.NaN,np.NaN,np.NaN,np.NaN,np.NaN]

d = dict.fromkeys(col_list, sample_vals)
results = pd.DataFrame(d)   # trying to make the columns the same so I can merge later


for city in set(['New+York', 'Chicago', 'San+Francisco', 'Austin', 'Atlanta', 'Boston']):
    for start in range(0, max_results_per_city, 10):
        foo = requests.get(url_template.format(city, start))
        indeed = BeautifulSoup(foo.content, "lxml")
        indeed_results = prime_time(indeed)
        indeed_results.columns = col_list
        
        results = pd.concat([indeed_results, results], ignore_index=True)
    first = requests.get(url_template_first.format(city)) #GETS THE FIRST PAGE OF RESULTS, MISSED
    first_indeed = BeautifulSoup(first.content, "lxml")
    first_indeed_results = prime_time(first_indeed)
    first_indeed_results.columns = col_list
    results = pd.concat([first_indeed_results, results], ignore_index=True)
results.head(50)
# Out:
#                                               company  \
# 0                                              Indeed
# 1                                              Indeed
# 2                                            MaxPoint
# 3                                                 IBM
# 4                                                 IBM
# 5                   Samsung Austin Semiconductor, LLC
# 6                                             Samsung
# 7                                Amazon Corporate LLC
# 8                                                Dell
# 9                                            HomeAway
# 10      Intersys:Big Data And Application Development
# 11                                               21CT
# 12                                             Gallup
# 13                                         Sense Corp
# 14                                             Gallup
# 15                                         Sense Corp
# 16                                           MaxPoint
# 17                      Atlantic Engineering Services
# 18                                    Express Scripts
# 19                                Precision For Value
# 20                                     City of Austin
# 21                                     Alcatel-Lucent
# 22                          Worldwide Clinical Trials
# 23                     The University of Texas System
# 24                                      Gartner, Inc.
# 25                      University of Texas at Austin
# 26                                             Micron
# 27                                             Indeed
# 28                                             Gallup
# 29                                             Indeed
# 30                                         Sense Corp
# 31                                           MaxPoint
# 32                                             NVIDIA
# 33                                        BazaarVoice
# 34                             Signature Science, LLC
# 35                                                IBM
# 36                                             NVIDIA
# 37                                     Alcatel-Lucent
# 38                                          SmarterHQ
# 39                                           Asuragen
# 40                                  RetailMeNot, Inc.
# 41                      University of Texas at Austin
# 42                                             Gallup
# 43                                             Indeed
# 44                                             Indeed
# 45                                         Sense Corp
# 46                                           MaxPoint
# 47                UT Health Science Center at Houston
# 48                  Texas Department of Public Safety
# 49                                Precision For Value
#
#                                           description  \
# 0   How a Data Scientist works. As a Data Scientis...
# 1   Work closely with stakeholders on the data dem...
# 2   Senior Data Scientist. Mentor other data scien...
# 3   \nCreating and maintaining machine learning mo...
# 4   \nAutomatically find and interpret data rich s...
# 5   \nData Engineer position in the Data Science g...
# 6   \nData Engineer position in the Data Science g...
# 7   \nStrong grasp of data structures and algorith...
# 8   \nData Scientist - Round Rock, TX. Strong fami...
# 9   \nIf so, then HomeAway has a Data Scientist ro...
# 10  \nJr Data Scientist*. Jr Data Scientist Job De...
# 11  \nDeep learning, data mining, data fusion, mac...
# 12  \nGallup data scientists help clients effectiv...
# 13  Data analyst/data scientist role:. Perform dat...
# 14  Gallup data scientists help clients effectivel...
# 15  Data analyst/data scientist role:. Perform dat...
# 16  Senior Data Scientist. Mentor other data scien...
# 17  \nData entry of mathematical analysis for wire...
# 18  \nMapping qualitative data to quantitative dat...
# 19  \nAdministrative hospital data, Electronic hea...
# 20  \n2 years experience in data statistical analy...
# 21  \nWorld-wide, our software helps service provi...
# 22  \nReview data, recognize and report inconsiste...
# 23  \nAssist in ongoing development of data wareho...
# 24  \nHypothesis formation and data identification...
# 25  \nData analysis for space weather remediation....
# 26  \nWorking knowledge of fundamental Computer Sc...
# 27  Work closely with stakeholders on the data dem...
# 28  Gallup data scientists help clients effectivel...
# 29  How a Data Scientist works. As a Data Scientis...
# 30  Data analyst/data scientist role:. Perform dat...
# 31  Senior Data Scientist. Mentor other data scien...
# 32  \nCompiler Machine Learning Verification Engin...
# 33  \nYou’ll extract key data and findings, define...
# 34  \nQuality Assurance Scientist - Summer Intern....
# 35  \nData analytics and modeling, data visualizat...
# 36  \nExperience in optimization, common CAD data ...
# 37  \nWorld-wide, our software helps service provi...
# 38  \nExperience working with data scientists a pl...
# 39  \nScientist I, Development*. Scientist I, Rese...
# 40  \nCollaborate effectively with engineers, data...
# 41  \nInvestigate new applications of GPS/GNSS rec...
# 42  Gallup data scientists help clients effectivel...
# 43  Work closely with stakeholders on the data dem...
# 44  How a Data Scientist works. As a Data Scientis...
# 45  Data analyst/data scientist role:. Perform dat...
# 46  Senior Data Scientist. Mentor other data scien...
# 47  \nFour (4) years of experience analyzing outco...
# 48  \nDevelop plans, policies, and procedures for ...
# 49  \nExperience in systematic reviews, designing,...
#
#                                              location  \
# 0                                          Austin, TX
# 1                                          Austin, TX
# 2                                          Austin, TX
# 3                                          Austin, TX
# 4                                          Austin, TX
# 5                                    Austin, TX 78754
# 6                                    Austin, TX 78754
# 7                                    Austin, TX 78728
# 8                                Round Rock, TX 78664
# 9   Austin, TX 78704 (South Lamar-South Congress a...
# 10                                         Austin, TX
# 11                                         Austin, TX
# 12                                         Austin, TX
# 13                                         Austin, TX
# 14                                         Austin, TX
# 15                                         Austin, TX
# 16                                         Austin, TX
# 17  Austin, TX 78704 (South Lamar-South Congress a...
# 18                                         Austin, TX
# 19                                         Austin, TX
# 20                                         Austin, TX
# 21                                         Austin, TX
# 22                                         Austin, TX
# 23                                         Austin, TX
# 24                                         Austin, TX
# 25                                         Austin, TX
# 26                                         Austin, TX
# 27                                         Austin, TX
# 28                                         Austin, TX
# 29                                         Austin, TX
# 30                                         Austin, TX
# 31                                         Austin, TX
# 32                                         Austin, TX
# 33                                   Austin, TX 78746
# 34                  Austin, TX 78759 (Arboretum area)
# 35                                         Austin, TX
# 36                                         Austin, TX
# 37                                         Austin, TX
# 38                                         Austin, TX
# 39                                         Austin, TX
# 40                                         Austin, TX
# 41                                         Austin, TX
# 42                                         Austin, TX
# 43                                         Austin, TX
# 44                                         Austin, TX
# 45                                         Austin, TX
# 46                                         Austin, TX
# 47                                         Austin, TX
# 48                                         Austin, TX
# 49                                         Austin, TX
#
#                                    salary  \
# 0                                    None
# 1                                    None
# 2                                    None
# 3                                    None
# 4                                    None
# 5                                    None
# 6                                    None
# 7                                    None
# 8                                    None
# 9                                    None
# 10                                   None
# 11                                   None
# 12                                   None
# 13                                   None
# 14                                   None
# 15                                   None
# 16                                   None
# 17                                   None
# 18                                   None
# 19                                   None
# 20   <nobr>$21.31 - $27.06 an hour</nobr>
# 21                                   None
# 22                                   None
# 23            <nobr>$4,459 a month</nobr>
# 24                                   None
# 25   <nobr>$5,400 - $6,500 a month</nobr>
# 26                                   None
# 27                                   None
# 28                                   None
# 29                                   None
# 30                                   None
# 31                                   None
# 32                                   None
# 33                                   None
# 34                                   None
# 35                                   None
# 36                                   None
# 37                                   None
# 38                                   None
# 39                                   None
# 40                                   None
# 41  <nobr>$6,250 - $10,833 a month</nobr>
# 42                                   None
# 43                                   None
# 44                                   None
# 45                                   None
# 46                                   None
# 47                                   None
# 48   <nobr>$3,763 - $5,665 a month</nobr>
# 49                                   None
#
#                                                 title
# 0                                      Data Scientist
# 1                                       Data Engineer
# 2                               Senior Data Scientist
# 3     Blue Spark - Watson Cognitive Software Engineer
# 4                      Data Engineer / Data Scientist
# 5                                      Data Scientist
# 6                                      Data Scientist
# 7                          Machine Learning Scientist
# 8                        Data Scientist Round Rock TX
# 9                             Research Data Scientist
# 10                                  Jr Data Scientist
# 11                                 Research Scientist
# 12              Data Scientist – Predictive Analytics
# 13                                     Data Scientist
# 14              Data Scientist – Predictive Analytics
# 15                                     Data Scientist
# 16                              Senior Data Scientist
# 17  Make Ready Engineering Specialist (data analys...
# 18                  Senior Quantitative UX Researcher
# 19              Research Scientist, Advanced Modeling
# 20  MuniProg, Research Analyst (Temp) Paraprofessi...
# 21                           Software Developer Co-op
# 22                                 Automation Analyst
# 23                     Institutional Research Analyst
# 24        Content Marketing Analyst, Gartner Research
# 25  Engineering Scientist Associate - R and D Soft...
# 26                    Principal Software Engineer Job
# 27                                      Data Engineer
# 28              Data Scientist – Predictive Analytics
# 29                                     Data Scientist
# 30                                     Data Scientist
# 31                              Senior Data Scientist
# 32    Compiler Machine Learning Verification Engineer
# 33                                  Sr. UX Researcher
# 34           Internship - Quality Assurance Scientist
# 35  Worldwide CoC Team –Data Scientist and Managin...
# 36             Machine Learning for VLSI CAD Engineer
# 37                                  PMO CNO CXS Co-op
# 38                          Junior Back-End Developer
# 39                                 Research Scientist
# 40                                 Sr. Data Scientist
# 41               Engineering Scientist - GNSS Analyst
# 42              Data Scientist – Predictive Analytics
# 43                                      Data Engineer
# 44                                     Data Scientist
# 45                                     Data Scientist
# 46                              Senior Data Scientist
# 47                          Sr. Statistician - Austin
# 48              Statistician III-IV, HSOC, THP-Austin
# 49         Research Scientist, HEOR, Health Analytics

# %% [markdown]
# #### Use the functions you wrote above to parse out the 4 fields - location, title, company and salary. Create a dataframe from the results with those 4 columns.

# %% [markdown]
# Lastly, we need to clean up salary data.
# 1. Some of the salaries are not yearly but hourly, these will be useful to us for now 2. The salaries are given as text and usually with ranges.
#
# #### Filter out the salaries that are not yearly (filter those that refer to hour)

# %%
import numpy as np


            
            
# results['annual_salary'] = results['salary']

results_nan = results.replace({None:np.NaN})
results = results_nan
results.head(10)
# Out:
#                                  company  \
# 0                                 Indeed
# 1                                 Indeed
# 2                               MaxPoint
# 3                                    IBM
# 4                                    IBM
# 5      Samsung Austin Semiconductor, LLC
# 6                                Samsung
# 7                   Amazon Corporate LLC
# 8                                   Dell
# 9                               HomeAway
#
#                                          description  \
# 0  How a Data Scientist works. As a Data Scientis...
# 1  Work closely with stakeholders on the data dem...
# 2  Senior Data Scientist. Mentor other data scien...
# 3  \nCreating and maintaining machine learning mo...
# 4  \nAutomatically find and interpret data rich s...
# 5  \nData Engineer position in the Data Science g...
# 6  \nData Engineer position in the Data Science g...
# 7  \nStrong grasp of data structures and algorith...
# 8  \nData Scientist - Round Rock, TX. Strong fami...
# 9  \nIf so, then HomeAway has a Data Scientist ro...
#
#                                             location salary  \
# 0                                         Austin, TX    NaN
# 1                                         Austin, TX    NaN
# 2                                         Austin, TX    NaN
# 3                                         Austin, TX    NaN
# 4                                         Austin, TX    NaN
# 5                                   Austin, TX 78754    NaN
# 6                                   Austin, TX 78754    NaN
# 7                                   Austin, TX 78728    NaN
# 8                               Round Rock, TX 78664    NaN
# 9  Austin, TX 78704 (South Lamar-South Congress a...    NaN
#
#                                              title
# 0                                   Data Scientist
# 1                                    Data Engineer
# 2                            Senior Data Scientist
# 3  Blue Spark - Watson Cognitive Software Engineer
# 4                   Data Engineer / Data Scientist
# 5                                   Data Scientist
# 6                                   Data Scientist
# 7                       Machine Learning Scientist
# 8                     Data Scientist Round Rock TX
# 9                          Research Data Scientist

# %%
def salary_clean(string):
    if type(string) == float:
        return np.NaN
    elif string == np.NaN:
        return np.NaN
    else:
        try:
            return((string.split("<nobr>")[1]).split("</nobr>")[0])
        except (TypeError, IndexError): 
            return np.NaN

for b in range(len(results['salary'])):
    results['salary'][b] = salary_clean(str(results['salary'][b]))
    

results.head(15)
# Out:
#                                               company  \
# 0                                              Indeed
# 1                                              Indeed
# 2                                            MaxPoint
# 3                                                 IBM
# 4                                                 IBM
# 5                   Samsung Austin Semiconductor, LLC
# 6                                             Samsung
# 7                                Amazon Corporate LLC
# 8                                                Dell
# 9                                            HomeAway
# 10      Intersys:Big Data And Application Development
# 11                                               21CT
# 12                                             Gallup
# 13                                         Sense Corp
# 14                                             Gallup
#
#                                           description  \
# 0   How a Data Scientist works. As a Data Scientis...
# 1   Work closely with stakeholders on the data dem...
# 2   Senior Data Scientist. Mentor other data scien...
# 3   \nCreating and maintaining machine learning mo...
# 4   \nAutomatically find and interpret data rich s...
# 5   \nData Engineer position in the Data Science g...
# 6   \nData Engineer position in the Data Science g...
# 7   \nStrong grasp of data structures and algorith...
# 8   \nData Scientist - Round Rock, TX. Strong fami...
# 9   \nIf so, then HomeAway has a Data Scientist ro...
# 10  \nJr Data Scientist*. Jr Data Scientist Job De...
# 11  \nDeep learning, data mining, data fusion, mac...
# 12  \nGallup data scientists help clients effectiv...
# 13  Data analyst/data scientist role:. Perform dat...
# 14  Gallup data scientists help clients effectivel...
#
#                                              location salary  \
# 0                                          Austin, TX    NaN
# 1                                          Austin, TX    NaN
# 2                                          Austin, TX    NaN
# 3                                          Austin, TX    NaN
# 4                                          Austin, TX    NaN
# 5                                    Austin, TX 78754    NaN
# 6                                    Austin, TX 78754    NaN
# 7                                    Austin, TX 78728    NaN
# 8                                Round Rock, TX 78664    NaN
# 9   Austin, TX 78704 (South Lamar-South Congress a...    NaN
# 10                                         Austin, TX    NaN
# 11                                         Austin, TX    NaN
# 12                                         Austin, TX    NaN
# 13                                         Austin, TX    NaN
# 14                                         Austin, TX    NaN
#
#                                               title
# 0                                    Data Scientist
# 1                                     Data Engineer
# 2                             Senior Data Scientist
# 3   Blue Spark - Watson Cognitive Software Engineer
# 4                    Data Engineer / Data Scientist
# 5                                    Data Scientist
# 6                                    Data Scientist
# 7                        Machine Learning Scientist
# 8                      Data Scientist Round Rock TX
# 9                           Research Data Scientist
# 10                                Jr Data Scientist
# 11                               Research Scientist
# 12            Data Scientist – Predictive Analytics
# 13                                   Data Scientist
# 14            Data Scientist – Predictive Analytics

# %%
# print(results['salary'].isnull().value_counts()) #only 62 salaries in here it appears

# %% [markdown]
# #### Write a function that takes a salary string and converts it to a number, averaging a salary range if necessary

# %%
import re
import string 

def salarizer(salary):  
    if pd.isnull(salary) == False:
        salary = salary.translate(None, "$|anmonthhurye, ")
        return(salary) # test line -- cut interior function to split/ average and moved outside
    else:
        return np.NaN

    


def salary_average(salary): 
    float_sal_list = []
    try:
        salary_str = str(salary)
        sal_list = str.split(salary_str, "-")
        for item in sal_list:
            try:
                float_sal_list.append(float(item))
            except ValueError:
                return salary
        if len(float_sal_list) > 1:
            avg_sal = sum(float_sal_list)/float(len(float_sal_list))
            return(avg_sal)
        else:
            return float(salary)
    except IndexError:
        return np.NaN
    

    
for hannah in range(len(results['salary'])):
    results['salary'][hannah] = salarizer(results['salary'][hannah])
    results['salary'][hannah] = salary_average(results['salary'][hannah])
results.head(20)
# Out:
#                                               company  \
# 0                                              Indeed
# 1                                              Indeed
# 2                                            MaxPoint
# 3                                                 IBM
# 4                                                 IBM
# 5                   Samsung Austin Semiconductor, LLC
# 6                                             Samsung
# 7                                Amazon Corporate LLC
# 8                                                Dell
# 9                                            HomeAway
# 10      Intersys:Big Data And Application Development
# 11                                               21CT
# 12                                             Gallup
# 13                                         Sense Corp
# 14                                             Gallup
# 15                                         Sense Corp
# 16                                           MaxPoint
# 17                      Atlantic Engineering Services
# 18                                    Express Scripts
# 19                                Precision For Value
#
#                                           description  \
# 0   How a Data Scientist works. As a Data Scientis...
# 1   Work closely with stakeholders on the data dem...
# 2   Senior Data Scientist. Mentor other data scien...
# 3   \nCreating and maintaining machine learning mo...
# 4   \nAutomatically find and interpret data rich s...
# 5   \nData Engineer position in the Data Science g...
# 6   \nData Engineer position in the Data Science g...
# 7   \nStrong grasp of data structures and algorith...
# 8   \nData Scientist - Round Rock, TX. Strong fami...
# 9   \nIf so, then HomeAway has a Data Scientist ro...
# 10  \nJr Data Scientist*. Jr Data Scientist Job De...
# 11  \nDeep learning, data mining, data fusion, mac...
# 12  \nGallup data scientists help clients effectiv...
# 13  Data analyst/data scientist role:. Perform dat...
# 14  Gallup data scientists help clients effectivel...
# 15  Data analyst/data scientist role:. Perform dat...
# 16  Senior Data Scientist. Mentor other data scien...
# 17  \nData entry of mathematical analysis for wire...
# 18  \nMapping qualitative data to quantitative dat...
# 19  \nAdministrative hospital data, Electronic hea...
#
#                                              location salary  \
# 0                                          Austin, TX    NaN
# 1                                          Austin, TX    NaN
# 2                                          Austin, TX    NaN
# 3                                          Austin, TX    NaN
# 4                                          Austin, TX    NaN
# 5                                    Austin, TX 78754    NaN
# 6                                    Austin, TX 78754    NaN
# 7                                    Austin, TX 78728    NaN
# 8                                Round Rock, TX 78664    NaN
# 9   Austin, TX 78704 (South Lamar-South Congress a...    NaN
# 10                                         Austin, TX    NaN
# 11                                         Austin, TX    NaN
# 12                                         Austin, TX    NaN
# 13                                         Austin, TX    NaN
# 14                                         Austin, TX    NaN
# 15                                         Austin, TX    NaN
# 16                                         Austin, TX    NaN
# 17  Austin, TX 78704 (South Lamar-South Congress a...    NaN
# 18                                         Austin, TX    NaN
# 19                                         Austin, TX    NaN
#
#                                                 title
# 0                                      Data Scientist
# 1                                       Data Engineer
# 2                               Senior Data Scientist
# 3     Blue Spark - Watson Cognitive Software Engineer
# 4                      Data Engineer / Data Scientist
# 5                                      Data Scientist
# 6                                      Data Scientist
# 7                          Machine Learning Scientist
# 8                        Data Scientist Round Rock TX
# 9                             Research Data Scientist
# 10                                  Jr Data Scientist
# 11                                 Research Scientist
# 12              Data Scientist – Predictive Analytics
# 13                                     Data Scientist
# 14              Data Scientist – Predictive Analytics
# 15                                     Data Scientist
# 16                              Senior Data Scientist
# 17  Make Ready Engineering Specialist (data analys...
# 18                  Senior Quantitative UX Researcher
# 19              Research Scientist, Advanced Modeling

# %%
#check if salary_average works

salary = results['salary'][10]
# salary = re.sub('$|anmonthhur,', '', str(salary))
salary = salary_average(salary)
print(salary)
# Out:
# nan

# %%
#check if all my values are floats

da_list = []
for gabe in results['salary']:
    if pd.isnull(gabe) == False:
        da_list.append(gabe)
        
print(da_list)
# Out:
# [24.185, 4459.0, 5950.0, 8541.5, 4714.0, 27.96, 17.99, 3519.0, 150000.0, 6388.0, 8541.5, 65.0, 8124.5, 3935.0, 8541.5, 6666.0, 8541.5, 85000.0, 140000.0, 8333.0, 141158.0, 120000.0, 50794.0, 41000.0, 100000.0, 75.0, 94531.0, 60.0, 150000.0, 79247.0, 130000.0, 90000.0, 112500.0, 100000.0, 150000.0, 127500.0, 110000.0, 120000.0, 142500.0, 165000.0, 165000.0, 100000.0, 180000.0, 32.31, 110000.0, 120000.0, 138300.0, 175000.0, 140000.0, 120000.0, 155000.0, 140000.0, 132500.0, 95000.0, 85000.0, 85000.0, 105000.0, 71000.0, 200000.0, 140000.0, 150000.0, 132500.0, 122500.0, 185000.0]

# %%
#categorize hourly, monthly, salaries
results['hourly_salary'] = np.NaN
results['monthly_salary'] = np.NaN
results['annual_salary'] = np.NaN

for where, number in enumerate(results['salary']):
    if number < 200:
        results['hourly_salary'][where] = number
    elif number <= 10000: #check if this is fair, based on 8.5k type figures
        results['monthly_salary'][where] = number
    else:
        results['annual_salary'][where] = number
        
results.head(50)
# Out:
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                               company  \
# 0                                              Indeed
# 1                                              Indeed
# 2                                            MaxPoint
# 3                                                 IBM
# 4                                                 IBM
# 5                   Samsung Austin Semiconductor, LLC
# 6                                             Samsung
# 7                                Amazon Corporate LLC
# 8                                                Dell
# 9                                            HomeAway
# 10      Intersys:Big Data And Application Development
# 11                                               21CT
# 12                                             Gallup
# 13                                         Sense Corp
# 14                                             Gallup
# 15                                         Sense Corp
# 16                                           MaxPoint
# 17                      Atlantic Engineering Services
# 18                                    Express Scripts
# 19                                Precision For Value
# 20                                     City of Austin
# 21                                     Alcatel-Lucent
# 22                          Worldwide Clinical Trials
# 23                     The University of Texas System
# 24                                      Gartner, Inc.
# 25                      University of Texas at Austin
# 26                                             Micron
# 27                                             Indeed
# 28                                             Gallup
# 29                                             Indeed
# 30                                         Sense Corp
# 31                                           MaxPoint
# 32                                             NVIDIA
# 33                                        BazaarVoice
# 34                             Signature Science, LLC
# 35                                                IBM
# 36                                             NVIDIA
# 37                                     Alcatel-Lucent
# 38                                          SmarterHQ
# 39                                           Asuragen
# 40                                  RetailMeNot, Inc.
# 41                      University of Texas at Austin
# 42                                             Gallup
# 43                                             Indeed
# 44                                             Indeed
# 45                                         Sense Corp
# 46                                           MaxPoint
# 47                UT Health Science Center at Houston
# 48                  Texas Department of Public Safety
# 49                                Precision For Value
#
#                                           description  \
# 0   How a Data Scientist works. As a Data Scientis...
# 1   Work closely with stakeholders on the data dem...
# 2   Senior Data Scientist. Mentor other data scien...
# 3   \nCreating and maintaining machine learning mo...
# 4   \nAutomatically find and interpret data rich s...
# 5   \nData Engineer position in the Data Science g...
# 6   \nData Engineer position in the Data Science g...
# 7   \nStrong grasp of data structures and algorith...
# 8   \nData Scientist - Round Rock, TX. Strong fami...
# 9   \nIf so, then HomeAway has a Data Scientist ro...
# 10  \nJr Data Scientist*. Jr Data Scientist Job De...
# 11  \nDeep learning, data mining, data fusion, mac...
# 12  \nGallup data scientists help clients effectiv...
# 13  Data analyst/data scientist role:. Perform dat...
# 14  Gallup data scientists help clients effectivel...
# 15  Data analyst/data scientist role:. Perform dat...
# 16  Senior Data Scientist. Mentor other data scien...
# 17  \nData entry of mathematical analysis for wire...
# 18  \nMapping qualitative data to quantitative dat...
# 19  \nAdministrative hospital data, Electronic hea...
# 20  \n2 years experience in data statistical analy...
# 21  \nWorld-wide, our software helps service provi...
# 22  \nReview data, recognize and report inconsiste...
# 23  \nAssist in ongoing development of data wareho...
# 24  \nHypothesis formation and data identification...
# 25  \nData analysis for space weather remediation....
# 26  \nWorking knowledge of fundamental Computer Sc...
# 27  Work closely with stakeholders on the data dem...
# 28  Gallup data scientists help clients effectivel...
# 29  How a Data Scientist works. As a Data Scientis...
# 30  Data analyst/data scientist role:. Perform dat...
# 31  Senior Data Scientist. Mentor other data scien...
# 32  \nCompiler Machine Learning Verification Engin...
# 33  \nYou’ll extract key data and findings, define...
# 34  \nQuality Assurance Scientist - Summer Intern....
# 35  \nData analytics and modeling, data visualizat...
# 36  \nExperience in optimization, common CAD data ...
# 37  \nWorld-wide, our software helps service provi...
# 38  \nExperience working with data scientists a pl...
# 39  \nScientist I, Development*. Scientist I, Rese...
# 40  \nCollaborate effectively with engineers, data...
# 41  \nInvestigate new applications of GPS/GNSS rec...
# 42  Gallup data scientists help clients effectivel...
# 43  Work closely with stakeholders on the data dem...
# 44  How a Data Scientist works. As a Data Scientis...
# 45  Data analyst/data scientist role:. Perform dat...
# 46  Senior Data Scientist. Mentor other data scien...
# 47  \nFour (4) years of experience analyzing outco...
# 48  \nDevelop plans, policies, and procedures for ...
# 49  \nExperience in systematic reviews, designing,...
#
#                                              location  salary  \
# 0                                          Austin, TX     NaN
# 1                                          Austin, TX     NaN
# 2                                          Austin, TX     NaN
# 3                                          Austin, TX     NaN
# 4                                          Austin, TX     NaN
# 5                                    Austin, TX 78754     NaN
# 6                                    Austin, TX 78754     NaN
# 7                                    Austin, TX 78728     NaN
# 8                                Round Rock, TX 78664     NaN
# 9   Austin, TX 78704 (South Lamar-South Congress a...     NaN
# 10                                         Austin, TX     NaN
# 11                                         Austin, TX     NaN
# 12                                         Austin, TX     NaN
# 13                                         Austin, TX     NaN
# 14                                         Austin, TX     NaN
# 15                                         Austin, TX     NaN
# 16                                         Austin, TX     NaN
# 17  Austin, TX 78704 (South Lamar-South Congress a...     NaN
# 18                                         Austin, TX     NaN
# 19                                         Austin, TX     NaN
# 20                                         Austin, TX  24.185
# 21                                         Austin, TX     NaN
# 22                                         Austin, TX     NaN
# 23                                         Austin, TX    4459
# 24                                         Austin, TX     NaN
# 25                                         Austin, TX    5950
# 26                                         Austin, TX     NaN
# 27                                         Austin, TX     NaN
# 28                                         Austin, TX     NaN
# 29                                         Austin, TX     NaN
# 30                                         Austin, TX     NaN
# 31                                         Austin, TX     NaN
# 32                                         Austin, TX     NaN
# 33                                   Austin, TX 78746     NaN
# 34                  Austin, TX 78759 (Arboretum area)     NaN
# 35                                         Austin, TX     NaN
# 36                                         Austin, TX     NaN
# 37                                         Austin, TX     NaN
# 38                                         Austin, TX     NaN
# 39                                         Austin, TX     NaN
# 40                                         Austin, TX     NaN
# 41                                         Austin, TX  8541.5
# 42                                         Austin, TX     NaN
# 43                                         Austin, TX     NaN
# 44                                         Austin, TX     NaN
# 45                                         Austin, TX     NaN
# 46                                         Austin, TX     NaN
# 47                                         Austin, TX     NaN
# 48                                         Austin, TX    4714
# 49                                         Austin, TX     NaN
#
#                                                 title  hourly_salary  \
# 0                                      Data Scientist            NaN
# 1                                       Data Engineer            NaN
# 2                               Senior Data Scientist            NaN
# 3     Blue Spark - Watson Cognitive Software Engineer            NaN
# 4                      Data Engineer / Data Scientist            NaN
# 5                                      Data Scientist            NaN
# 6                                      Data Scientist            NaN
# 7                          Machine Learning Scientist            NaN
# 8                        Data Scientist Round Rock TX            NaN
# 9                             Research Data Scientist            NaN
# 10                                  Jr Data Scientist            NaN
# 11                                 Research Scientist            NaN
# 12              Data Scientist – Predictive Analytics            NaN
# 13                                     Data Scientist            NaN
# 14              Data Scientist – Predictive Analytics            NaN
# 15                                     Data Scientist            NaN
# 16                              Senior Data Scientist            NaN
# 17  Make Ready Engineering Specialist (data analys...            NaN
# 18                  Senior Quantitative UX Researcher            NaN
# 19              Research Scientist, Advanced Modeling            NaN
# 20  MuniProg, Research Analyst (Temp) Paraprofessi...         24.185
# 21                           Software Developer Co-op            NaN
# 22                                 Automation Analyst            NaN
# 23                     Institutional Research Analyst            NaN
# 24        Content Marketing Analyst, Gartner Research            NaN
# 25  Engineering Scientist Associate - R and D Soft...            NaN
# 26                    Principal Software Engineer Job            NaN
# 27                                      Data Engineer            NaN
# 28              Data Scientist – Predictive Analytics            NaN
# 29                                     Data Scientist            NaN
# 30                                     Data Scientist            NaN
# 31                              Senior Data Scientist            NaN
# 32    Compiler Machine Learning Verification Engineer            NaN
# 33                                  Sr. UX Researcher            NaN
# 34           Internship - Quality Assurance Scientist            NaN
# 35  Worldwide CoC Team –Data Scientist and Managin...            NaN
# 36             Machine Learning for VLSI CAD Engineer            NaN
# 37                                  PMO CNO CXS Co-op            NaN
# 38                          Junior Back-End Developer            NaN
# 39                                 Research Scientist            NaN
# 40                                 Sr. Data Scientist            NaN
# 41               Engineering Scientist - GNSS Analyst            NaN
# 42              Data Scientist – Predictive Analytics            NaN
# 43                                      Data Engineer            NaN
# 44                                     Data Scientist            NaN
# 45                                     Data Scientist            NaN
# 46                              Senior Data Scientist            NaN
# 47                          Sr. Statistician - Austin            NaN
# 48              Statistician III-IV, HSOC, THP-Austin            NaN
# 49         Research Scientist, HEOR, Health Analytics            NaN
#
#     monthly_salary  annual_salary
# 0              NaN            NaN
# 1              NaN            NaN
# 2              NaN            NaN
# 3              NaN            NaN
# 4              NaN            NaN
# 5              NaN            NaN
# 6              NaN            NaN
# 7              NaN            NaN
# 8              NaN            NaN
# 9              NaN            NaN
# 10             NaN            NaN
# 11             NaN            NaN
# 12             NaN            NaN
# 13             NaN            NaN
# 14             NaN            NaN
# 15             NaN            NaN
# 16             NaN            NaN
# 17             NaN            NaN
# 18             NaN            NaN
# 19             NaN            NaN
# 20             NaN            NaN
# 21             NaN            NaN
# 22             NaN            NaN
# 23          4459.0            NaN
# 24             NaN            NaN
# 25          5950.0            NaN
# 26             NaN            NaN
# 27             NaN            NaN
# 28             NaN            NaN
# 29             NaN            NaN
# 30             NaN            NaN
# 31             NaN            NaN
# 32             NaN            NaN
# 33             NaN            NaN
# 34             NaN            NaN
# 35             NaN            NaN
# 36             NaN            NaN
# 37             NaN            NaN
# 38             NaN            NaN
# 39             NaN            NaN
# 40             NaN            NaN
# 41          8541.5            NaN
# 42             NaN            NaN
# 43             NaN            NaN
# 44             NaN            NaN
# 45             NaN            NaN
# 46             NaN            NaN
# 47             NaN            NaN
# 48          4714.0            NaN
# 49             NaN            NaN

# %% [markdown]
# ### Save your results as a CSV

# %%
results.to_csv("indeed_ds_data6.csv", encoding='utf8')
