# %% [markdown]
# # Web Scraping for Indeed.com & Predicting Salaries

# %% [markdown]
# In this project, we will practice two major skills: collecting data by scraping a website and then building a binary predictor with Logistic Regression.
#
# We are going to collect salary information on data science jobs in a variety of markets. Then using the location, title and summary of the job we will attempt to predict the salary of the job. For job posting sites, this would be extraordinarily useful. While most listings DO NOT come with salary information (as you will see in this exercise), being to able extrapolate or predict the expected salaries from other listings can help guide negotiations.
#
# Normally, we could use regression for this task; however, we will convert this problem into classification and use Logistic Regression.
#
# - Question: Why would we want this to be a classification problem?
# - Answer: While more precision may be better, there is a fair amount of natural variance in job salaries - predicting a range be may be useful.
#
# Therefore, the first part of the assignment will be focused on scraping Indeed.com. In the second, we'll focus on using listings with salary information to build a model and predict additional salaries.

# %% [markdown]
# ### Scraping job listings from Indeed.com

# %% [markdown]
# We will be scraping job listings from Indeed.com using BeautifulSoup. Luckily, Indeed.com is a simple text page where we can easily find relevant entries.
#
# First, look at the source of an Indeed.com page: (http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10")
#
# Notice, each job listing is underneath a `div` tag with a class name of `result`. We can use BeautifulSoup to extract those.

# %% [markdown]
# #### Setup a request (using `requests`) to the URL below. Use BeautifulSoup to parse the page and extract all results (HINT: Look for div tags with class name result)

# %%
URL = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"

# %%
import requests
import bs4
from bs4 import BeautifulSoup
from __future__ import division, print_function

import requests
from bs4 import BeautifulSoup
from selenium import webdriver

import pandas as pd
import numpy as np

from IPython.core.display import HTML, Image

# %%
r = requests.get(URL)
indeed = BeautifulSoup(r.content, "lxml")

# %%
col_list = ['location', 'title', 'company', 'salary', 'description']

def prime_time(soup):
    location_list = []
    role_title_list = []
    company_list = []
    salaries = []
    summaries = []

    for t in soup.findAll("div", class_='result'):
#     url = t.find('a', 
#     url_list.append(url) #---- can return to this later
        location = t.find('span', class_='location').text # WORKS!
        location_list.append(location)
        title = t.find('a')['title'] # WORKS!
        role_title_list.append(title)
        company_name = t.find('span', class_='company').text
        company_name = company_name.strip('\n')
        company_list.append(company_name)
        salary = t.find('nobr' or 'sjcl')   #('nobr').next_sibling sjcl
        salaries.append(salary)
        summary = t.find('span', class_="summary").text
        summaries.append(summary)
    
    results = zip(location_list, role_title_list, company_list, salaries, summaries)
    results = pd.DataFrame(results)
    results.columns = col_list
    return(results)

# indeed_results = prime_time(indeed)
# indeed_output = pd.DataFrame(indeed_results)
# indeed_output.head()

# %% [markdown]
# Let's look at one result more closely. A single `result` looks like
#
# ```
# <div class=" row result" data-jk="2480d203f7e97210" data-tn-component="organicJob" id="p_2480d203f7e97210" itemscope="" itemtype="http://schema.org/JobPosting">
# <h2 class="jobtitle" id="jl_2480d203f7e97210">
# <a class="turnstileLink" data-tn-element="jobTitle" onmousedown="return rclk(this,jobmap[0],1);" rel="nofollow" target="_blank" title="AVP/Quantitative Analyst">AVP/Quantitative Analyst</a>
# </h2>
# <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
# <span itemprop="name">
# <a href="/cmp/Alliancebernstein?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=2480d203f7e97210&amp;jcid=b374f2a780e04789" target="_blank">
#     AllianceBernstein</a></span>
# </span>
# <tr>
# <td class="snip">
# <nobr>$117,500 - $127,500 a year</nobr>
# <div>
# <span class="summary" itemprop="description">
# C onduct quantitative and statistical research as well as portfolio management for various investment portfolios. Collaborate with Quantitative Analysts and</span>
# </div>
# </div>
# </td>
# </tr>
# </table>
# </div>
# ```
#
# While this has some more verbose elements removed, we can see that there is some structure to the above:
# - The salary is available in a `nobr` element inside of a `td` element with `class='snip`.
# - The title of a job is in a link with class set to `jobtitle` and a `data-tn-element="jobTitle`.
# - The location is set in a `span` with `class='location'`.
# - The company is set in a `span` with `class='company'`.

# %% [markdown]
# ### Write 4 functions to extract each item: location, company, job, and salary.
#
# example:
# ```python
# def extract_location_from_result(result):
#     return result.find ...
# ```
#
#
# - Make sure these functions are robust and can handle cases where the data/field may not be available.
# - Test the functions on the results above
# - Include any other features you may want to use later (e.g. summary, #of reviews...)

# %% [markdown]
# Now, to scale up our scraping, we need to accumulate more results. We can do this by examining the URL above.
#
# - "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"
#
# There are two query parameters here we can alter to collect more results, the `l=New+York` and the `start=10`. The first controls the location of the results (so we can try a different city). The second controls where in the results to start and gives 10 results (thus, we can keep incrementing by 10 to go further in the list).

# %% [markdown]
# ### Complete the following code to collect results from multiple cities and starting points.
# - Indeed.com only has salary information for an estimated 20% of job postings. You may want to add other cities to the list below to gather more data.
# - Remember to convert your salary to U.S. Dollars to match the other cities if the currency is different

# %%
import numpy as np

url_template_first = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l={}"
url_template = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l={}&start={}"

max_results_per_city = 100
col_list = ['location', 'title', 'company', 'salary', 'description']
sample_vals = [np.NaN,np.NaN,np.NaN,np.NaN,np.NaN]

d = dict.fromkeys(col_list, sample_vals)
results = pd.DataFrame(d)   # trying to make the columns the same so I can merge later


for city in set(['New+York', 'Chicago', 'San+Francisco', 'Austin', 'Atlanta','Boston','Berkeley',\
                 'Oakland', 'Raleigh', 'Brooklyn','Queens', 'St+Louis','Asheville','Portland','Maine',\
                 'Baltimore', 'Boulder', 'Denver', 'Reno', 'Des Moines', 'Cleveland',  'Detroit', 'Kansas+City',\
                 'Dallas', 'Washington+DC', 'Nashville', 'Seattle', 'Salt+Lake+City', 'Sacramento', 'Minneapolis', 'St+Paul']): 
    for start in range(0, max_results_per_city, 10):
        foo = requests.get(url_template.format(city, start))
        indeed = BeautifulSoup(foo.content, "lxml")
        indeed_results = prime_time(indeed)
        indeed_results.columns = col_list
        
        results = pd.concat([indeed_results, results], ignore_index=True)
    first = requests.get(url_template_first.format(city)) #GETS THE FIRST PAGE OF RESULTS, MISSED
    first_indeed = BeautifulSoup(first.content, "lxml")
    first_indeed_results = prime_time(first_indeed)
    first_indeed_results.columns = col_list
    results = pd.concat([first_indeed_results, results], ignore_index=True)
results.head(50)
# Out:
#                                        company  \
# 0                          AdvancePierre Foods
# 1                               U.S. Air Force
# 2                                 Sensory, Inc
# 3                                Etech Hi Inc.
# 4                                      Xpandit
# 5            Maine Health Management Coalition
# 6                                        Alere
# 7                                        Alere
# 8                           IDEXX Laboratories
# 9                           IDEXX Laboratories
# 10                      Dept. Marine Resources
# 11                         KP Recruiting Group
# 12                           Dept. Agriculture
# 13           Maine Health Management Coalition
# 14                                Sensory, Inc
# 15                   Amazon Web Services, Inc.
# 16                          IDEXX Laboratories
# 17                         AdvancePierre Foods
# 18                                       Alere
# 19                               Staff Hunters
# 20      Maine Molecular Quality Controls, Inc.
# 21                    IDEXX Laboratories, Inc.
# 22                      Department of the Navy
# 23                                       Alere
# 24                      Department of the Navy
# 25                                    CashStar
# 26                        Amazon Corporate LLC
# 27                        Amazon Corporate LLC
# 28           Maine Health Management Coalition
# 29                                Sensory, Inc
# 30                   Amazon Web Services, Inc.
# 31                          IDEXX Laboratories
# 32                         AdvancePierre Foods
# 33                                       Alere
# 34                               Staff Hunters
# 35      Maine Molecular Quality Controls, Inc.
# 36                    IDEXX Laboratories, Inc.
# 37                      Department of the Navy
# 38                                       Alere
# 39                      Department of the Navy
# 40                                    CashStar
# 41                        Amazon Corporate LLC
# 42                        Amazon Corporate LLC
# 43           Maine Health Management Coalition
# 44                              U.S. Air Force
# 45                    Ricerca Biosciences, LLC
# 46                          IDEXX Laboratories
# 47                         AdvancePierre Foods
# 48                                       Alere
# 49                               Staff Hunters
#
#                                           description  \
# 0   Lead multiple complex development projects usi...
# 1   Help Airman get the proper healthcare they nee...
# 2   16-01 - Research Scientist – BOULDER, CO. As a...
# 3   \nData analyst, data programmer, data scientis...
# 4   \nBut, more than just a “Buzzword Guy”, we see...
# 5   \nUnderstands mapping of data elements to anal...
# 6   \nAdvanced knowledge of a variety of statistic...
# 7   \nConducts and interprets data. Phases of a pr...
# 8   \nPrepares materials, performs experiments, ga...
# 9   \nWill interpret internally and externally gen...
# 10  \nMARINE RESOURCES SCIENTIST I. The incumbent ...
# 11  \nWill interpret internally and externally gen...
# 12  \nCollaborating with scientists in other state...
# 13  Understands mapping of data elements to analyt...
# 14  15-02 - Research Scientist (Emerging Technolog...
# 15  Solid communication and data presentation skil...
# 16  \nSeeking an Associate Scientist to join a gro...
# 17  \nLead multiple complex development projects u...
# 18  \nDirect and oversee CRO activities including ...
# 19  \nEvaluate data from a variety of sources to d...
# 20  \nProducts through use of public data bases. W...
# 21  \nSeeking an Associate Scientist to join a gro...
# 22  \nFrom pipefitters to accountants, scientists ...
# 23  \nWorks in a multidisciplinary team with other...
# 24  \nEvaluating exposure data, surveys, work prac...
# 25  \nWork with engineering team and data scientis...
# 26  As a Principal, you will provide leadership to...
# 27  Are you interested in building data pipelines ...
# 28  Understands mapping of data elements to analyt...
# 29  16-01 - Research Scientist – BOULDER, CO. As a...
# 30  Solid communication and data presentation skil...
# 31  \nSeeking an Associate Scientist to join a gro...
# 32  \nLead multiple complex development projects u...
# 33  \nDirect and oversee CRO activities including ...
# 34  \nEvaluate data from a variety of sources to d...
# 35  \nProducts through use of public data bases. W...
# 36  \nSeeking an Associate Scientist to join a gro...
# 37  \nFrom pipefitters to accountants, scientists ...
# 38  \nWorks in a multidisciplinary team with other...
# 39  \nEvaluating exposure data, surveys, work prac...
# 40  \nWork with engineering team and data scientis...
# 41  As a Principal, you will provide leadership to...
# 42  Are you interested in building data pipelines ...
# 43  Understands mapping of data elements to analyt...
# 44  Help Airman get the proper healthcare they nee...
# 45  Review data for technical content and regulato...
# 46  \nSeeking an Associate Scientist to join a gro...
# 47  \nLead multiple complex development projects u...
# 48  \nDirect and oversee CRO activities including ...
# 49  \nEvaluate data from a variety of sources to d...
#
#                                   location  \
# 0                             Portland, ME
# 1                            United States
# 2                            United States
# 3                               Brewer, ME
# 4                               Lisbon, ME
# 5                              Topsham, ME
# 6                          Scarborough, ME
# 7                          Scarborough, ME
# 8                      Westbrook, ME 04092
# 9                      Westbrook, ME 04092
# 10                             Augusta, ME
# 11                           Westbrook, ME
# 12                             Augusta, ME
# 13                             Topsham, ME
# 14                           United States
# 15                           United States
# 16                     Westbrook, ME 04092
# 17                            Portland, ME
# 18                         Scarborough, ME
# 19                           Westbrook, ME
# 20                                Saco, ME
# 21                     Westbrook, ME 04092
# 22           Portsmouth Naval Shipyard, ME
# 23                         Scarborough, ME
# 24                             Kittery, ME
# 25  Portland, ME 04101 (West Bayside area)
# 26                           United States
# 27                           United States
# 28                             Topsham, ME
# 29                           United States
# 30                           United States
# 31                     Westbrook, ME 04092
# 32                            Portland, ME
# 33                         Scarborough, ME
# 34                           Westbrook, ME
# 35                                Saco, ME
# 36                     Westbrook, ME 04092
# 37           Portsmouth Naval Shipyard, ME
# 38                         Scarborough, ME
# 39                             Kittery, ME
# 40  Portland, ME 04101 (West Bayside area)
# 41                           United States
# 42                           United States
# 43                             Topsham, ME
# 44                           United States
# 45                           United States
# 46                     Westbrook, ME 04092
# 47                            Portland, ME
# 48                         Scarborough, ME
# 49                           Westbrook, ME
#
#                                     salary  \
# 0                                     None
# 1                                     None
# 2                                     None
# 3             <nobr>$120,000 a year</nobr>
# 4                                     None
# 5                                     None
# 6                                     None
# 7                                     None
# 8                                     None
# 9                                     None
# 10   <nobr>$39,374 - $53,290 a year</nobr>
# 11                                    None
# 12   <nobr>$42,099 - $57,158 a year</nobr>
# 13                                    None
# 14                                    None
# 15                                    None
# 16                                    None
# 17                                    None
# 18                                    None
# 19                                    None
# 20                                    None
# 21                                    None
# 22  <nobr>$77,744 - $101,067 a year</nobr>
# 23                                    None
# 24  <nobr>$64,862 - $101,067 a year</nobr>
# 25                                    None
# 26                                    None
# 27                                    None
# 28                                    None
# 29                                    None
# 30                                    None
# 31                                    None
# 32                                    None
# 33                                    None
# 34                                    None
# 35                                    None
# 36                                    None
# 37  <nobr>$77,744 - $101,067 a year</nobr>
# 38                                    None
# 39  <nobr>$64,862 - $101,067 a year</nobr>
# 40                                    None
# 41                                    None
# 42                                    None
# 43                                    None
# 44                                    None
# 45                                    None
# 46                                    None
# 47                                    None
# 48                                    None
# 49                                    None
#
#                                                 title
# 0   Food Scientist-Poultry Protein, Culinary Conce...
# 1                       Biomedical Laboratory Officer
# 2   Research Scientist [Exp. with Machine Learning...
# 3                                 Data Analyst II/III
# 4                                   Big Data Engineer
# 5                             Senior Research Analyst
# 6                                        Statistician
# 7                        Scientist I (Research Assoc)
# 8                               Associate Scientist I
# 9                                    Systems Engineer
# 10                       MARINE RESOURCES SCIENTIST I
# 11                     Systems Engineer-Biotechnology
# 12                                   SENIOR GEOLOGIST
# 13                            Senior Research Analyst
# 14  Research Scientist-Emerging Technology [3 to 5...
# 15  Principal Research Scientist, Forecasting and ...
# 16   Associate Scientist/Engineer – Systems Chemistry
# 17  Food Scientist-Poultry Protein, Culinary Conce...
# 18      Director, Clinical Affairs Infectious Disease
# 19                                   Systems Engineer
# 20           R & D Scientist II MOLECULAR DIAGNOSTICS
# 21             Associate Scientist/Engineer – Systems
# 22                       QUALITY ASSURANCE SPECIALIST
# 23                  Technical Manufacturing Chemist I
# 24          PHYSICAL SCIENCE TECHNICIAN (INSTRUCTOR),
# 25  Director, Product Management - Risk Solutions ...
# 26  Principal Data Scientist - Consumer Website- R...
# 27  Software Development Engineer, Big Data- Reloc...
# 28                            Senior Research Analyst
# 29  Research Scientist [Exp. with Machine Learning...
# 30  Principal Research Scientist, Forecasting and ...
# 31   Associate Scientist/Engineer – Systems Chemistry
# 32  Food Scientist-Poultry Protein, Culinary Conce...
# 33      Director, Clinical Affairs Infectious Disease
# 34                                   Systems Engineer
# 35           R & D Scientist II MOLECULAR DIAGNOSTICS
# 36             Associate Scientist/Engineer – Systems
# 37                       QUALITY ASSURANCE SPECIALIST
# 38                  Technical Manufacturing Chemist I
# 39          PHYSICAL SCIENCE TECHNICIAN (INSTRUCTOR),
# 40  Director, Product Management - Risk Solutions ...
# 41  Principal Data Scientist - Consumer Website- R...
# 42  Software Development Engineer, Big Data- Reloc...
# 43                            Senior Research Analyst
# 44                      Biomedical Laboratory Officer
# 45  Analytical Scientist (LC-MSMS / NMR Small Mole...
# 46   Associate Scientist/Engineer – Systems Chemistry
# 47  Food Scientist-Poultry Protein, Culinary Conce...
# 48      Director, Clinical Affairs Infectious Disease
# 49                                   Systems Engineer

# %% [markdown]
# #### Use the functions you wrote above to parse out the 4 fields - location, title, company and salary. Create a dataframe from the results with those 4 columns.

# %% [markdown]
# Lastly, we need to clean up salary data.
# 1. Some of the salaries are not yearly but hourly, these will be useful to us for now 2. The salaries are given as text and usually with ranges.
#
# #### Filter out the salaries that are not yearly (filter those that refer to hour)

# %%
import numpy as np


            
            
# results['annual_salary'] = results['salary']

results_nan = results.replace({None:np.NaN})
results = results_nan
results.head(10)
# Out:
#                                  company  \
# 0                    AdvancePierre Foods
# 1                         U.S. Air Force
# 2                           Sensory, Inc
# 3                          Etech Hi Inc.
# 4                                Xpandit
# 5      Maine Health Management Coalition
# 6                                  Alere
# 7                                  Alere
# 8                     IDEXX Laboratories
# 9                     IDEXX Laboratories
#
#                                          description             location  \
# 0  Lead multiple complex development projects usi...         Portland, ME
# 1  Help Airman get the proper healthcare they nee...        United States
# 2  16-01 - Research Scientist – BOULDER, CO. As a...        United States
# 3  \nData analyst, data programmer, data scientis...           Brewer, ME
# 4  \nBut, more than just a “Buzzword Guy”, we see...           Lisbon, ME
# 5  \nUnderstands mapping of data elements to anal...          Topsham, ME
# 6  \nAdvanced knowledge of a variety of statistic...      Scarborough, ME
# 7  \nConducts and interprets data. Phases of a pr...      Scarborough, ME
# 8  \nPrepares materials, performs experiments, ga...  Westbrook, ME 04092
# 9  \nWill interpret internally and externally gen...  Westbrook, ME 04092
#
#                          salary  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3  <nobr>$120,000 a year</nobr>
# 4                           NaN
# 5                           NaN
# 6                           NaN
# 7                           NaN
# 8                           NaN
# 9                           NaN
#
#                                                title
# 0  Food Scientist-Poultry Protein, Culinary Conce...
# 1                      Biomedical Laboratory Officer
# 2  Research Scientist [Exp. with Machine Learning...
# 3                                Data Analyst II/III
# 4                                  Big Data Engineer
# 5                            Senior Research Analyst
# 6                                       Statistician
# 7                       Scientist I (Research Assoc)
# 8                              Associate Scientist I
# 9                                   Systems Engineer

# %%
def salary_clean(string):
    if type(string) == float:
        return np.NaN
    elif string == np.NaN:
        return np.NaN
    else:
        try:
            return((string.split("<nobr>")[1]).split("</nobr>")[0])
        except (TypeError, IndexError): 
            return np.NaN

for b in range(len(results['salary'])):
    results['salary'][b] = salary_clean(str(results['salary'][b]))
    

results.head(15)
# Out:
#                                   company  \
# 0                     AdvancePierre Foods
# 1                          U.S. Air Force
# 2                            Sensory, Inc
# 3                           Etech Hi Inc.
# 4                                 Xpandit
# 5       Maine Health Management Coalition
# 6                                   Alere
# 7                                   Alere
# 8                      IDEXX Laboratories
# 9                      IDEXX Laboratories
# 10                 Dept. Marine Resources
# 11                    KP Recruiting Group
# 12                      Dept. Agriculture
# 13      Maine Health Management Coalition
# 14                           Sensory, Inc
#
#                                           description             location  \
# 0   Lead multiple complex development projects usi...         Portland, ME
# 1   Help Airman get the proper healthcare they nee...        United States
# 2   16-01 - Research Scientist – BOULDER, CO. As a...        United States
# 3   \nData analyst, data programmer, data scientis...           Brewer, ME
# 4   \nBut, more than just a “Buzzword Guy”, we see...           Lisbon, ME
# 5   \nUnderstands mapping of data elements to anal...          Topsham, ME
# 6   \nAdvanced knowledge of a variety of statistic...      Scarborough, ME
# 7   \nConducts and interprets data. Phases of a pr...      Scarborough, ME
# 8   \nPrepares materials, performs experiments, ga...  Westbrook, ME 04092
# 9   \nWill interpret internally and externally gen...  Westbrook, ME 04092
# 10  \nMARINE RESOURCES SCIENTIST I. The incumbent ...          Augusta, ME
# 11  \nWill interpret internally and externally gen...        Westbrook, ME
# 12  \nCollaborating with scientists in other state...          Augusta, ME
# 13  Understands mapping of data elements to analyt...          Topsham, ME
# 14  15-02 - Research Scientist (Emerging Technolog...        United States
#
#                       salary  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3            $120,000 a year
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10  $39,374 - $53,290 a year
# 11                       NaN
# 12  $42,099 - $57,158 a year
# 13                       NaN
# 14                       NaN
#
#                                                 title
# 0   Food Scientist-Poultry Protein, Culinary Conce...
# 1                       Biomedical Laboratory Officer
# 2   Research Scientist [Exp. with Machine Learning...
# 3                                 Data Analyst II/III
# 4                                   Big Data Engineer
# 5                             Senior Research Analyst
# 6                                        Statistician
# 7                        Scientist I (Research Assoc)
# 8                               Associate Scientist I
# 9                                    Systems Engineer
# 10                       MARINE RESOURCES SCIENTIST I
# 11                     Systems Engineer-Biotechnology
# 12                                   SENIOR GEOLOGIST
# 13                            Senior Research Analyst
# 14  Research Scientist-Emerging Technology [3 to 5...

# %%
# print(results['salary'].isnull().value_counts()) #only 62 salaries in here it appears

# %% [markdown]
# #### Write a function that takes a salary string and converts it to a number, averaging a salary range if necessary

# %%
import re
import string 

def salarizer(salary):  
    if pd.isnull(salary) == False:
        salary = salary.translate(None, "$|anmonthhurye, ")
        return(salary) # test line -- cut interior function to split/ average and moved outside
    else:
        return np.NaN

    


def salary_average(salary): 
    float_sal_list = []
    try:
        salary_str = str(salary)
        sal_list = str.split(salary_str, "-")
        for item in sal_list:
            try:
                float_sal_list.append(float(item))
            except ValueError:
                return salary
        if len(float_sal_list) > 1:
            avg_sal = sum(float_sal_list)/float(len(float_sal_list))
            return(avg_sal)
        else:
            return float(salary)
    except IndexError:
        return np.NaN
    

    
for hannah in range(len(results['salary'])):
    results['salary'][hannah] = salarizer(results['salary'][hannah])
    results['salary'][hannah] = salary_average(results['salary'][hannah])
results.head(20)
# Out:
#                                   company  \
# 0                     AdvancePierre Foods
# 1                          U.S. Air Force
# 2                            Sensory, Inc
# 3                           Etech Hi Inc.
# 4                                 Xpandit
# 5       Maine Health Management Coalition
# 6                                   Alere
# 7                                   Alere
# 8                      IDEXX Laboratories
# 9                      IDEXX Laboratories
# 10                 Dept. Marine Resources
# 11                    KP Recruiting Group
# 12                      Dept. Agriculture
# 13      Maine Health Management Coalition
# 14                           Sensory, Inc
# 15              Amazon Web Services, Inc.
# 16                     IDEXX Laboratories
# 17                    AdvancePierre Foods
# 18                                  Alere
# 19                          Staff Hunters
#
#                                           description             location  \
# 0   Lead multiple complex development projects usi...         Portland, ME
# 1   Help Airman get the proper healthcare they nee...        United States
# 2   16-01 - Research Scientist – BOULDER, CO. As a...        United States
# 3   \nData analyst, data programmer, data scientis...           Brewer, ME
# 4   \nBut, more than just a “Buzzword Guy”, we see...           Lisbon, ME
# 5   \nUnderstands mapping of data elements to anal...          Topsham, ME
# 6   \nAdvanced knowledge of a variety of statistic...      Scarborough, ME
# 7   \nConducts and interprets data. Phases of a pr...      Scarborough, ME
# 8   \nPrepares materials, performs experiments, ga...  Westbrook, ME 04092
# 9   \nWill interpret internally and externally gen...  Westbrook, ME 04092
# 10  \nMARINE RESOURCES SCIENTIST I. The incumbent ...          Augusta, ME
# 11  \nWill interpret internally and externally gen...        Westbrook, ME
# 12  \nCollaborating with scientists in other state...          Augusta, ME
# 13  Understands mapping of data elements to analyt...          Topsham, ME
# 14  15-02 - Research Scientist (Emerging Technolog...        United States
# 15  Solid communication and data presentation skil...        United States
# 16  \nSeeking an Associate Scientist to join a gro...  Westbrook, ME 04092
# 17  \nLead multiple complex development projects u...         Portland, ME
# 18  \nDirect and oversee CRO activities including ...      Scarborough, ME
# 19  \nEvaluate data from a variety of sources to d...        Westbrook, ME
#
#      salary                                              title
# 0       NaN  Food Scientist-Poultry Protein, Culinary Conce...
# 1       NaN                      Biomedical Laboratory Officer
# 2       NaN  Research Scientist [Exp. with Machine Learning...
# 3    120000                                Data Analyst II/III
# 4       NaN                                  Big Data Engineer
# 5       NaN                            Senior Research Analyst
# 6       NaN                                       Statistician
# 7       NaN                       Scientist I (Research Assoc)
# 8       NaN                              Associate Scientist I
# 9       NaN                                   Systems Engineer
# 10    46332                       MARINE RESOURCES SCIENTIST I
# 11      NaN                     Systems Engineer-Biotechnology
# 12  49628.5                                   SENIOR GEOLOGIST
# 13      NaN                            Senior Research Analyst
# 14      NaN  Research Scientist-Emerging Technology [3 to 5...
# 15      NaN  Principal Research Scientist, Forecasting and ...
# 16      NaN   Associate Scientist/Engineer – Systems Chemistry
# 17      NaN  Food Scientist-Poultry Protein, Culinary Conce...
# 18      NaN      Director, Clinical Affairs Infectious Disease
# 19      NaN                                   Systems Engineer

# %%
#check if salary_average works

salary = results['salary'][10]
# salary = re.sub('$|anmonthhur,', '', str(salary))
salary = salary_average(salary)
print(salary)
# Out:
# 46332.0

# %%
#check if all my values are floats

da_list = []
for gabe in results['salary']:
    if pd.isnull(gabe) == False:
        da_list.append(gabe)
        
print(da_list)
# Out:
# [120000.0, 46332.0, 49628.5, 89405.5, 82964.5, 89405.5, 82964.5, 89405.5, 82964.5, 89405.5, 82964.5, 89405.5, 82964.5, 89405.5, 82964.5, 89405.5, 82964.5, 89405.5, 82964.5, 89405.5, 82964.5, 120000.0, 46332.0, 49628.5, 110000.0, 120000.0, 5438.5, 165000.0, 165000.0, 100000.0, 160000.0, 84649.0, 137500.0, 32.31, 180000.0, 110000.0, 120000.0, 78195.5, '95d', 5790.0, 5790.0, 2864.0, 3306.5, 2864.0, 25.24, 3306.5, 20.0, 32.215, 60000.0, 15.0, 42840.0, 15.0, 78195.5, 25.0, 15.0, 155000.0, 31.189999999999998, 76856.5, 36.065, 110000.0, 43014.5, 103014.0, 22.825, 38.365, 31.189999999999998, 76856.5, 36.065, 127500.0, 110000.0, 240000.0, 130000.0, 112500.0, 150000.0, 90000.0, 100000.0, 100000.0, 127500.0, 110000.0, 16.0, 16.0, 140000.0, 17.17, 140000.0, 23.36, 68216.0, 110000.0, 28.525, 30000.0, 190000.0, 58175.5, 50112.0, 80000.0, 78483.0, 54351.5, 140000.0, 50508.0, 67373.5, 65643.5, 46332.0, 107500.0, 78483.0, 43123.5, 48201.0, 60934.5, 28.525, 30000.0, 190000.0, 58175.5, 50112.0, 165000.0, 130000.0, 122500.0, 30.0, 51363.0, 132500.0, 185000.0, 130000.0, 110000.0, 40.0, 58442.0, 150000.0, 20.65, 150000.0, 46000.0, 34.0, 76215.0, 125000.0, 70000.0, 46000.0, 20.0, 20.65, 20.65, 130000.0, 110000.0, 116850.0, 120000.0, 98642.0, 86930.5, 140000.0, 105969.5, 127500.0, 170000.0, 98642.0, 95.0, 101701.5, 101701.5, 116850.0, 120000.0, 98642.0, 51438.0, 127968.0, 77500.0, 52842.0, 52842.0, 52842.0, 61183.0, 52842.0, 50439.5, 51438.0, 52842.0, 52842.0, 51438.0, 150000.0, 150000.0, 55.0, 55.0, 21.0, 21.0, 21.0, 21.26, 21.26, 21.26, 155000.0, 15.0, 11.965, 155000.0, 130000.0, 165000.0, 97866.5, 122500.0, 130000.0, 75065.0, 132500.0, 53.565, 51363.0, 185000.0, 150000.0, 75.0, 120000.0, 33400.0, 56200.0, 41000.0, 141158.0, 50794.0, 79247.0, 100000.0, 94531.0, 155000.0, 60.0, 150000.0, 75.0, 110000.0, 137500.0, 120000.0, 32.31, 142500.0, 84649.0, 3850.0, 165000.0, 165000.0, 100000.0, 160000.0, 180000.0, 110000.0, 137500.0, 120000.0, 32.31, 11.995000000000001, 48904.0, 22.085, 65060.0, 9350.0, 135000.0, 4018.5, 120000.0, 120000.0, 150000.0, 190000.0, 55.0, 130000.0, 165000.0, 130000.0, 122500.0, 132500.0, 51363.0, 185000.0, 70.0, 5285.5, 58000.0, 112500.0, 25.0, 95000.0, 130000.0, 70.0, 5285.5, 85000.0, 5950.0, 85000.0, 8541.5, 4714.0, 65.0, 17.99, 3519.0, 24.185, 6806.0, 150000.0, 6388.0, 8124.5, 8541.5, 8541.5, 8541.5, 27.96, 8333.0, 6666.0, 140000.0, 85000.0, 26.57, 87792.0, '475wk', 68983.5, 27000.0, 10.0, 75000.0, 110000.0, 22.825, 38.365, 43014.5, 103014.0, 36.065, 31.189999999999998, 76856.5, 10.0, 44250.0, 68983.5, 26.57, 87792.0, 130000.0, '475wk', 66654.0, 93645.0, 75000.0, 110000.0, 120000.0, 32.31, 142500.0, 137500.0, 165000.0, 100000.0, 165000.0, 160000.0, 180000.0, 110000.0, 120000.0, 71000.0, 95000.0, 140000.0, 120000.0, 125000.0, 95000.0, 85000.0, 120000.0, 150000.0, 155000.0, 132500.0, 105000.0, 71000.0, 95000.0, 24.5, 24.5, 24.5, 24.5, 24.5, 23.0, 124000.0]

# %%
#categorize hourly, monthly, salaries
results['hourly_salary'] = np.NaN
results['monthly_salary'] = np.NaN
results['annual_salary'] = np.NaN

for where, number in enumerate(results['salary']):
    if number < 200:
        results['hourly_salary'][where] = number
    elif number <= 10000: #check if this is fair, based on 8.5k type figures
        results['monthly_salary'][where] = number
    else:
        results['annual_salary'][where] = number
        
results.head(50)
# Out:
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#                                        company  \
# 0                          AdvancePierre Foods
# 1                               U.S. Air Force
# 2                                 Sensory, Inc
# 3                                Etech Hi Inc.
# 4                                      Xpandit
# 5            Maine Health Management Coalition
# 6                                        Alere
# 7                                        Alere
# 8                           IDEXX Laboratories
# 9                           IDEXX Laboratories
# 10                      Dept. Marine Resources
# 11                         KP Recruiting Group
# 12                           Dept. Agriculture
# 13           Maine Health Management Coalition
# 14                                Sensory, Inc
# 15                   Amazon Web Services, Inc.
# 16                          IDEXX Laboratories
# 17                         AdvancePierre Foods
# 18                                       Alere
# 19                               Staff Hunters
# 20      Maine Molecular Quality Controls, Inc.
# 21                    IDEXX Laboratories, Inc.
# 22                      Department of the Navy
# 23                                       Alere
# 24                      Department of the Navy
# 25                                    CashStar
# 26                        Amazon Corporate LLC
# 27                        Amazon Corporate LLC
# 28           Maine Health Management Coalition
# 29                                Sensory, Inc
# 30                   Amazon Web Services, Inc.
# 31                          IDEXX Laboratories
# 32                         AdvancePierre Foods
# 33                                       Alere
# 34                               Staff Hunters
# 35      Maine Molecular Quality Controls, Inc.
# 36                    IDEXX Laboratories, Inc.
# 37                      Department of the Navy
# 38                                       Alere
# 39                      Department of the Navy
# 40                                    CashStar
# 41                        Amazon Corporate LLC
# 42                        Amazon Corporate LLC
# 43           Maine Health Management Coalition
# 44                              U.S. Air Force
# 45                    Ricerca Biosciences, LLC
# 46                          IDEXX Laboratories
# 47                         AdvancePierre Foods
# 48                                       Alere
# 49                               Staff Hunters
#
#                                           description  \
# 0   Lead multiple complex development projects usi...
# 1   Help Airman get the proper healthcare they nee...
# 2   16-01 - Research Scientist – BOULDER, CO. As a...
# 3   \nData analyst, data programmer, data scientis...
# 4   \nBut, more than just a “Buzzword Guy”, we see...
# 5   \nUnderstands mapping of data elements to anal...
# 6   \nAdvanced knowledge of a variety of statistic...
# 7   \nConducts and interprets data. Phases of a pr...
# 8   \nPrepares materials, performs experiments, ga...
# 9   \nWill interpret internally and externally gen...
# 10  \nMARINE RESOURCES SCIENTIST I. The incumbent ...
# 11  \nWill interpret internally and externally gen...
# 12  \nCollaborating with scientists in other state...
# 13  Understands mapping of data elements to analyt...
# 14  15-02 - Research Scientist (Emerging Technolog...
# 15  Solid communication and data presentation skil...
# 16  \nSeeking an Associate Scientist to join a gro...
# 17  \nLead multiple complex development projects u...
# 18  \nDirect and oversee CRO activities including ...
# 19  \nEvaluate data from a variety of sources to d...
# 20  \nProducts through use of public data bases. W...
# 21  \nSeeking an Associate Scientist to join a gro...
# 22  \nFrom pipefitters to accountants, scientists ...
# 23  \nWorks in a multidisciplinary team with other...
# 24  \nEvaluating exposure data, surveys, work prac...
# 25  \nWork with engineering team and data scientis...
# 26  As a Principal, you will provide leadership to...
# 27  Are you interested in building data pipelines ...
# 28  Understands mapping of data elements to analyt...
# 29  16-01 - Research Scientist – BOULDER, CO. As a...
# 30  Solid communication and data presentation skil...
# 31  \nSeeking an Associate Scientist to join a gro...
# 32  \nLead multiple complex development projects u...
# 33  \nDirect and oversee CRO activities including ...
# 34  \nEvaluate data from a variety of sources to d...
# 35  \nProducts through use of public data bases. W...
# 36  \nSeeking an Associate Scientist to join a gro...
# 37  \nFrom pipefitters to accountants, scientists ...
# 38  \nWorks in a multidisciplinary team with other...
# 39  \nEvaluating exposure data, surveys, work prac...
# 40  \nWork with engineering team and data scientis...
# 41  As a Principal, you will provide leadership to...
# 42  Are you interested in building data pipelines ...
# 43  Understands mapping of data elements to analyt...
# 44  Help Airman get the proper healthcare they nee...
# 45  Review data for technical content and regulato...
# 46  \nSeeking an Associate Scientist to join a gro...
# 47  \nLead multiple complex development projects u...
# 48  \nDirect and oversee CRO activities including ...
# 49  \nEvaluate data from a variety of sources to d...
#
#                                   location   salary  \
# 0                             Portland, ME      NaN
# 1                            United States      NaN
# 2                            United States      NaN
# 3                               Brewer, ME   120000
# 4                               Lisbon, ME      NaN
# 5                              Topsham, ME      NaN
# 6                          Scarborough, ME      NaN
# 7                          Scarborough, ME      NaN
# 8                      Westbrook, ME 04092      NaN
# 9                      Westbrook, ME 04092      NaN
# 10                             Augusta, ME    46332
# 11                           Westbrook, ME      NaN
# 12                             Augusta, ME  49628.5
# 13                             Topsham, ME      NaN
# 14                           United States      NaN
# 15                           United States      NaN
# 16                     Westbrook, ME 04092      NaN
# 17                            Portland, ME      NaN
# 18                         Scarborough, ME      NaN
# 19                           Westbrook, ME      NaN
# 20                                Saco, ME      NaN
# 21                     Westbrook, ME 04092      NaN
# 22           Portsmouth Naval Shipyard, ME  89405.5
# 23                         Scarborough, ME      NaN
# 24                             Kittery, ME  82964.5
# 25  Portland, ME 04101 (West Bayside area)      NaN
# 26                           United States      NaN
# 27                           United States      NaN
# 28                             Topsham, ME      NaN
# 29                           United States      NaN
# 30                           United States      NaN
# 31                     Westbrook, ME 04092      NaN
# 32                            Portland, ME      NaN
# 33                         Scarborough, ME      NaN
# 34                           Westbrook, ME      NaN
# 35                                Saco, ME      NaN
# 36                     Westbrook, ME 04092      NaN
# 37           Portsmouth Naval Shipyard, ME  89405.5
# 38                         Scarborough, ME      NaN
# 39                             Kittery, ME  82964.5
# 40  Portland, ME 04101 (West Bayside area)      NaN
# 41                           United States      NaN
# 42                           United States      NaN
# 43                             Topsham, ME      NaN
# 44                           United States      NaN
# 45                           United States      NaN
# 46                     Westbrook, ME 04092      NaN
# 47                            Portland, ME      NaN
# 48                         Scarborough, ME      NaN
# 49                           Westbrook, ME      NaN
#
#                                                 title  hourly_salary  \
# 0   Food Scientist-Poultry Protein, Culinary Conce...            NaN
# 1                       Biomedical Laboratory Officer            NaN
# 2   Research Scientist [Exp. with Machine Learning...            NaN
# 3                                 Data Analyst II/III            NaN
# 4                                   Big Data Engineer            NaN
# 5                             Senior Research Analyst            NaN
# 6                                        Statistician            NaN
# 7                        Scientist I (Research Assoc)            NaN
# 8                               Associate Scientist I            NaN
# 9                                    Systems Engineer            NaN
# 10                       MARINE RESOURCES SCIENTIST I            NaN
# 11                     Systems Engineer-Biotechnology            NaN
# 12                                   SENIOR GEOLOGIST            NaN
# 13                            Senior Research Analyst            NaN
# 14  Research Scientist-Emerging Technology [3 to 5...            NaN
# 15  Principal Research Scientist, Forecasting and ...            NaN
# 16   Associate Scientist/Engineer – Systems Chemistry            NaN
# 17  Food Scientist-Poultry Protein, Culinary Conce...            NaN
# 18      Director, Clinical Affairs Infectious Disease            NaN
# 19                                   Systems Engineer            NaN
# 20           R & D Scientist II MOLECULAR DIAGNOSTICS            NaN
# 21             Associate Scientist/Engineer – Systems            NaN
# 22                       QUALITY ASSURANCE SPECIALIST            NaN
# 23                  Technical Manufacturing Chemist I            NaN
# 24          PHYSICAL SCIENCE TECHNICIAN (INSTRUCTOR),            NaN
# 25  Director, Product Management - Risk Solutions ...            NaN
# 26  Principal Data Scientist - Consumer Website- R...            NaN
# 27  Software Development Engineer, Big Data- Reloc...            NaN
# 28                            Senior Research Analyst            NaN
# 29  Research Scientist [Exp. with Machine Learning...            NaN
# 30  Principal Research Scientist, Forecasting and ...            NaN
# 31   Associate Scientist/Engineer – Systems Chemistry            NaN
# 32  Food Scientist-Poultry Protein, Culinary Conce...            NaN
# 33      Director, Clinical Affairs Infectious Disease            NaN
# 34                                   Systems Engineer            NaN
# 35           R & D Scientist II MOLECULAR DIAGNOSTICS            NaN
# 36             Associate Scientist/Engineer – Systems            NaN
# 37                       QUALITY ASSURANCE SPECIALIST            NaN
# 38                  Technical Manufacturing Chemist I            NaN
# 39          PHYSICAL SCIENCE TECHNICIAN (INSTRUCTOR),            NaN
# 40  Director, Product Management - Risk Solutions ...            NaN
# 41  Principal Data Scientist - Consumer Website- R...            NaN
# 42  Software Development Engineer, Big Data- Reloc...            NaN
# 43                            Senior Research Analyst            NaN
# 44                      Biomedical Laboratory Officer            NaN
# 45  Analytical Scientist (LC-MSMS / NMR Small Mole...            NaN
# 46   Associate Scientist/Engineer – Systems Chemistry            NaN
# 47  Food Scientist-Poultry Protein, Culinary Conce...            NaN
# 48      Director, Clinical Affairs Infectious Disease            NaN
# 49                                   Systems Engineer            NaN
#
#     monthly_salary annual_salary
# 0              NaN           NaN
# 1              NaN           NaN
# 2              NaN           NaN
# 3              NaN        120000
# 4              NaN           NaN
# 5              NaN           NaN
# 6              NaN           NaN
# 7              NaN           NaN
# 8              NaN           NaN
# 9              NaN           NaN
# 10             NaN         46332
# 11             NaN           NaN
# 12             NaN       49628.5
# 13             NaN           NaN
# 14             NaN           NaN
# 15             NaN           NaN
# 16             NaN           NaN
# 17             NaN           NaN
# 18             NaN           NaN
# 19             NaN           NaN
# 20             NaN           NaN
# 21             NaN           NaN
# 22             NaN       89405.5
# 23             NaN           NaN
# 24             NaN       82964.5
# 25             NaN           NaN
# 26             NaN           NaN
# 27             NaN           NaN
# 28             NaN           NaN
# 29             NaN           NaN
# 30             NaN           NaN
# 31             NaN           NaN
# 32             NaN           NaN
# 33             NaN           NaN
# 34             NaN           NaN
# 35             NaN           NaN
# 36             NaN           NaN
# 37             NaN       89405.5
# 38             NaN           NaN
# 39             NaN       82964.5
# 40             NaN           NaN
# 41             NaN           NaN
# 42             NaN           NaN
# 43             NaN           NaN
# 44             NaN           NaN
# 45             NaN           NaN
# 46             NaN           NaN
# 47             NaN           NaN
# 48             NaN           NaN
# 49             NaN           NaN

# %% [markdown]
# ### Save your results as a CSV

# %%
#here I should remove duplicates!!! Addition of Oakland, Berkeley, SF etc... will lead to dupes

results.drop_duplicates(inplace=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-e1448d77ed47> in <module>()
#       1 #here I should remove duplicates!!! Addition of Oakland, Berkeley, SF etc... will lead to dupes
#       2
# ----> 3 results.drop_duplicates(inplace=1)
#
# AttributeError: 'function' object has no attribute 'drop_duplicates'

# %%
results.to_csv("indeed_ds_data30_dedupe.csv", encoding='utf8')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-31440383e0b8> in <module>()
# ----> 1 results.to_csv("indeed_ds_data30_dedupe.csv", encoding='utf8')
#
# AttributeError: 'function' object has no attribute 'to_csv'
