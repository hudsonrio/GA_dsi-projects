# %% [markdown]
# # Web Scraping for Indeed.com & Predicting Salaries

# %% [markdown]
# In this project, we will practice two major skills: collecting data by scraping a website and then building a binary predictor with Logistic Regression.
#
# We are going to collect salary information on data science jobs in a variety of markets. Then using the location, title and summary of the job we will attempt to predict the salary of the job. For job posting sites, this would be extraordinarily useful. While most listings DO NOT come with salary information (as you will see in this exercise), being to able extrapolate or predict the expected salaries from other listings can help guide negotiations.
#
# Normally, we could use regression for this task; however, we will convert this problem into classification and use Logistic Regression.
#
# - Question: Why would we want this to be a classification problem?
# - Answer: While more precision may be better, there is a fair amount of natural variance in job salaries - predicting a range be may be useful.
#
# Therefore, the first part of the assignment will be focused on scraping Indeed.com. In the second, we'll focus on using listings with salary information to build a model and predict additional salaries.

# %% [markdown]
# ### Scraping job listings from Indeed.com

# %% [markdown]
# We will be scraping job listings from Indeed.com using BeautifulSoup. Luckily, Indeed.com is a simple text page where we can easily find relevant entries.
#
# First, look at the source of an Indeed.com page: (http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10")
#
# Notice, each job listing is underneath a `div` tag with a class name of `result`. We can use BeautifulSoup to extract those.

# %% [markdown]
# #### Setup a request (using `requests`) to the URL below. Use BeautifulSoup to parse the page and extract all results (HINT: Look for div tags with class name result)

# %%
URL = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"

# %%
import requests
import bs4
from bs4 import BeautifulSoup
from __future__ import division, print_function

import requests
from bs4 import BeautifulSoup
from selenium import webdriver

import pandas as pd
import numpy as np

from IPython.core.display import HTML, Image

# %%
r = requests.get(URL)
indeed = BeautifulSoup(r.content, "lxml")

# %%
col_list = ['location', 'title', 'company', 'salary', 'description']

def prime_time(soup):
    location_list = []
    role_title_list = []
    company_list = []
    salaries = []
    summaries = []

    for t in soup.findAll("div", class_='result'):
        location = t.find('span', class_='location').text # WORKS!
        location_list.append(location)
        title = t.find('a')['title'] # WORKS!
        role_title_list.append(title)
        company_name = t.find('span', class_='company').text
        company_name = company_name.strip('\n')
        company_list.append(company_name)
        salary = t.find('nobr' or 'sjcl')   #('nobr').next_sibling sjcl
        salaries.append(salary)
        summary = t.find('span', class_="summary").text
        summaries.append(summary)
    
    results = zip(location_list, role_title_list, company_list, salaries, summaries)
    results = pd.DataFrame(results)
    results.columns = col_list
    return(results)

# indeed_results = prime_time(indeed)
# indeed_output = pd.DataFrame(indeed_results)
# indeed_output.head()

# %% [markdown]
# Let's look at one result more closely. A single `result` looks like
#
# ```
# <div class=" row result" data-jk="2480d203f7e97210" data-tn-component="organicJob" id="p_2480d203f7e97210" itemscope="" itemtype="http://schema.org/JobPosting">
# <h2 class="jobtitle" id="jl_2480d203f7e97210">
# <a class="turnstileLink" data-tn-element="jobTitle" onmousedown="return rclk(this,jobmap[0],1);" rel="nofollow" target="_blank" title="AVP/Quantitative Analyst">AVP/Quantitative Analyst</a>
# </h2>
# <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
# <span itemprop="name">
# <a href="/cmp/Alliancebernstein?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=2480d203f7e97210&amp;jcid=b374f2a780e04789" target="_blank">
#     AllianceBernstein</a></span>
# </span>
# <tr>
# <td class="snip">
# <nobr>$117,500 - $127,500 a year</nobr>
# <div>
# <span class="summary" itemprop="description">
# C onduct quantitative and statistical research as well as portfolio management for various investment portfolios. Collaborate with Quantitative Analysts and</span>
# </div>
# </div>
# </td>
# </tr>
# </table>
# </div>
# ```
#
# While this has some more verbose elements removed, we can see that there is some structure to the above:
# - The salary is available in a `nobr` element inside of a `td` element with `class='snip`.
# - The title of a job is in a link with class set to `jobtitle` and a `data-tn-element="jobTitle`.
# - The location is set in a `span` with `class='location'`.
# - The company is set in a `span` with `class='company'`.

# %% [markdown]
# ### Write 4 functions to extract each item: location, company, job, and salary.
#
# example:
# ```python
# def extract_location_from_result(result):
#     return result.find ...
# ```
#
#
# - Make sure these functions are robust and can handle cases where the data/field may not be available.
# - Test the functions on the results above
# - Include any other features you may want to use later (e.g. summary, #of reviews...)

# %% [markdown]
# Now, to scale up our scraping, we need to accumulate more results. We can do this by examining the URL above.
#
# - "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"
#
# There are two query parameters here we can alter to collect more results, the `l=New+York` and the `start=10`. The first controls the location of the results (so we can try a different city). The second controls where in the results to start and gives 10 results (thus, we can keep incrementing by 10 to go further in the list).

# %% [markdown]
# ### Complete the following code to collect results from multiple cities and starting points.
# - Indeed.com only has salary information for an estimated 20% of job postings. You may want to add other cities to the list below to gather more data.
# - Remember to convert your salary to U.S. Dollars to match the other cities if the currency is different

# %%
#main scraping piece
import numpy as np

url_template_first = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l={}"
url_template = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l={}&start={}"

max_results_per_city = 100
col_list = ['location', 'title', 'company', 'salary', 'description']
sample_vals = [np.NaN,np.NaN,np.NaN,np.NaN,np.NaN]

d = dict.fromkeys(col_list, sample_vals)
results = pd.DataFrame(d)   # trying to make the columns the same so I can merge later


for city in set(['New+York', 'Chicago', 'San+Francisco', 'Austin', 'Atlanta','Boston','Berkeley',\
                 'Oakland', 'Raleigh', 'Brooklyn','Queens', 'St+Louis','Asheville','Portland','Maine',\
                 'Baltimore', 'Boulder', 'Denver', 'Reno', 'Des Moines', 'Cleveland',  'Detroit', 'Kansas+City',\
                 'Dallas', 'Washington+DC', 'Nashville', 'Seattle', 'Salt+Lake+City', 'Sacramento', 'Minneapolis', 'St+Paul']): 
    for start in range(0, max_results_per_city, 10):
        foo = requests.get(url_template.format(city, start))
        indeed = BeautifulSoup(foo.content, "lxml")
        indeed_results = prime_time(indeed)
        indeed_results.columns = col_list
        
        results = pd.concat([indeed_results, results], ignore_index=True)
    first = requests.get(url_template_first.format(city)) #GETS THE FIRST PAGE OF RESULTS, MISSED
    first_indeed = BeautifulSoup(first.content, "lxml")
    first_indeed_results = prime_time(first_indeed)
    first_indeed_results.columns = col_list
    results = pd.concat([first_indeed_results, results], ignore_index=True)
results.head(50)
# Out:
#                                        company  \
# 0            Maine Health Management Coalition
# 1                         Amazon Corporate LLC
# 2                         Amazon Corporate LLC
# 3                                      Xpandit
# 4                                        Alere
# 5                                        Alere
# 6                                Etech Hi Inc.
# 7                          AdvancePierre Foods
# 8            Maine Health Management Coalition
# 9                           IDEXX Laboratories
# 10                      Department of the Navy
# 11                                 MaineHealth
# 12                      Dept. Marine Resources
# 13                        Amazon Corporate LLC
# 14                        Amazon Corporate LLC
# 15      Maine Molecular Quality Controls, Inc.
# 16       MAINE MOLECULAR QUALITY CONTROLS, INC
# 17           Maine Health Management Coalition
# 18                   Amazon Web Services, Inc.
# 19                        Amazon Corporate LLC
# 20                        Amazon Corporate LLC
# 21                                Sensory, Inc
# 22                              U.S. Air Force
# 23                   Amazon Web Services, Inc.
# 24                        Amazon Corporate LLC
# 25                    Ricerca Biosciences, LLC
# 26                        Amazon Corporate LLC
# 27      Maine Molecular Quality Controls, Inc.
# 28       MAINE MOLECULAR QUALITY CONTROLS, INC
# 29                        Amazon Corporate LLC
# 30           Maine Health Management Coalition
# 31                   Amazon Web Services, Inc.
# 32                        Amazon Corporate LLC
# 33                        Amazon Corporate LLC
# 34                                Sensory, Inc
# 35                              U.S. Air Force
# 36                   Amazon Web Services, Inc.
# 37                        Amazon Corporate LLC
# 38                   Amazon Web Services, Inc.
# 39                        Amazon Corporate LLC
# 40      Maine Molecular Quality Controls, Inc.
# 41       MAINE MOLECULAR QUALITY CONTROLS, INC
# 42                        Amazon Corporate LLC
# 43           Maine Health Management Coalition
# 44                   Amazon Web Services, Inc.
# 45                        Amazon Corporate LLC
# 46                        Amazon Corporate LLC
# 47                                Sensory, Inc
# 48                              U.S. Air Force
# 49                   Amazon Web Services, Inc.
#
#                                           description             location  \
# 0   Understands mapping of data elements to analyt...          Topsham, ME
# 1   As a Principal, you will provide leadership to...        United States
# 2   Are you interested in building data pipelines ...        United States
# 3   \nBut, more than just a “Buzzword Guy”, we see...           Lisbon, ME
# 4   \nAdvanced knowledge of a variety of statistic...      Scarborough, ME
# 5   \nConducts and interprets data. Phases of a pr...      Scarborough, ME
# 6   \nData analyst, data programmer, data scientis...           Brewer, ME
# 7   \nLead multiple complex development projects u...         Portland, ME
# 8   \nUnderstands mapping of data elements to anal...          Topsham, ME
# 9   \nSeeking an Associate Scientist to join a gro...  Westbrook, ME 04092
# 10  \nEvaluating exposure data, surveys, work prac...          Kittery, ME
# 11  \nSkills should include ability to troubleshoo...         Portland, ME
# 12  \nMARINE RESOURCES SCIENTIST I. The incumbent ...          Augusta, ME
# 13  Are you interested in building data pipelines ...        United States
# 14  As a Principal, you will provide leadership to...        United States
# 15  \nProducts through use of public data bases. W...             Saco, ME
# 16  \nWe are seeking an experienced scientist to a...       Saco, ME 04072
# 17  Understands mapping of data elements to analyt...          Topsham, ME
# 18  Solid communication and data presentation skil...        United States
# 19  Solid communication and data presentation skil...        United States
# 20  Familiarity with data structures, algorithms, ...        United States
# 21  15-02 - Research Scientist (Emerging Technolog...        United States
# 22  Help Airman get the proper healthcare they nee...        United States
# 23  Computer Science fundamentals in object-orient...        United States
# 24  We love data and we have lots of it. Our appli...        United States
# 25  Review data for technical content and regulato...        United States
# 26  As a Principal, you will provide leadership to...        United States
# 27  \nProducts through use of public data bases. W...             Saco, ME
# 28  \nWe are seeking an experienced scientist to a...       Saco, ME 04072
# 29  Are you interested in building data pipelines ...        United States
# 30  Understands mapping of data elements to analyt...          Topsham, ME
# 31  Solid communication and data presentation skil...        United States
# 32  Solid communication and data presentation skil...        United States
# 33  Familiarity with data structures, algorithms, ...        United States
# 34  15-02 - Research Scientist (Emerging Technolog...        United States
# 35  Help Airman get the proper healthcare they nee...        United States
# 36  Computer Science fundamentals in object-orient...        United States
# 37  We love data and we have lots of it. Our appli...        United States
# 38  Computer Science fundamentals in object-orient...        United States
# 39  Are you interested in building data pipelines ...        United States
# 40  \nProducts through use of public data bases. W...             Saco, ME
# 41  \nWe are seeking an experienced scientist to a...       Saco, ME 04072
# 42  As a Principal, you will provide leadership to...        United States
# 43  Understands mapping of data elements to analyt...          Topsham, ME
# 44  Solid communication and data presentation skil...        United States
# 45  Solid communication and data presentation skil...        United States
# 46  Familiarity with data structures, algorithms, ...        United States
# 47  15-02 - Research Scientist (Emerging Technolog...        United States
# 48  Help Airman get the proper healthcare they nee...        United States
# 49  Computer Science fundamentals in object-orient...        United States
#
#                                     salary  \
# 0                                     None
# 1                                     None
# 2                                     None
# 3                                     None
# 4                                     None
# 5                                     None
# 6             <nobr>$120,000 a year</nobr>
# 7                                     None
# 8                                     None
# 9                                     None
# 10  <nobr>$64,862 - $101,067 a year</nobr>
# 11                                    None
# 12   <nobr>$39,374 - $53,290 a year</nobr>
# 13                                    None
# 14                                    None
# 15                                    None
# 16                                    None
# 17                                    None
# 18                                    None
# 19                                    None
# 20                                    None
# 21                                    None
# 22                                    None
# 23                                    None
# 24                                    None
# 25                                    None
# 26                                    None
# 27                                    None
# 28                                    None
# 29                                    None
# 30                                    None
# 31                                    None
# 32                                    None
# 33                                    None
# 34                                    None
# 35                                    None
# 36                                    None
# 37                                    None
# 38                                    None
# 39                                    None
# 40                                    None
# 41                                    None
# 42                                    None
# 43                                    None
# 44                                    None
# 45                                    None
# 46                                    None
# 47                                    None
# 48                                    None
# 49                                    None
#
#                                                 title
# 0                             Senior Research Analyst
# 1   Principal Data Scientist - Consumer Website- R...
# 2   Software Development Engineer, Big Data- Reloc...
# 3                                   Big Data Engineer
# 4                                        Statistician
# 5                        Scientist I (Research Assoc)
# 6                                 Data Analyst II/III
# 7   Food Scientist-Poultry Protein, Culinary Conce...
# 8                             Senior Research Analyst
# 9    Associate Scientist/Engineer – Systems Chemistry
# 10          PHYSICAL SCIENCE TECHNICIAN (INSTRUCTOR),
# 11  Technology Manager/Data Analyst - Maine Medica...
# 12                       MARINE RESOURCES SCIENTIST I
# 13  Software Development Engineer, Big Data- Reloc...
# 14  Principal Data Scientist - Consumer Website- R...
# 15           R & D Scientist II MOLECULAR DIAGNOSTICS
# 16           R&D Scientist II - Molecular Diagnostics
# 17                            Senior Research Analyst
# 18  Principal Research Scientist, Forecasting and ...
# 19  Principal Research Scientist- Relocation Oppor...
# 20  Director, Research Science- Relocation Opportu...
# 21  Research Scientist-Emerging Technology [3 to 5...
# 22                      Biomedical Laboratory Officer
# 23  Software Development Engineer – Emerging AWS M...
# 24  Principal Applied Scientist, Machine Learning-...
# 25  Analytical Scientist (LC-MSMS / NMR Small Mole...
# 26  Principal Data Scientist - Consumer Website- R...
# 27           R & D Scientist II MOLECULAR DIAGNOSTICS
# 28           R&D Scientist II - Molecular Diagnostics
# 29  Software Development Engineer, Big Data- Reloc...
# 30                            Senior Research Analyst
# 31  Principal Research Scientist, Forecasting and ...
# 32  Principal Research Scientist- Relocation Oppor...
# 33  Director, Research Science- Relocation Opportu...
# 34  Research Scientist-Emerging Technology [3 to 5...
# 35                      Biomedical Laboratory Officer
# 36  Software Development Engineer – Emerging AWS M...
# 37  Principal Applied Scientist, Machine Learning-...
# 38  Software Development Engineer – New AWS Machin...
# 39  Software Development Engineer, Big Data- Reloc...
# 40           R & D Scientist II MOLECULAR DIAGNOSTICS
# 41           R&D Scientist II - Molecular Diagnostics
# 42  Principal Data Scientist - Consumer Website- R...
# 43                            Senior Research Analyst
# 44  Principal Research Scientist, Forecasting and ...
# 45  Principal Research Scientist- Relocation Oppor...
# 46  Director, Research Science- Relocation Opportu...
# 47  Research Scientist-Emerging Technology [3 to 5...
# 48                      Biomedical Laboratory Officer
# 49  Software Development Engineer – Emerging AWS M...

# %% [markdown]
# #### Use the functions you wrote above to parse out the 4 fields - location, title, company and salary. Create a dataframe from the results with those 4 columns.

# %% [markdown]
# Lastly, we need to clean up salary data.
# 1. Some of the salaries are not yearly but hourly, these will be useful to us for now 2. The salaries are given as text and usually with ranges.
#
# #### Filter out the salaries that are not yearly (filter those that refer to hour)

# %%
import numpy as np
            
# results['annual_salary'] = results['salary']

results_nan = results.replace({None:np.NaN})
results = results_nan
results.head(10)
# Out:
#                                  company  \
# 0      Maine Health Management Coalition
# 1                   Amazon Corporate LLC
# 2                   Amazon Corporate LLC
# 3                                Xpandit
# 4                                  Alere
# 5                                  Alere
# 6                          Etech Hi Inc.
# 7                    AdvancePierre Foods
# 8      Maine Health Management Coalition
# 9                     IDEXX Laboratories
#
#                                          description             location  \
# 0  Understands mapping of data elements to analyt...          Topsham, ME
# 1  As a Principal, you will provide leadership to...        United States
# 2  Are you interested in building data pipelines ...        United States
# 3  \nBut, more than just a “Buzzword Guy”, we see...           Lisbon, ME
# 4  \nAdvanced knowledge of a variety of statistic...      Scarborough, ME
# 5  \nConducts and interprets data. Phases of a pr...      Scarborough, ME
# 6  \nData analyst, data programmer, data scientis...           Brewer, ME
# 7  \nLead multiple complex development projects u...         Portland, ME
# 8  \nUnderstands mapping of data elements to anal...          Topsham, ME
# 9  \nSeeking an Associate Scientist to join a gro...  Westbrook, ME 04092
#
#                          salary  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6  <nobr>$120,000 a year</nobr>
# 7                           NaN
# 8                           NaN
# 9                           NaN
#
#                                                title
# 0                            Senior Research Analyst
# 1  Principal Data Scientist - Consumer Website- R...
# 2  Software Development Engineer, Big Data- Reloc...
# 3                                  Big Data Engineer
# 4                                       Statistician
# 5                       Scientist I (Research Assoc)
# 6                                Data Analyst II/III
# 7  Food Scientist-Poultry Protein, Culinary Conce...
# 8                            Senior Research Analyst
# 9   Associate Scientist/Engineer – Systems Chemistry

# %%
def salary_clean(string):
    if type(string) == float:
        return np.NaN
    elif string == np.NaN:
        return np.NaN
    else:
        try:
            return((string.split("<nobr>")[1]).split("</nobr>")[0])
        except (TypeError, IndexError): 
            return np.NaN

for b in range(len(results['salary'])):
    results['salary'][b] = salary_clean(str(results['salary'][b]))
    

results.head(15)
# Out:
#                                   company  \
# 0       Maine Health Management Coalition
# 1                    Amazon Corporate LLC
# 2                    Amazon Corporate LLC
# 3                                 Xpandit
# 4                                   Alere
# 5                                   Alere
# 6                           Etech Hi Inc.
# 7                     AdvancePierre Foods
# 8       Maine Health Management Coalition
# 9                      IDEXX Laboratories
# 10                 Department of the Navy
# 11                            MaineHealth
# 12                 Dept. Marine Resources
# 13                   Amazon Corporate LLC
# 14                   Amazon Corporate LLC
#
#                                           description             location  \
# 0   Understands mapping of data elements to analyt...          Topsham, ME
# 1   As a Principal, you will provide leadership to...        United States
# 2   Are you interested in building data pipelines ...        United States
# 3   \nBut, more than just a “Buzzword Guy”, we see...           Lisbon, ME
# 4   \nAdvanced knowledge of a variety of statistic...      Scarborough, ME
# 5   \nConducts and interprets data. Phases of a pr...      Scarborough, ME
# 6   \nData analyst, data programmer, data scientis...           Brewer, ME
# 7   \nLead multiple complex development projects u...         Portland, ME
# 8   \nUnderstands mapping of data elements to anal...          Topsham, ME
# 9   \nSeeking an Associate Scientist to join a gro...  Westbrook, ME 04092
# 10  \nEvaluating exposure data, surveys, work prac...          Kittery, ME
# 11  \nSkills should include ability to troubleshoo...         Portland, ME
# 12  \nMARINE RESOURCES SCIENTIST I. The incumbent ...          Augusta, ME
# 13  Are you interested in building data pipelines ...        United States
# 14  As a Principal, you will provide leadership to...        United States
#
#                        salary  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6             $120,000 a year
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 10  $64,862 - $101,067 a year
# 11                        NaN
# 12   $39,374 - $53,290 a year
# 13                        NaN
# 14                        NaN
#
#                                                 title
# 0                             Senior Research Analyst
# 1   Principal Data Scientist - Consumer Website- R...
# 2   Software Development Engineer, Big Data- Reloc...
# 3                                   Big Data Engineer
# 4                                        Statistician
# 5                        Scientist I (Research Assoc)
# 6                                 Data Analyst II/III
# 7   Food Scientist-Poultry Protein, Culinary Conce...
# 8                             Senior Research Analyst
# 9    Associate Scientist/Engineer – Systems Chemistry
# 10          PHYSICAL SCIENCE TECHNICIAN (INSTRUCTOR),
# 11  Technology Manager/Data Analyst - Maine Medica...
# 12                       MARINE RESOURCES SCIENTIST I
# 13  Software Development Engineer, Big Data- Reloc...
# 14  Principal Data Scientist - Consumer Website- R...

# %%
# print(results['salary'].isnull().value_counts()) #only 62 salaries in here it appears

# %% [markdown]
# #### Write a function that takes a salary string and converts it to a number, averaging a salary range if necessary

# %%
import re
import string 

def salarizer(salary):  
    '''remove all non-numeric characters from salary strings for non-null vals '''
    if pd.isnull(salary) == False:
        salary = salary.translate(None, "$|anmonthhurye,dwk ")
        return(salary) 
    else:
        return np.NaN

    


def salary_average(salary): 
    '''if a salary range, take the average, otherwise return the number'''
    float_sal_list = []
    try:
        salary_str = str(salary)
        sal_list = str.split(salary_str, "-")
        for item in sal_list:
            try:
                float_sal_list.append(float(item))
            except ValueError:
                return salary
        if len(float_sal_list) > 1:
            avg_sal = sum(float_sal_list)/float(len(float_sal_list))
            return(avg_sal)
        else:
            return float(salary)
    except IndexError:
        return np.NaN
    

    
for hannah in range(len(results['salary'])):
    results['salary'][hannah] = salarizer(results['salary'][hannah])
    results['salary'][hannah] = salary_average(results['salary'][hannah])

# %%
results['hourly_salary'] = results['salary'].apply(lambda x: x if float(x) < 200 else np.nan) 
results['monthly_salary'] = results['salary'].apply(lambda x: x if float(x) < 10000 else np.nan)
results['annual_salary'] = results['salary'].apply(lambda x: x if float(x) > 10000 else np.nan)



# #categorize hourly, monthly, salaries ---- this is far and away the most time-intensive part of the script
###REWROTE THIS FUNCTION BELOW ABOVE FOR PERFORMANCE REASONS

# results['monthly_salary'] = np.NaN
# results['annual_salary'] = np.NaN

# for where, number in enumerate(results['salary']):
#     if number < 200: #max of hourly is less
#         results['hourly_salary'][where] = number
#     elif number <= 10000: #max of monthly is less than this 
#         results['monthly_salary'][where] = number
#     else:
#         results['annual_salary'][where] = number

# %% [markdown]
# ### Save your results as a CSV

# %%
#remove duplicates! Addition of Oakland, Berkeley, SF etc... will lead to dupes

results.drop_duplicates(inplace=1)

# %%
results.to_csv("indeed_ds_data30_dedupe.csv", encoding='utf8')

#at this point, there are 158 annual salaries in my dataset
#https://docs.google.com/spreadsheets/d/1Luw7rFbYnh31zq2ZsCJ0pGrJQ4FnVfsHv1RRTUmGGuw/edit?usp=sharing

# %%
results.head()
# Out:
#                                  company  \
# 0      Maine Health Management Coalition
# 1                   Amazon Corporate LLC
# 2                   Amazon Corporate LLC
# 3                                Xpandit
# 4                                  Alere
#
#                                          description         location salary  \
# 0  Understands mapping of data elements to analyt...      Topsham, ME    NaN
# 1  As a Principal, you will provide leadership to...    United States    NaN
# 2  Are you interested in building data pipelines ...    United States    NaN
# 3  \nBut, more than just a “Buzzword Guy”, we see...       Lisbon, ME    NaN
# 4  \nAdvanced knowledge of a variety of statistic...  Scarborough, ME    NaN
#
#                                                title  hourly_salary  \
# 0                            Senior Research Analyst            NaN
# 1  Principal Data Scientist - Consumer Website- R...            NaN
# 2  Software Development Engineer, Big Data- Reloc...            NaN
# 3                                  Big Data Engineer            NaN
# 4                                       Statistician            NaN
#
#    monthly_salary  annual_salary
# 0             NaN            NaN
# 1             NaN            NaN
# 2             NaN            NaN
# 3             NaN            NaN
# 4             NaN            NaN

# %%
indeeder = results
indeeder.head()
# Out:
#                                  company  \
# 0      Maine Health Management Coalition
# 1                   Amazon Corporate LLC
# 2                   Amazon Corporate LLC
# 3                                Xpandit
# 4                                  Alere
#
#                                          description         location salary  \
# 0  Understands mapping of data elements to analyt...      Topsham, ME    NaN
# 1  As a Principal, you will provide leadership to...    United States    NaN
# 2  Are you interested in building data pipelines ...    United States    NaN
# 3  \nBut, more than just a “Buzzword Guy”, we see...       Lisbon, ME    NaN
# 4  \nAdvanced knowledge of a variety of statistic...  Scarborough, ME    NaN
#
#                                                title  hourly_salary  \
# 0                            Senior Research Analyst            NaN
# 1  Principal Data Scientist - Consumer Website- R...            NaN
# 2  Software Development Engineer, Big Data- Reloc...            NaN
# 3                                  Big Data Engineer            NaN
# 4                                       Statistician            NaN
#
#    monthly_salary  annual_salary
# 0             NaN            NaN
# 1             NaN            NaN
# 2             NaN            NaN
# 3             NaN            NaN
# 4             NaN            NaN

# %%
indeeder.describe()
# Out:
#        hourly_salary  monthly_salary  annual_salary
# count      41.000000       76.000000     150.000000
# mean       31.467683     2455.022039  106529.860000
# std        17.174516     3086.856517   40814.298371
# min        10.250000       10.250000   30000.000000
# 25%        20.000000       24.421250   75000.000000
# 50%        25.000000       62.500000  108750.000000
# 75%        38.365000     4716.500000  136875.000000
# max        75.000000     9350.000000  240000.000000

# %% [markdown]
# ### Beginning Analysis Phase of Project

# %%
print(type(indeeder['annual_salary'][4]),type(indeeder['annual_salary'][5]))
# Out:
# <type 'numpy.float64'> <type 'numpy.float64'>

# %%
# annual_avg_sal = np.mean(indeed['annual_salary']) #not working, typeerror but can't figure it out

def meaner(series):
    '''finds the mean amidst nans'''
    mean_list = []
    for example in series:
        if example != np.NaN:
            try:
                mean_list.append(float(example))
            except (TypeError, ValueError):
                continue
        else:
            continue
    return(np.nanmean(mean_list))

# %%
indeeder['salary'] = (indeeder['monthly_salary']*12)
indeeder['salary'] = (indeeder['hourly_salary']*12*5*9)#12 month, 5 days/ week, 9 hours/day
avg_pay = meaner(indeeder['salary'])
avg_annual_salary = float(meaner(indeeder['annual_salary']))

print("all data:", avg_pay,"annual:", avg_annual_salary)
#all data: 17248.0764706 annual: 107525.268987
#conclusion is: only use annual pay salaries, or avg_annual_salary
# Out:
# all data: 16992.5487805 annual: 106529.86

# %%
# indeeder['above_average_salary'] = indeeder['annual_salary'].apply(lambda x: 1 if x > avg_annual_salary else continue)
# indeeder['above_average_salary'] = indeeder['annual_salary'].apply(lambda x: 0 if x < avg_annual_salary else continue)

def checker(value):
    try:
        if value > avg_annual_salary:
            return 1
        elif value < avg_annual_salary:
            return 0
    except ValueError:
        return 'error'

indeeder['above_average_salary'] = indeeder['annual_salary'].to_frame().applymap(checker)

# %%
skill_list = ['python', 'r', 'learning', 'SQL', 'visualiz', 'mining', 'mung', 'clean', 'scikit-learn']
big_list = ['big', 'advanced', 'volume', 'hadoop', 'spark', 'engineer', 'large']
senior_list = ['senior', 'sr', 'Sr.', 'lead', 'principle', 'chief', 'specialist']

indeeder['skill_count'] = 0  
indeeder['senior_count'] = 0 
indeeder['big_count'] = 0 
indeeder['constant'] = 1
indeeder = indeeder.reset_index()
        
        
for z in range(len(indeeder['description'])):
    try:
        for h in str(indeeder['description'][z]).split():  
            if any(h in s for s in skill_list):
                indeeder.ix[z,'skill_count'] += 1
        for u in indeeder['description'][z].split():  
            if any(u in k for k in senior_list):
                indeeder.ix[z,'senior_count'] += 1
        for d in indeeder['description'][z].split():
            if any(d in q for q in big_list):
                indeeder.ix[z,'big_count'] += 1
    except (ValueError, AttributeError):
        continue
            
indeeder.head(30)

#looks like this starts dropping values around 15th row, also rows 29-39
# Out:
#     index                                     company  \
# 0       0           Maine Health Management Coalition
# 1       1                        Amazon Corporate LLC
# 2       2                        Amazon Corporate LLC
# 3       3                                     Xpandit
# 4       4                                       Alere
# 5       5                                       Alere
# 6       6                               Etech Hi Inc.
# 7       7                         AdvancePierre Foods
# 8       8           Maine Health Management Coalition
# 9       9                          IDEXX Laboratories
# 10     10                      Department of the Navy
# 11     11                                 MaineHealth
# 12     12                      Dept. Marine Resources
# 13     15      Maine Molecular Quality Controls, Inc.
# 14     16       MAINE MOLECULAR QUALITY CONTROLS, INC
# 15     18                   Amazon Web Services, Inc.
# 16     19                        Amazon Corporate LLC
# 17     20                        Amazon Corporate LLC
# 18     21                                Sensory, Inc
# 19     22                              U.S. Air Force
# 20     23                   Amazon Web Services, Inc.
# 21     24                        Amazon Corporate LLC
# 22     25                    Ricerca Biosciences, LLC
# 23     38                   Amazon Web Services, Inc.
# 24    110                         AdvancePierre Foods
# 25    114           Amazon Fulfillment Services, Inc.
# 26    117                        Amazon Corporate LLC
# 27    121                          IDEXX Laboratories
# 28    122                                 MaineHealth
# 29    123                          IDEXX Laboratories
#
#                                           description             location  \
# 0   Understands mapping of data elements to analyt...          Topsham, ME
# 1   As a Principal, you will provide leadership to...        United States
# 2   Are you interested in building data pipelines ...        United States
# 3   \nBut, more than just a “Buzzword Guy”, we see...           Lisbon, ME
# 4   \nAdvanced knowledge of a variety of statistic...      Scarborough, ME
# 5   \nConducts and interprets data. Phases of a pr...      Scarborough, ME
# 6   \nData analyst, data programmer, data scientis...           Brewer, ME
# 7   \nLead multiple complex development projects u...         Portland, ME
# 8   \nUnderstands mapping of data elements to anal...          Topsham, ME
# 9   \nSeeking an Associate Scientist to join a gro...  Westbrook, ME 04092
# 10  \nEvaluating exposure data, surveys, work prac...          Kittery, ME
# 11  \nSkills should include ability to troubleshoo...         Portland, ME
# 12  \nMARINE RESOURCES SCIENTIST I. The incumbent ...          Augusta, ME
# 13  \nProducts through use of public data bases. W...             Saco, ME
# 14  \nWe are seeking an experienced scientist to a...       Saco, ME 04072
# 15  Solid communication and data presentation skil...        United States
# 16  Solid communication and data presentation skil...        United States
# 17  Familiarity with data structures, algorithms, ...        United States
# 18  15-02 - Research Scientist (Emerging Technolog...        United States
# 19  Help Airman get the proper healthcare they nee...        United States
# 20  Computer Science fundamentals in object-orient...        United States
# 21  We love data and we have lots of it. Our appli...        United States
# 22  Review data for technical content and regulato...        United States
# 23  Computer Science fundamentals in object-orient...        United States
# 24  Lead multiple complex development projects usi...         Portland, ME
# 25  Experience with analytics and large data sets....        United States
# 26  Experience managing, or working closely with, ...        United States
# 27  \nPrepares materials, performs experiments, ga...  Westbrook, ME 04092
# 28  \nThe Clinical Research Analyst develops writt...         Portland, ME
# 29  \nWill interpret internally and externally gen...  Westbrook, ME 04092
#
#     salary                                              title  hourly_salary  \
# 0      NaN                            Senior Research Analyst            NaN
# 1      NaN  Principal Data Scientist - Consumer Website- R...            NaN
# 2      NaN  Software Development Engineer, Big Data- Reloc...            NaN
# 3      NaN                                  Big Data Engineer            NaN
# 4      NaN                                       Statistician            NaN
# 5      NaN                       Scientist I (Research Assoc)            NaN
# 6      NaN                                Data Analyst II/III            NaN
# 7      NaN  Food Scientist-Poultry Protein, Culinary Conce...            NaN
# 8      NaN                            Senior Research Analyst            NaN
# 9      NaN   Associate Scientist/Engineer – Systems Chemistry            NaN
# 10     NaN          PHYSICAL SCIENCE TECHNICIAN (INSTRUCTOR),            NaN
# 11     NaN  Technology Manager/Data Analyst - Maine Medica...            NaN
# 12     NaN                       MARINE RESOURCES SCIENTIST I            NaN
# 13     NaN           R & D Scientist II MOLECULAR DIAGNOSTICS            NaN
# 14     NaN           R&D Scientist II - Molecular Diagnostics            NaN
# 15     NaN  Principal Research Scientist, Forecasting and ...            NaN
# 16     NaN  Principal Research Scientist- Relocation Oppor...            NaN
# 17     NaN  Director, Research Science- Relocation Opportu...            NaN
# 18     NaN  Research Scientist-Emerging Technology [3 to 5...            NaN
# 19     NaN                      Biomedical Laboratory Officer            NaN
# 20     NaN  Software Development Engineer – Emerging AWS M...            NaN
# 21     NaN  Principal Applied Scientist, Machine Learning-...            NaN
# 22     NaN  Analytical Scientist (LC-MSMS / NMR Small Mole...            NaN
# 23     NaN  Software Development Engineer – New AWS Machin...            NaN
# 24     NaN  Food Scientist-Poultry Protein, Culinary Conce...            NaN
# 25     NaN  Director, Inbound Optimization- Relocation Opp...            NaN
# 26     NaN  Principal Product Manager- Relocation Opportunity            NaN
# 27     NaN                              Associate Scientist I            NaN
# 28     NaN                          Clinical Research Analyst            NaN
# 29     NaN                                   Systems Engineer            NaN
#
#     monthly_salary  annual_salary  above_average_salary  skill_count  \
# 0              NaN            NaN                   NaN            0
# 1              NaN            NaN                   NaN            2
# 2              NaN            NaN                   NaN            1
# 3              NaN            NaN                   NaN            0
# 4              NaN            NaN                   NaN            1
# 5              NaN            NaN                   NaN            3
# 6              NaN       120000.0                     1            0
# 7              NaN            NaN                   NaN            0
# 8              NaN            NaN                   NaN            0
# 9              NaN            NaN                   NaN            2
# 10             NaN        82964.5                     0            0
# 11             NaN            NaN                   NaN            0
# 12             NaN        46332.0                     0            1
# 13             NaN            NaN                   NaN            1
# 14             NaN            NaN                   NaN            1
# 15             NaN            NaN                   NaN            1
# 16             NaN            NaN                   NaN            1
# 17             NaN            NaN                   NaN            2
# 18             NaN            NaN                   NaN            2
# 19             NaN            NaN                   NaN            2
# 20             NaN            NaN                   NaN            1
# 21             NaN            NaN                   NaN            0
# 22             NaN            NaN                   NaN            0
# 23             NaN            NaN                   NaN            1
# 24             NaN            NaN                   NaN            0
# 25             NaN            NaN                   NaN            0
# 26             NaN            NaN                   NaN            0
# 27             NaN            NaN                   NaN            1
# 28             NaN            NaN                   NaN            1
# 29             NaN            NaN                   NaN            0
#
#     senior_count  big_count  constant
# 0              0          0         1
# 1              2          2         1
# 2              1          1         1
# 3              0          0         1
# 4              1          1         1
# 5              3          3         1
# 6              0          0         1
# 7              0          0         1
# 8              0          0         1
# 9              1          2         1
# 10             0          0         1
# 11             0          0         1
# 12             1          0         1
# 13             0          1         1
# 14             0          1         1
# 15             0          0         1
# 16             1          2         1
# 17             1          2         1
# 18             0          0         1
# 19             1          2         1
# 20             1          1         1
# 21             0          0         1
# 22             0          0         1
# 23             1          1         1
# 24             0          0         1
# 25             0          0         1
# 26             2          0         1
# 27             0          1         1
# 28             1          1         1
# 29             0          0         1

# %%
# before creating subsample with valid y values, checking shape/size
indeeder['annual_salary'].value_counts()
# Out:
# 150000.0    12
# 110000.0     6
# 52842.0      5
# 155000.0     5
# 120000.0     5
# 130000.0     4
# 140000.0     4
# 85000.0      4
# 100000.0     4
# 125000.0     3
# 135000.0     3
# 105000.0     3
# 95000.0      3
# 112500.0     2
# 75000.0      2
# 46332.0      2
# 116850.0     2
# 125221.0     2
# 190000.0     2
# 165000.0     2
# 132500.0     2
# 94531.0      2
# 127500.0     2
# 70000.0      2
# 78483.0      2
# 98642.0      2
# 185000.0     1
# 41000.0      1
# 49165.0      1
# 101701.5     1
#             ..
# 138300.0     1
# 40000.0      1
# 200000.0     1
# 93645.0      1
# 65000.0      1
# 44543.0      1
# 65060.0      1
# 77500.0      1
# 61183.0      1
# 180000.0     1
# 110445.0     1
# 89405.5      1
# 84649.0      1
# 240000.0     1
# 54351.5      1
# 50794.0      1
# 87792.0      1
# 90000.0      1
# 141158.0     1
# 43014.5      1
# 78195.5      1
# 67588.0      1
# 47406.0      1
# 43123.5      1
# 65643.5      1
# 54963.5      1
# 170000.0     1
# 51438.0      1
# 137500.0     1
# 82964.5      1
# Name: annual_salary, dtype: int64

# %% [markdown]
# Baseline accuracy in the model should be 50%, as we're going to compare each opportunity to the mean value found in the dataset, meaning there are only two options: higher or lower. If we cannot create a model that outperforms a coinflip, we have failed miserably.

# %%
import statsmodels.api as sm
import pandas as pd
import pylab as pl
import numpy as np
import patsy

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.cross_validation import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import roc_auc_score

vals = [0,1]
indeeder_subsamp = indeeder.loc[indeeder['above_average_salary'].isin(vals)]
y = indeeder_subsamp['above_average_salary']
y.head()
#only 5 values to train on? Can't figure out where I'm losing all this data
# Out:
# 6     1
# 10    0
# 12    0
# 31    0
# 42    1
# Name: above_average_salary, dtype: float64

# %%
#WILL RETURN TO THIS, TRYING TO UNDERSTAND DROPPED DATA

# city_list = ['SF', 'San Francisco', 'Francisco', 'New York', 'York', 'NY', 'NYC']
# indeeder['big_city'] = 0

# for gindex, gvalue in enumerate(indeeder['location']):
#     if any(str(gvalue).split()) in city_list:
#         indeeder['big_city'][gindex] = 1


# X_lame = pd.get_dummies(indeeder.loc['big_city', 'constant'])

# %%
#most basic logistic regression
indeeder.describe()
# Out:
#              index        salary  hourly_salary  monthly_salary  \
# count  2297.000000     41.000000      41.000000       76.000000
# mean   2303.210710  16992.548780      31.467683     2455.022039
# std    1409.753225   9274.238605      17.174516     3086.856517
# min       0.000000   5535.000000      10.250000       10.250000
# 25%    1143.000000  10800.000000      20.000000       24.421250
# 50%    2060.000000  13500.000000      25.000000       62.500000
# 75%    3378.000000  20717.100000      38.365000     4716.500000
# max    5044.000000  40500.000000      75.000000     9350.000000
#
#        annual_salary  above_average_salary  skill_count  senior_count  \
# count     150.000000            150.000000  2297.000000   2297.000000
# mean   106529.860000              0.506667     0.965607      0.875054
# std     40814.298371              0.501630     1.091678      1.041211
# min     30000.000000              0.000000     0.000000      0.000000
# 25%     75000.000000              0.000000     0.000000      0.000000
# 50%    108750.000000              1.000000     1.000000      1.000000
# 75%    136875.000000              1.000000     2.000000      1.000000
# max    240000.000000              1.000000     6.000000      6.000000
#
#          big_count  constant
# count  2297.000000      2297
# mean      0.741402         1
# std       0.901120         0
# min       0.000000         1
# 25%       0.000000         1
# 50%       1.000000         1
# 75%       1.000000         1
# max       5.000000         1

# %%
features = indeeder_subsamp.loc[:,['senior_count', 'skill_count', 'big_count', 'constant']]#will add 'big_city' later

# %%
indeeder['skill_binary'] = indeeder['skill_count'].apply(lambda x: 1 if x > 0 else 0)
indeeder['senior_binary'] = indeeder['senior_count'].apply(lambda x: 1 if x > 0 else 0)
indeeder['big_binary'] = indeeder['big_count'].apply(lambda x: 1 if x > 0 else 0)
binary_features = indeeder_subsamp.loc[:,['senior_binary', 'skill_binary', 'big_binary', 'constant']]

# %%
X = features
X1 = binary_features
X.head()
# Out:
#     senior_count  skill_count  big_count  constant
# 6              0            0          0         1
# 10             0            0          0         1
# 12             1            1          0         1
# 31             1            1          1         1
# 42             4            4          3         1

# %% [markdown]
# ### PLEASE NOTE: FROM HERE ON, I CONDUCTED MY ANALYSIS IN MORE DEPTH USING ALEX'S DATA
# #### It can be found here: GA_dsi-projects/projects/4th/project4_final-Alex_data.ipynb

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=50)

# %%
lr_basic = LogisticRegression(solver='liblinear') #can i take away penalty? make sure this is statsmodels
lr_basic_model = lr_basic.fit(X_train, y_train)
lr_basic_ypred = lr_basic_model.predict(X_test)

lr_basic_cm = confusion_matrix(y_test, lr_basic_ypred, labels=lr_basic.classes_)
lr_basic_cm_df = pd.DataFrame(lr_basic_cm, columns=lr_basic.classes_, index=lr_basic.classes_) #lr_l1_SF is instance of model
lr_basic_cm_df
#can't print classification report? Taking too long to run
#appears my model is about as well as average; precision = 11/19, recall = 11/27
# Out:
#     0  1
# 0  13  6
# 1  24  7

# %%
# generic curve plotting function
import matplotlib.pyplot as plt
from sklearn import metrics
def auc_plotting_function(rate1, rate2, rate1_name, rate2_name, curve_name):
    AUC = metrics.auc(rate1, rate2)
    # Plot of a ROC curve for class 1 (has_cancer)
    plt.figure(figsize=[11,9])
    plt.plot(rate1, rate2, label=curve_name + ' (area = %0.2f)' % AUC, linewidth=4)
    plt.plot([0, 1], [0, 1], 'k--', linewidth=4)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel(rate1_name, fontsize=18)
    plt.ylabel(rate2_name, fontsize=18)
    plt.title(curve_name + ' for salary above average', fontsize=18)
    plt.legend(loc="lower right")
    plt.show()

# plot receiving operator characteristic curve
def plot_roc(y_true, y_score):
    fpr, tpr, _ = metrics.roc_curve(y_true, y_score)
    auc_plotting_function(fpr, tpr, 'False Positive Rate', 'True Positive Rate', 'ROC')

# %%
y_score_basic = lr_basic.decision_function(X_test)
plot_roc(y_test, y_score_basic)

# %%
classification_report(y_test, lr_basic_ypred, labels=lr_basic.classes_)

# %%
cross_val_score(lr_basic, X, y, cv=10).mean()

# %%
#Lasso
lr_l1 = LogisticRegression(penalty='l1', solver='liblinear') #can i take away penalty? make sure this is statsmodels
lr_l1_model = lr_l1.fit(X_train, y_train)
lr_l1_ypred = lr_l1_model.predict(X_test)

lr_l1_cm = confusion_matrix(y_test, lr_l1_ypred, labels=lr_l1.classes_)
lr_l1_cm_df = pd.DataFrame(lr_l1_cm, columns=lr_basic.classes_, index=lr_l1.classes_) #lr_l1_SF is instance of model
lr_l1_cm_df

# %%
print(classification_report(y_test, lr_l1_ypred, labels=lr_l1.classes_))

# %%
cross_val_score(lr_l1, X, y, cv=10).mean()

# %%
Y_score_l1 = lr_l1.decision_function(X_test)
plot_roc(Y_test, Y_score_l1)

# %%
#Ridge
lr_l2 = LogisticRegression(penalty='l2', solver='liblinear') #can i take away penalty? make sure this is statsmodels
lr_l2_model = lr_l2.fit(X_train, y_train)
lr_l2_ypred = lr_l2_model.predict(X_test)

lr_l2_cm = confusion_matrix(y_test, lr_l2_ypred, labels=lr_l2.classes_)
lr_l2_cm_df = pd.DataFrame(lr_lr_l2_cm, columns=lr_l2.classes_, index=lr_l2.classes_) #lr_l1_SF is instance of model
lr_l2_cm_df

# %%
print(classification_report(y_test, lr_l2_ypred, labels=lr_l2.classes_))

# %%
cross_val_score(lr_l2, X, y, cv=10).mean()

# %%
Y_score_l2 = lr_l1.decision_function(X_test)
plot_roc(Y_test, Y_score_l2)

# %%
#grid search optimization
logreg = LogisticRegression(solver='liblinear')
C_vals = [0.0001, 0.001, 0.01, 0.1, .15, .25, .275, .33, 0.5, .66, 0.75, 1.0, 2.5, 5.0, 10.0, 100.0, 1000.0]
penalties = ['l1','l2']

gs = GridSearchCV(logreg, {'penalty': penalties, 'C': C_vals}, verbose=False, cv=15)
gs.fit(X, y)

# %%
gs.best_params_

# %%
logreg = LogisticRegression(C=gs.best_params_['C'], penalty=gs.best_params_['penalty'])
cv_model = logreg.fit(X_train, y_train)

# %%
cv_pred = cv_model.predict(X_test)

# %%
cm3 = confusion_matrix(y_test, cv_pred, labels=logreg.classes_)
cm3 = pd.DataFrame(cm3, columns=logreg.classes_, index=logreg.classes_)

# %%
cm3

# %%
print(classification_report(y_test, cv_pred, labels=logreg.classes_))

# %%
Y_score_gs = logreg.decision_function(X_test)
plot_roc(y_test, Y_score_gs)

# %%
import seaborn as sns
sns.distplot(indeeder_subsamp['annual_salary'].dropna())
