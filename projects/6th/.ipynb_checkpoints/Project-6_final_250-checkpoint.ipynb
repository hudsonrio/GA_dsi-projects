# %%
import pandas as pd
import numpy as np
import sklearn 
import json
import urllib2
import requests
import json
import re
import matplotlib.pyplot as plt
# %matplotlib inline
from imdbpie import Imdb

# %%
imdb = Imdb()
top_250 = imdb.top_250()
top_250 = pd.DataFrame(top_250)


url = 'http://www.omdbapi.com/?i=tt0111161&plot=full&r=json'

keys = (json.load(urllib2.urlopen(url)).keys())


api_base_url = 'http://www.omdbapi.com/?i={}&plot=full&r=json'

value_list = []
for id_example in set(top_250['tconst'].values):
    value_list.append((json.load(urllib2.urlopen(api_base_url.format(id_example)))).values())
    
df = pd.DataFrame(value_list, columns=keys) #pandas takes each list within list and stacks it into a dataframe

# %%
df.head(15)
# Out:
#                                                  Plot      Rated Response  \
# 0   A young and talented drummer attending a prest...          R     True
# 1   A veteran samurai, who has fallen on hard time...    UNRATED     True
# 2   Archaeologist and adventurer Indiana Jones is ...         PG     True
# 3   The film deals with the situation of British p...         PG     True
# 4   Earth's mightiest heroes must come together an...      PG-13     True
# 5   While exploring the uncharted wilderness in 18...          R     True
# 6   Chan Wing Yan, a young police officer, has bee...          R     True
# 7   In a decrepit South American village, men are ...  NOT RATED     True
# 8   A crafty ronin comes to a town divided by two ...    UNRATED     True
# 9   A clown fish named Marlin lives in the Great B...          G     True
# 10  Eve is waiting backstage to meet her "idol" ag...   APPROVED     True
# 11  A city of monsters with no humans called Monst...          G     True
# 12  Set against the sexy, glamorous golden age of ...          R     True
# 13  Wanting to learn from the best, aspiring boxer...      PG-13     True
# 14  Allied P.O.W.s plan for several hundred of the...   APPROVED     True
#
#                                              Language  \
# 0                                             English
# 1                                            Japanese
# 2    English, German, Hebrew, Spanish, Arabic, Nepali
# 3                             English, Japanese, Thai
# 4                                    English, Russian
# 5                             English, Pawnee, French
# 6                            Cantonese, English, Thai
# 7   French, English, Spanish, German, Italian, Rus...
# 8                                            Japanese
# 9                                             English
# 10                                    English, French
# 11                                            English
# 12          English, German, Italian, French, Spanish
# 13                                     English, Irish
# 14                   English, German, French, Russian
#
#                            Title                         Country  \
# 0                       Whiplash                             USA
# 1                  Seven Samurai                           Japan
# 2        Raiders of the Lost Ark                             USA
# 3   The Bridge on the River Kwai                         UK, USA
# 4                   The Avengers                             USA
# 5                   The Revenant  USA, Hong Kong, Taiwan, Canada
# 6               Infernal Affairs                       Hong Kong
# 7              The Wages of Fear                   France, Italy
# 8                        Yojimbo                           Japan
# 9                   Finding Nemo                             USA
# 10                 All About Eve                             USA
# 11                Monsters, Inc.                             USA
# 12                          Rush                UK, Germany, USA
# 13           Million Dollar Baby                             USA
# 14              The Great Escape                             USA
#
#                                                Writer Metascore imdbRating  \
# 0                                     Damien Chazelle        88        8.5
# 1   Akira Kurosawa (screenplay), Shinobu Hashimoto...        99        8.7
# 2   Lawrence Kasdan (screenplay), George Lucas (st...        85        8.5
# 3   Pierre Boulle (novel), Carl Foreman (screenpla...       N/A        8.2
# 4   Joss Whedon (screenplay), Zak Penn (story), Jo...        69        8.1
# 5   Mark L. Smith (screenplay), Alejandro G. Iñárr...        76        8.1
# 6                               Alan Mak, Felix Chong        75        8.1
# 7   Georges Arnaud (novel), Henri-Georges Clouzot ...       N/A        8.2
# 8   Akira Kurosawa (story), Akira Kurosawa (screen...       N/A        8.3
# 9   Andrew Stanton (original story by), Andrew Sta...        90        8.1
# 10   Joseph L. Mankiewicz (written for the screen by)       N/A        8.3
# 11  Pete Docter (original story by), Jill Culton (...        78        8.1
# 12                                       Peter Morgan        75        8.1
# 13     Paul Haggis (screenplay), F.X. Toole (stories)        86        8.1
# 14  Paul Brickhill (book), James Clavell (screenpl...       N/A        8.3
#
#                                      Director     Released  \
# 0                             Damien Chazelle  15 Oct 2014
# 1                              Akira Kurosawa  19 Nov 1956
# 2                            Steven Spielberg  12 Jun 1981
# 3                                  David Lean  14 Dec 1957
# 4                                 Joss Whedon  04 May 2012
# 5                       Alejandro G. Iñárritu  08 Jan 2016
# 6                     Wai-Keung Lau, Alan Mak  12 Dec 2002
# 7                       Henri-Georges Clouzot  16 Feb 1955
# 8                              Akira Kurosawa  13 Sep 1961
# 9                 Andrew Stanton, Lee Unkrich  30 May 2003
# 10                       Joseph L. Mankiewicz  15 Jan 1951
# 11  Pete Docter, David Silverman, Lee Unkrich  02 Nov 2001
# 12                                 Ron Howard  27 Sep 2013
# 13                             Clint Eastwood  28 Jan 2005
# 14                               John Sturges  04 Jul 1963
#
#                                                Actors  Year  \
# 0   Miles Teller, J.K. Simmons, Paul Reiser, Melis...  2014
# 1   Toshirô Mifune, Takashi Shimura, Keiko Tsushim...  1954
# 2   Harrison Ford, Karen Allen, Paul Freeman, Rona...  1981
# 3   William Holden, Alec Guinness, Jack Hawkins, S...  1957
# 4   Robert Downey Jr., Chris Evans, Mark Ruffalo, ...  2012
# 5   Leonardo DiCaprio, Tom Hardy, Domhnall Gleeson...  2015
# 6   Andy Lau, Tony Chiu Wai Leung, Anthony Chau-Sa...  2002
# 7   Yves Montand, Charles Vanel, Folco Lulli, Pete...  1953
# 8   Toshirô Mifune, Tatsuya Nakadai, Yôko Tsukasa,...  1961
# 9   Albert Brooks, Ellen DeGeneres, Alexander Goul...  2003
# 10  Bette Davis, Anne Baxter, George Sanders, Cele...  1950
# 11  John Goodman, Billy Crystal, Mary Gibbs, Steve...  2001
# 12  Chris Hemsworth, Daniel Brühl, Olivia Wilde, A...  2013
# 13  Clint Eastwood, Hilary Swank, Morgan Freeman, ...  2004
# 14  Steve McQueen, James Garner, Richard Attenboro...  1963
#
#                            Genre  \
# 0                   Drama, Music
# 1       Action, Adventure, Drama
# 2              Action, Adventure
# 3          Adventure, Drama, War
# 4      Action, Adventure, Sci-Fi
# 5     Adventure, Drama, Thriller
# 6       Crime, Mystery, Thriller
# 7     Adventure, Drama, Thriller
# 8        Comedy, Drama, Thriller
# 9   Animation, Adventure, Comedy
# 10                         Drama
# 11  Animation, Adventure, Comedy
# 12      Action, Biography, Drama
# 13                  Drama, Sport
# 14     Adventure, Drama, History
#
#                                                Awards  Runtime   Type  \
# 0    Won 3 Oscars. Another 87 wins & 128 nominations.  107 min  movie
# 1   Nominated for 2 Oscars. Another 5 wins & 6 nom...  207 min  movie
# 2     Won 4 Oscars. Another 29 wins & 23 nominations.  115 min  movie
# 3      Won 7 Oscars. Another 23 wins & 7 nominations.  161 min  movie
# 4   Nominated for 1 Oscar. Another 36 wins & 78 no...  143 min  movie
# 5    Won 3 Oscars. Another 73 wins & 156 nominations.  156 min  movie
# 6                           23 wins & 21 nominations.  101 min  movie
# 7             Won 1 BAFTA Film Award. Another 5 wins.  131 min  movie
# 8   Nominated for 1 Oscar. Another 4 wins & 1 nomi...  110 min  movie
# 9      Won 1 Oscar. Another 46 wins & 59 nominations.  100 min  movie
# 10    Won 6 Oscars. Another 16 wins & 17 nominations.  138 min  movie
# 11     Won 1 Oscar. Another 13 wins & 38 nominations.   92 min  movie
# 12  Nominated for 2 Golden Globes. Another 6 wins ...  123 min  movie
# 13    Won 4 Oscars. Another 60 wins & 81 nominations.  132 min  movie
# 14  Nominated for 1 Oscar. Another 2 wins & 7 nomi...  172 min  movie
#
#                                                Poster imdbVotes     imdbID
# 0   http://ia.media-imdb.com/images/M/MV5BMTU4OTQ3...   384,504  tt2582802
# 1   http://ia.media-imdb.com/images/M/MV5BMTc5MDY1...   226,364  tt0047478
# 2   http://ia.media-imdb.com/images/M/MV5BMjA0ODEz...   653,557  tt0082971
# 3   http://ia.media-imdb.com/images/M/MV5BMTc2NzA0...   147,591  tt0050212
# 4   http://ia.media-imdb.com/images/M/MV5BMTk2NTI1...   980,989  tt0848228
# 5   http://ia.media-imdb.com/images/M/MV5BMjU4NDEx...   377,143  tt1663202
# 6   http://ia.media-imdb.com/images/M/MV5BMTc0Mjg2...    90,435  tt0338564
# 7   http://ia.media-imdb.com/images/M/MV5BMTQ5Mzky...    34,849  tt0046268
# 8   http://ia.media-imdb.com/images/M/MV5BMjAwNTQ3...    73,272  tt0055630
# 9   http://ia.media-imdb.com/images/M/MV5BMTY1MTg1...   676,475  tt0266543
# 10  http://ia.media-imdb.com/images/M/MV5BMTY2MTAz...    81,857  tt0042192
# 11  http://ia.media-imdb.com/images/M/MV5BMTY1NTI0...   574,196  tt0198781
# 12  http://ia.media-imdb.com/images/M/MV5BMTQyMDE0...   305,831  tt1979320
# 13  http://ia.media-imdb.com/images/M/MV5BMTkxNzA1...   475,688  tt0405159
# 14  http://ia.media-imdb.com/images/M/MV5BMjI2MTQw...   164,017  tt0057115

# %%
actor_list = set(df['Actors'])

# %%
df_small.columns
# Out:
# Index([u'Plot', u'Rated', u'Response', u'Language', u'Title', u'Country',
#        u'Writer', u'Metascore', u'imdbRating', u'Director', u'Released',
#        u'Actors', u'Year', u'Genre', u'Awards', u'Runtime', u'Type', u'Poster',
#        u'imdbVotes', u'imdbID'],
#       dtype='object')

# %%
#Also importing data based on omdb python wrapper: https://github.com/dgilland/omdb.py

import omdb

# # must use OMDb API parameters https://github.com/dgilland/omdb.py
#json is default, but this wrapper converts to a dict under the hood so I can use .keys and .values directly on it
#won't work with ID, need title, but don;t need to clean it

keys_wrapper = (omdb.get(title='True Grit', tomatoes=True)).keys() #looks like this is going to require title

# omdb.get(title='True Grit', year=1969, fullplot=True, tomatoes=True)
movie_info_vals = []

for titlez in set(df['Title'].values):
    movie_info_vals.append((omdb.get(title=titlez, tomatoes=True).values()))

df_2 = pd.DataFrame(movie_info_vals, columns=keys_wrapper) 

df_2.columns
# Out:
# Index([u'metascore', u'year', u'tomato_rating', u'tomato_meter', u'plot',
#        u'rated', u'tomato_rotten', u'title', u'tomato_consensus', u'writer',
#        u'tomato_user_meter', u'production', u'actors', u'tomato_fresh',
#        u'imdb_votes', u'type', u'tomato_user_reviews', u'website', u'poster',
#        u'imdb_id', u'director', u'released', u'tomato_reviews', u'awards',
#        u'tomato_user_rating', u'genre', u'response', u'language', u'dvd',
#        u'imdb_rating', u'country', u'tomato_image', u'runtime', u'box_office'],
#       dtype='object')

# %%
df.columns
# Out:
# Index([      u'Plot',      u'Rated',   u'Response',   u'Language',
#             u'Title',    u'Country',     u'Writer',  u'Metascore',
#        u'imdbRating',   u'Director',   u'Released',     u'Actors',
#              u'Year',      u'Genre',     u'Awards',    u'Runtime',
#              u'Type',     u'Poster',  u'imdbVotes',     u'imdbID',
#         u'mod_title'],
#       dtype='object')

# %%
Index([u'metascore', u'year', u'tomato_rating', u'tomato_meter', u'plot',
       u'rated', u'tomato_rotten', u'title', u'tomato_consensus', u'writer',
       u'tomato_user_meter', u'production', u'actors', u'tomato_fresh',
       u'imdb_votes', u'type', u'tomato_user_reviews', u'website', u'poster',
       u'imdb_id', u'director', u'released', u'tomato_reviews', u'awards',
       u'tomato_user_rating', u'genre', u'response', u'language', u'dvd',
       u'imdb_rating', u'country', u'tomato_image', u'runtime', u'box_office'],
      dtype='object')

# %%
# df_2.describe()

# %%
print(df_2)


ratings_list = ['metascore', 'tomato_rating', 'tomato_meter', 'tomato_rotten','tomato_consensus','tomato_user_meter','tomato_user_reviews', 'tomato_reviews', 'tomato_user_rating', 'imdb_rating']
# Out:
#     metascore  year tomato_rating tomato_meter  \
# 0          79  2014           8.0           88
# 1          65  2016           6.9           84
# 2         N/A  1986           8.1           88
# 3          58  1969           8.2           89
# 4         N/A  1963           N/A          N/A
# 5          75  1979           8.3           96
# 6          79  2004           8.0           90
# 7         N/A  1986           8.0           91
# 8         100  1962           9.1           97
# 9          55  2000           6.4           73
# 10         80  1968           9.0           98
# 11        N/A  1963           8.5           98
# 12        N/A  1950           N/A          N/A
# 13         76  1953           8.4           98
# 14         80  2009           7.8           91
# 15         78  1971           8.4           90
# 16         98  1927           9.1           99
# 17         78  2016           8.1           98
# 18         82  2010           7.9           92
# 19         69  2012           8.0           92
# 20         92  1995           9.0          100
# 21         69  2003           7.7           85
# 22        N/A  1931           9.1           98
# 23         61  1980           8.5           88
# 24        N/A  1941           9.4          100
# 25        N/A  1985           8.1           95
# 26         74  2010           8.1           86
# 27         80  1994           8.2           91
# 28        N/A  1927           8.9           98
# 29        N/A  1941           9.0          100
# ..        ...   ...           ...          ...
# 220        86  1974           9.3           98
# 221        94  2015           8.9           98
# 222        75  1991           8.4           93
# 223      None  None          None         None
# 224        67  2009           7.2          100
# 225        92  2001           8.2           91
# 226       N/A  1940           9.0          100
# 227       N/A  1991           8.4           93
# 228        73  2007           7.5           82
# 229       N/A  1982           8.0           88
# 230        88  1954           9.1           98
# 231        74  2010           7.9           98
# 232        87  2011           8.3           96
# 233        89  2006           8.3           93
# 234        92  2010           8.9           99
# 235        90  1975           8.5           97
# 236        85  2002           8.2           96
# 237        78  2012           8.0           87
# 238        76  2002           7.9           96
# 239        76  2014           7.7           91
# 240        86  2006           8.2           91
# 241        79  1975           8.9           95
# 242       N/A  1946           8.6           96
# 243        75  2002           7.6           95
# 244       N/A  1995           8.0          100
# 245        66  1998           6.8           76
# 246       N/A  1962           8.8           91
# 247       N/A  1952           8.7          100
# 248        83  1984           8.8          100
# 249        93  1976           9.0           99
#
#                                                   plot      rated  \
# 0    With his wife's disappearance having become th...          R
# 1    A former Special Forces operative turned merce...          R
# 2    A young recruit in Vietnam faces a moral crisi...          R
# 3    Two Western bank/train robbers flee to Bolivia...          M
# 4    Allied P.O.W.s plan for several hundred of the...   APPROVED
# 5    Brian is born on the original Christmas, in th...          R
# 6    The true story of Paul Rusesabagina, a hotel m...      PG-13
# 7    After the death of a friend, a writer recounts...          R
# 8    The story of TE Lawrence, the English officer ...         PG
# 9    Unscrupulous boxing promoters, violent bookmak...          R
# 10   Epic story of a mysterious stranger with a har...      PG-13
# 11   A harried movie director retreats into his mem...  NOT RATED
# 12   A heinous crime and its aftermath are recalled...    UNRATED
# 13   A bored and sheltered princess escapes her gua...  NOT RATED
# 14   A retired legal counselor writes a novel hopin...          R
# 15   In future Britain, charismatic delinquent Alex...          X
# 16   In a futuristic city sharply divided between t...  NOT RATED
# 17   In a city of anthropomorphic animals, a rookie...         PG
# 18   Twins journey to the Middle East to discover t...          R
# 19   Earth's mightiest heroes must come together an...      PG-13
# 20   A cowboy doll is profoundly threatened and jea...          G
# 21   The Bride wakens from a four-year coma. The ch...          R
# 22   With the aid of a wealthy erratic tippler, a d...     PASSED
# 23   A family heads to an isolated hotel for the wi...          R
# 24   Following the death of a publishing tycoon, ne...   APPROVED
# 25   After finding an old rifle, a young boy joins ...  NOT RATED
# 26   A thief, who steals corporate secrets through ...      PG-13
# 27   Two imprisoned men bond over a number of years...          R
# 28   A married farmer falls under the spell of a sl...  NOT RATED
# 29   A private detective takes on a case that invol...  NOT RATED
# ..                                                 ...        ...
# 220  A private detective hired to expose an adulter...          R
# 221  After young Riley is uprooted from her Midwest...         PG
# 222  A cyborg, identical to the one who failed to k...          R
# 223                                               None       None
# 224  Two friends are searching for their long lost ...      PG-13
# 225  A meek Hobbit and eight companions set out on ...      PG-13
# 226  A poor Midwest family is forced off of their l...  NOT RATED
# 227  Belle, whose father is imprisoned by the Beast...          G
# 228  After graduating from Emory University, top st...          R
# 229  Gandhi's character is fully explained as a man...         PG
# 230  An ex-prize fighter turned longshoreman strugg...  NOT RATED
# 231  A hapless young Viking who aspires to hunt dra...         PG
# 232  Harry, Ron and Hermione search for Voldemort's...      PG-13
# 233  In 1984 East Berlin, an agent of the secret po...          R
# 234  The toys are mistakenly delivered to a day-car...          G
# 235  King Arthur and his knights embark on a low-bu...         PG
# 236  A Polish Jewish musician struggles to survive ...          R
# 237  Eight years after the Joker's reign of anarchy...      PG-13
# 238  The true story of Frank Abagnale Jr. who, befo...      PG-13
# 239  A group of intergalactic criminals are forced ...      PG-13
# 240  An undercover cop and a mole in the police att...          R
# 241  A criminal pleads insanity after getting into ...          R
# 242  Three World War II veterans return home to sma...  NOT RATED
# 243  A story between a mole in the police departmen...          R
# 244  24 hours in the lives of three young men in th...  NOT RATED
# 245  A botched card game in London triggers four fr...          R
# 246  Atticus Finch, a lawyer in the Depression-era ...  NOT RATED
# 247  A bureaucrat tries to find a meaning in his li...  NOT RATED
# 248  A human-looking indestructible cyborg is sent ...          R
# 249  A mentally unstable Vietnam War veteran works ...          R
#
#     tomato_rotten                                              title  \
# 0              35                                          Gone Girl
# 1              44                                           Deadpool
# 2               7                                            Platoon
# 3               5                 Butch Cassidy and the Sundance Kid
# 4             N/A                                   The Great Escape
# 5               2                                      Life of Brian
# 6              18                                       Hotel Rwanda
# 7               5                                        Stand by Me
# 8               2                                 Lawrence of Arabia
# 9              38                                            Snatch.
# 10              1                       Once Upon a Time in the West
# 11              1                                                 8½
# 12            N/A                                           Rashomon
# 13              1                                      Roman Holiday
# 14             12                           The Secret in Their Eyes
# 15              5                                 A Clockwork Orange
# 16              1                                         Metropolis
# 17              4                                           Zootopia
# 18              9                                          Incendies
# 19             26                                       The Avengers
# 20              0                                          Toy Story
# 21             34                                  Kill Bill: Vol. 1
# 22              1                                        City Lights
# 23              8                                        The Shining
# 24              0                                       Citizen Kane
# 25              1                                       Come and See
# 26             46                                          Inception
# 27              6                           The Shawshank Redemption
# 28              1                                            Sunrise
# 29              0                                 The Maltese Falcon
# ..            ...                                                ...
# 220             1                                          Chinatown
# 221             6                                         Inside Out
# 222             5                         Terminator 2: Judgment Day
# 223          None                                               None
# 224             0                                           3 Idiots
# 225            20  The Lord of the Rings: The Fellowship of the Ring
# 226             0                                The Grapes of Wrath
# 227             7                               Beauty and the Beast
# 228            34                                      Into the Wild
# 229             6                                             Gandhi
# 230             1                                  On the Waterfront
# 231             4                           How to Train Your Dragon
# 232            13       Harry Potter and the Deathly Hallows: Part 2
# 233            10                                The Lives of Others
# 234             4                                        Toy Story 3
# 235             2                    Monty Python and the Holy Grail
# 236             8                                        The Pianist
# 237            44                              The Dark Knight Rises
# 238             8                                Catch Me If You Can
# 239            25                            Guardians of the Galaxy
# 240            25                                       The Departed
# 241             3                    One Flew Over the Cuckoo's Nest
# 242             2                        The Best Years of Our Lives
# 243             3                                   Infernal Affairs
# 244             0                                           La Haine
# 245            14                Lock, Stock and Two Smoking Barrels
# 246             5                              To Kill a Mockingbird
# 247             0                                              Ikiru
# 248             0                                     The Terminator
# 249             1                                        Taxi Driver
#
#                                       tomato_consensus  \
# 0    Dark, intelligent, and stylish to a fault, Gon...
# 1    Fast, funny, and gleefully profane, the fourth...
# 2    Informed by director Oliver Stone's personal e...
# 3    With its iconic pairing of Paul Newman and Rob...
# 4                                                  N/A
# 5    One of the more cutting=edge films of the 1970...
# 6    A sobering and heartfelt tale about massacre t...
# 7                                                  N/A
# 8    The epic of all epics, Lawrence of Arabia ceme...
# 9    Though perhaps a case of style over substance,...
# 10   A landmark Sergio Leone spaghetti western mast...
# 11   Inventive, thought-provoking, and funny, 8 1/2...
# 12                                                 N/A
# 13   With Audrey Hepburn luminous in her American d...
# 14   Unpredictable and rich with symbolism, this Ar...
# 15   Disturbing and thought-provoking, A Clockwork ...
# 16   A visually awe-inspiring science fiction class...
# 17   The brilliantly well-rounded Zootopia offers a...
# 18   It's messy, overlong, and a touch melodramatic...
# 19   Thanks to a script that emphasizes its heroes'...
# 20   Entertaining as it is innovative, Toy Story re...
# 21   Kill Bill is admittedly little more than a sty...
# 22                                                 N/A
# 23   Though it deviates from Stephen King's novel, ...
# 24   Orson Welles's epic tale of a publishing tycoo...
# 25                                                 N/A
# 26   Smart, innovative, and thrilling, Inception is...
# 27   The Shawshank Redemption is an uplifting, deep...
# 28   Boasting masterful cinematography to match its...
# 29   Suspenseful, labyrinthine, and brilliantly cas...
# ..                                                 ...
# 220  As bruised and cynical as the decade that prod...
# 221  Inventive, gorgeously animated, and powerfully...
# 222  T2 features thrilling action sequences and eye...
# 223                                               None
# 224                                                N/A
# 225  Full of eye-popping special effects, and featu...
# 226  A potent drama that is as socially important t...
# 227  Enchanting, sweepingly romantic, and featuring...
# 228  With his sturdy cast and confident direction, ...
# 229  Director Richard Attenborough is typically sym...
# 230  With his electrifying performance in Elia Kaza...
# 231  Boasting dazzling animation, a script with sur...
# 232  Thrilling, powerfully acted, and visually dazz...
# 233  Unlike more traditional spy films,  The Lives ...
# 234  Deftly blending comedy, adventure, and honest ...
# 235  A cult classic as gut-bustingly hilarious as i...
# 236  Well-acted and dramatically moving, The Pianis...
# 237  The Dark Knight Rises is an ambitious, thought...
# 238  With help from a strong performance by Leonard...
# 239  Guardians of the Galaxy is just as irreverent ...
# 240  Featuring outstanding work from an excellent c...
# 241  The onscreen battle between Jack Nicholson and...
# 242  An engrossing look at the triumphs and travail...
# 243  Smart and engrossing, this is one of Hong Kong...
# 244                                                N/A
# 245  Lock, Stock, and Two Smoking Barrels is a grim...
# 246                                                N/A
# 247  Ikiru is a well-acted and deeply moving humani...
# 248  With its impressive action sequences, taut eco...
# 249  A must-see film for movie lovers, this Martin ...
#
#                                                 writer    ...      \
# 0    Gillian Flynn (screenplay), Gillian Flynn (novel)    ...
# 1    Rhett Reese, Paul Wernick, Fabian Nicieza (cha...    ...
# 2                                         Oliver Stone    ...
# 3                                      William Goldman    ...
# 4    Paul Brickhill (book), James Clavell (screenpl...    ...
# 5    Graham Chapman, John Cleese, Terry Gilliam, Er...    ...
# 6                           Keir Pearson, Terry George    ...
# 7    Stephen King (novel), Raynold Gideon (screenpl...    ...
# 8    T.E. Lawrence (writings), Robert Bolt (screenp...    ...
# 9                                          Guy Ritchie    ...
# 10   Sergio Donati (screenplay), Sergio Leone (scre...    ...
# 11   Federico Fellini (story), Ennio Flaiano (story...    ...
# 12   Ryûnosuke Akutagawa (stories), Akira Kurosawa ...    ...
# 13   Ian McLellan Hunter (screenplay), John Dighton...    ...
# 14   Eduardo Sacheri, Juan José Campanella, Eduardo...    ...
# 15   Stanley Kubrick (screenplay), Anthony Burgess ...    ...
# 16   Thea von Harbou (screenplay), Thea von Harbou ...    ...
# 17   Byron Howard (story by), Rich Moore (story by)...    ...
# 18   Denis Villeneuve (scenario), Wajdi Mouawad (pl...    ...
# 19   Joss Whedon (screenplay), Zak Penn (story), Jo...    ...
# 20   John Lasseter (original story by), Pete Docter...    ...
# 21   Quentin Tarantino, Quentin Tarantino (characte...    ...
# 22                                     Charles Chaplin    ...
# 23   Stephen King (novel), Stanley Kubrick (screenp...    ...
# 24   Herman J. Mankiewicz (original screen play), O...    ...
# 25   Ales Adamovich (screenplay), Ales Adamovich (s...    ...
# 26                                   Christopher Nolan    ...
# 27   Stephen King (short story "Rita Hayworth and S...    ...
# 28   Carl Mayer (scenario), Hermann Sudermann (from...    ...
# 29   John Huston (screenplay), Dashiell Hammett (ba...    ...
# ..                                                 ...    ...
# 220                                       Robert Towne    ...
# 221  Pete Docter (original story by), Ronnie Del Ca...    ...
# 222                  James Cameron, William Wisher Jr.    ...
# 223                                               None    ...
# 224  Rajkumar Hirani (screenplay), Abhijat Joshi (s...    ...
# 225  J.R.R. Tolkien (novel), Fran Walsh (screenplay...    ...
# 226  Nunnally Johnson (screen play), John Steinbeck...    ...
# 227  Linda Woolverton (animation screenplay by), Br...    ...
# 228        Sean Penn (screenplay), Jon Krakauer (book)    ...
# 229                                        John Briley    ...
# 230  Budd Schulberg (screenplay), Budd Schulberg (b...    ...
# 231  William Davies (screenplay), Dean DeBlois (scr...    ...
# 232    Steve Kloves (screenplay), J.K. Rowling (novel)    ...
# 233                   Florian Henckel von Donnersmarck    ...
# 234  John Lasseter (story by), Andrew Stanton (stor...    ...
# 235  Graham Chapman, John Cleese, Eric Idle, Terry ...    ...
# 236  Ronald Harwood (screenplay), Wladyslaw Szpilma...    ...
# 237  Jonathan Nolan (screenplay), Christopher Nolan...    ...
# 238  Jeff Nathanson (screenplay), Frank Abagnale Jr...    ...
# 239  James Gunn, Nicole Perlman, Dan Abnett (comic ...    ...
# 240  William Monahan (screenplay), Alan Mak, Felix ...    ...
# 241  Lawrence Hauben (screenplay), Bo Goldman (scre...    ...
# 242  Robert E. Sherwood (screen play), MacKinlay Ka...    ...
# 243                              Alan Mak, Felix Chong    ...
# 244                                  Mathieu Kassovitz    ...
# 245                                        Guy Ritchie    ...
# 246  Harper Lee (based on her novel "To Kill a Mock...    ...
# 247     Akira Kurosawa, Shinobu Hashimoto, Hideo Oguni    ...
# 248  James Cameron, Gale Anne Hurd, William Wisher ...    ...
# 249                                      Paul Schrader    ...
#
#     tomato_user_rating                         genre response  \
# 0                  4.1         Crime, Drama, Mystery     True
# 1                  4.3     Action, Adventure, Comedy     True
# 2                  3.9                    Drama, War     True
# 3                  4.0       Biography, Crime, Drama     True
# 4                  N/A     Adventure, Drama, History     True
# 5                  3.9                        Comedy     True
# 6                  4.0           Drama, History, War     True
# 7                  4.0              Adventure, Drama     True
# 8                  4.2   Adventure, Biography, Drama     True
# 9                  4.0                 Comedy, Crime     True
# 10                 4.3                       Western     True
# 11                 4.3                Drama, Fantasy     True
# 12                 N/A                  Crime, Drama     True
# 13                 4.1               Comedy, Romance     True
# 14                 4.2      Drama, Mystery, Thriller     True
# 15                 4.0          Crime, Drama, Sci-Fi     True
# 16                 4.1                 Drama, Sci-Fi     True
# 17                 4.4  Animation, Action, Adventure     True
# 18                 4.3           Drama, Mystery, War     True
# 19                 4.4     Action, Adventure, Sci-Fi     True
# 20                 3.7  Animation, Adventure, Comedy     True
# 21                 3.4                        Action     True
# 22                 4.4        Comedy, Drama, Romance     True
# 23                 4.0                 Drama, Horror     True
# 24                 4.1                Drama, Mystery     True
# 25                 4.5                    Drama, War     True
# 26                 4.2      Action, Adventure, Crime     True
# 27                 4.4                  Crime, Drama     True
# 28                 4.4                Drama, Romance     True
# 29                 4.0       Crime, Drama, Film-Noir     True
# ..                 ...                           ...      ...
# 220                4.2      Drama, Mystery, Thriller     True
# 221                4.3  Animation, Adventure, Comedy     True
# 222                3.8                Action, Sci-Fi     True
# 223               None                          None     None
# 224                4.4                 Comedy, Drama     True
# 225                4.1      Action, Adventure, Drama     True
# 226                3.9                         Drama     True
# 227                3.7    Animation, Family, Fantasy     True
# 228                4.1   Adventure, Biography, Drama     True
# 229                4.0     Biography, Drama, History     True
# 230                4.2         Crime, Drama, Romance     True
# 231                4.2  Animation, Adventure, Family     True
# 232                4.3     Adventure, Drama, Fantasy     True
# 233                4.4               Drama, Thriller     True
# 234                4.3  Animation, Adventure, Comedy     True
# 235                4.1    Adventure, Comedy, Fantasy     True
# 236                4.1         Biography, Drama, War     True
# 237                4.3      Action, Adventure, Drama     True
# 238                3.6       Biography, Crime, Drama     True
# 239                4.4     Action, Adventure, Sci-Fi     True
# 240                4.1        Crime, Drama, Thriller     True
# 241                4.2                         Drama     True
# 242                4.2           Drama, Romance, War     True
# 243                4.2      Crime, Mystery, Thriller     True
# 244                4.3                  Crime, Drama     True
# 245                4.0                 Comedy, Crime     True
# 246                3.9                  Crime, Drama     True
# 247                4.5                         Drama     True
# 248                3.6                Action, Sci-Fi     True
# 249                4.1                  Crime, Drama     True
#
#                              language          dvd imdb_rating  \
# 0                             English  13 Jan 2015         8.1
# 1                             English  10 May 2016         8.2
# 2                 English, Vietnamese  09 Dec 1997         8.1
# 3                    English, Spanish  16 May 2000         8.1
# 4    English, German, French, Russian  11 Oct 2005         8.3
# 5                      English, Latin  30 Apr 1999         8.1
# 6                     English, French  12 Apr 2005         8.1
# 7                             English  29 Aug 2000         8.1
# 8            English, Arabic, Turkish  03 Apr 2001         8.4
# 9                    English, Russian  03 Jul 2001         8.3
# 10          English, Spanish, Italian  18 Nov 2003         8.6
# 11   Italian, English, French, German  04 Dec 2001         8.1
# 12                           Japanese          N/A         8.3
# 13           English, German, Italian  26 Nov 2002         8.1
# 14                            Spanish  21 Sep 2010         8.2
# 15                            English  29 Jun 1999         8.4
# 16                             German  18 Feb 2003         8.3
# 17                 English, Norwegian  07 Jun 2016         8.2
# 18            French, Arabic, English  13 Sep 2011         8.2
# 19                   English, Russian  25 Sep 2012         8.1
# 20                            English  20 Mar 2001         8.3
# 21          English, Japanese, French  13 Apr 2004         8.1
# 22                            English  08 Feb 2000         8.6
# 23                            English  29 Jun 1999         8.4
# 24                            English  25 Sep 2001         8.4
# 25        Belarusian, Russian, German  23 Oct 2001         8.3
# 26          English, Japanese, French  07 Dec 2010         8.8
# 27                            English  27 Jan 1998         9.3
# 28                                N/A  09 Dec 2008         8.3
# 29                            English  15 Feb 2000         8.1
# ..                                ...          ...         ...
# 220       English, Cantonese, Spanish  23 Nov 1999         8.2
# 221                           English  03 Nov 2015         8.3
# 222                  English, Spanish  31 Mar 1998         8.5
# 223                              None         None        None
# 224                    Hindi, English  26 Apr 2011         8.4
# 225                 English, Sindarin  06 Aug 2002         8.8
# 226                           English  06 Apr 2004         8.1
# 227                   French, English  08 Oct 2002         8.0
# 228                   English, Danish  04 Mar 2008         8.2
# 229                           English  28 Aug 2001         8.1
# 230                           English  23 Oct 2001         8.3
# 231                           English  15 Oct 2010         8.2
# 232                           English  11 Nov 2011         8.1
# 233                            German  21 Aug 2007         8.5
# 234                  English, Spanish  02 Nov 2010         8.3
# 235            English, French, Latin  07 Sep 1999         8.3
# 236          English, German, Russian  27 May 2003         8.5
# 237                   English, Arabic  03 Dec 2012         8.5
# 238                   French, English  06 May 2003         8.0
# 239                           English  09 Dec 2014         8.1
# 240                English, Cantonese  13 Feb 2007         8.5
# 241                           English  09 Dec 1997         8.7
# 242                           English  30 Oct 1997         8.1
# 243          Cantonese, English, Thai  07 Dec 2004         8.1
# 244                            French  17 Apr 2007         8.1
# 245                           English  31 Aug 1999         8.2
# 246                           English  28 Apr 1998         8.4
# 247                          Japanese  06 Jan 2004         8.3
# 248                  English, Spanish  03 Sep 1997         8.1
# 249                  English, Spanish  15 Jun 1999         8.3
#
#                          country tomato_image  runtime box_office
# 0                            USA    certified  149 min        N/A
# 1                            USA    certified  108 min        N/A
# 2                        UK, USA    certified  120 min        N/A
# 3                            USA    certified  110 min        N/A
# 4                            USA          N/A  172 min        N/A
# 5                             UK    certified   94 min        N/A
# 6        UK, South Africa, Italy    certified  121 min        N/A
# 7                            USA    certified   89 min        N/A
# 8                             UK    certified  216 min        N/A
# 9                        UK, USA        fresh  102 min        N/A
# 10     Italy, USA, Spain, Mexico    certified  175 min        N/A
# 11                 Italy, France    certified  138 min        N/A
# 12                         Japan          N/A   88 min        N/A
# 13                           USA    certified  118 min        N/A
# 14              Argentina, Spain    certified  129 min        N/A
# 15                       UK, USA    certified  136 min        N/A
# 16                       Germany    certified  153 min        N/A
# 17                           USA    certified  108 min    $167968
# 18                Canada, France    certified  139 min        N/A
# 19                           USA    certified  143 min        N/A
# 20                           USA    certified   81 min        N/A
# 21                           USA    certified  111 min        N/A
# 22                           USA    certified   87 min        N/A
# 23                       USA, UK    certified  146 min        N/A
# 24                           USA    certified  119 min        N/A
# 25                  Soviet Union        fresh  140 min        N/A
# 26                       USA, UK    certified  148 min        N/A
# 27                           USA    certified  142 min        N/A
# 28                           USA    certified   94 min        N/A
# 29                           USA    certified  100 min        N/A
# ..                           ...          ...      ...        ...
# 220                          USA    certified  130 min        N/A
# 221                          USA    certified   95 min        N/A
# 222                  USA, France    certified  137 min        N/A
# 223                         None         None     None       None
# 224                        India        fresh  170 min        N/A
# 225             New Zealand, USA    certified  178 min        N/A
# 226                          USA    certified  129 min        N/A
# 227                          USA    certified   84 min        N/A
# 228                          USA    certified  148 min        N/A
# 229                    UK, India    certified  191 min        N/A
# 230                          USA    certified  108 min        N/A
# 231                          USA    certified   98 min        N/A
# 232                      USA, UK    certified  130 min        N/A
# 233                      Germany    certified  137 min        N/A
# 234                          USA    certified  103 min        N/A
# 235                           UK    certified   91 min        N/A
# 236  France, Poland, Germany, UK    certified  150 min        N/A
# 237                      USA, UK    certified  164 min        N/A
# 238                  USA, Canada    certified  141 min        N/A
# 239                      USA, UK    certified  121 min        N/A
# 240               USA, Hong Kong    certified  151 min        N/A
# 241                          USA    certified  133 min        N/A
# 242                          USA    certified  172 min        N/A
# 243                    Hong Kong    certified  101 min        N/A
# 244                       France        fresh   98 min        N/A
# 245                           UK    certified  107 min        N/A
# 246                          USA    certified  129 min        N/A
# 247                        Japan        fresh  143 min        N/A
# 248                      UK, USA    certified  107 min        N/A
# 249                          USA    certified  113 min        N/A
#
# [250 rows x 34 columns]

# %%
movies = pd.merge(df_2, df, how='left',left_on='imdb_id', right_on='imdbID')
len(set(movies['title']))
# Out:
# 250

# %% [markdown]
# ## Here is where I decided to switch to a much bigger dataset
#
# When i realized I could get all this data with the python wrapper, I found a csv from imdb which had super basic information on all movies realeased 1972-2016
#
# http://www.imdb.com/list/ls057823854/?start=1&view=compact&sort=listorian:asc
#
# I had been working on scraping it, but when I found this list

# %%
all_movies = pd.read_csv("/Users/HudsonCavanagh/Documents/All U.S. Released Movies- 1972-2016.csv")
# Out:
#    position      const                   created                  modified  \
# 0         1  tt0110912  Mon Apr 22 18:23:19 2013  Mon Apr 22 18:23:19 2013
# 1         2  tt1872181  Mon Apr 22 18:23:22 2013  Mon Apr 22 18:23:22 2013
# 2         3  tt0111161  Mon Apr 22 18:23:19 2013  Mon Apr 22 18:23:19 2013
# 3         4  tt0076759  Mon Apr 22 18:23:19 2013  Mon Apr 22 18:23:19 2013
# 4         5  tt0088763  Mon Apr 22 18:23:19 2013  Mon Apr 22 18:23:19 2013
#
#   description                               Title    Title type  \
# 0         NaN                        Pulp Fiction  Feature Film
# 1         NaN            The Amazing Spider-Man 2  Feature Film
# 2         NaN            The Shawshank Redemption  Feature Film
# 3         NaN  Star Wars: Episode IV - A New Hope  Feature Film
# 4         NaN                  Back to the Future  Feature Film
#
#            Directors  RDLongoria rated  IMDb Rating  Runtime (mins)  Year  \
# 0  Quentin Tarantino                10          8.9             154  1994
# 1          Marc Webb               NaN          6.8             142  2014
# 2     Frank Darabont                10          9.3             142  1994
# 3       George Lucas                 7          8.7             121  1977
# 4    Robert Zemeckis                 7          8.5             116  1985
#
#                                Genres  Num. Votes  \
# 0                        crime, drama     1316445
# 1  action, adventure, fantasy, sci_fi      318993
# 2                        crime, drama     1679452
# 3  action, adventure, fantasy, sci_fi      905480
# 4           adventure, comedy, sci_fi      727038
#
#   Release Date (month/day/year)                                   URL
# 0                    1994-05-12  http://www.imdb.com/title/tt0110912/
# 1                    2014-04-10  http://www.imdb.com/title/tt1872181/
# 2                    1994-09-10  http://www.imdb.com/title/tt0111161/
# 3                    1977-05-25  http://www.imdb.com/title/tt0076759/
# 4                    1985-07-03  http://www.imdb.com/title/tt0088763/

# %%
len(all_movies['Title'])
# Out:
# 9964

# %%
full_movie_list = pd.read_csv("/Users/HudsonCavanagh/Documents/df_full.csv")
#here's the script for this, but i ran it in the terminal:

# import pandas as pd
# import omdb

# def big_movie_extractor(series, keys):
#     movie_list = []
#     for i in set(series):
#         try:
#             movie_list.append((omdb.get(title=i, tomatoes=True).values()))
#         except:
#             print("er ")
#     df_full = pd.DataFrame(movie_list, columns=keys)
#     return(df_full)


# keys_wrapper = (omdb.get(title='True Grit', tomatoes=True)).keys()
# all_movies = pd.read_csv("/Users/HudsonCavanagh/Documents/All U.S. Released Movies- 1972-2016.csv")
# big_df = big_movie_extractor(all_movies['Title'].values, keys_wrapper)
# big_df.to_csv("/Users/HudsonCavanagh/Documents/df_full.csv", encoding='utf-8')



# len(full_movie_list) #9647

# %%
most_movie_list = full_movie_list.dropna(axis=0, inplace=0, thresh=2)
len(most_movie_list)
# Out:
# 7886

# %%
training_movie_list = full_movie_list.dropna(axis=0, inplace=0, how='any')
len(training_movie_list)
# Out:
# 7

# %%
tomato_user_list = full_movie_list.dropna(axis=0, inplace=0, how='any', subset=['tomato_user_rating'])
len(tomato_user_list)
# Out:
# 7259

# %%
len(tomato_user_list)
# Out:
# 3497

# %%
import seaborn as sns

sns.distplot(tomato_user_list.isnull().sum() )

# %%
tomato_user_list.isnull().sum()
# Out:
# Unnamed: 0                0
# metascore                 0
# year                      0
# tomato_rating             0
# tomato_meter              0
# plot                      0
# rated                     0
# tomato_rotten             0
# title                     0
# tomato_consensus        586
# writer                   31
# tomato_user_meter         0
# production                0
# actors                    0
# tomato_fresh              0
# imdb_votes                0
# type                      0
# tomato_user_reviews       0
# website                3441
# poster                    1
# imdb_id                   0
# director                  0
# released                  3
# tomato_reviews            0
# awards                  381
# tomato_user_rating        0
# genre                     0
# response                  0
# language                  0
# dvd                       0
# imdb_rating               0
# country                   0
# tomato_image              0
# runtime                   0
# box_office             3482
# genre_1st                 0
# dtype: int64

# %%
df = tomato_user_list
df.dropna(axis=0, inplace=0, how='any', subset=['dvd'])
df.dropna(axis=0, inplace=0, how='any', subset=['tomato_rating'])
#df.dropna(axis=0, inplace=0, how='any', subset=['tomato_user_rating']) #did this above
df.dropna(axis=0, inplace=1, how='any', subset=['tomato_fresh'])
df.dropna(axis=0, inplace=1, how='any', subset=['tomato_meter'])
df.dropna(axis=0, inplace=1, how='any', subset=['production'])
df.dropna(axis=0, inplace=1, how='any', subset=['tomato_rating'])
df.dropna(axis=0, inplace=1, how='any', subset=['rated'])
df.dropna(axis=0, inplace=1, how='any', subset=['imdb_votes'])
df.dropna(axis=0, inplace=1, how='any', subset=['tomato_user_reviews'])
df.dropna(axis=0, inplace=1, how='any', subset=['imdb_rating'])
df.dropna(axis=0, inplace=1, how='any', subset=['dvd'])
df.dropna(axis=0, inplace=1, how='any', subset=['rated'])
df.dropna(axis=0, inplace=1, how='any', subset=['metascore']) #this drops a whole 2000 values, need to investigate bias
# Out:
# 7211

# %%
#### Actor frequency feature beginning
# master_actor_list = []
# for i in tomato_user_list['actors']:
#     for h in str(i).split(", "):
#         master_actor_list.append(h)
# master_actor_list = pd.Series(master_actor_list)
# len(master_actor_list)


#Features to extract:


#Dummies:
# rated
# genre (first listed)
# language (first listed)
# country

#Cont:
#count(languages)

#Datetime: 
#Year
#DVD
#Diff Year DVD
# Out:
# 13982

# %%
#FEATURE EXTRACTION EXTRAVAGANZA!


def genre_clean(char):
    a = str(char).split(",")[0].strip().lower()
    return(a)
    
df['genre_1st'] = df['genre'].apply(genre_clean)

genre_dums = pd.get_dummies(df['genre_1st'])
df = pd.concat([df, genre_dums], axis =1)

df['country_1st'] = df['country'].apply(genre_clean)

country_dums = pd.get_dummies(df['country_1st'])
df = pd.concat([df, country_dums], axis =1)

df['language_1st'] = df['language'].apply(genre_clean)

language_dums = pd.get_dummies(df['language_1st'])
df = pd.concat([df, language_dums], axis =1)

rating_dums = pd.get_dummies(df['rated'])
df = pd.concat([df, rating_dums], axis =1)

production_dums = pd.get_dummies(df['production'])
df = pd.concat([df, production_dums], axis =1)


def lang_counter(entry):
    return(float(entry.count(","))+1)


df['lang_count'] = df['language'].apply(lang_counter)


df['theater_date'] = pd.to_datetime(df['year'],infer_datetime_format=1)# optional arguement for trying various options out should be on
df['dvd_date'] = pd.to_datetime(df['dvd'],infer_datetime_format=1)# optional arguement for trying various options out should be on

df['delta_theater_dvd'] = df['dvd_date'] - df['theater_date']


# genre_dums


df.head()
# Out:
#     year  tomato_rating  tomato_meter  \
# 12  2013            7.3            83
# 19  1998            5.7            54
# 67  1989            8.9            93
# 73  2003            4.5            21
# 74  1984            7.1            83
#
#                                                  plot rated  tomato_rotten  \
# 12  A young woman's world unravels when a drug pre...     R             34
# 19  A half-vampire, half-mortal man becomes a prot...     R             43
# 67  On the hottest day of the year on a street in ...     R              5
# 73  A DEA agent investigates the disappearance of ...     R            112
# 74  A freewheeling Detroit cop pursuing a murder i...     R              7
#
#                  title                                   tomato_consensus  \
# 12        Side Effects  A smart, clever thriller with plenty of disqui...
# 19               Blade  Though some may find the plot a bit lacking, B...
# 67  Do the Right Thing  Smart, vibrant, and urgent without being didac...
# 73               Basic  Basic gets so needlessly convoluted in its plo...
# 74   Beverly Hills Cop                                                NaN
#
#                                                writer  tomato_user_meter  \
# 12                                     Scott Z. Burns                 70
# 19                                     David S. Goyer                 78
# 67                                          Spike Lee                 90
# 73                                   James Vanderbilt                 63
# 74  Daniel Petrie Jr. (screenplay), Danilo Bach (s...                 81
#
#      ...    documentary drama  family fantasy horror  musical mystery romance  \
# 12   ...              0     0       0       0      0        0       0       0
# 19   ...              0     0       0       0      0        0       0       0
# 67   ...              0     1       0       0      0        0       0       0
# 73   ...              0     0       0       0      0        0       0       0
# 74   ...              0     0       0       0      0        0       0       0
#
#    sci-fi thriller
# 12      0        0
# 19      0        0
# 67      0        0
# 73      0        0
# 74      0        0
#
# [5 rows x 146 columns]

# %%
# #count(languages)




# top_250['year'] = top_250['year'].astype(int) #should i make this feature, years since release? 2016-x?
df['theater_date'] = pd.to_datetime(df['year'],infer_datetime_format=1)# optional arguement for trying various options out should be on
df['dvd_date'] = pd.to_datetime(df['dvd'],infer_datetime_format=1)# optional arguement for trying various options out should be on

df['delta_theater_dvd'] = df['dvd_date'] - df['theater_date']

#WORK ON THIS
# Out:
#     year  tomato_rating  tomato_meter  \
# 12  2013            7.3            83
# 19  1998            5.7            54
# 67  1989            8.9            93
# 73  2003            4.5            21
# 74  1984            7.1            83
#
#                                                  plot rated  tomato_rotten  \
# 12  A young woman's world unravels when a drug pre...     R             34
# 19  A half-vampire, half-mortal man becomes a prot...     R             43
# 67  On the hottest day of the year on a street in ...     R              5
# 73  A DEA agent investigates the disappearance of ...     R            112
# 74  A freewheeling Detroit cop pursuing a murder i...     R              7
#
#                  title                                   tomato_consensus  \
# 12        Side Effects  A smart, clever thriller with plenty of disqui...
# 19               Blade  Though some may find the plot a bit lacking, B...
# 67  Do the Right Thing  Smart, vibrant, and urgent without being didac...
# 73               Basic  Basic gets so needlessly convoluted in its plo...
# 74   Beverly Hills Cop                                                NaN
#
#                                                writer  tomato_user_meter  \
# 12                                     Scott Z. Burns                 70
# 19                                     David S. Goyer                 78
# 67                                          Spike Lee                 90
# 73                                   James Vanderbilt                 63
# 74  Daniel Petrie Jr. (screenplay), Danilo Bach (s...                 81
#
#           ...        PG PG-13  R UNRATED  X  lang_count  year_date   dvd_date  \
# 12        ...         0     0  1       0  0           2 2013-01-01 2013-05-21
# 19        ...         0     0  1       0  0           2 1998-01-01 1998-12-22
# 67        ...         0     0  1       0  0           4 1989-01-01 2009-06-30
# 73        ...         0     0  1       0  0           1 2003-01-01 2003-07-08
# 74        ...         0     0  1       0  0           1 1984-01-01 2002-01-29
#
#    theater_date delta_theater_dvd
# 12   2013-01-01          140 days
# 19   1998-01-01          355 days
# 67   1989-01-01         7485 days
# 73   2003-01-01          188 days
# 74   1984-01-01         6603 days
#
# [5 rows x 410 columns]

# %%
tomato_user_list.head() # ['actors'], plot', 'tomato_consensus']
# Out:
#     Unnamed: 0  metascore  year  tomato_rating  tomato_meter  \
# 12          12         75  2013            7.3            83
# 19          19         45  1998            5.7            54
# 67          67         91  1989            8.9            93
# 73          73         34  2003            4.5            21
# 74          74         64  1984            7.1            83
#
#                                                  plot rated  tomato_rotten  \
# 12  A young woman's world unravels when a drug pre...     R             34
# 19  A half-vampire, half-mortal man becomes a prot...     R             43
# 67  On the hottest day of the year on a street in ...     R              5
# 73  A DEA agent investigates the disappearance of ...     R            112
# 74  A freewheeling Detroit cop pursuing a murder i...     R              7
#
#                  title                                   tomato_consensus  \
# 12        Side Effects  A smart, clever thriller with plenty of disqui...
# 19               Blade  Though some may find the plot a bit lacking, B...
# 67  Do the Right Thing  Smart, vibrant, and urgent without being didac...
# 73               Basic  Basic gets so needlessly convoluted in its plo...
# 74   Beverly Hills Cop                                                NaN
#
#       ...     tomato_user_rating                   genre response  \
# 12    ...                    3.6  Crime, Drama, Thriller     True
# 19    ...                    3.6          Action, Horror     True
# 67    ...                    3.9                   Drama     True
# 73    ...                    3.2    Action, Crime, Drama     True
# 74    ...                    3.4   Action, Comedy, Crime     True
#
#                              language          dvd imdb_rating       country  \
# 12                    English, French  21 May 2013         7.1           USA
# 19                   English, Russian  22 Dec 1998         7.1           USA
# 67  English, Italian, Spanish, Korean  30 Jun 2009         7.9           USA
# 73                            English  08 Jul 2003         6.5  Germany, USA
# 74                            English  29 Jan 2002         7.3           USA
#
#     tomato_image  runtime box_office
# 12     certified  106 min        NaN
# 19        rotten  120 min        NaN
# 67     certified  120 min        NaN
# 73        rotten   98 min        NaN
# 74     certified  105 min        NaN
#
# [5 rows x 35 columns]

# %%
#df['year','tomato_rating', 'tomato_meter','rated','tomato_rotten','tomato_user_meter', 'production', 'tomato_fresh', 'imdb_votes','type','tomato_user_reviews','imdb_id', 'director', 'released', 'tomato_user_rating','genre', 'response', 'language', 'dvd', 'imdb_rating', 'country', 'runtime']
#Pre-cleaned feature list ^^

#print(len(df),df.isnull().sum())
df.describe()

#I would have to drop another 1057 rows for awards, 
#but write function to parse this for # oscars and re-run later
# Out:
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#         Unnamed: 0    metascore  tomato_rating  tomato_meter  tomato_rotten  \
# count  3497.000000  3497.000000    3497.000000   3497.000000    3497.000000
# mean   5615.653417    54.510438       5.784244     54.908207      44.027166
# std    2374.396160    18.017026       1.483390     27.655404      35.057171
# min      12.000000     1.000000       1.600000      0.000000       0.000000
# 25%    3626.000000    42.000000       4.700000     32.000000      15.000000
# 50%    5656.000000    55.000000       5.800000     56.000000      36.000000
# 75%    7657.000000    68.000000       6.900000     80.000000      66.000000
# max    9646.000000    98.000000       9.500000    100.000000     187.000000
#
#        tomato_user_meter  tomato_fresh  tomato_user_reviews  tomato_reviews  \
# count        3497.000000   3497.000000          3497.000000     3497.000000
# mean           61.812697     62.138404        505155.585073      106.166714
# std            19.469306     56.365748       3319462.782849       64.592238
# min             9.000000      0.000000           121.000000        5.000000
# 25%            47.000000     20.000000         16781.000000       52.000000
# 50%            63.000000     45.000000         61530.000000       98.000000
# 75%            78.000000     88.000000        223345.000000      149.000000
# max            98.000000    342.000000      35794556.000000      358.000000
#
#        tomato_user_rating  imdb_rating
# count         3497.000000  3497.000000
# mean             3.313011     6.493966
# std              0.431854     1.027221
# min              1.600000     1.900000
# 25%              3.000000     5.900000
# 50%              3.300000     6.600000
# 75%              3.600000     7.200000
# max              4.400000     9.300000

# %%
y = df['tomato_user_rating']


features = ['metascore', 'tomato_rating','tomato_meter','tomato_rotten',/
            'tomato_user_meter','tomato_fresh', 'tomato_user_reviews', 'tomato_reviews',/
            'imdb_rating', ]])


quants_working = df.loc[:,['metascore', 'tomato_rating','tomato_meter','tomato_rotten','tomato_user_meter','tomato_fresh', 'tomato_user_reviews', 'tomato_reviews', 'imdb_rating']]

#print(len(df),df.isnull().sum())

quants_working.isnull().sum().sum() #quants are ready to go!
# Out:
# 0

# %%
#now to scale the quant features in df
from sklearn import preprocessing

#pausing here to extract categorical features

df_scale = preprocessing.StandardScaler().fit_transform(df.loc[:,['metascore', 'tomato_rating','tomato_meter','tomato_rotten','tomato_user_meter','tomato_fresh', 'tomato_user_reviews', 'tomato_reviews', 'imdb_rating']])
df_scale = pd.DataFrame(df_scale, columns=['metascore', 'tomato_rating','tomato_meter','tomato_rotten','tomato_user_meter','tomato_fresh', 'tomato_user_reviews', 'tomato_reviews', 'imdb_rating'])

df_scale.describe()
# Out:
#           metascore  tomato_rating  tomato_meter  tomato_rotten  \
# count  3.497000e+03   3.497000e+03  3.497000e+03   3.497000e+03
# mean   1.308012e-17  -4.107222e-16  1.417225e-16  -5.657470e-17
# std    1.000143e+00   1.000143e+00  1.000143e+00   1.000143e+00
# min   -2.970417e+00  -2.821133e+00 -1.985726e+00  -1.256047e+00
# 25%   -6.944668e-01  -7.310272e-01 -8.284631e-01  -8.281135e-01
# 50%    2.717610e-02   1.062338e-02  3.948411e-02  -2.290063e-01
# 75%    7.488190e-01   7.522740e-01  9.074314e-01   6.268611e-01
# max    2.414149e+00   2.505266e+00  1.630721e+00   4.078860e+00
#
#        tomato_user_meter  tomato_fresh  tomato_user_reviews  tomato_reviews  \
# count       3.497000e+03  3.497000e+03         3.497000e+03    3.497000e+03
# mean       -1.248961e-16 -4.190719e-17         2.666821e-18    3.283127e-17
# std         1.000143e+00  1.000143e+00         1.000143e+00    1.000143e+00
# min        -2.713001e+00 -1.102572e+00        -1.521652e-01   -1.566460e+00
# 25%        -7.609319e-01 -7.476958e-01        -1.471456e-01   -8.387147e-01
# 50%         6.099207e-02 -3.041006e-01        -1.336629e-01   -1.264530e-01
# 75%         8.315457e-01  4.588832e-01        -8.490858e-02    6.632285e-01
# max         1.858951e+00  4.965810e+00         1.063258e+01    3.899374e+00
#
#         imdb_rating
# count  3.497000e+03
# mean   8.139836e-16
# std    1.000143e+00
# min   -4.472866e+00
# 25%   -5.783088e-01
# 50%    1.032386e-01
# 75%    6.874221e-01
# max    2.732064e+00

# %%
def vote_clean(item):
    a = str(item)
    b = a.replace(',', '')
    return float(b)


df['imdb_votes'] = df['imdb_votes'].apply(vote_clean)
df['years_dvd-theatre'] = df['delta_theater_dvd'].apply(lambda x: float(x)/31536000)
# Out:
# 12      3.835616e+08
# 19      9.726027e+08
# 67      2.050685e+10
# 73      5.150685e+08
# 74      1.809041e+10
# 77      7.778082e+09
# 88      1.263014e+09
# 90      5.898630e+09
# 129     1.279452e+09
# 130     9.479452e+08
# 155     1.293151e+09
# 182     4.380822e+09
# 189     1.156164e+09
# 194     1.484932e+09
# 213     1.030137e+09
# 227     5.769863e+09
# 260     4.383562e+08
# 266     1.317808e+09
# 285     1.446575e+09
# 290     1.465753e+09
# 321     1.338904e+10
# 329     1.479452e+09
# 346     1.981644e+10
# 353     1.649315e+09
# 393     1.191781e+09
# 443     1.090411e+09
# 446     9.764384e+09
# 492     5.260274e+08
# 525     2.975342e+09
# 539     2.109589e+09
#             ...
# 9583    1.339726e+09
# 9584    2.474521e+10
# 9586    4.876712e+08
# 9587    1.119178e+10
# 9588    4.027397e+08
# 9589    3.178082e+08
# 9591    1.583562e+09
# 9593    6.876712e+08
# 9595    2.120548e+09
# 9596    4.520548e+08
# 9597    1.331507e+09
# 9599    2.873973e+09
# 9602    3.945205e+09
# 9605    1.131507e+09
# 9609    9.452055e+08
# 9615    1.663014e+09
# 9617    1.095890e+09
# 9619    1.120548e+09
# 9620    1.706849e+09
# 9623    9.342466e+08
# 9633    1.052055e+09
# 9635    3.150685e+09
# 9636    3.041096e+09
# 9637    1.000000e+09
# 9639    2.066849e+10
# 9640    1.202740e+09
# 9641    1.056986e+10
# 9644    9.369863e+08
# 9645    1.279452e+09
# 9646    1.745205e+09
# Name: years_dvd-theatre, dtype: float64

# %%
df.head()
# Out:
#     year  tomato_rating  tomato_meter  \
# 12  2013            7.3            83
# 19  1998            5.7            54
# 67  1989            8.9            93
# 73  2003            4.5            21
# 74  1984            7.1            83
#
#                                                  plot rated  tomato_rotten  \
# 12  A young woman's world unravels when a drug pre...     R             34
# 19  A half-vampire, half-mortal man becomes a prot...     R             43
# 67  On the hottest day of the year on a street in ...     R              5
# 73  A DEA agent investigates the disappearance of ...     R            112
# 74  A freewheeling Detroit cop pursuing a murder i...     R              7
#
#                  title                                   tomato_consensus  \
# 12        Side Effects  A smart, clever thriller with plenty of disqui...
# 19               Blade  Though some may find the plot a bit lacking, B...
# 67  Do the Right Thing  Smart, vibrant, and urgent without being didac...
# 73               Basic  Basic gets so needlessly convoluted in its plo...
# 74   Beverly Hills Cop                                                NaN
#
#                                                writer  tomato_user_meter  \
# 12                                     Scott Z. Burns                 70
# 19                                     David S. Goyer                 78
# 67                                          Spike Lee                 90
# 73                                   James Vanderbilt                 63
# 74  Daniel Petrie Jr. (screenplay), Danilo Bach (s...                 81
#
#           ...        UNRATED  X  lang_count  year_date   dvd_date  \
# 12        ...              0  0           2 2013-01-01 2013-05-21
# 19        ...              0  0           2 1998-01-01 1998-12-22
# 67        ...              0  0           4 1989-01-01 2009-06-30
# 73        ...              0  0           1 2003-01-01 2003-07-08
# 74        ...              0  0           1 1984-01-01 2002-01-29
#
#     theater_date delta_theater_dvd imdb_votes_num  days_theatre  \
# 12    2013-01-01          140 days         147422  1.209600e+16
# 19    1998-01-01          355 days         189074  3.067200e+16
# 67    1989-01-01         7485 days          58887  6.467040e+17
# 73    2003-01-01          188 days          49556  1.624320e+16
# 74    1984-01-01         6603 days         125218  5.704992e+17
#
#    years_dvd-theatre
# 12      3.835616e+08
# 19      9.726027e+08
# 67      2.050685e+10
# 73      5.150685e+08
# 74      1.809041e+10
#
# [5 rows x 413 columns]

# %%
# allcols = df.columns
features = df[df.describe().columns] #this saved writing all of the ones I wanted to take out down....
features.
features.head()

#'metascore'
# Out:
#     tomato_rating  tomato_meter  tomato_rotten  tomato_user_meter  \
# 12            7.3            83             34                 70
# 19            5.7            54             43                 78
# 67            8.9            93              5                 90
# 73            4.5            21            112                 63
# 74            7.1            83              7                 81
#
#     tomato_fresh  imdb_votes  tomato_user_reviews  tomato_reviews  \
# 12           166      147422                69015             200
# 19            50      189074               498735              93
# 67            62       58887                72518              67
# 73            30       49556                56593             142
# 74            35      125218               376783              42
#
#     tomato_user_rating  imdb_rating       ...        NC-17  NOT RATED  PG  \
# 12                 3.6          7.1       ...            0          0   0
# 19                 3.6          7.1       ...            0          0   0
# 67                 3.9          7.9       ...            0          0   0
# 73                 3.2          6.5       ...            0          0   0
# 74                 3.4          7.3       ...            0          0   0
#
#     PG-13  R  UNRATED  X  lang_count  delta_theater_dvd  imdb_votes_num
# 12      0  1        0  0           2           140 days          147422
# 19      0  1        0  0           2           355 days          189074
# 67      0  1        0  0           4          7485 days           58887
# 73      0  1        0  0           1           188 days           49556
# 74      0  1        0  0           1          6603 days          125218
#
# [5 rows x 1890 columns]

# %%
features.isnull().sum().sum() #0
# Out:
# 0

# %%
X = preprocessing.StandardScaler().fit_transform(features)
X = pd.DataFrame(X, columns=features)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-147-10b9dfa7461c> in <module>()
#       1
# ----> 2 X = preprocessing.StandardScaler().fit_transform(features)
#       3 X = pd.DataFrame(X, columns=features)
#
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/sklearn/base.pyc in fit_transform(self, X, y, **fit_params)
#     453         if y is None:
#     454             # fit method of arity 1 (unsupervised transformation)
# --> 455             return self.fit(X, **fit_params).transform(X)
#     456         else:
#     457             # fit method of arity 2 (supervised transformation)
#
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/sklearn/preprocessing/data.pyc in fit(self, X, y)
#     555         # Reset internal state before fitting
#     556         self._reset()
# --> 557         return self.partial_fit(X, y)
#     558
#     559     def partial_fit(self, X, y=None):
#
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/sklearn/preprocessing/data.pyc in partial_fit(self, X, y)
#     578         X = check_array(X, accept_sparse=('csr', 'csc'), copy=self.copy,
#     579                         ensure_2d=False, warn_on_dtype=True,
# --> 580                         estimator=self, dtype=FLOAT_DTYPES)
#     581
#     582         if X.ndim == 1:
#
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     371                                       force_all_finite)
#     372     else:
# --> 373         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     374
#     375         if ensure_2d:
#
# TypeError: float() argument must be a string or a number

# %%
##FEATURE BRAINSTORM/GRAVEYARD

# Rating Dummy
# Scaled Metafore
# Scaled Imdb votes
# Genre Dummy
# If ‘novel' in df[‘Writer’]
# If Oscar in Awards (1/0)
# If Oscar in Awards (number before it) else 0
# SUM(If wins, number before, If nominations, number before/((5*(23/24))+(8*(1/24))) #5 noms per award, except best picture in oscars, assuming this holds true
# #http://www.mtv.com/news/2750915/mtv-movie-awards-nominations-2016/ this is 6 per category, so assumption above seems more or less right
# #http://oscar.go.com/nominees
# Count(languages)
# Count(countries)
# Plot language parse - number of verbs/ adjectives?
# Frequency analysis of actors in the set of actors in the data
# Released
# Count(actors)
# Year

# TO ADD(??):

# Dummy value of Studio - per Wikipedia, “The Eight Golden Age Majors" = [Columbia Pictures, 20th Century Fox, Warner Bros., Paramount Pictures, Universal Pictures, Metro-Goldwin-Mayer (MGM) OR United Artists (UA), KO Radio Pictures]

# Avg Value of Studio worth producing
# Sum value studio worth producing
# Opening Weekend
# Gross
# Production Co Parse

# %%
#If I have time, go back to the original dataset and play with boxscore instead of tomato user rating score!!!
