# %% [markdown]
# # Project 7
#
# In this project, you will implement the the clustering techniques that you've learned this week.
#
# #### Step 1: Load the python libraries that you will need for this project

# %%
import pandas as pd 
import matplotlib as plt
import numpy as np
import sklearn
import psycopg2 as psy
import os 
import matplotlib.pyplot as plt
import numpy as np
import math
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA 
from sklearn.cluster import KMeans
from sklearn import metrics
from matplotlib import *
import sys
from pylab import *
from matplotlib import offsetbox
from sklearn import (manifold, datasets, decomposition, ensemble,
                     discriminant_analysis, random_projection)
from sklearn import metrics
from sklearn.cross_validation import cross_val_score, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, BaggingRegressor

# %matplotlib inline

os.getcwd()
# Out:
# '/Users/HudsonCavanagh/GA_dsi-projects/projects/7th'

# %% [markdown]
# #### Step 2: Examine your data

# %%
airports = pd.read_csv('/Users/HudsonCavanagh/Documents/airports.csv')
ops = pd.read_csv('/Users/HudsonCavanagh/Documents/Airport_operations.csv')
cancelations = pd.read_csv('/Users/HudsonCavanagh/Documents/airport_cancellations.csv')

airports.head()
# Out:
#     Key LocID                   AP_NAME                                ALIAS  \
# 0  3443   STX           HENRY E ROHLSEN        Henry E Rohlsen Int'l Airport
# 1  5088   X64                  PATILLAS                                  NaN
# 2  2886   PSE                 MERCEDITA                 Aeropuerto Mercedita
# 3  2879   VQS  ANTONIO RIVERA RODRIGUEZ  Aeropuerto Antonio Rivera Rodr�guez
# 4  2883   X63                   HUMACAO       Aeropuerto Regional De Humacao
#
#   Facility Type FAA REGION            COUNTY             CITY STATE  \
# 0       Airport        ASO  -VIRGIN ISLANDS-    CHRISTIANSTED    VI
# 1       Airport        ASO            #NAME?         PATILLAS    PR
# 2       Airport        ASO            #NAME?            PONCE    PR
# 3       Airport        ASO            #NAME?  ISLA DE VIEQUES    PR
# 4       Airport        ASO            #NAME?          HUMACAO    PR
#
#       AP Type   Latitude  Longitude Boundary Data Available
# 0  Public Use  17.701556 -64.801722                     Yes
# 1  Public Use  17.982189 -66.019330                      No
# 2  Public Use  18.008306 -66.563028                     Yes
# 3  Public Use  18.134811 -65.493617                     Yes
# 4  Public Use  18.138017 -65.800718                     Yes

# %%
airports['AP Type'].value_counts() # way more public use than federal/ commercial (95%)
# Out:
# Public Use                4876
# Federalized/Commercial     288
# Name: AP Type, dtype: int64

# %%
print(len(ops), len(cancelations))
# Out:
# (841, 805)

# %%
ops['str_year'] = ops['year'].apply(lambda x: str(int(x)))
ops['airport_year'] = ops['airport'] + ops['str_year']
ops['airport_year']
# Out:
# 0      ABQ2004
# 1      ABQ2005
# 2      ABQ2006
# 3      ABQ2007
# 4      ABQ2008
# 5      ABQ2009
# 6      ABQ2010
# 7      ABQ2011
# 8      ABQ2012
# 9      ABQ2013
# 10     ABQ2014
# 11     ANC2004
# 12     ANC2005
# 13     ANC2006
# 14     ANC2007
# 15     ANC2008
# 16     ANC2009
# 17     ANC2010
# 18     ANC2011
# 19     ANC2012
# 20     ANC2013
# 21     ANC2014
# 22     ATL2004
# 23     ATL2005
# 24     ATL2006
# 25     ATL2007
# 26     ATL2008
# 27     ATL2009
# 28     ATL2010
# 29     ATL2011
#         ...
# 811    TPA2007
# 812    TPA2008
# 813    TPA2009
# 814    TPA2010
# 815    TPA2011
# 816    TPA2012
# 817    TPA2013
# 818    TPA2014
# 819    TUS2004
# 820    TUS2005
# 821    TUS2006
# 822    TUS2007
# 823    TUS2008
# 824    TUS2009
# 825    TUS2010
# 826    TUS2011
# 827    TUS2012
# 828    TUS2013
# 829    TUS2014
# 830    VNY2004
# 831    VNY2005
# 832    VNY2006
# 833    VNY2007
# 834    VNY2008
# 835    VNY2009
# 836    VNY2010
# 837    VNY2011
# 838    VNY2012
# 839    VNY2013
# 840    VNY2014
# Name: airport_year, dtype: object

# %%
cancelations

cancelations['str_year'] = cancelations['Year'].apply(lambda x: str(int(x)))
cancelations['airport_year'] = cancelations['Airport'] + cancelations['str_year']
cancelations['airport_year']
# Out:
# 0      ABQ2004
# 1      ABQ2005
# 2      ABQ2006
# 3      ABQ2007
# 4      ABQ2008
# 5      ABQ2009
# 6      ABQ2010
# 7      ABQ2011
# 8      ABQ2012
# 9      ABQ2013
# 10     ABQ2014
# 11     ANC2004
# 12     ANC2005
# 13     ANC2006
# 14     ANC2007
# 15     ANC2008
# 16     ANC2009
# 17     ANC2010
# 18     ANC2011
# 19     ANC2012
# 20     ANC2013
# 21     ANC2014
# 22     ATL2004
# 23     ATL2005
# 24     ATL2006
# 25     ATL2007
# 26     ATL2008
# 27     ATL2009
# 28     ATL2010
# 29     ATL2011
#         ...
# 775    SWF2007
# 776    SWF2008
# 777    SWF2009
# 778    SWF2010
# 779    SWF2011
# 780    SWF2012
# 781    SWF2013
# 782    SWF2014
# 783    TPA2004
# 784    TPA2005
# 785    TPA2006
# 786    TPA2007
# 787    TPA2008
# 788    TPA2009
# 789    TPA2010
# 790    TPA2011
# 791    TPA2012
# 792    TPA2013
# 793    TPA2014
# 794    TUS2004
# 795    TUS2005
# 796    TUS2006
# 797    TUS2007
# 798    TUS2008
# 799    TUS2009
# 800    TUS2010
# 801    TUS2011
# 802    TUS2012
# 803    TUS2013
# 804    TUS2014
# Name: airport_year, dtype: object

# %%
ops.head()
# Out:
#   airport  year  departures for metric computation  \
# 0     ABQ  2004                              53971
# 1     ABQ  2005                              51829
# 2     ABQ  2006                              49682
# 3     ABQ  2007                              53255
# 4     ABQ  2008                              49589
#
#    arrivals for metric computation  percent on-time gate departures  \
# 0                            53818                           0.8030
# 1                            51877                           0.8140
# 2                            51199                           0.7983
# 3                            53611                           0.8005
# 4                            49512                           0.8103
#
#    percent on-time airport departures  percent on-time gate arrivals  \
# 0                              0.7809                         0.7921
# 1                              0.7922                         0.8001
# 2                              0.7756                         0.7746
# 3                              0.7704                         0.7647
# 4                              0.7844                         0.7875
#
#    average_gate_departure_delay  average_taxi_out_time  \
# 0                         10.38                   9.89
# 1                          9.60                   9.79
# 2                         10.84                   9.89
# 3                         11.29                  10.34
# 4                         10.79                  10.41
#
#    average taxi out delay  average airport departure delay  \
# 0                    2.43                            12.10
# 1                    2.29                            11.20
# 2                    2.16                            12.33
# 3                    2.40                            12.95
# 4                    2.41                            12.32
#
#    average airborne delay  average taxi in delay  average block delay  \
# 0                    2.46                   0.83                 2.55
# 1                    2.26                   0.89                 2.34
# 2                    2.12                   0.84                 2.66
# 3                    2.19                   1.29                 3.06
# 4                    1.82                   1.03                 2.79
#
#    average gate arrival delay str_year airport_year
# 0                       10.87     2004      ABQ2004
# 1                       10.24     2005      ABQ2005
# 2                       11.82     2006      ABQ2006
# 3                       12.71     2007      ABQ2007
# 4                       11.48     2008      ABQ2008

# %%
df = pd.merge(ops, cancelations, how='left', on='airport_year')
df = pd.merge(df, airports,how='left', left_on='airport', right_on='LocID')
df.head()

df.drop(['str_year_x', 'str_year_y', 'Airport', 'Year', 'airport_year'], axis=1, inplace=1)

num_port = {}
for i,v in enumerate(set(df['airport'])):
    num_port[v] = i

df['airport_num'] = df['airport'].apply(lambda x: num_port[x])
# df['airport_num'].value_counts() #58 and 73 don't have 11
# df[df['airport_num']==58] #no 2004-2007 data for these airports. 
# df[df['airport_num']==73]

# %%
df.head()
# Out:
#   airport  year  departures for metric computation  \
# 0     ABQ  2004                              53971
# 1     ABQ  2005                              51829
# 2     ABQ  2006                              49682
# 3     ABQ  2007                              53255
# 4     ABQ  2008                              49589
#
#    arrivals for metric computation  percent on-time gate departures  \
# 0                            53818                           0.8030
# 1                            51877                           0.8140
# 2                            51199                           0.7983
# 3                            53611                           0.8005
# 4                            49512                           0.8103
#
#    percent on-time airport departures  percent on-time gate arrivals  \
# 0                              0.7809                         0.7921
# 1                              0.7922                         0.8001
# 2                              0.7756                         0.7746
# 3                              0.7704                         0.7647
# 4                              0.7844                         0.7875
#
#    average_gate_departure_delay  average_taxi_out_time  \
# 0                         10.38                   9.89
# 1                          9.60                   9.79
# 2                         10.84                   9.89
# 3                         11.29                  10.34
# 4                         10.79                  10.41
#
#    average taxi out delay     ...       Facility Type  FAA REGION      COUNTY  \
# 0                    2.43     ...             Airport         ASW  BERNALILLO
# 1                    2.29     ...             Airport         ASW  BERNALILLO
# 2                    2.16     ...             Airport         ASW  BERNALILLO
# 3                    2.40     ...             Airport         ASW  BERNALILLO
# 4                    2.41     ...             Airport         ASW  BERNALILLO
#
#           CITY  STATE                 AP Type   Latitude   Longitude  \
# 0  ALBUQUERQUE     NM  Federalized/Commercial  35.040194 -106.609194
# 1  ALBUQUERQUE     NM  Federalized/Commercial  35.040194 -106.609194
# 2  ALBUQUERQUE     NM  Federalized/Commercial  35.040194 -106.609194
# 3  ALBUQUERQUE     NM  Federalized/Commercial  35.040194 -106.609194
# 4  ALBUQUERQUE     NM  Federalized/Commercial  35.040194 -106.609194
#
#    Boundary Data Available  airport_num
# 0                      Yes           44
# 1                      Yes           44
# 2                      Yes           44
# 3                      Yes           44
# 4                      Yes           44
#
# [5 rows x 33 columns]

# %%
df.isnull().sum() #last 4 from cancelations have nulls
# Out:
# airport                                0
# year                                   0
# departures for metric computation      0
# arrivals for metric computation        0
# percent on-time gate departures        0
# percent on-time airport departures     0
# percent on-time gate arrivals          0
# average_gate_departure_delay           0
# average_taxi_out_time                  0
# average taxi out delay                 0
# average airport departure delay        0
# average airborne delay                 0
# average taxi in delay                  0
# average block delay                    0
# average gate arrival delay             0
# Departure Cancellations               42
# Arrival Cancellations                 42
# Departure Diversions                  42
# Arrival Diversions                    42
# Key                                    0
# LocID                                  0
# AP_NAME                                0
# ALIAS                                  0
# Facility Type                          0
# FAA REGION                             0
# COUNTY                                 0
# CITY                                   0
# STATE                                  0
# AP Type                                0
# Latitude                               0
# Longitude                              0
# Boundary Data Available                0
# airport_num                            0
# dtype: int64

# %%
# df[df.isnull().any(axis=1)] #prints the nan rows
df['airport'][df.isnull().any(axis=1)].unique() #prints the names of the airports I'm dropping
#gary near chicago in IN, ventura california, rockford in chicago, TEB in NJ, VNY in LA, CA. Doesn't seem like I'm losing a ton by dropping these

df.dropna(axis=0, how='any', inplace=1)
len(df)
# Out:
# 799

# %%
import seaborn as sns

df['diff_gate_airport_departures'] = df['percent on-time gate departures'] - df['percent on-time airport departures']
df['diff_gate_airport_departures']

sns.distplot(df['percent on-time gate departures'], color="blue")
sns.distplot(df['percent on-time airport departures'], color="green")
sns.distplot(df['percent on-time gate arrivals'], color="red")
sns.distplot(df['diff_gate_airport_departures'], color="purple")

# %%
# df['Departure Cancellations'].value_counts()

# %% [markdown]
# ### Intro: Write a problem statement / aim for this project

# %% [markdown]
# ### Part 1: Create a PostgreSQL database

# %% [markdown]
# #### 1. Let's create a database where we can house our airport data

# %%
#Will return to this later in week
from sqlalchemy import create_engine
from sqlalchemy.engine.url import URL
import psycopg2


# %load_ext sql

df1 = df

df1.columns = [c.lower().replace(' ','') for c in df1.columns] #postgres doesn't like capitals or spaces

engine = create_engine('postgresql://localhost:5432')
df1.to_sql('airport_ops', engine)
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# Load our csv files into tables

# %% [markdown]
# Join airport_cancellations.csv and airports.csv into one table

# %%
#done above

# %% [markdown]
# Query the database for our intial data

# %%
# %%sql postgresql://localhost:5432/
#
# SELECT * FROM airport_ops;
# Out:
# 799 rows affected.
# [(0L, u'ABQ', 2004L, 53971L, 53818L, 0.803, 0.7809, 0.7921, 10.38, 9.89, 2.43, 12.1, 2.46, 0.83, 2.55, 10.87, 242.0, 235.0, 71.0, 46.0, 2348.0, u'ABQ', u'ALBUQUERQUE INTL SUNPORT', u"Albuquerque Int'l Sunport", u'Airport', u'ASW', u'BERNALILLO', u'ALBUQUERQUE', u'NM', u'Federalized/Commercial', 35.040194, -106.609194, u'Yes', 44L, 0.0220999999999999),
#  (1L, u'ABQ', 2005L, 51829L, 51877L, 0.814, 0.7922, 0.8001, 9.6, 9.79, 2.29, 11.2, 2.26, 0.89, 2.34, 10.24, 221.0, 190.0, 61.0, 33.0, 2348.0, u'ABQ', u'ALBUQUERQUE INTL SUNPORT', u"Albuquerque Int'l Sunport", u'Airport', u'ASW', u'BERNALILLO', u'ALBUQUERQUE', u'NM', u'Federalized/Commercial', 35.040194, -106.609194, u'Yes', 44L, 0.0218),
#  (2L, u'ABQ', 2006L, 49682L, 51199L, 0.7983, 0.7756, 0.7746, 10.84, 9.89, 2.16, 12.33, 2.12, 0.84, 2.66, 11.82, 392.0, 329.0, 71.0, 124.0, 2348.0, u'ABQ', u'ALBUQUERQUE INTL SUNPORT', u"Albuquerque Int'l Sunport", u'Airport', u'ASW', u'BERNALILLO', u'ALBUQUERQUE', u'NM', u'Federalized/Commercial', 35.040194, -106.609194, u'Yes', 44L, 0.0227000000000001),
#  (3L, u'ABQ', 2007L, 53255L, 53611L, 0.8005, 0.7704, 0.7647, 11.29, 10.34, 2.4, 12.95, 2.19, 1.29, 3.06, 12.71, 366.0, 304.0, 107.0, 45.0, 2348.0, u'ABQ', u'ALBUQUERQUE INTL SUNPORT', u"Albuquerque Int'l Sunport", u'Airport', u'ASW', u'BERNALILLO', u'ALBUQUERQUE', u'NM', u'Federalized/Commercial', 35.040194, -106.609194, u'Yes', 44L, 0.0301),
#  (4L, u'ABQ', 2008L, 49589L, 49512L, 0.8103, 0.7844, 0.7875, 10.79, 10.41, 2.41, 12.32, 1.82, 1.03, 2.79, 11.48, 333.0, 300.0, 79.0, 42.0, 2348.0, u'ABQ', u'ALBUQUERQUE INTL SUNPORT', u"Albuquerque Int'l Sunport", u'Airport', u'ASW', u'BERNALILLO', u'ALBUQUERQUE', u'NM', u'Federalized/Commercial', 35.040194, -106.609194, u'Yes', 44L, 0.0259),
#  (5L, u'ABQ', 2009L, 42550L, 42704L, 0.8341, 0.8147, 0.8224, 9.24, 9.88, 1.89, 10.45, 1.74, 0.92, 1.98, 9.27, 192.0, 162.0, 74.0, 26.0, 2348.0, u'ABQ', u'ALBUQUERQUE INTL SUNPORT', u"Albuquerque Int'l Sunport", u'Airport', u'ASW', u'BERNALILLO', u'ALBUQUERQUE', u'NM', u'Federalized/Commercial', 35.040194, -106.609194, u'Yes', 44L, 0.0194),
#  (6L, u'ABQ', 2010L, 42302L, 42169L, 0.8144, 0.7907, 0.8047, 10.25, 9.95, 2.05, 11.58, 1.66, 0.95, 1.9, 10.23, 222.0, 177.0, 71.0, 50.0, 2348.0, u'ABQ', u'ALBUQUERQUE INTL SUNPORT', u"Albuquerque Int'l Sunport", u'Airport', u'ASW', u'BERNALILLO', u'ALBUQUERQUE', u'NM', u'Federalized/Commercial', 35.040194, -106.609194, u'Yes', 44L, 0.0237000000000001),
#  (7L, u'ABQ', 2011L, 42283L, 42297L, 0.8072, 0.7758, 0.8022, 10.81, 10.5, 2.51, 12.57, 1.58, 0.84, 1.87, 10.63, 345.0, 294.0, 77.0, 61.0, 2348.0, u'ABQ', u'ALBUQUERQUE INTL SUNPORT', u"Albuquerque Int'l Sunport", u'Airport', u'ASW', u'BERNALILLO', u'ALBUQUERQUE', u'NM', u'Federalized/Commercial', 35.040194, -106.609194, u'Yes', 44L, 0.0314),
#  (8L, u'ABQ', 2012L, 39105L, 39107L, 0.8219, 0.794, 0.8177, 10.55, 10.27, 2.32, 12.11, 1.41, 0.98, 1.8, 9.73, 237.0, 181.0, 65.0, 60.0, 2348.0, u'ABQ', u'ALBUQUERQUE INTL SUNPORT', u"Albuquerque Int'l Sunport", u'Airport', u'ASW', u'BERNALILLO', u'ALBUQUERQUE', u'NM', u'Federalized/Commercial', 35.040194, -106.609194, u'Yes', 44L, 0.0278999999999999),
#  (9L, u'ABQ', 2013L, 35277L, 34989L, 0.771, 0.7402, 0.7554, 12.56, 10.77, 2.64, 14.28, 1.6, 0.92, 2.35, 12.76, 232.0, 212.0, 62.0, 46.0, 2348.0, u'ABQ', u'ALBUQUERQUE INTL SUNPORT', u"Albuquerque Int'l Sunport", u'Airport', u'ASW', u'BERNALILLO', u'ALBUQUERQUE', u'NM', u'Federalized/Commercial', 35.040194, -106.609194, u'Yes', 44L, 0.0307999999999999),
#  (10L, u'ABQ', 2014L, 33292L, 33137L, 0.7451, 0.7148, 0.732, 14.3, 10.64, 2.41, 15.99, 1.73, 1.02, 2.4, 14.72, 315.0, 274.0, 66.0, 37.0, 2348.0, u'ABQ', u'ALBUQUERQUE INTL SUNPORT', u"Albuquerque Int'l Sunport", u'Airport', u'ASW', u'BERNALILLO', u'ALBUQUERQUE', u'NM', u'Federalized/Commercial', 35.040194, -106.609194, u'Yes', 44L, 0.0303),
#  (11L, u'ANC', 2004L, 16503L, 15511L, 0.7109, 0.677, 0.6502, 21.45, 12.41, 2.92, 23.05, 4.03, 1.08, 5.93, 22.62, 473.0, 532.0, 73.0, 30.0, 246.0, u'ANC', u'TED STEVENS ANCHORAGE INTL', u"Ted Stevens Anchorage Int'l Airport", u'Airport', u'AAL', u'ANCHORAGE', u'ANCHORAGE', u'AK', u'Federalized/Commercial', 61.174083, -149.998194, u'Yes', 61L, 0.0338999999999999),
#  (12L, u'ANC', 2005L, 72043L, 67034L, 0.7394, 0.7061, 0.6955, 18.36, 12.19, 2.78, 19.97, 3.65, 1.01, 4.96, 19.35, 424.0, 484.0, 74.0, 31.0, 246.0, u'ANC', u'TED STEVENS ANCHORAGE INTL', u"Ted Stevens Anchorage Int'l Airport", u'Airport', u'AAL', u'ANCHORAGE', u'ANCHORAGE', u'AK', u'Federalized/Commercial', 61.174083, -149.998194, u'Yes', 61L, 0.0333),
#  (13L, u'ANC', 2006L, 75708L, 69995L, 0.7771, 0.7455, 0.711, 15.56, 12.84, 2.54, 17.07, 4.29, 0.72, 5.83, 17.71, 367.0, 436.0, 88.0, 50.0, 246.0, u'ANC', u'TED STEVENS ANCHORAGE INTL', u"Ted Stevens Anchorage Int'l Airport", u'Airport', u'AAL', u'ANCHORAGE', u'ANCHORAGE', u'AK', u'Federalized/Commercial', 61.174083, -149.998194, u'Yes', 61L, 0.0316),
#  (14L, u'ANC', 2007L, 78741L, 73323L, 0.7838, 0.7457, 0.7196, 15.69, 13.19, 2.29, 17.52, 5.13, 0.39, 5.87, 18.09, 359.0, 423.0, 93.0, 54.0, 246.0, u'ANC', u'TED STEVENS ANCHORAGE INTL', u"Ted Stevens Anchorage Int'l Airport", u'Airport', u'AAL', u'ANCHORAGE', u'ANCHORAGE', u'AK', u'Federalized/Commercial', 61.174083, -149.998194, u'Yes', 61L, 0.0381),
#  (15L, u'ANC', 2008L, 76606L, 72479L, 0.7972, 0.7698, 0.7573, 13.45, 13.44, 1.86, 14.72, 5.13, 0.63, 5.93, 15.89, 268.0, 355.0, 97.0, 57.0, 246.0, u'ANC', u'TED STEVENS ANCHORAGE INTL', u"Ted Stevens Anchorage Int'l Airport", u'Airport', u'AAL', u'ANCHORAGE', u'ANCHORAGE', u'AK', u'Federalized/Commercial', 61.174083, -149.998194, u'Yes', 61L, 0.0274),
#  (16L, u'ANC', 2009L, 67252L, 63135L, 0.8112, 0.7952, 0.8264, 15.1, 12.49, 1.55, 15.88, 3.85, 0.31, 4.19, 15.95, 354.0, 421.0, 84.0, 80.0, 246.0, u'ANC', u'TED STEVENS ANCHORAGE INTL', u"Ted Stevens Anchorage Int'l Airport", u'Airport', u'AAL', u'ANCHORAGE', u'ANCHORAGE', u'AK', u'Federalized/Commercial', 61.174083, -149.998194, u'Yes', 61L, 0.016),
#  (17L, u'ANC', 2010L, 73089L, 68125L, 0.7992, 0.776, 0.8045, 17.77, 11.97, 1.79, 18.83, 3.75, 0.37, 3.91, 20.28, 149.0, 204.0, 84.0, 32.0, 246.0, u'ANC', u'TED STEVENS ANCHORAGE INTL', u"Ted Stevens Anchorage Int'l Airport", u'Airport', u'AAL', u'ANCHORAGE', u'ANCHORAGE', u'AK', u'Federalized/Commercial', 61.174083, -149.998194, u'Yes', 61L, 0.0232000000000001),
#  (18L, u'ANC', 2011L, 72556L, 66845L, 0.8276, 0.805, 0.8292, 14.56, 11.89, 1.66, 15.6, 3.92, 0.55, 4.01, 13.93, 191.0, 265.0, 87.0, 36.0, 246.0, u'ANC', u'TED STEVENS ANCHORAGE INTL', u"Ted Stevens Anchorage Int'l Airport", u'Airport', u'AAL', u'ANCHORAGE', u'ANCHORAGE', u'AK', u'Federalized/Commercial', 61.174083, -149.998194, u'Yes', 61L, 0.0226),
#  (19L, u'ANC', 2012L, 70322L, 66453L, 0.8442, 0.8235, 0.8521, 10.01, 11.71, 1.52, 11.0, 3.86, 0.34, 3.75, 9.33, 216.0, 284.0, 78.0, 36.0, 246.0, u'ANC', u'TED STEVENS ANCHORAGE INTL', u"Ted Stevens Anchorage Int'l Airport", u'Airport', u'AAL', u'ANCHORAGE', u'ANCHORAGE', u'AK', u'Federalized/Commercial', 61.174083, -149.998194, u'Yes', 61L, 0.0206999999999999),
#  (20L, u'ANC', 2013L, 69984L, 65469L, 0.8432, 0.8228, 0.8631, 9.18, 12.03, 1.51, 10.09, 3.4, 0.47, 3.82, 8.46, 141.0, 184.0, 65.0, 40.0, 246.0, u'ANC', u'TED STEVENS ANCHORAGE INTL', u"Ted Stevens Anchorage Int'l Airport", u'Airport', u'AAL', u'ANCHORAGE', u'ANCHORAGE', u'AK', u'Federalized/Commercial', 61.174083, -149.998194, u'Yes', 61L, 0.0204),
#  (21L, u'ANC', 2014L, 71099L, 66704L, 0.8288, 0.8074, 0.86, 11.33, 11.33, 1.33, 12.34, 4.09, 0.54, 4.57, 10.82, 111.0, 162.0, 74.0, 28.0, 246.0, u'ANC', u'TED STEVENS ANCHORAGE INTL', u"Ted Stevens Anchorage Int'l Airport", u'Airport', u'AAL', u'ANCHORAGE', u'ANCHORAGE', u'AK', u'Federalized/Commercial', 61.174083, -149.998194, u'Yes', 61L, 0.0214),
#  (22L, u'ATL', 2004L, 477323L, 473249L, 0.7596, 0.5757, 0.737, 13.59, 20.45, 8.73, 21.36, 5.0, 2.79, 4.69, 15.31, 7870.0, 8433.0, 737.0, 772.0, 921.0, u'ATL', u'HARTSFIELD - JACKSON ATLANTA INTL', u"Hartsfield-Jackson Atlanta Int'l", u'Airport', u'ASO', u'FULTON', u'ATLANTA', u'GA', u'Federalized/Commercial', 33.6367, -84.427864, u'Yes', 5L, 0.1839),
#  (23L, u'ATL', 2005L, 484570L, 480171L, 0.7413, 0.6216, 0.7337, 15.5, 18.52, 7.26, 21.8, 4.24, 2.72, 4.62, 17.23, 13837.0, 14480.0, 790.0, 1080.0, 921.0, u'ATL', u'HARTSFIELD - JACKSON ATLANTA INTL', u"Hartsfield-Jackson Atlanta Int'l", u'Airport', u'ASO', u'FULTON', u'ATLANTA', u'GA', u'Federalized/Commercial', 33.6367, -84.427864, u'Yes', 5L, 0.1197),
#  (24L, u'ATL', 2006L, 483334L, 478735L, 0.715, 0.5324, 0.7205, 16.2, 20.38, 9.63, 24.85, 3.71, 4.13, 4.72, 16.95, 6624.0, 7301.0, 913.0, 787.0, 921.0, u'ATL', u'HARTSFIELD - JACKSON ATLANTA INTL', u"Hartsfield-Jackson Atlanta Int'l", u'Airport', u'ASO', u'FULTON', u'ATLANTA', u'GA', u'Federalized/Commercial', 33.6367, -84.427864, u'Yes', 5L, 0.1826),
#  (25L, u'ATL', 2007L, 491826L, 486799L, 0.7167, 0.5713, 0.7446, 16.77, 19.67, 8.28, 24.18, 3.88, 4.17, 4.43, 16.09, 6796.0, 7790.0, 920.0, 1045.0, 921.0, u'ATL', u'HARTSFIELD - JACKSON ATLANTA INTL', u"Hartsfield-Jackson Atlanta Int'l", u'Airport', u'ASO', u'FULTON', u'ATLANTA', u'GA', u'Federalized/Commercial', 33.6367, -84.427864, u'Yes', 5L, 0.1454),
#  (26L, u'ATL', 2008L, 482903L, 478627L, 0.7696, 0.6071, 0.7559, 13.86, 20.6, 9.01, 21.59, 4.11, 4.07, 5.09, 15.71, 5830.0, 6705.0, 982.0, 1072.0, 921.0, u'ATL', u'HARTSFIELD - JACKSON ATLANTA INTL', u"Hartsfield-Jackson Atlanta Int'l", u'Airport', u'ASO', u'FULTON', u'ATLANTA', u'GA', u'Federalized/Commercial', 33.6367, -84.427864, u'Yes', 5L, 0.1625),
#  (27L, u'ATL', 2009L, 479957L, 475882L, 0.7775, 0.59, 0.7335, 13.2, 21.84, 9.73, 21.48, 3.31, 4.75, 5.7, 16.54, 5324.0, 6303.0, 1064.0, 1116.0, 921.0, u'ATL', u'HARTSFIELD - JACKSON ATLANTA INTL', u"Hartsfield-Jackson Atlanta Int'l", u'Airport', u'ASO', u'FULTON', u'ATLANTA', u'GA', u'Federalized/Commercial', 33.6367, -84.427864, u'Yes', 5L, 0.1875),
#  (28L, u'ATL', 2010L, 469542L, 465911L, 0.7961, 0.6405, 0.7956, 12.82, 21.26, 8.61, 19.9, 2.66, 4.32, 3.67, 14.16, 8198.0, 9279.0, 971.0, 945.0, 921.0, u'ATL', u'HARTSFIELD - JACKSON ATLANTA INTL', u"Hartsfield-Jackson Atlanta Int'l", u'Airport', u'ASO', u'FULTON', u'ATLANTA', u'GA', u'Federalized/Commercial', 33.6367, -84.427864, u'Yes', 5L, 0.1556),
#  (29L, u'ATL', 2011L, 454954L, 453734L, 0.8008, 0.673, 0.8068, 12.2, 20.33, 7.52, 18.25, 2.41, 4.0, 3.54, 12.56, 6555.0, 7484.0, 903.0, 812.0, 921.0, u'ATL', u'HARTSFIELD - JACKSON ATLANTA INTL', u"Hartsfield-Jackson Atlanta Int'l", u'Airport', u'ASO', u'FULTON', u'ATLANTA', u'GA', u'Federalized/Commercial', 33.6367, -84.427864, u'Yes', 5L, 0.1278),
#  (30L, u'ATL', 2012L, 457501L, 455968L, 0.832, 0.7401, 0.8422, 9.84, 18.8, 6.03, 14.44, 1.62, 3.13, 2.89, 10.27, 2259.0, 2782.0, 798.0, 655.0, 921.0, u'ATL', u'HARTSFIELD - JACKSON ATLANTA INTL', u"Hartsfield-Jackson Atlanta Int'l", u'Airport', u'ASO', u'FULTON', u'ATLANTA', u'GA', u'Federalized/Commercial', 33.6367, -84.427864, u'Yes', 5L, 0.0919000000000001),
#  (31L, u'ATL', 2013L, 448180L, 445498L, 0.7917, 0.7025, 0.807, 12.28, 18.2, 5.83, 16.98, 2.38, 2.6, 3.64, 12.74, 2916.0, 3450.0, 870.0, 655.0, 921.0, u'ATL', u'HARTSFIELD - JACKSON ATLANTA INTL', u"Hartsfield-Jackson Atlanta Int'l", u'Airport', u'ASO', u'FULTON', u'ATLANTA', u'GA', u'Federalized/Commercial', 33.6367, -84.427864, u'Yes', 5L, 0.0891999999999999),
#  (32L, u'ATL', 2014L, 428954L, 428312L, 0.7899, 0.7134, 0.8123, 11.99, 17.4, 4.92, 15.93, 2.74, 2.77, 3.21, 12.42, 5977.0, 6483.0, 781.0, 655.0, 921.0, u'ATL', u'HARTSFIELD - JACKSON ATLANTA INTL', u"Hartsfield-Jackson Atlanta Int'l", u'Airport', u'ASO', u'FULTON', u'ATLANTA', u'GA', u'Federalized/Commercial', 33.6367, -84.427864, u'Yes', 5L, 0.0765),
#  (33L, u'AUS', 2004L, 14094L, 14052L, 0.7845, 0.7658, 0.7486, 12.05, 11.0, 2.33, 13.73, 2.85, 0.82, 3.26, 13.95, 477.0, 436.0, 53.0, 40.0, 3097.0, u'AUS', u'AUSTIN-BERGSTROM INTL', u"Austin-Bergstrom Int'l Airport", u'Airport', u'ASW', u'TRAVIS', u'AUSTIN', u'TX', u'Federalized/Commercial', 30.194528, -97.669889, u'Yes', 45L, 0.0186999999999999),
#  (34L, u'AUS', 2005L, 55790L, 55678L, 0.8107, 0.7892, 0.7641, 10.31, 10.98, 2.42, 12.04, 2.61, 0.99, 2.74, 12.62, 435.0, 411.0, 57.0, 76.0, 3097.0, u'AUS', u'AUSTIN-BERGSTROM INTL', u"Austin-Bergstrom Int'l Airport", u'Airport', u'ASW', u'TRAVIS', u'AUSTIN', u'TX', u'Federalized/Commercial', 30.194528, -97.669889, u'Yes', 45L, 0.0215),
#  (35L, u'AUS', 2006L, 56809L, 56704L, 0.7826, 0.7579, 0.7424, 12.29, 11.33, 2.34, 13.95, 2.39, 1.02, 3.28, 14.35, 440.0, 387.0, 82.0, 51.0, 3097.0, u'AUS', u'AUSTIN-BERGSTROM INTL', u"Austin-Bergstrom Int'l Airport", u'Airport', u'ASW', u'TRAVIS', u'AUSTIN', u'TX', u'Federalized/Commercial', 30.194528, -97.669889, u'Yes', 45L, 0.0246999999999999),
#  (36L, u'AUS', 2007L, 62255L, 62685L, 0.7789, 0.7499, 0.7241, 12.84, 12.1, 2.74, 14.79, 2.41, 1.27, 3.45, 15.39, 827.0, 773.0, 116.0, 114.0, 3097.0, u'AUS', u'AUSTIN-BERGSTROM INTL', u"Austin-Bergstrom Int'l Airport", u'Airport', u'ASW', u'TRAVIS', u'AUSTIN', u'TX', u'Federalized/Commercial', 30.194528, -97.669889, u'Yes', 45L, 0.029),
#  (37L, u'AUS', 2008L, 60425L, 60559L, 0.7986, 0.773, 0.7473, 11.77, 12.11, 2.6, 13.51, 2.05, 1.02, 3.06, 14.42, 732.0, 688.0, 95.0, 86.0, 3097.0, u'AUS', u'AUSTIN-BERGSTROM INTL', u"Austin-Bergstrom Int'l Airport", u'Airport', u'ASW', u'TRAVIS', u'AUSTIN', u'TX', u'Federalized/Commercial', 30.194528, -97.669889, u'Yes', 45L, 0.0256),
#  (38L, u'AUS', 2009L, 53686L, 53651L, 0.8154, 0.7943, 0.772, 10.91, 11.67, 2.05, 12.23, 2.26, 1.16, 2.69, 12.73, 298.0, 261.0, 72.0, 69.0, 3097.0, u'AUS', u'AUSTIN-BERGSTROM INTL', u"Austin-Bergstrom Int'l Airport", u'Airport', u'ASW', u'TRAVIS', u'AUSTIN', u'TX', u'Federalized/Commercial', 30.194528, -97.669889, u'Yes', 45L, 0.0211),
#  (39L, u'AUS', 2010L, 54502L, 54481L, 0.8068, 0.7857, 0.7734, 10.98, 11.46, 1.91, 12.18, 1.88, 0.91, 2.36, 12.38, 356.0, 307.0, 74.0, 67.0, 3097.0, u'AUS', u'AUSTIN-BERGSTROM INTL', u"Austin-Bergstrom Int'l Airport", u'Airport', u'ASW', u'TRAVIS', u'AUSTIN', u'TX', u'Federalized/Commercial', 30.194528, -97.669889, u'Yes', 45L, 0.0211),
#  (40L, u'AUS', 2011L, 55584L, 55526L, 0.8051, 0.7841, 0.7738, 11.29, 11.38, 1.97, 12.56, 1.65, 0.97, 2.42, 12.56, 425.0, 399.0, 102.0, 30.0, 3097.0, u'AUS', u'AUSTIN-BERGSTROM INTL', u"Austin-Bergstrom Int'l Airport", u'Airport', u'ASW', u'TRAVIS', u'AUSTIN', u'TX', u'Federalized/Commercial', 30.194528, -97.669889, u'Yes', 45L, 0.021),
#  (41L, u'AUS', 2012L, 56043L, 55752L, 0.8083, 0.784, 0.7769, 10.98, 11.59, 2.25, 12.46, 1.69, 1.18, 2.46, 12.3, 353.0, 323.0, 80.0, 60.0, 3097.0, u'AUS', u'AUSTIN-BERGSTROM INTL', u"Austin-Bergstrom Int'l Airport", u'Airport', u'ASW', u'TRAVIS', u'AUSTIN', u'TX', u'Federalized/Commercial', 30.194528, -97.669889, u'Yes', 45L, 0.0243),
#  (42L, u'AUS', 2013L, 58240L, 58316L, 0.7716, 0.7433, 0.7261, 13.25, 11.8, 2.33, 14.85, 1.8, 1.19, 3.04, 16.35, 390.0, 318.0, 84.0, 80.0, 3097.0, u'AUS', u'AUSTIN-BERGSTROM INTL', u"Austin-Bergstrom Int'l Airport", u'Airport', u'ASW', u'TRAVIS', u'AUSTIN', u'TX', u'Federalized/Commercial', 30.194528, -97.669889, u'Yes', 45L, 0.0283),
#  (43L, u'AUS', 2014L, 60588L, 60264L, 0.7627, 0.7382, 0.7222, 14.16, 11.76, 2.06, 15.59, 2.25, 1.08, 2.88, 16.2, 484.0, 435.0, 88.0, 97.0, 3097.0, u'AUS', u'AUSTIN-BERGSTROM INTL', u"Austin-Bergstrom Int'l Airport", u'Airport', u'ASW', u'TRAVIS', u'AUSTIN', u'TX', u'Federalized/Commercial', 30.194528, -97.669889, u'Yes', 45L, 0.0245000000000001),
#  (375L, u'LGA', 2005L, 196606L, 196474L, 0.7429, 0.569, 0.6829, 16.09, 22.44, 10.35, 24.55, 5.73, 2.41, 5.67, 20.41, 5060.0, 4879.0, 271.0, 592.0, 2462.0, u'LGA', u'LA GUARDIA', u'Laguardia Airport', u'Airport', u'AEA', u'QUEENS', u'NEW YORK', u'NY', u'Federalized/Commercial', 40.77725, -73.872611, u'Yes', 64L, 0.1739),
#  (44L, u'BDL', 2004L, 52897L, 52093L, 0.8222, 0.7719, 0.768, 10.26, 13.58, 3.95, 13.1, 2.95, 0.89, 3.48, 12.95, 426.0, 368.0, 70.0, 26.0, 755.0, u'BDL', u'BRADLEY INTL', u"Bradley Int'l Airport", u'Airport', u'ANE', u'HARTFORD', u'WINDSOR LOCKS', u'CT', u'Federalized/Commercial', 41.939145, -72.683371, u'Yes', 40L, 0.0503),
#  (45L, u'BDL', 2005L, 58287L, 57128L, 0.8108, 0.7668, 0.7549, 11.34, 13.03, 3.66, 13.86, 3.06, 1.03, 3.38, 14.02, 719.0, 669.0, 74.0, 32.0, 755.0, u'BDL', u'BRADLEY INTL', u"Bradley Int'l Airport", u'Airport', u'ANE', u'HARTFORD', u'WINDSOR LOCKS', u'CT', u'Federalized/Commercial', 41.939145, -72.683371, u'Yes', 40L, 0.0439999999999999),
#  (46L, u'BDL', 2006L, 54169L, 53701L, 0.794, 0.7496, 0.7488, 12.09, 13.02, 3.32, 14.51, 2.9, 1.01, 3.47, 14.12, 561.0, 486.0, 78.0, 34.0, 755.0, u'BDL', u'BRADLEY INTL', u"Bradley Int'l Airport", u'Airport', u'ANE', u'HARTFORD', u'WINDSOR LOCKS', u'CT', u'Federalized/Commercial', 41.939145, -72.683371, u'Yes', 40L, 0.0444),
#  (47L, u'BDL', 2007L, 52603L, 52050L, 0.783, 0.7305, 0.7226, 13.64, 13.71, 3.76, 16.59, 3.12, 1.19, 3.7, 15.85, 757.0, 685.0, 82.0, 40.0, 755.0, u'BDL', u'BRADLEY INTL', u"Bradley Int'l Airport", u'Airport', u'ANE', u'HARTFORD', u'WINDSOR LOCKS', u'CT', u'Federalized/Commercial', 41.939145, -72.683371, u'Yes', 40L, 0.0524999999999999),
#  (48L, u'BDL', 2008L, 47467L, 46956L, 0.8105, 0.7682, 0.7525, 12.27, 13.56, 3.32, 14.74, 3.39, 1.08, 3.46, 14.4, 587.0, 499.0, 74.0, 80.0, 755.0, u'BDL', u'BRADLEY INTL', u"Bradley Int'l Airport", u'Airport', u'ANE', u'HARTFORD', u'WINDSOR LOCKS', u'CT', u'Federalized/Commercial', 41.939145, -72.683371, u'Yes', 40L, 0.0423),
#  (49L, u'BDL', 2009L, 39994L, 39698L, 0.8349, 0.7944, 0.7933, 10.26, 13.02, 2.89, 12.33, 2.97, 0.86, 2.93, 11.7, 347.0, 314.0, 79.0, 52.0, 755.0, u'BDL', u'BRADLEY INTL', u"Bradley Int'l Airport", u'Airport', u'ANE', u'HARTFORD', u'WINDSOR LOCKS', u'CT', u'Federalized/Commercial', 41.939145, -72.683371, u'Yes', 40L, 0.0405),
#  (50L, u'BDL', 2010L, 39685L, 39309L, 0.8154, 0.7707, 0.7748, 10.79, 13.07, 3.0, 12.89, 3.04, 0.97, 3.19, 12.62, 466.0, 425.0, 71.0, 35.0, 755.0, u'BDL', u'BRADLEY INTL', u"Bradley Int'l Airport", u'Airport', u'ANE', u'HARTFORD', u'WINDSOR LOCKS', u'CT', u'Federalized/Commercial', 41.939145, -72.683371, u'Yes', 40L, 0.0447),
#  (51L, u'BDL', 2011L, 42774L, 42628L, 0.8042, 0.7676, 0.7715, 12.24, 12.81, 2.67, 14.15, 2.9, 0.99, 2.78, 13.42, 614.0, 554.0, 54.0, 35.0, 755.0, u'BDL', u'BRADLEY INTL', u"Bradley Int'l Airport", u'Airport', u'ANE', u'HARTFORD', u'WINDSOR LOCKS', u'CT', u'Federalized/Commercial', 41.939145, -72.683371, u'Yes', 40L, 0.0366000000000001),
#  (52L, u'BDL', 2012L, 39274L, 39122L, 0.8166, 0.7863, 0.7832, 11.2, 12.4, 2.33, 12.77, 2.34, 0.76, 2.43, 12.46, 295.0, 257.0, 48.0, 26.0, 755.0, u'BDL', u'BRADLEY INTL', u"Bradley Int'l Airport", u'Airport', u'ANE', u'HARTFORD', u'WINDSOR LOCKS', u'CT', u'Federalized/Commercial', 41.939145, -72.683371, u'Yes', 40L, 0.0303),
#  (53L, u'BDL', 2013L, 38505L, 38508L, 0.7931, 0.7521, 0.7493, 12.7, 12.62, 2.69, 14.8, 2.46, 0.9, 2.97, 14.58, 364.0, 331.0, 45.0, 17.0, 755.0, u'BDL', u'BRADLEY INTL', u"Bradley Int'l Airport", u'Airport', u'ANE', u'HARTFORD', u'WINDSOR LOCKS', u'CT', u'Federalized/Commercial', 41.939145, -72.683371, u'Yes', 40L, 0.041),
#  (54L, u'BDL', 2014L, 39279L, 39109L, 0.7953, 0.7605, 0.7569, 12.64, 12.76, 2.58, 14.39, 2.34, 0.95, 2.64, 14.79, 467.0, 421.0, 57.0, 32.0, 755.0, u'BDL', u'BRADLEY INTL', u"Bradley Int'l Airport", u'Airport', u'ANE', u'HARTFORD', u'WINDSOR LOCKS', u'CT', u'Federalized/Commercial', 41.939145, -72.683371, u'Yes', 40L, 0.0348000000000001),
#  (55L, u'BHM', 2004L, 9336L, 9557L, 0.7822, 0.7528, 0.7282, 12.41, 10.5, 2.77, 14.25, 2.45, 1.07, 2.63, 14.41, 402.0, 332.0, 71.0, 24.0, 263.0, u'BHM', u'BIRMINGHAM-SHUTTLESWORTH INTL', u"Birmingham Int'l Airport", u'Airport', u'ASO', u'JEFFERSON', u'BIRMINGHAM', u'AL', u'Federalized/Commercial', 33.563889, -86.752306, u'Yes', 59L, 0.0294),
#  (56L, u'BHM', 2005L, 36146L, 36973L, 0.7815, 0.7555, 0.719, 12.01, 10.64, 2.93, 13.86, 2.47, 0.99, 2.55, 14.95, 419.0, 395.0, 63.0, 25.0, 263.0, u'BHM', u'BIRMINGHAM-SHUTTLESWORTH INTL', u"Birmingham Int'l Airport", u'Airport', u'ASO', u'JEFFERSON', u'BIRMINGHAM', u'AL', u'Federalized/Commercial', 33.563889, -86.752306, u'Yes', 59L, 0.026),
#  (57L, u'BHM', 2006L, 33169L, 33672L, 0.7537, 0.7279, 0.6976, 14.13, 11.11, 2.66, 15.96, 2.54, 0.94, 3.33, 16.07, 287.0, 257.0, 53.0, 30.0, 263.0, u'BHM', u'BIRMINGHAM-SHUTTLESWORTH INTL', u"Birmingham Int'l Airport", u'Airport', u'ASO', u'JEFFERSON', u'BIRMINGHAM', u'AL', u'Federalized/Commercial', 33.563889, -86.752306, u'Yes', 59L, 0.0258),
#  (58L, u'BHM', 2007L, 35612L, 35925L, 0.7583, 0.7257, 0.7055, 14.55, 11.77, 2.84, 16.69, 2.68, 0.81, 3.28, 17.23, 459.0, 371.0, 59.0, 23.0, 263.0, u'BHM', u'BIRMINGHAM-SHUTTLESWORTH INTL', u"Birmingham Int'l Airport", u'Airport', u'ASO', u'JEFFERSON', u'BIRMINGHAM', u'AL', u'Federalized/Commercial', 33.563889, -86.752306, u'Yes', 59L, 0.0326),
#  (59L, u'BHM', 2008L, 34605L, 34766L, 0.7715, 0.7406, 0.7289, 13.82, 11.94, 2.88, 15.82, 2.14, 0.65, 3.0, 15.37, 385.0, 341.0, 58.0, 42.0, 263.0, u'BHM', u'BIRMINGHAM-SHUTTLESWORTH INTL', u"Birmingham Int'l Airport", u'Airport', u'ASO', u'JEFFERSON', u'BIRMINGHAM', u'AL', u'Federalized/Commercial', 33.563889, -86.752306, u'Yes', 59L, 0.0308999999999999),
#  (60L, u'BHM', 2009L, 29422L, 29959L, 0.7785, 0.7362, 0.7443, 13.02, 12.38, 3.21, 15.3, 1.82, 0.73, 2.77, 14.34, 249.0, 209.0, 61.0, 64.0, 263.0, u'BHM', u'BIRMINGHAM-SHUTTLESWORTH INTL', u"Birmingham Int'l Airport", u'Airport', u'ASO', u'JEFFERSON', u'BIRMINGHAM', u'AL', u'Federalized/Commercial', 33.563889, -86.752306, u'Yes', 59L, 0.0423),
#  (61L, u'BHM', 2010L, 29563L, 29907L, 0.7792, 0.7303, 0.7449, 12.62, 12.54, 3.22, 15.07, 1.5, 0.75, 2.28, 13.49, 315.0, 266.0, 60.0, 55.0, 263.0, u'BHM', u'BIRMINGHAM-SHUTTLESWORTH INTL', u"Birmingham Int'l Airport", u'Airport', u'ASO', u'JEFFERSON', u'BIRMINGHAM', u'AL', u'Federalized/Commercial', 33.563889, -86.752306, u'Yes', 59L, 0.0489000000000001),
#  (62L, u'BHM', 2011L, 27376L, 27705L, 0.7898, 0.7573, 0.7509, 12.37, 11.8, 2.34, 13.84, 1.59, 0.62, 2.32, 13.38, 266.0, 243.0, 42.0, 55.0, 263.0, u'BHM', u'BIRMINGHAM-SHUTTLESWORTH INTL', u"Birmingham Int'l Airport", u'Airport', u'ASO', u'JEFFERSON', u'BIRMINGHAM', u'AL', u'Federalized/Commercial', 33.563889, -86.752306, u'Yes', 59L, 0.0325),
#  (63L, u'BHM', 2012L, 26436L, 26597L, 0.8107, 0.7832, 0.7638, 11.45, 11.86, 2.21, 12.89, 1.28, 0.71, 1.93, 13.18, 147.0, 143.0, 31.0, 18.0, 263.0, u'BHM', u'BIRMINGHAM-SHUTTLESWORTH INTL', u"Birmingham Int'l Airport", u'Airport', u'ASO', u'JEFFERSON', u'BIRMINGHAM', u'AL', u'Federalized/Commercial', 33.563889, -86.752306, u'Yes', 59L, 0.0275),
#  (64L, u'BHM', 2013L, 24460L, 24402L, 0.7691, 0.7327, 0.7165, 13.62, 12.45, 2.6, 15.48, 1.55, 1.03, 2.85, 15.4, 203.0, 186.0, 50.0, 52.0, 263.0, u'BHM', u'BIRMINGHAM-SHUTTLESWORTH INTL', u"Birmingham Int'l Airport", u'Airport', u'ASO', u'JEFFERSON', u'BIRMINGHAM', u'AL', u'Federalized/Commercial', 33.563889, -86.752306, u'Yes', 59L, 0.0364),
#  (65L, u'BHM', 2014L, 23725L, 23682L, 0.7421, 0.7183, 0.7016, 15.58, 12.19, 2.05, 16.75, 1.74, 0.93, 2.93, 16.7, 336.0, 311.0, 46.0, 30.0, 263.0, u'BHM', u'BIRMINGHAM-SHUTTLESWORTH INTL', u"Birmingham Int'l Airport", u'Airport', u'ASO', u'JEFFERSON', u'BIRMINGHAM', u'AL', u'Federalized/Commercial', 33.563889, -86.752306, u'Yes', 59L, 0.0237999999999999),
#  (66L, u'BNA', 2004L, 84167L, 84551L, 0.7849, 0.7597, 0.7638, 11.37, 10.63, 2.5, 13.34, 3.52, 0.75, 2.83, 12.8, 752.0, 723.0, 163.0, 49.0, 3061.0, u'BNA', u'NASHVILLE INTL', u"Nashville Int'l Airport", u'Airport', u'ASO', u'DAVIDSON', u'NASHVILLE', u'TN', u'Federalized/Commercial', 36.124472, -86.678194, u'Yes', 51L, 0.0252),
#  (67L, u'BNA', 2005L, 83922L, 84108L, 0.7837, 0.7614, 0.7655, 11.61, 10.9, 2.51, 13.43, 3.48, 0.89, 2.57, 12.79, 706.0, 642.0, 138.0, 84.0, 3061.0, u'BNA', u'NASHVILLE INTL', u"Nashville Int'l Airport", u'Airport', u'ASO', u'DAVIDSON', u'NASHVILLE', u'TN', u'Federalized/Commercial', 36.124472, -86.678194, u'Yes', 51L, 0.0223),
#  (68L, u'BNA', 2006L, 80868L, 80903L, 0.7649, 0.7339, 0.7472, 13.18, 11.6, 2.74, 15.21, 3.35, 1.0, 2.82, 14.26, 739.0, 712.0, 187.0, 87.0, 3061.0, u'BNA', u'NASHVILLE INTL', u"Nashville Int'l Airport", u'Airport', u'ASO', u'DAVIDSON', u'NASHVILLE', u'TN', u'Federalized/Commercial', 36.124472, -86.678194, u'Yes', 51L, 0.031),
#  (69L, u'BNA', 2007L, 81020L, 81183L, 0.7513, 0.7282, 0.7265, 14.56, 11.51, 2.37, 16.08, 3.26, 1.31, 3.11, 15.83, 973.0, 931.0, 163.0, 82.0, 3061.0, u'BNA', u'NASHVILLE INTL', u"Nashville Int'l Airport", u'Airport', u'ASO', u'DAVIDSON', u'NASHVILLE', u'TN', u'Federalized/Commercial', 36.124472, -86.678194, u'Yes', 51L, 0.0231),
#  (70L, u'BNA', 2008L, 75174L, 75172L, 0.7713, 0.7424, 0.7518, 13.75, 11.66, 2.56, 15.57, 2.88, 1.1, 2.95, 14.53, 791.0, 743.0, 169.0, 58.0, 3061.0, u'BNA', u'NASHVILLE INTL', u"Nashville Int'l Airport", u'Airport', u'ASO', u'DAVIDSON', u'NASHVILLE', u'TN', u'Federalized/Commercial', 36.124472, -86.678194, u'Yes', 51L, 0.0289),
#  (71L, u'BNA', 2009L, 69219L, 69209L, 0.7961, 0.7722, 0.7871, 12.05, 11.37, 2.18, 13.35, 2.61, 1.03, 2.72, 12.04, 573.0, 496.0, 132.0, 78.0, 3061.0, u'BNA', u'NASHVILLE INTL', u"Nashville Int'l Airport", u'Airport', u'ASO', u'DAVIDSON', u'NASHVILLE', u'TN', u'Federalized/Commercial', 36.124472, -86.678194, u'Yes', 51L, 0.0239),
#  (72L, u'BNA', 2010L, 69024L, 69292L, 0.7733, 0.736, 0.783, 12.74, 11.8, 2.64, 14.54, 2.3, 1.09, 2.52, 11.87, 886.0, 830.0, 137.0, 98.0, 3061.0, u'BNA', u'NASHVILLE INTL', u"Nashville Int'l Airport", u'Airport', u'ASO', u'DAVIDSON', u'NASHVILLE', u'TN', u'Federalized/Commercial', 36.124472, -86.678194, u'Yes', 51L, 0.0373),
#  (73L, u'BNA', 2011L, 69429L, 69281L, 0.7883, 0.7602, 0.7869, 12.51, 11.51, 2.43, 14.06, 1.94, 0.86, 2.48, 12.22, 795.0, 772.0, 140.0, 79.0, 3061.0, u'BNA', u'NASHVILLE INTL', u"Nashville Int'l Airport", u'Airport', u'ASO', u'DAVIDSON', u'NASHVILLE', u'TN', u'Federalized/Commercial', 36.124472, -86.678194, u'Yes', 51L, 0.0281),
#  (74L, u'BNA', 2012L, 69369L, 69234L, 0.8155, 0.791, 0.805, 11.02, 11.28, 2.24, 12.32, 1.68, 0.97, 2.13, 11.09, 579.0, 527.0, 100.0, 89.0, 3061.0, u'BNA', u'NASHVILLE INTL', u"Nashville Int'l Airport", u'Airport', u'ASO', u'DAVIDSON', u'NASHVILLE', u'TN', u'Federalized/Commercial', 36.124472, -86.678194, u'Yes', 51L, 0.0245000000000001),
#  (75L, u'BNA', 2013L, 71623L, 71103L, 0.7639, 0.7292, 0.7599, 13.91, 12.07, 2.96, 15.84, 1.61, 1.19, 2.76, 13.85, 870.0, 775.0, 157.0, 71.0, 3061.0, u'BNA', u'NASHVILLE INTL', u"Nashville Int'l Airport", u'Airport', u'ASO', u'DAVIDSON', u'NASHVILLE', u'TN', u'Federalized/Commercial', 36.124472, -86.678194, u'Yes', 51L, 0.0347000000000001),
#  (76L, u'BNA', 2014L, 70497L, 70414L, 0.7404, 0.7064, 0.7364, 15.44, 12.15, 2.71, 17.31, 1.85, 1.21, 3.01, 15.4, 1266.0, 1222.0, 152.0, 60.0, 3061.0, u'BNA', u'NASHVILLE INTL', u"Nashville Int'l Airport", u'Airport', u'ASO', u'DAVIDSON', u'NASHVILLE', u'TN', u'Federalized/Commercial', 36.124472, -86.678194, u'Yes', 51L, 0.0339999999999999),
#  (77L, u'BOS', 2004L, 188413L, 184869L, 0.8095, 0.7234, 0.7755, 11.35, 18.2, 6.25, 16.15, 3.96, 1.91, 4.45, 12.95, 3332.0, 3343.0, 269.0, 127.0, 1531.0, u'BOS', u'GENERAL EDWARD LAWRENCE LOGAN INTL', u"Logan Int'l Airport", u'Airport', u'ANE', u'SUFFOLK', u'BOSTON', u'MA', u'Public Use', 42.362972, -71.006417, u'Yes', 6L, 0.0861),
#  (78L, u'BOS', 2005L, 190420L, 185755L, 0.7728, 0.6902, 0.7267, 14.0, 18.04, 5.91, 18.53, 4.48, 2.25, 5.19, 16.65, 4199.0, 4155.0, 266.0, 185.0, 1531.0, u'BOS', u'GENERAL EDWARD LAWRENCE LOGAN INTL', u"Logan Int'l Airport", u'Airport', u'ANE', u'SUFFOLK', u'BOSTON', u'MA', u'Public Use', 42.362972, -71.006417, u'Yes', 6L, 0.0826),
#  (79L, u'BOS', 2006L, 187003L, 182418L, 0.7739, 0.694, 0.7175, 14.18, 18.25, 5.9, 18.61, 4.43, 1.82, 5.14, 17.55, 3359.0, 3302.0, 377.0, 142.0, 1531.0, u'BOS', u'GENERAL EDWARD LAWRENCE LOGAN INTL', u"Logan Int'l Airport", u'Airport', u'ANE', u'SUFFOLK', u'BOSTON', u'MA', u'Public Use', 42.362972, -71.006417, u'Yes', 6L, 0.0799),
#  (80L, u'BOS', 2007L, 183078L, 179565L, 0.7553, 0.6567, 0.7024, 15.82, 19.3, 6.8, 21.48, 4.55, 2.23, 5.01, 18.48, 4379.0, 4257.0, 268.0, 192.0, 1531.0, u'BOS', u'GENERAL EDWARD LAWRENCE LOGAN INTL', u"Logan Int'l Airport", u'Airport', u'ANE', u'SUFFOLK', u'BOSTON', u'MA', u'Public Use', 42.362972, -71.006417, u'Yes', 6L, 0.0986),
#  (81L, u'BOS', 2008L, 170491L, 166566L, 0.7897, 0.7075, 0.7311, 14.03, 18.91, 5.84, 18.72, 4.79, 1.75, 4.79, 17.44, 3655.0, 3601.0, 354.0, 183.0, 1531.0, u'BOS', u'GENERAL EDWARD LAWRENCE LOGAN INTL', u"Logan Int'l Airport", u'Airport', u'ANE', u'SUFFOLK', u'BOSTON', u'MA', u'Public Use', 42.362972, -71.006417, u'Yes', 6L, 0.0821999999999999),
#  (82L, u'BOS', 2009L, 162271L, 160775L, 0.8209, 0.7492, 0.7649, 11.52, 18.32, 5.39, 15.59, 4.22, 1.64, 4.22, 14.92, 2891.0, 2838.0, 284.0, 126.0, 1531.0, u'BOS', u'GENERAL EDWARD LAWRENCE LOGAN INTL', u"Logan Int'l Airport", u'Airport', u'ANE', u'SUFFOLK', u'BOSTON', u'MA', u'Public Use', 42.362972, -71.006417, u'Yes', 6L, 0.0717),
#  (83L, u'BOS', 2010L, 164933L, 162520L, 0.8095, 0.727, 0.7612, 11.7, 18.39, 5.47, 15.99, 4.32, 1.49, 4.24, 14.6, 3071.0, 3035.0, 275.0, 137.0, 1531.0, u'BOS', u'GENERAL EDWARD LAWRENCE LOGAN INTL', u"Logan Int'l Airport", u'Airport', u'ANE', u'SUFFOLK', u'BOSTON', u'MA', u'Public Use', 42.362972, -71.006417, u'Yes', 6L, 0.0825),
#  (84L, u'BOS', 2011L, 168358L, 164961L, 0.7878, 0.7065, 0.7378, 13.38, 18.15, 5.2, 17.57, 4.26, 2.02, 4.24, 16.17, 3621.0, 3633.0, 320.0, 113.0, 1531.0, u'BOS', u'GENERAL EDWARD LAWRENCE LOGAN INTL', u"Logan Int'l Airport", u'Airport', u'ANE', u'SUFFOLK', u'BOSTON', u'MA', u'Public Use', 42.362972, -71.006417, u'Yes', 6L, 0.0812999999999999),
#  (85L, u'BOS', 2012L, 161639L, 158227L, 0.8204, 0.7563, 0.795, 11.56, 17.15, 4.23, 14.82, 3.53, 1.86, 3.0, 11.98, 1498.0, 1523.0, 215.0, 79.0, 1531.0, u'BOS', u'GENERAL EDWARD LAWRENCE LOGAN INTL', u"Logan Int'l Airport", u'Airport', u'ANE', u'SUFFOLK', u'BOSTON', u'MA', u'Public Use', 42.362972, -71.006417, u'Yes', 6L, 0.0641),
#  (86L, u'BOS', 2013L, 167549L, 164108L, 0.7987, 0.7174, 0.7682, 12.81, 18.19, 5.29, 17.08, 3.2, 1.87, 3.46, 13.77, 1640.0, 1633.0, 275.0, 148.0, 1531.0, u'BOS', u'GENERAL EDWARD LAWRENCE LOGAN INTL', u"Logan Int'l Airport", u'Airport', u'ANE', u'SUFFOLK', u'BOSTON', u'MA', u'Public Use', 42.362972, -71.006417, u'Yes', 6L, 0.0812999999999999),
#  (87L, u'BOS', 2014L, 170013L, 165166L, 0.8067, 0.7295, 0.7696, 11.73, 18.19, 5.0, 15.68, 3.23, 1.62, 3.23, 13.8, 2316.0, 2330.0, 349.0, 121.0, 1531.0, u'BOS', u'GENERAL EDWARD LAWRENCE LOGAN INTL', u"Logan Int'l Airport", u'Airport', u'ANE', u'SUFFOLK', u'BOSTON', u'MA', u'Public Use', 42.362972, -71.006417, u'Yes', 6L, 0.0771999999999999),
#  (88L, u'BUF', 2004L, 12215L, 12188L, 0.7764, 0.7403, 0.7173, 12.94, 12.41, 3.16, 15.0, 2.29, 0.85, 2.85, 15.89, 514.0, 435.0, 40.0, 46.0, 2431.0, u'BUF', u'BUFFALO NIAGARA INTL', u"Buffalo Niagara Int'l Airport", u'Airport', u'AEA', u'ERIE', u'BUFFALO', u'NY', u'Federalized/Commercial', 42.940417, -78.730583, u'Yes', 30L, 0.0361),
#  (89L, u'BUF', 2005L, 46558L, 46582L, 0.7535, 0.716, 0.7104, 14.94, 12.46, 3.32, 17.14, 2.08, 1.21, 3.14, 16.67, 456.0, 416.0, 41.0, 35.0, 2431.0, u'BUF', u'BUFFALO NIAGARA INTL', u"Buffalo Niagara Int'l Airport", u'Airport', u'AEA', u'ERIE', u'BUFFALO', u'NY', u'Federalized/Commercial', 42.940417, -78.730583, u'Yes', 30L, 0.0375),
#  (376L, u'LGA', 2006L, 196274L, 196378L, 0.7398, 0.5213, 0.6671, 16.55, 25.75, 13.0, 27.64, 5.97, 2.39, 5.99, 21.05, 4718.0, 4668.0, 278.0, 537.0, 2462.0, u'LGA', u'LA GUARDIA', u'Laguardia Airport', u'Airport', u'AEA', u'QUEENS', u'NEW YORK', u'NY', u'Federalized/Commercial', 40.77725, -73.872611, u'Yes', 64L, 0.2185),
#  (90L, u'BUF', 2006L, 45322L, 45345L, 0.7477, 0.712, 0.7095, 15.26, 12.62, 3.17, 17.51, 2.46, 1.16, 3.59, 16.63, 559.0, 489.0, 87.0, 37.0, 2431.0, u'BUF', u'BUFFALO NIAGARA INTL', u"Buffalo Niagara Int'l Airport", u'Airport', u'AEA', u'ERIE', u'BUFFALO', u'NY', u'Federalized/Commercial', 42.940417, -78.730583, u'Yes', 30L, 0.0357),
#  (91L, u'BUF', 2007L, 44568L, 44509L, 0.729, 0.6837, 0.6785, 17.39, 13.03, 3.25, 20.01, 3.41, 0.83, 4.07, 19.13, 689.0, 622.0, 54.0, 46.0, 2431.0, u'BUF', u'BUFFALO NIAGARA INTL', u"Buffalo Niagara Int'l Airport", u'Airport', u'AEA', u'ERIE', u'BUFFALO', u'NY', u'Federalized/Commercial', 42.940417, -78.730583, u'Yes', 30L, 0.0453000000000001),
#  (92L, u'BUF', 2008L, 43245L, 42984L, 0.7606, 0.7239, 0.7287, 16.06, 12.88, 3.02, 18.18, 3.56, 0.93, 3.82, 16.65, 611.0, 539.0, 60.0, 37.0, 2431.0, u'BUF', u'BUFFALO NIAGARA INTL', u"Buffalo Niagara Int'l Airport", u'Airport', u'AEA', u'ERIE', u'BUFFALO', u'NY', u'Federalized/Commercial', 42.940417, -78.730583, u'Yes', 30L, 0.0367000000000001),
#  (93L, u'BUF', 2009L, 40467L, 40256L, 0.7901, 0.7502, 0.761, 13.9, 12.88, 3.02, 16.17, 3.33, 1.0, 3.07, 13.92, 344.0, 301.0, 38.0, 45.0, 2431.0, u'BUF', u'BUFFALO NIAGARA INTL', u"Buffalo Niagara Int'l Airport", u'Airport', u'AEA', u'ERIE', u'BUFFALO', u'NY', u'Federalized/Commercial', 42.940417, -78.730583, u'Yes', 30L, 0.0399),
#  (94L, u'BUF', 2010L, 39546L, 39398L, 0.7826, 0.7362, 0.7534, 13.93, 12.95, 3.1, 16.25, 3.08, 1.03, 2.83, 14.56, 483.0, 421.0, 46.0, 33.0, 2431.0, u'BUF', u'BUFFALO NIAGARA INTL', u"Buffalo Niagara Int'l Airport", u'Airport', u'AEA', u'ERIE', u'BUFFALO', u'NY', u'Federalized/Commercial', 42.940417, -78.730583, u'Yes', 30L, 0.0464),
#  (95L, u'BUF', 2011L, 39067L, 38890L, 0.7663, 0.7338, 0.7574, 15.14, 12.08, 2.38, 16.74, 2.66, 0.78, 2.76, 14.96, 387.0, 362.0, 45.0, 27.0, 2431.0, u'BUF', u'BUFFALO NIAGARA INTL', u"Buffalo Niagara Int'l Airport", u'Airport', u'AEA', u'ERIE', u'BUFFALO', u'NY', u'Federalized/Commercial', 42.940417, -78.730583, u'Yes', 30L, 0.0325),
#  (96L, u'BUF', 2012L, 38909L, 38714L, 0.7857, 0.7638, 0.7744, 13.48, 11.54, 1.88, 14.63, 2.37, 0.9, 2.28, 13.34, 330.0, 298.0, 35.0, 36.0, 2431.0, u'BUF', u'BUFFALO NIAGARA INTL', u"Buffalo Niagara Int'l Airport", u'Airport', u'AEA', u'ERIE', u'BUFFALO', u'NY', u'Federalized/Commercial', 42.940417, -78.730583, u'Yes', 30L, 0.0218999999999999),
#  (97L, u'BUF', 2013L, 38706L, 38393L, 0.7736, 0.7248, 0.7437, 14.56, 12.71, 3.22, 16.95, 2.33, 1.15, 2.76, 15.31, 422.0, 356.0, 27.0, 21.0, 2431.0, u'BUF', u'BUFFALO NIAGARA INTL', u"Buffalo Niagara Int'l Airport", u'Airport', u'AEA', u'ERIE', u'BUFFALO', u'NY', u'Federalized/Commercial', 42.940417, -78.730583, u'Yes', 30L, 0.0488),
#  (98L, u'BUF', 2014L, 34314L, 34112L, 0.7584, 0.7237, 0.7376, 15.53, 12.17, 2.42, 17.26, 2.33, 0.7, 2.5, 15.96, 612.0, 562.0, 46.0, 27.0, 2431.0, u'BUF', u'BUFFALO NIAGARA INTL', u"Buffalo Niagara Int'l Airport", u'Airport', u'AEA', u'ERIE', u'BUFFALO', u'NY', u'Federalized/Commercial', 42.940417, -78.730583, u'Yes', 30L, 0.0347),
#  (99L, u'BUR', 2004L, 38148L, 37293L, 0.7792, 0.7637, 0.7703, 11.33, 10.28, 2.12, 12.78, 2.55, 0.58, 2.33, 11.73, 263.0, 260.0, 98.0, 23.0, 496.0, u'BUR', u'BOB HOPE', u'Bob Hope Airport', u'Airport', u'AWP', u'LOS ANGELES', u'BURBANK', u'CA', u'Federalized/Commercial', 34.200667, -118.358667, u'Yes', 20L, 0.0155),
#  (100L, u'BUR', 2005L, 40769L, 40424L, 0.7733, 0.7435, 0.747, 11.33, 10.93, 2.73, 13.47, 2.66, 0.89, 2.89, 12.56, 285.0, 235.0, 110.0, 19.0, 496.0, u'BUR', u'BOB HOPE', u'Bob Hope Airport', u'Airport', u'AWP', u'LOS ANGELES', u'BURBANK', u'CA', u'Federalized/Commercial', 34.200667, -118.358667, u'Yes', 20L, 0.0297999999999999),
#  (101L, u'BUR', 2006L, 42697L, 42915L, 0.7762, 0.7414, 0.7631, 11.4, 11.56, 2.74, 13.5, 2.57, 0.58, 2.63, 11.79, 427.0, 400.0, 217.0, 69.0, 496.0, u'BUR', u'BOB HOPE', u'Bob Hope Airport', u'Airport', u'AWP', u'LOS ANGELES', u'BURBANK', u'CA', u'Federalized/Commercial', 34.200667, -118.358667, u'Yes', 20L, 0.0348000000000001),
#  (102L, u'BUR', 2007L, 43833L, 43406L, 0.7804, 0.7448, 0.7707, 11.79, 11.89, 2.74, 13.86, 2.8, 0.69, 2.52, 11.99, 517.0, 477.0, 288.0, 34.0, 496.0, u'BUR', u'BOB HOPE', u'Bob Hope Airport', u'Airport', u'AWP', u'LOS ANGELES', u'BURBANK', u'CA', u'Federalized/Commercial', 34.200667, -118.358667, u'Yes', 20L, 0.0356),
#  (103L, u'BUR', 2008L, 40341L, 40135L, 0.7948, 0.772, 0.7942, 10.78, 11.6, 2.24, 12.24, 2.29, 0.71, 2.16, 10.9, 535.0, 507.0, 141.0, 56.0, 496.0, u'BUR', u'BOB HOPE', u'Bob Hope Airport', u'Airport', u'AWP', u'LOS ANGELES', u'BURBANK', u'CA', u'Federalized/Commercial', 34.200667, -118.358667, u'Yes', 20L, 0.0227999999999999),
#  (104L, u'BUR', 2009L, 34863L, 34744L, 0.8419, 0.8302, 0.8305, 8.3, 10.9, 1.72, 9.19, 2.4, 0.57, 1.73, 8.61, 412.0, 390.0, 115.0, 47.0, 496.0, u'BUR', u'BOB HOPE', u'Bob Hope Airport', u'Airport', u'AWP', u'LOS ANGELES', u'BURBANK', u'CA', u'Federalized/Commercial', 34.200667, -118.358667, u'Yes', 20L, 0.0116999999999999),
#  (105L, u'BUR', 2010L, 34610L, 34039L, 0.8092, 0.7926, 0.8027, 9.99, 10.76, 1.89, 11.16, 2.02, 0.66, 1.74, 9.96, 465.0, 444.0, 124.0, 46.0, 496.0, u'BUR', u'BOB HOPE', u'Bob Hope Airport', u'Airport', u'AWP', u'LOS ANGELES', u'BURBANK', u'CA', u'Federalized/Commercial', 34.200667, -118.358667, u'Yes', 20L, 0.0166000000000001),
#  (106L, u'BUR', 2011L, 32875L, 32495L, 0.8194, 0.7992, 0.7949, 9.6, 10.95, 2.07, 10.81, 2.07, 0.59, 2.06, 10.38, 493.0, 426.0, 76.0, 66.0, 496.0, u'BUR', u'BOB HOPE', u'Bob Hope Airport', u'Airport', u'AWP', u'LOS ANGELES', u'BURBANK', u'CA', u'Federalized/Commercial', 34.200667, -118.358667, u'Yes', 20L, 0.0202),
#  (107L, u'BUR', 2012L, 32152L, 31902L, 0.8369, 0.8173, 0.8249, 8.88, 10.94, 2.09, 10.16, 1.81, 0.59, 1.56, 8.8, 488.0, 456.0, 33.0, 40.0, 496.0, u'BUR', u'BOB HOPE', u'Bob Hope Airport', u'Airport', u'AWP', u'LOS ANGELES', u'BURBANK', u'CA', u'Federalized/Commercial', 34.200667, -118.358667, u'Yes', 20L, 0.0196),
#  (108L, u'BUR', 2013L, 31469L, 31215L, 0.8072, 0.7889, 0.8009, 10.2, 10.77, 1.87, 11.44, 1.73, 0.51, 1.62, 10.14, 399.0, 386.0, 30.0, 8.0, 496.0, u'BUR', u'BOB HOPE', u'Bob Hope Airport', u'Airport', u'AWP', u'LOS ANGELES', u'BURBANK', u'CA', u'Federalized/Commercial', 34.200667, -118.358667, u'Yes', 20L, 0.0183),
#  (109L, u'BUR', 2014L, 30148L, 29885L, 0.7821, 0.7613, 0.7657, 11.3, 10.86, 1.95, 12.58, 2.05, 0.52, 1.84, 12.19, 427.0, 403.0, 36.0, 39.0, 496.0, u'BUR', u'BOB HOPE', u'Bob Hope Airport', u'Airport', u'AWP', u'LOS ANGELES', u'BURBANK', u'CA', u'Federalized/Commercial', 34.200667, -118.358667, u'Yes', 20L, 0.0208),
#  (110L, u'BWI', 2004L, 131690L, 131476L, 0.781, 0.7491, 0.7853, 11.53, 12.09, 3.14, 14.07, 4.65, 1.06, 2.99, 12.14, 1186.0, 1093.0, 162.0, 176.0, 1556.0, u'BWI', u'BALTIMORE/WASHINGTON INTL THURGOOD MARSHAL', u"Baltimore Washington Int'l Airport", u'Airport', u'AEA', u'ANNE ARUNDEL', u'BALTIMORE', u'MD', u'Federalized/Commercial', 39.175361, -76.668333, u'Yes', 28L, 0.0318999999999999),
#  (111L, u'BWI', 2005L, 132011L, 131803L, 0.7682, 0.7354, 0.7787, 12.58, 12.05, 3.39, 15.28, 4.33, 1.11, 2.76, 12.66, 1407.0, 1313.0, 153.0, 150.0, 1556.0, u'BWI', u'BALTIMORE/WASHINGTON INTL THURGOOD MARSHAL', u"Baltimore Washington Int'l Airport", u'Airport', u'AEA', u'ANNE ARUNDEL', u'BALTIMORE', u'MD', u'Federalized/Commercial', 39.175361, -76.668333, u'Yes', 28L, 0.0327999999999999),
#  (112L, u'BWI', 2006L, 131521L, 131308L, 0.7608, 0.7255, 0.7703, 13.35, 11.98, 3.17, 15.8, 4.14, 0.92, 2.69, 13.13, 1127.0, 1057.0, 165.0, 172.0, 1556.0, u'BWI', u'BALTIMORE/WASHINGTON INTL THURGOOD MARSHAL', u"Baltimore Washington Int'l Airport", u'Airport', u'AEA', u'ANNE ARUNDEL', u'BALTIMORE', u'MD', u'Federalized/Commercial', 39.175361, -76.668333, u'Yes', 28L, 0.0353),
#  (377L, u'LGA', 2007L, 191343L, 191847L, 0.7004, 0.4267, 0.6109, 19.48, 27.32, 15.0, 33.26, 6.93, 2.56, 6.84, 25.0, 6415.0, 6304.0, 290.0, 573.0, 2462.0, u'LGA', u'LA GUARDIA', u'Laguardia Airport', u'Airport', u'AEA', u'QUEENS', u'NEW YORK', u'NY', u'Federalized/Commercial', 40.77725, -73.872611, u'Yes', 64L, 0.2737),
#  (113L, u'BWI', 2007L, 130735L, 130812L, 0.748, 0.702, 0.7493, 14.67, 12.5, 3.59, 17.67, 3.83, 1.41, 3.21, 14.58, 1759.0, 1614.0, 154.0, 162.0, 1556.0, u'BWI', u'BALTIMORE/WASHINGTON INTL THURGOOD MARSHAL', u"Baltimore Washington Int'l Airport", u'Airport', u'AEA', u'ANNE ARUNDEL', u'BALTIMORE', u'MD', u'Federalized/Commercial', 39.175361, -76.668333, u'Yes', 28L, 0.0459999999999999),
#  (114L, u'BWI', 2008L, 123340L, 123587L, 0.7833, 0.7467, 0.7824, 13.24, 12.0, 2.97, 15.53, 3.37, 1.22, 2.88, 13.23, 1002.0, 964.0, 206.0, 128.0, 1556.0, u'BWI', u'BALTIMORE/WASHINGTON INTL THURGOOD MARSHAL', u"Baltimore Washington Int'l Airport", u'Airport', u'AEA', u'ANNE ARUNDEL', u'BALTIMORE', u'MD', u'Federalized/Commercial', 39.175361, -76.668333, u'Yes', 28L, 0.0366),
#  (115L, u'BWI', 2009L, 121056L, 120992L, 0.7886, 0.7335, 0.8134, 12.09, 12.82, 3.82, 15.24, 3.06, 1.43, 2.69, 10.74, 1042.0, 970.0, 206.0, 172.0, 1556.0, u'BWI', u'BALTIMORE/WASHINGTON INTL THURGOOD MARSHAL', u"Baltimore Washington Int'l Airport", u'Airport', u'AEA', u'ANNE ARUNDEL', u'BALTIMORE', u'MD', u'Federalized/Commercial', 39.175361, -76.668333, u'Yes', 28L, 0.0550999999999999),
#  (116L, u'BWI', 2010L, 124683L, 124272L, 0.7613, 0.7112, 0.7952, 13.1, 12.52, 3.39, 15.8, 3.1, 1.66, 2.83, 11.51, 2282.0, 2180.0, 203.0, 229.0, 1556.0, u'BWI', u'BALTIMORE/WASHINGTON INTL THURGOOD MARSHAL', u"Baltimore Washington Int'l Airport", u'Airport', u'AEA', u'ANNE ARUNDEL', u'BALTIMORE', u'MD', u'Federalized/Commercial', 39.175361, -76.668333, u'Yes', 28L, 0.0500999999999999),
#  (117L, u'BWI', 2011L, 127281L, 126806L, 0.773, 0.7239, 0.8038, 13.55, 12.53, 3.35, 16.31, 2.75, 1.54, 2.77, 11.92, 1567.0, 1418.0, 177.0, 310.0, 1556.0, u'BWI', u'BALTIMORE/WASHINGTON INTL THURGOOD MARSHAL', u"Baltimore Washington Int'l Airport", u'Airport', u'AEA', u'ANNE ARUNDEL', u'BALTIMORE', u'MD', u'Federalized/Commercial', 39.175361, -76.668333, u'Yes', 28L, 0.0491),
#  (118L, u'BWI', 2012L, 124035L, 123690L, 0.7756, 0.7216, 0.8055, 13.02, 12.65, 3.46, 15.78, 2.55, 1.69, 2.83, 11.56, 1511.0, 1400.0, 151.0, 296.0, 1556.0, u'BWI', u'BALTIMORE/WASHINGTON INTL THURGOOD MARSHAL', u"Baltimore Washington Int'l Airport", u'Airport', u'AEA', u'ANNE ARUNDEL', u'BALTIMORE', u'MD', u'Federalized/Commercial', 39.175361, -76.668333, u'Yes', 28L, 0.0539999999999999),
#  (119L, u'BWI', 2013L, 118012L, 117135L, 0.7305, 0.6674, 0.7756, 15.23, 13.1, 3.92, 18.53, 2.28, 2.05, 2.84, 12.83, 954.0, 878.0, 145.0, 208.0, 1556.0, u'BWI', u'BALTIMORE/WASHINGTON INTL THURGOOD MARSHAL', u"Baltimore Washington Int'l Airport", u'Airport', u'AEA', u'ANNE ARUNDEL', u'BALTIMORE', u'MD', u'Federalized/Commercial', 39.175361, -76.668333, u'Yes', 28L, 0.0631),
#  (120L, u'BWI', 2014L, 110589L, 110243L, 0.7159, 0.6517, 0.7672, 16.1, 13.34, 3.97, 19.4, 3.27, 1.74, 2.75, 13.73, 1588.0, 1549.0, 213.0, 181.0, 1556.0, u'BWI', u'BALTIMORE/WASHINGTON INTL THURGOOD MARSHAL', u"Baltimore Washington Int'l Airport", u'Airport', u'AEA', u'ANNE ARUNDEL', u'BALTIMORE', u'MD', u'Federalized/Commercial', 39.175361, -76.668333, u'Yes', 28L, 0.0642),
#  (121L, u'CLE', 2004L, 122511L, 121774L, 0.8433, 0.7643, 0.7949, 9.31, 17.06, 6.18, 13.63, 3.76, 1.59, 4.56, 11.9, 1438.0, 1498.0, 173.0, 131.0, 2527.0, u'CLE', u'CLEVELAND-HOPKINS INTL', u"Cleveland-Hopkins Int'l Airport", u'Airport', u'AGL', u'CUYAHOGA', u'CLEVELAND', u'OH', u'Federalized/Commercial', 41.409417, -81.854694, u'Yes', 27L, 0.0790000000000001),
#  (122L, u'CLE', 2005L, 122375L, 121467L, 0.8304, 0.7623, 0.7798, 10.15, 16.84, 5.44, 13.91, 3.36, 1.91, 4.38, 12.72, 1207.0, 1216.0, 158.0, 152.0, 2527.0, u'CLE', u'CLEVELAND-HOPKINS INTL', u"Cleveland-Hopkins Int'l Airport", u'Airport', u'AGL', u'CUYAHOGA', u'CLEVELAND', u'OH', u'Federalized/Commercial', 41.409417, -81.854694, u'Yes', 27L, 0.0681),
#  (123L, u'CLE', 2006L, 117753L, 116801L, 0.8323, 0.7866, 0.7861, 10.34, 15.81, 4.09, 13.05, 3.12, 1.14, 3.95, 12.86, 1116.0, 1114.0, 182.0, 164.0, 2527.0, u'CLE', u'CLEVELAND-HOPKINS INTL', u"Cleveland-Hopkins Int'l Airport", u'Airport', u'AGL', u'CUYAHOGA', u'CLEVELAND', u'OH', u'Federalized/Commercial', 41.409417, -81.854694, u'Yes', 27L, 0.0457000000000001),
#  (124L, u'CLE', 2007L, 114795L, 114523L, 0.7907, 0.7195, 0.7518, 12.89, 16.07, 4.76, 16.64, 3.7, 1.8, 4.41, 14.93, 1427.0, 1422.0, 182.0, 125.0, 2527.0, u'CLE', u'CLEVELAND-HOPKINS INTL', u"Cleveland-Hopkins Int'l Airport", u'Airport', u'AGL', u'CUYAHOGA', u'CLEVELAND', u'OH', u'Federalized/Commercial', 41.409417, -81.854694, u'Yes', 27L, 0.0711999999999999),
#  (125L, u'CLE', 2008L, 111315L, 111455L, 0.8072, 0.7576, 0.7842, 12.53, 14.71, 3.53, 15.18, 3.48, 1.19, 3.46, 13.47, 1359.0, 1306.0, 178.0, 156.0, 2527.0, u'CLE', u'CLEVELAND-HOPKINS INTL', u"Cleveland-Hopkins Int'l Airport", u'Airport', u'AGL', u'CUYAHOGA', u'CLEVELAND', u'OH', u'Federalized/Commercial', 41.409417, -81.854694, u'Yes', 27L, 0.0496),
#  (126L, u'CLE', 2009L, 95317L, 95461L, 0.8599, 0.8295, 0.8456, 8.97, 13.06, 2.52, 10.66, 3.04, 0.87, 2.42, 9.39, 628.0, 578.0, 131.0, 90.0, 2527.0, u'CLE', u'CLEVELAND-HOPKINS INTL', u"Cleveland-Hopkins Int'l Airport", u'Airport', u'AGL', u'CUYAHOGA', u'CLEVELAND', u'OH', u'Federalized/Commercial', 41.409417, -81.854694, u'Yes', 27L, 0.0304),
#  (127L, u'CLE', 2010L, 91769L, 91615L, 0.8416, 0.7968, 0.8151, 9.88, 12.98, 2.98, 12.09, 2.98, 1.25, 3.2, 11.06, 801.0, 809.0, 117.0, 55.0, 2527.0, u'CLE', u'CLEVELAND-HOPKINS INTL', u"Cleveland-Hopkins Int'l Airport", u'Airport', u'AGL', u'CUYAHOGA', u'CLEVELAND', u'OH', u'Federalized/Commercial', 41.409417, -81.854694, u'Yes', 27L, 0.0448000000000001),
#  (128L, u'CLE', 2011L, 89033L, 89039L, 0.8135, 0.778, 0.7923, 12.06, 12.54, 2.74, 14.0, 3.05, 1.21, 3.17, 12.89, 1022.0, 1010.0, 116.0, 69.0, 2527.0, u'CLE', u'CLEVELAND-HOPKINS INTL', u"Cleveland-Hopkins Int'l Airport", u'Airport', u'AGL', u'CUYAHOGA', u'CLEVELAND', u'OH', u'Federalized/Commercial', 41.409417, -81.854694, u'Yes', 27L, 0.0355),
#  (129L, u'CLE', 2012L, 85359L, 85279L, 0.8093, 0.7809, 0.8019, 12.41, 12.24, 2.3, 13.93, 2.72, 1.18, 2.19, 12.49, 654.0, 666.0, 98.0, 57.0, 2527.0, u'CLE', u'CLEVELAND-HOPKINS INTL', u"Cleveland-Hopkins Int'l Airport", u'Airport', u'AGL', u'CUYAHOGA', u'CLEVELAND', u'OH', u'Federalized/Commercial', 41.409417, -81.854694, u'Yes', 27L, 0.0284),
#  (130L, u'CLE', 2013L, 85240L, 84805L, 0.7837, 0.7384, 0.7667, 14.34, 12.94, 3.04, 16.64, 2.7, 1.19, 2.65, 15.02, 759.0, 762.0, 117.0, 54.0, 2527.0, u'CLE', u'CLEVELAND-HOPKINS INTL', u"Cleveland-Hopkins Int'l Airport", u'Airport', u'AGL', u'CUYAHOGA', u'CLEVELAND', u'OH', u'Federalized/Commercial', 41.409417, -81.854694, u'Yes', 27L, 0.0453),
#  (131L, u'CLE', 2014L, 60369L, 60247L, 0.7761, 0.7203, 0.7512, 15.1, 13.37, 3.36, 17.84, 2.47, 1.14, 2.78, 16.3, 1282.0, 1280.0, 124.0, 74.0, 2527.0, u'CLE', u'CLEVELAND-HOPKINS INTL', u"Cleveland-Hopkins Int'l Airport", u'Airport', u'AGL', u'CUYAHOGA', u'CLEVELAND', u'OH', u'Federalized/Commercial', 41.409417, -81.854694, u'Yes', 27L, 0.0558),
#  (132L, u'CLT', 2004L, 211833L, 210977L, 0.7748, 0.7225, 0.8178, 11.85, 15.08, 3.6, 14.4, 5.66, 0.7, 2.82, 9.67, 1519.0, 1593.0, 178.0, 132.0, 2094.0, u'CLT', u'CHARLOTTE/DOUGLAS INTL', u"Charlotte/Douglas Int'l Airport", u'Airport', u'ASO', u'MECKLENBURG', u'CHARLOTTE', u'NC', u'Federalized/Commercial', 35.213741, -80.949069, u'Yes', 49L, 0.0523),
#  (133L, u'CLT', 2005L, 241565L, 240918L, 0.7481, 0.6569, 0.7899, 13.3, 15.87, 5.08, 17.36, 5.95, 1.78, 3.28, 11.4, 1715.0, 1881.0, 196.0, 165.0, 2094.0, u'CLT', u'CHARLOTTE/DOUGLAS INTL', u"Charlotte/Douglas Int'l Airport", u'Airport', u'ASO', u'MECKLENBURG', u'CHARLOTTE', u'NC', u'Federalized/Commercial', 35.213741, -80.949069, u'Yes', 49L, 0.0911999999999999),
#  (134L, u'CLT', 2006L, 234974L, 234521L, 0.7799, 0.6602, 0.7785, 12.07, 17.3, 6.28, 17.31, 5.89, 2.15, 4.06, 12.22, 1569.0, 1742.0, 283.0, 204.0, 2094.0, u'CLT', u'CHARLOTTE/DOUGLAS INTL', u"Charlotte/Douglas Int'l Airport", u'Airport', u'ASO', u'MECKLENBURG', u'CHARLOTTE', u'NC', u'Federalized/Commercial', 35.213741, -80.949069, u'Yes', 49L, 0.1197),
# ...
#  (771L, u'SNA', 2011L, 45157L, 45435L, 0.8199, 0.7672, 0.8182, 9.76, 11.72, 3.36, 11.92, 1.96, 1.29, 2.23, 9.07, 531.0, 475.0, 96.0, 77.0, 570.0, u'SNA', u'JOHN WAYNE AIRPORT-ORANGE COUNTY', u'John Wayne-Orange County Airport', u'Airport', u'AWP', u'ORANGE', u'SANTA ANA', u'CA', u'Federalized/Commercial', 33.675667, -117.868222, u'Yes', 14L, 0.0527),
#  (772L, u'SNA', 2012L, 45397L, 45653L, 0.8133, 0.7646, 0.8234, 10.47, 11.59, 3.28, 12.69, 1.74, 1.04, 1.91, 8.95, 496.0, 423.0, 82.0, 98.0, 570.0, u'SNA', u'JOHN WAYNE AIRPORT-ORANGE COUNTY', u'John Wayne-Orange County Airport', u'Airport', u'AWP', u'ORANGE', u'SANTA ANA', u'CA', u'Federalized/Commercial', 33.675667, -117.868222, u'Yes', 14L, 0.0487000000000001),
#  (773L, u'SNA', 2013L, 46656L, 46935L, 0.7907, 0.7531, 0.7986, 11.06, 11.28, 3.09, 13.08, 1.61, 1.04, 2.1, 9.89, 443.0, 387.0, 89.0, 93.0, 570.0, u'SNA', u'JOHN WAYNE AIRPORT-ORANGE COUNTY', u'John Wayne-Orange County Airport', u'Airport', u'AWP', u'ORANGE', u'SANTA ANA', u'CA', u'Federalized/Commercial', 33.675667, -117.868222, u'Yes', 14L, 0.0376),
#  (774L, u'SNA', 2014L, 47176L, 47252L, 0.7578, 0.715, 0.7688, 12.75, 11.39, 3.1, 14.85, 1.77, 0.82, 2.36, 11.67, 468.0, 425.0, 85.0, 71.0, 570.0, u'SNA', u'JOHN WAYNE AIRPORT-ORANGE COUNTY', u'John Wayne-Orange County Airport', u'Airport', u'AWP', u'ORANGE', u'SANTA ANA', u'CA', u'Federalized/Commercial', 33.675667, -117.868222, u'Yes', 14L, 0.0428000000000001),
#  (775L, u'STL', 2004L, 130440L, 130684L, 0.8232, 0.8126, 0.8263, 10.0, 11.42, 1.67, 10.94, 3.93, 0.53, 2.06, 9.76, 832.0, 805.0, 119.0, 135.0, 1895.0, u'STL', u'LAMBERT-ST LOUIS INTL', u"Lambert-St Louis Int'l Airport", u'Airport', u'ACE', u'ST LOUIS CITY', u'ST LOUIS', u'MO', u'Federalized/Commercial', 38.748697, -90.370029, u'Yes', 39L, 0.0106000000000001),
#  (776L, u'STL', 2005L, 134794L, 134879L, 0.8164, 0.7915, 0.8193, 10.41, 11.69, 2.68, 12.15, 3.6, 1.31, 2.09, 10.72, 790.0, 756.0, 136.0, 116.0, 1895.0, u'STL', u'LAMBERT-ST LOUIS INTL', u"Lambert-St Louis Int'l Airport", u'Airport', u'ACE', u'ST LOUIS CITY', u'ST LOUIS', u'MO', u'Federalized/Commercial', 38.748697, -90.370029, u'Yes', 39L, 0.0249),
#  (777L, u'STL', 2006L, 127485L, 127934L, 0.794, 0.7746, 0.8061, 11.71, 11.49, 2.06, 13.03, 3.03, 0.79, 2.25, 11.43, 994.0, 940.0, 158.0, 119.0, 1895.0, u'STL', u'LAMBERT-ST LOUIS INTL', u"Lambert-St Louis Int'l Airport", u'Airport', u'ACE', u'ST LOUIS CITY', u'ST LOUIS', u'MO', u'Federalized/Commercial', 38.748697, -90.370029, u'Yes', 39L, 0.0194000000000001),
#  (778L, u'STL', 2007L, 118824L, 119185L, 0.761, 0.7371, 0.7604, 14.26, 11.45, 2.15, 15.77, 3.66, 1.18, 2.69, 14.37, 1292.0, 1256.0, 138.0, 144.0, 1895.0, u'STL', u'LAMBERT-ST LOUIS INTL', u"Lambert-St Louis Int'l Airport", u'Airport', u'ACE', u'ST LOUIS CITY', u'ST LOUIS', u'MO', u'Federalized/Commercial', 38.748697, -90.370029, u'Yes', 39L, 0.0238999999999999),
#  (779L, u'STL', 2008L, 116267L, 116638L, 0.7737, 0.7515, 0.7758, 13.73, 11.4, 2.19, 15.22, 3.95, 1.15, 2.92, 13.86, 1316.0, 1244.0, 162.0, 165.0, 1895.0, u'STL', u'LAMBERT-ST LOUIS INTL', u"Lambert-St Louis Int'l Airport", u'Airport', u'ACE', u'ST LOUIS CITY', u'ST LOUIS', u'MO', u'Federalized/Commercial', 38.748697, -90.370029, u'Yes', 39L, 0.0222000000000001),
#  (780L, u'STL', 2009L, 98714L, 98773L, 0.8163, 0.7976, 0.8168, 10.74, 11.0, 1.76, 11.93, 3.29, 0.78, 2.25, 10.54, 695.0, 642.0, 113.0, 83.0, 1895.0, u'STL', u'LAMBERT-ST LOUIS INTL', u"Lambert-St Louis Int'l Airport", u'Airport', u'ACE', u'ST LOUIS CITY', u'ST LOUIS', u'MO', u'Federalized/Commercial', 38.748697, -90.370029, u'Yes', 39L, 0.0187),
#  (781L, u'STL', 2010L, 85835L, 85963L, 0.7849, 0.7635, 0.7952, 12.16, 10.84, 1.89, 13.33, 2.78, 1.28, 2.5, 11.6, 715.0, 700.0, 129.0, 85.0, 1895.0, u'STL', u'LAMBERT-ST LOUIS INTL', u"Lambert-St Louis Int'l Airport", u'Airport', u'ACE', u'ST LOUIS CITY', u'ST LOUIS', u'MO', u'Federalized/Commercial', 38.748697, -90.370029, u'Yes', 39L, 0.0214000000000001),
#  (782L, u'STL', 2011L, 88445L, 88387L, 0.7855, 0.7623, 0.7897, 12.52, 10.74, 1.95, 13.86, 2.41, 1.38, 2.79, 12.15, 1238.0, 1135.0, 140.0, 150.0, 1895.0, u'STL', u'LAMBERT-ST LOUIS INTL', u"Lambert-St Louis Int'l Airport", u'Airport', u'ACE', u'ST LOUIS CITY', u'ST LOUIS', u'MO', u'Federalized/Commercial', 38.748697, -90.370029, u'Yes', 39L, 0.0232),
#  (783L, u'STL', 2012L, 89904L, 89576L, 0.8094, 0.7851, 0.816, 11.03, 10.61, 1.89, 12.41, 2.03, 1.27, 2.3, 10.68, 502.0, 477.0, 107.0, 100.0, 1895.0, u'STL', u'LAMBERT-ST LOUIS INTL', u"Lambert-St Louis Int'l Airport", u'Airport', u'ACE', u'ST LOUIS CITY', u'ST LOUIS', u'MO', u'Federalized/Commercial', 38.748697, -90.370029, u'Yes', 39L, 0.0243),
#  (784L, u'STL', 2013L, 87766L, 88139L, 0.7694, 0.7416, 0.7805, 13.24, 10.61, 2.04, 14.81, 1.59, 0.89, 2.36, 12.62, 765.0, 708.0, 116.0, 114.0, 1895.0, u'STL', u'LAMBERT-ST LOUIS INTL', u"Lambert-St Louis Int'l Airport", u'Airport', u'ACE', u'ST LOUIS CITY', u'ST LOUIS', u'MO', u'Federalized/Commercial', 38.748697, -90.370029, u'Yes', 39L, 0.0277999999999999),
#  (785L, u'STL', 2014L, 86632L, 86474L, 0.743, 0.715, 0.7506, 15.01, 10.74, 2.1, 16.62, 1.78, 0.99, 2.75, 14.64, 1014.0, 920.0, 135.0, 105.0, 1895.0, u'STL', u'LAMBERT-ST LOUIS INTL', u"Lambert-St Louis Int'l Airport", u'Airport', u'ACE', u'ST LOUIS CITY', u'ST LOUIS', u'MO', u'Federalized/Commercial', 38.748697, -90.370029, u'Yes', 39L, 0.028),
#  (786L, u'SWF', 2004L, 2734L, 2662L, 0.7008, 0.6544, 0.6525, 16.63, 12.91, 3.42, 18.9, 3.63, 0.45, 4.34, 18.67, 81.0, 70.0, 4.0, 3.0, 2494.0, u'SWF', u'STEWART INTL', u"Stewart Int'l Airport", u'Airport', u'AEA', u'ORANGE', u'NEWBURGH', u'NY', u'Federalized/Commercial', 41.504111, -74.104833, u'Yes', 17L, 0.0464),
#  (787L, u'SWF', 2005L, 8820L, 8666L, 0.6991, 0.6776, 0.6547, 17.3, 12.1, 2.38, 18.61, 3.3, 0.74, 4.75, 17.92, 94.0, 80.0, 5.0, 7.0, 2494.0, u'SWF', u'STEWART INTL', u"Stewart Int'l Airport", u'Airport', u'AEA', u'ORANGE', u'NEWBURGH', u'NY', u'Federalized/Commercial', 41.504111, -74.104833, u'Yes', 17L, 0.0215000000000001),
#  (788L, u'SWF', 2006L, 6582L, 6359L, 0.6694, 0.6542, 0.6141, 18.78, 11.91, 1.92, 19.73, 3.38, 0.67, 5.72, 21.09, 39.0, 37.0, 3.0, 4.0, 2494.0, u'SWF', u'STEWART INTL', u"Stewart Int'l Airport", u'Airport', u'AEA', u'ORANGE', u'NEWBURGH', u'NY', u'Federalized/Commercial', 41.504111, -74.104833, u'Yes', 17L, 0.0152),
#  (789L, u'SWF', 2007L, 9634L, 9418L, 0.7162, 0.6583, 0.6277, 17.4, 13.76, 3.84, 20.49, 2.49, 1.61, 6.14, 20.78, 120.0, 103.0, 19.0, 21.0, 2494.0, u'SWF', u'STEWART INTL', u"Stewart Int'l Airport", u'Airport', u'AEA', u'ORANGE', u'NEWBURGH', u'NY', u'Federalized/Commercial', 41.504111, -74.104833, u'Yes', 17L, 0.0579),
#  (790L, u'SWF', 2008L, 8096L, 7907L, 0.7456, 0.7155, 0.692, 16.07, 13.37, 2.42, 17.78, 2.71, 0.68, 4.27, 17.68, 53.0, 41.0, 13.0, 15.0, 2494.0, u'SWF', u'STEWART INTL', u"Stewart Int'l Airport", u'Airport', u'AEA', u'ORANGE', u'NEWBURGH', u'NY', u'Federalized/Commercial', 41.504111, -74.104833, u'Yes', 17L, 0.0301),
#  (791L, u'SWF', 2009L, 5068L, 4975L, 0.7129, 0.6687, 0.6476, 16.71, 14.65, 3.02, 19.2, 2.84, 0.75, 4.93, 19.37, 29.0, 18.0, 7.0, 6.0, 2494.0, u'SWF', u'STEWART INTL', u"Stewart Int'l Airport", u'Airport', u'AEA', u'ORANGE', u'NEWBURGH', u'NY', u'Federalized/Commercial', 41.504111, -74.104833, u'Yes', 17L, 0.0442),
#  (792L, u'SWF', 2010L, 4840L, 4819L, 0.7519, 0.7192, 0.6559, 14.95, 14.09, 2.46, 16.71, 2.89, 0.51, 4.91, 19.69, 67.0, 54.0, 5.0, 12.0, 2494.0, u'SWF', u'STEWART INTL', u"Stewart Int'l Airport", u'Airport', u'AEA', u'ORANGE', u'NEWBURGH', u'NY', u'Federalized/Commercial', 41.504111, -74.104833, u'Yes', 17L, 0.0327000000000001),
#  (793L, u'SWF', 2011L, 5546L, 5444L, 0.7034, 0.6918, 0.6275, 17.8, 13.17, 1.3, 18.35, 2.91, 0.84, 4.34, 20.71, 42.0, 40.0, 4.0, 5.0, 2494.0, u'SWF', u'STEWART INTL', u"Stewart Int'l Airport", u'Airport', u'AEA', u'ORANGE', u'NEWBURGH', u'NY', u'Federalized/Commercial', 41.504111, -74.104833, u'Yes', 17L, 0.0116000000000001),
#  (794L, u'SWF', 2012L, 5546L, 5474L, 0.7495, 0.7467, 0.6955, 14.4, 12.31, 0.83, 14.59, 2.72, 0.34, 3.78, 16.55, 14.0, 12.0, 3.0, 1.0, 2494.0, u'SWF', u'STEWART INTL', u"Stewart Int'l Airport", u'Airport', u'AEA', u'ORANGE', u'NEWBURGH', u'NY', u'Federalized/Commercial', 41.504111, -74.104833, u'Yes', 17L, 0.00280000000000002),
#  (795L, u'SWF', 2013L, 4935L, 4873L, 0.74, 0.6987, 0.6483, 14.62, 14.03, 2.7, 16.73, 2.49, 0.82, 5.5, 18.87, 27.0, 23.0, 7.0, 6.0, 2494.0, u'SWF', u'STEWART INTL', u"Stewart Int'l Airport", u'Airport', u'AEA', u'ORANGE', u'NEWBURGH', u'NY', u'Federalized/Commercial', 41.504111, -74.104833, u'Yes', 17L, 0.0413),
#  (796L, u'SWF', 2014L, 4863L, 4871L, 0.7027, 0.6955, 0.6843, 16.78, 12.42, 0.65, 17.24, 2.83, 0.23, 4.73, 17.14, 17.0, 11.0, 3.0, 11.0, 2494.0, u'SWF', u'STEWART INTL', u"Stewart Int'l Airport", u'Airport', u'AEA', u'ORANGE', u'NEWBURGH', u'NY', u'Federalized/Commercial', 41.504111, -74.104833, u'Yes', 17L, 0.00719999999999998),
#  (808L, u'TPA', 2004L, 100556L, 100312L, 0.8245, 0.8023, 0.7921, 9.85, 11.88, 2.39, 11.53, 2.24, 0.7, 3.1, 11.3, 1167.0, 1016.0, 154.0, 139.0, 864.0, u'TPA', u'TAMPA INTL', u"Tampa Int'l Airport", u'Airport', u'ASO', u'HILLSBOROUGH', u'TAMPA', u'FL', u'Federalized/Commercial', 27.975472, -82.53325, u'Yes', 71L, 0.0222),
#  (809L, u'TPA', 2005L, 111899L, 111953L, 0.7996, 0.7656, 0.7696, 11.39, 12.17, 3.12, 13.76, 2.58, 1.03, 3.52, 12.84, 771.0, 746.0, 212.0, 103.0, 864.0, u'TPA', u'TAMPA INTL', u"Tampa Int'l Airport", u'Airport', u'ASO', u'HILLSBOROUGH', u'TAMPA', u'FL', u'Federalized/Commercial', 27.975472, -82.53325, u'Yes', 71L, 0.034),
#  (810L, u'TPA', 2006L, 106426L, 106040L, 0.8129, 0.7871, 0.7869, 10.78, 12.13, 2.87, 12.7, 2.48, 0.93, 3.0, 11.87, 427.0, 356.0, 197.0, 189.0, 864.0, u'TPA', u'TAMPA INTL', u"Tampa Int'l Airport", u'Airport', u'ASO', u'HILLSBOROUGH', u'TAMPA', u'FL', u'Federalized/Commercial', 27.975472, -82.53325, u'Yes', 71L, 0.0257999999999999),
#  (811L, u'TPA', 2007L, 107523L, 107579L, 0.7903, 0.762, 0.7542, 12.55, 12.03, 2.78, 14.49, 2.19, 0.89, 3.51, 14.26, 705.0, 655.0, 186.0, 121.0, 864.0, u'TPA', u'TAMPA INTL', u"Tampa Int'l Airport", u'Airport', u'ASO', u'HILLSBOROUGH', u'TAMPA', u'FL', u'Federalized/Commercial', 27.975472, -82.53325, u'Yes', 71L, 0.0283),
#  (812L, u'TPA', 2008L, 100289L, 100528L, 0.7983, 0.7684, 0.7672, 12.39, 12.19, 2.85, 14.37, 1.3, 0.89, 3.7, 13.76, 727.0, 654.0, 194.0, 182.0, 864.0, u'TPA', u'TAMPA INTL', u"Tampa Int'l Airport", u'Airport', u'ASO', u'HILLSBOROUGH', u'TAMPA', u'FL', u'Federalized/Commercial', 27.975472, -82.53325, u'Yes', 71L, 0.0299),
#  (813L, u'TPA', 2009L, 83888L, 84140L, 0.8154, 0.7875, 0.7965, 10.86, 12.05, 2.59, 12.64, 1.08, 0.74, 3.0, 11.51, 349.0, 307.0, 201.0, 102.0, 864.0, u'TPA', u'TAMPA INTL', u"Tampa Int'l Airport", u'Airport', u'ASO', u'HILLSBOROUGH', u'TAMPA', u'FL', u'Federalized/Commercial', 27.975472, -82.53325, u'Yes', 71L, 0.0279),
#  (814L, u'TPA', 2010L, 82346L, 82582L, 0.8121, 0.7775, 0.7988, 11.02, 12.45, 3.03, 13.21, 1.86, 0.94, 2.68, 11.65, 709.0, 655.0, 157.0, 140.0, 864.0, u'TPA', u'TAMPA INTL', u"Tampa Int'l Airport", u'Airport', u'ASO', u'HILLSBOROUGH', u'TAMPA', u'FL', u'Federalized/Commercial', 27.975472, -82.53325, u'Yes', 71L, 0.0346000000000001),
#  (815L, u'TPA', 2011L, 81837L, 81897L, 0.8296, 0.8054, 0.8044, 10.6, 11.93, 2.42, 12.19, 1.66, 0.75, 2.53, 11.51, 667.0, 622.0, 176.0, 137.0, 864.0, u'TPA', u'TAMPA INTL', u"Tampa Int'l Airport", u'Airport', u'ASO', u'HILLSBOROUGH', u'TAMPA', u'FL', u'Federalized/Commercial', 27.975472, -82.53325, u'Yes', 71L, 0.0242),
#  (816L, u'TPA', 2012L, 80605L, 80523L, 0.8322, 0.8096, 0.808, 10.51, 11.69, 2.19, 11.88, 1.53, 0.85, 2.57, 11.3, 450.0, 411.0, 131.0, 132.0, 864.0, u'TPA', u'TAMPA INTL', u"Tampa Int'l Airport", u'Airport', u'ASO', u'HILLSBOROUGH', u'TAMPA', u'FL', u'Federalized/Commercial', 27.975472, -82.53325, u'Yes', 71L, 0.0226000000000001),
#  (817L, u'TPA', 2013L, 80603L, 79946L, 0.7997, 0.775, 0.7774, 11.9, 11.86, 2.36, 13.39, 1.63, 0.87, 3.0, 12.66, 326.0, 301.0, 152.0, 118.0, 864.0, u'TPA', u'TAMPA INTL', u"Tampa Int'l Airport", u'Airport', u'ASO', u'HILLSBOROUGH', u'TAMPA', u'FL', u'Federalized/Commercial', 27.975472, -82.53325, u'Yes', 71L, 0.0246999999999999),
#  (818L, u'TPA', 2014L, 79489L, 79173L, 0.7726, 0.7454, 0.7536, 14.33, 12.0, 2.39, 15.97, 2.24, 0.88, 3.53, 14.87, 723.0, 691.0, 183.0, 163.0, 864.0, u'TPA', u'TAMPA INTL', u"Tampa Int'l Airport", u'Airport', u'ASO', u'HILLSBOROUGH', u'TAMPA', u'FL', u'Federalized/Commercial', 27.975472, -82.53325, u'Yes', 71L, 0.0272),
#  (819L, u'TUS', 2004L, 7498L, 7501L, 0.7757, 0.7586, 0.7124, 14.09, 9.98, 2.31, 15.58, 2.37, 0.89, 3.48, 15.24, 103.0, 80.0, 50.0, 22.0, 474.0, u'TUS', u'TUCSON INTL', u"Tucson Int'l Airport", u'Airport', u'AWP', u'PIMA', u'TUCSON', u'AZ', u'Federalized/Commercial', 32.116083, -110.941028, u'Yes', 2L, 0.0170999999999999),
#  (820L, u'TUS', 2005L, 29803L, 29761L, 0.7868, 0.7666, 0.7493, 11.53, 9.87, 2.15, 12.89, 2.42, 0.79, 2.38, 12.86, 126.0, 101.0, 36.0, 26.0, 474.0, u'TUS', u'TUCSON INTL', u"Tucson Int'l Airport", u'Airport', u'AWP', u'PIMA', u'TUCSON', u'AZ', u'Federalized/Commercial', 32.116083, -110.941028, u'Yes', 2L, 0.0202000000000001),
#  (821L, u'TUS', 2006L, 29332L, 30490L, 0.8098, 0.7793, 0.7422, 10.49, 10.58, 2.56, 12.32, 2.11, 1.42, 3.3, 13.69, 206.0, 174.0, 63.0, 46.0, 474.0, u'TUS', u'TUCSON INTL', u"Tucson Int'l Airport", u'Airport', u'AWP', u'PIMA', u'TUCSON', u'AZ', u'Federalized/Commercial', 32.116083, -110.941028, u'Yes', 2L, 0.0305),
#  (822L, u'TUS', 2007L, 32136L, 32102L, 0.8152, 0.7827, 0.7412, 10.62, 11.1, 2.82, 12.41, 2.26, 1.08, 3.3, 13.94, 281.0, 237.0, 65.0, 22.0, 474.0, u'TUS', u'TUCSON INTL', u"Tucson Int'l Airport", u'Airport', u'AWP', u'PIMA', u'TUCSON', u'AZ', u'Federalized/Commercial', 32.116083, -110.941028, u'Yes', 2L, 0.0325000000000001),
#  (823L, u'TUS', 2008L, 30267L, 30337L, 0.8354, 0.8086, 0.7703, 9.51, 10.94, 2.42, 11.01, 1.63, 0.85, 2.93, 12.59, 206.0, 174.0, 59.0, 16.0, 474.0, u'TUS', u'TUCSON INTL', u"Tucson Int'l Airport", u'Airport', u'AWP', u'PIMA', u'TUCSON', u'AZ', u'Federalized/Commercial', 32.116083, -110.941028, u'Yes', 2L, 0.0268),
#  (824L, u'TUS', 2009L, 24475L, 24528L, 0.8507, 0.8278, 0.7965, 8.41, 10.7, 2.17, 9.71, 1.82, 0.79, 2.67, 10.73, 117.0, 100.0, 38.0, 28.0, 474.0, u'TUS', u'TUCSON INTL', u"Tucson Int'l Airport", u'Airport', u'AWP', u'PIMA', u'TUCSON', u'AZ', u'Federalized/Commercial', 32.116083, -110.941028, u'Yes', 2L, 0.0229),
#  (825L, u'TUS', 2010L, 24995L, 25088L, 0.8502, 0.8293, 0.7926, 8.27, 10.48, 2.01, 9.38, 1.64, 0.76, 2.33, 11.04, 144.0, 110.0, 42.0, 35.0, 474.0, u'TUS', u'TUCSON INTL', u"Tucson Int'l Airport", u'Airport', u'AWP', u'PIMA', u'TUCSON', u'AZ', u'Federalized/Commercial', 32.116083, -110.941028, u'Yes', 2L, 0.0208999999999999),
#  (826L, u'TUS', 2011L, 25149L, 25165L, 0.8458, 0.8216, 0.7795, 8.76, 11.06, 2.58, 10.17, 1.47, 0.8, 2.57, 11.77, 204.0, 183.0, 43.0, 28.0, 474.0, u'TUS', u'TUCSON INTL', u"Tucson Int'l Airport", u'Airport', u'AWP', u'PIMA', u'TUCSON', u'AZ', u'Federalized/Commercial', 32.116083, -110.941028, u'Yes', 2L, 0.0242),
#  (827L, u'TUS', 2012L, 23583L, 23679L, 0.8599, 0.8336, 0.7965, 8.1, 11.19, 2.59, 9.48, 1.56, 0.74, 2.29, 10.64, 117.0, 107.0, 38.0, 29.0, 474.0, u'TUS', u'TUCSON INTL', u"Tucson Int'l Airport", u'Airport', u'AWP', u'PIMA', u'TUCSON', u'AZ', u'Federalized/Commercial', 32.116083, -110.941028, u'Yes', 2L, 0.0263),
#  (828L, u'TUS', 2013L, 22502L, 22090L, 0.8145, 0.7914, 0.7628, 10.55, 11.43, 2.43, 11.96, 1.67, 0.7, 2.48, 12.76, 175.0, 153.0, 62.0, 18.0, 474.0, u'TUS', u'TUCSON INTL', u"Tucson Int'l Airport", u'Airport', u'AWP', u'PIMA', u'TUCSON', u'AZ', u'Federalized/Commercial', 32.116083, -110.941028, u'Yes', 2L, 0.0231),
#  (829L, u'TUS', 2014L, 22589L, 22340L, 0.7914, 0.7715, 0.7351, 12.33, 11.32, 2.03, 13.47, 1.84, 0.92, 2.57, 14.76, 178.0, 155.0, 55.0, 39.0, 474.0, u'TUS', u'TUCSON INTL', u"Tucson Int'l Airport", u'Airport', u'AWP', u'PIMA', u'TUCSON', u'AZ', u'Federalized/Commercial', 32.116083, -110.941028, u'Yes', 2L, 0.0199)]

# %% [markdown]
# #### 1.2 What are the risks and assumptions of our data?

# %% [markdown]
# ### Part 2: Exploratory Data Analysis

# %% [markdown]
# #### 2.1 Plot and Describe the Data

# %%
df.columns

# %%
# df.describe().columns#


# orig_index(['year', 'departures for metric computation',
#        'arrivals for metric computation', 'percent on-time gate departures',
#        'percent on-time airport departures', 'percent on-time gate arrivals',
#        'average_gate_departure_delay', 'average_taxi_out_time',
#        'average taxi out delay', 'average airport departure delay',
#        'average airborne delay', 'average taxi in delay',
#        'average block delay', 'average gate arrival delay',
#        'Departure Cancellations', 'Arrival Cancellations',
#        'Departure Diversions', 'Arrival Diversions', 'Key', 'Latitude',
#        'Longitude', 'airport_num', 'diff_gate_airport_departures'],
#       dtype='object')

# %%
decade_agg_ap = pd.pivot_table(df, index='airport')
grouped_years = pd.pivot_table(df, index='year')

# %%
import seaborn as sns

# sns.pairplot(decade_agg_ap.describe().iloc[:,10:-1])

# %%
# sns.pairplot(grouped_years.describe().iloc[:,10:-1])

# %%
sns.pairplot(df.describe().iloc[:,4:12])

# %% [markdown]
# #### Are there any unique values?

# %%
grouped_years['Year'] = grouped_years.index
grouped_years

# %% [markdown]
# ### Part 3: Data Mining

# %% [markdown]
# #### 3.1 Create Dummy Variables

# %%
#Goal analysis:
#1: df - airport-years, find patterns
#2: decade_agg_ap - by airport over entire decade
#3: grouped_years - by year to see trends over time

# %% [markdown]
# #### 3.2 Format and Clean the Data

# %% [markdown]
# ### Part 4: Define the Data

# %% [markdown]
# #### 4.1 Confirm that the dataset has a normal distribution. How can you tell?

# %%
sns.distplot(df['percent on-time gate arrivals'], c='blue')
sns.distplot(df.iloc[:,4], c= 'orange')

# %%
sns.distplot(df.iloc[:,4])

# %%
sns.distplot(df.iloc[:,7], c='red')
sns.distplot(df.iloc[:,8], c='green')

# %%
sns.distplot(df.iloc[:,8])

# %% [markdown]
# #### 4.2 Find correlations in the data

# %%
# variables for analysis:
#1: df - airport-years, find patterns
#2: decade_agg_ap - by airport over entire decade
#3: grouped_years

# %%
sns.distplot(decade_agg_ap['percent on-time gate arrivals'])

# %%
sns.regplot(grouped_years['Year'], grouped_years['percent on-time gate arrivals'])
#slightly positive trend in terms of ontime gate arrivals

# %%
sns.regplot(grouped_years['Year'], grouped_years.iloc[:,8])
#slight decrease in aavg. arrival delay

# %%
sns.regplot(grouped_years['Year'], grouped_years.iloc[:,11])
#slight decrease in aavg. arrival delay

# %%
import matplotlib as plt

decade_agg_ap['airport'] = decade_agg_ap.index
# decade_agg_ap
plt.style.use('fivethirtyeight')

# fig, ax = plt.subplots(figsize=(16,16))
decade_agg_ap.sort_values(by=['percent on-time gate departures'],axis=0, inplace=1)


# sns.barplot(decade_agg_ap['percent on-time gate arrivals'],decade_agg_ap['airport'], hue=decade_agg_ap['Arrival Cancellations'])
sns.barplot(decade_agg_ap['percent on-time gate departures'],decade_agg_ap['airport'],)
fig = plt.pyplot.gcf()
fig.set_size_inches(20, 16)
fig.savefig('test2png.png', dpi=100)

# %%
decade_agg_ap.head()

# %%
decade_agg_ap_short = decade_agg_ap[-20:] #df['20130102':'20130104']
decade_agg_ap_short.head(25)

# %%
# sns.barplot(decade_agg_ap['percent on-time gate arrivals'],decade_agg_ap['airport'], hue=decade_agg_ap['Arrival Cancellations'])
ax = sns.barplot(data=decade_agg_ap_short, y='percent on-time airport departures', x='airport',hue='average_gate_departure_delay', palette='plasma')
ax.legend_.remove()
sns.axes_style()
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})

fig = plt.pyplot.gcf()
fig.set_size_inches(16, 14)
# ax.legend_.remove()

# plt.xlim([0.7,1.0])
fig.savefig('most_delayed.png', dpi=100)

# %% [markdown]
# create buckets for departures (or use previously counted values)

# %%
# sns.barplot(decade_agg_ap['percent on-time gate arrivals'],decade_agg_ap['airport'], hue=decade_agg_ap['Arrival Cancellations'])
sns.barplot(data=decade_agg_ap_short, y='percent on-time gate departures', x='airport', hue='percent on-time gate arrivals', palette='plasma')
fig = plt.pyplot.gcf()
fig.set_size_inches(16, 12)
# plt.xlim([0.7,1.0])
fig.savefig('most_delayed.png', dpi=100)

# %% [markdown]
# #### 4.3 What is the value of understanding correlations before PCA?

# %% [markdown]
# Answer: When reducing the dimensionality of the underlying dataset, we lose relative feature importance and, therefore, interpretability. Additionally, although it is a matter of preference and is specific to the methodology of a given context, by including variables that are highly correlated with one another, we may be over-emphasizing the dimension of the shared "underlying factor" that is influencing multiple features (in contrast, this may also provide precision, depending on the context of the problem.

# %% [markdown]
# #### 4.4 Validate your findings using statistical analysis

# %%
df.head()

# %%
df['delay_score'] = ((1-df['percent on-time airport departures'])-df['percent on-time gate arrivals'])*(df['average airport departure delay']-df['average gate arrival delay'])

# %%
df['net_lateness_percent'] = ((1-df['percent on-time airport departures'])-(1-df['percent on-time gate arrivals']))

# %%
df['avg_delay_late_control'] = (df['average airport departure delay']+df['average airborne delay']+df['average taxi out delay']-df['average gate arrival delay'])

# %%
'average airport departure delay', 'average block delay', 'average airborne delay'

# %%
df['net_cancelations']= df['Departure Cancellations'] - df['Arrival Cancellations']
df['net_diversions']= df['Departure Diversions'] - df['Arrival Diversions']

# %%
sns.distplot(df['delay_score'])

# %% [markdown]
# Based on the above plot (where the more positive, the better performance) it appears that delays

# %% [markdown]
# #### 4.5 How can you improve your overall analysis?

# %% [markdown]
# Answer:

# %% [markdown]
# ### Part 5: Perform a PCA

# %% [markdown]
# #### 5.1 Conduct the PCA

# %%
df['delay_score']

df['samples'] = ((df['departures for metric computation'] + df['arrivals for metric computation'])/2)
sns.distplot(df['samples'])

# %%
df[df['samples']>100] # all these super low samples are commercial, let's leave them in and hope we differentiate
#also, its clear that AP type is really important - let's make dummies for those

# %%
df['AP Type'].value_counts() #definitely worth including, values for all 799 rows

# %%
len(df[df['samples']>100])

# %%
ap_type_dums = pd.get_dummies(df['AP Type'])
df = pd.concat([df,ap_type_dums], axis = 1)

# ['samples', 'Public Use', 'Ferderalized/Commercial']

# %%
ap_type_dums

# %%
from sklearn import preprocessing



unscaled_x = df.loc[:,['year','percent on-time gate departures','percent on-time airport departures', 'percent on-time gate arrivals','average_gate_departure_delay', 'average_taxi_out_time','average taxi out delay', 'average airport departure delay','average airborne delay', 'average taxi in delay','average block delay', 'average gate arrival delay', 'Latitude','Longitude', 'net_cancelations', 'net_diversions','samples', 'Public Use', 'Federalized/Commercial']]

X_orig = preprocessing.StandardScaler().fit_transform(unscaled_x)
X_orig = pd.DataFrame(X_orig, columns=unscaled_x.columns)

y = df['airport_num']
y_temp = df['delay_score']

# %%
rfc_cv = RandomForestRegressor(n_estimators=1000) #
stratk = StratifiedKFold(y_temp, n_folds=10, shuffle=True, random_state=66)

rfc_cv.fit(X_orig, y_temp)
s_rfc = cross_val_score(rfc_cv, X_orig, y_temp, cv=stratk, n_jobs=-1).mean()
s_rfc

# %%
feature_importances_rfc = pd.DataFrame(rfc_cv.feature_importances_,
                                   index = X_orig.columns,
                                    columns=['importance']).sort_values('importance',
                                                                        ascending=False)
feature_importances_rfc.head(35)

# %%
#because federal v. public airports are not predictive at all on the amount of lateness, seems like I should focus my analysis on non-public airports
#Looking online, I was unable to find a clear difference between 2 groups, so dropping as features (airports seem to be divided in other ways online)

# removed: 'Public Use', 'Federalized/Commercial'

features = df.loc[:,['year','avg_delay_late_control', 'net_lateness_percent', 'Latitude','Longitude', 'net_cancelations', 'net_diversions','samples']]
X = preprocessing.StandardScaler().fit_transform(features)
X = pd.DataFrame(X, columns=features.columns)

# %%
from sklearn.decomposition import PCA

pca_2 = PCA(n_components=2)
xPC_2 = pca_2.fit_transform(X) # Use the eigenvectors to transform xStand onto new axes
print pca_2.fit(X).components_# eigenvectors

# %%
from sklearn.decomposition import PCA

pca_3 = PCA(n_components=3)
xPC_3 = pca_3.fit_transform(X) # Use the eigenvectors to transform xStand onto new axes
print pca_3.fit(X).components_# eigenvectors

# %%
df_pca_2 = pd.DataFrame(xPC_2, columns=['PC1','PC2'])
# len(df_pca_2) #799, as expected
df_pca_labeled_full = pd.merge(df_pca_2, df, left_index=1, right_index=1)
df_pca_labeled = df_pca_labeled_full.iloc[:,:3]
df_pca_labeled.head()

# %%
df_pca_3 = pd.DataFrame(xPC_3, columns=['PC1','PC2', 'PC3']) #for use in analysis
df_pca3_labeled_full = pd.merge(df_pca_3, df, left_index=1, right_index=1)
df_pca3_labeled = df_pca3_labeled_full.iloc[:,:4]
df_pca_3.head()

# %%
df_pca3_labeled.head() #for visualizations later

# %%
# sns.regplot(data=df_pca_2,x='PC1', y='PC2')
# plt.style.use('fivethirtyeight')

# %%
kmeans = KMeans(n_clusters=5)
clusters = kmeans.fit(X)
labels = kmeans.labels_
centroids = kmeans.cluster_centers_
metrics.silhouette_score(X, labels, metric='euclidean')

# %%
kmeans3 = KMeans(n_clusters=3)
clusters3 = kmeans3.fit(X)
labels3 = kmeans3.labels_
centroids3 = kmeans3.cluster_centers_
metrics.silhouette_score(X, labels3, metric='euclidean')

# %%
kmeans10 = KMeans(n_clusters=10)
clusters10 = kmeans10.fit(X)
labels10 = kmeans10.labels_
centroids10 = kmeans10.cluster_centers_
metrics.silhouette_score(X, labels10, metric='euclidean')

# %%
#now assessing PCA results

kmeans3pca = KMeans(n_clusters=4)
clusters3pca = kmeans3pca.fit(df_pca_2)
labels3pca = kmeans3pca.labels_
centroids3pca = kmeans3pca.cluster_centers_
metrics.silhouette_score(df_pca_2, labels3pca, metric='euclidean')

# %%
kmeans4 = KMeans(n_clusters=4)
clusters4 = kmeans4.fit(df_pca_2)
labels4 = kmeans4.labels_
centroids4 = kmeans4.cluster_centers_
metrics.silhouette_score(df_pca_2, labels4, metric='euclidean')

# %%
kmeans_pca = KMeans(n_clusters=5)
clusters_pca = kmeans_pca.fit(df_pca_2)
labels_pca = kmeans_pca.labels_
centroids_pca = kmeans_pca.cluster_centers_
metrics.silhouette_score(df_pca_2, labels_pca, metric='euclidean')

# %%
kmeans6 = KMeans(n_clusters=6)
clusters6 = kmeans6.fit(df_pca_2)
labels6 = kmeans6.labels_
centroids6 = kmeans6.cluster_centers_
metrics.silhouette_score(df_pca_2, labels6, metric='euclidean')

# %%
df_pca_2['cluster'] = pd.Series(clusters_pca.labels_)
plt.style.use('fivethirtyeight')

graph = df_pca_2.plot(kind='scatter', x='PC2', y='PC1', figsize=(16,8))

for i, airport in enumerate(df_pca_labeled['airport']):
    graph.annotate(airport, (df_pca_2.iloc[i].PC2, df_pca_2.iloc[i].PC1))

# %% [markdown]
# Stopping Point: Future Analysis
#
# Next, I will implement:
#
# heirarchical clustering
# random forest classification (with feature importance to inform other analysis)
# t-SNE (to see if more obvious clusters emerge)
#
# Then, next goal is to determine number of clusters -- especially if unclear above (using the full dataset). I will do 2 methods and compare them:
#
# DBscan (grid-search optimized w/ silouette score)
#
# Once I have determined my number of clusters, I will perform the following on both PCA and full(scaled) features:
#
# Finally, try to visualize best clusters with best siluette

# %% [markdown]
# ### Part 6: Additional Analysis
# Include any other models you'd like to run here. These can include regressions, classifications, or clusters.

# %%
#heirarchical

from sklearn import cluster, metrics
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from scipy.cluster.hierarchy import dendrogram, linkage, cophenet, fcluster
from scipy.spatial.distance import pdist

Z = linkage(X, 'ward')
c, coph_dists = cophenet(Z, pdist(X))
c

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot') 
# %matplotlib inline


plt.figure(figsize=(30, 10))
plt.title('Dendrogram')
plt.xlabel('Index Numbers')
plt.ylabel('Distance')
dendrogram(
    Z,
    leaf_rotation=90.,  
    leaf_font_size=8.,
    truncate_mode='lastp')

plt.show()

# %%
#looks like 3 clusters will be reasonable given the above visualization. What does t-SNE think?
#this confirms the Kmeans silouettes scores

# %%
#edited plit imbedding

def plot_embedding(X, title=None):
    x_min, x_max = np.min(X, 0), np.max(X, 0)
    X = (X - x_min) / (x_max - x_min)

    fig = plt.figure(figsize=(15,8))
    ax = plt.subplot(111)
    for i in range(X.shape[0]):
        plt.text(X[i, 0], X[i, 1], str(df_pca_labeled['airport'][i]),
                 color=plt.cm.Set1(y[i] / 10.),
                 fontdict={'weight': 'bold', 'size': 9})

    if hasattr(offsetbox, 'AnnotationBbox'):
        # only print thumbnails with matplotlib > 1.0
        shown_images = np.array([[1., 1.]])  # just something big
        for i in range(df_pca_labeled['airport'].shape[0]):
            dist = np.sum((X[i] - shown_images) ** 2, 1)
            if np.min(dist) < 4e-3:
                # don't show points that are too close
                continue
            shown_images = np.r_[shown_images, [X[i]]]
            imagebox = offsetbox.AnnotationBbox(
                offsetbox.OffsetImage(df_pca_labeled['airport'][i], cmap=plt.cm.gray_r),
                X[i])
            ax.add_artist(imagebox)
    plt.xticks([]), plt.yticks([])
    if title is not None:
        plt.title(title)

# %%
def scatter_basic(x):
    # We choose a color palette with seaborn.
    palette = sns.color_palette("GnBu_d")

    # We create a scatter plot.
    plt.style.use('fivethirtyeight')
    f = plt.figure(figsize=(8, 8))
    ax = plt.subplot(aspect='equal')
    sc = ax.scatter(x[:,0], x[:,1], lw=0, s=40)
    plt.xlim(-25, 25)
    plt.ylim(-25, 25)
    ax.axis('off')
    ax.axis('tight')
    plt.show()


    return f, ax, sc

# %%
# original version of plot_embedding
# def plot_embedding(X, title=None):
#     x_min, x_max = np.min(X, 0), np.max(X, 0)
#     X = (X - x_min) / (x_max - x_min)

#     fig = plt.figure(figsize=(15,8))
#     ax = plt.subplot(111)
#     for i in range(X.shape[0]):
#         plt.text(X[i, 0], X[i, 1], str(df['airport_num'][i]),
#                  color=plt.cm.Set1(y[i] / 10.),
#                  fontdict={'weight': 'bold', 'size': 9})

#     if hasattr(offsetbox, 'AnnotationBbox'):
#         # only print thumbnails with matplotlib > 1.0
#         shown_images = np.array([[1., 1.]])  # just something big
#         for i in range(df['airport_num'].shape[0]):
#             dist = np.sum((X[i] - shown_images) ** 2, 1)
#             if np.min(dist) < 4e-3:
#                 # don't show points that are too close
#                 continue
#             shown_images = np.r_[shown_images, [X[i]]]
#             imagebox = offsetbox.AnnotationBbox(
#                 offsetbox.OffsetImage(df['airport_num'][i], cmap=plt.cm.gray_r),
#                 X[i])
#             ax.add_artist(imagebox)
#     plt.xticks([]), plt.yticks([])
#     if title is not None:
#         plt.title(title)

# %%
# t-SNE 
from time import time
from scipy.cluster import hierarchy


print("Computing t-SNE embedding")
tsne = manifold.TSNE(n_components=2, init='pca', random_state=5)
X_tsne = tsne.fit_transform(X)
scatter_basic(X_tsne)

#this plot seems to support more than three groupings

# %%
X.iloc[220:244,:]

# %%
#t-SNE resources for troubleshooting visualization errors: https://indico.io/blog/visualizing-with-t-sne/
#https://gist.github.com/lukemetz/be6123c7ee3b366e333a

# %%
from tsne import bh_sne
X_2d = bh_sne(X)
plt.style.use('fivethirtyeight')
plt.figure(figsize=(30, 10))
plt.scatter(X_2d[:,0],X_2d[:,1])
plt.title('t-SNE')
plt.xlabel('')
plt.ylabel('')
# plt.plot(X_2d)
# plt.show()

# %%
X_2d[1,1]

# %%
X_2d = bh_sne(X)
plt.style.use('fivethirtyeight')
plt.figure(figsize=(30, 10))
plt.scatter(X_2d[:,0],X_2d[:,1])
plt.title('t-SNE')
plt.xlabel('')
plt.ylabel('')

for i, airport in enumerate(df_pca_labeled['airport']):
    graph.annotate(airport, (X_2d[i,1], X_2d[i,0]))

# %%
# Isomap 
n_neighbors = 6
X_iso = manifold.Isomap(n_neighbors, n_components=2).fit_transform(X)
scatter_basic(X_iso)

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(30, 20))
plt.scatter(X_2d[:,0],X_2d[:,1])
plt.title('t-SNE')
plt.xlabel('')
plt.ylabel('')
plt.xlim([-25,25])
plt.ylim([-25,25]) #4 clusters here?

# %%
from sklearn.cluster import DBSCAN, KMeans

db1 = DBSCAN(eps = 1, min_samples = 5).fit(X)  
db1labels = db1.labels_  
core_samples = db1.core_sample_indices_

db1labels #too many

# %%
from sklearn.metrics import silhouette_score

print("Silhouette Coefficient: %0.3f" #what does negative mean???
      % silhouette_score(X, db1labels))

# %%
db2 = DBSCAN(eps = 3, min_samples = 10).fit(X)  #
db2labels = db2.labels_  
core_samples = db2.core_sample_indices_


print("Silhouette Coefficient: %0.3f" #this is returning all zeros (which yields a killer silhouette...)
      % silhouette_score(X, db2labels))

# %%
set(db2labels) #too few

# %%
db3 = DBSCAN(eps = 1, min_samples = 10).fit(xPC_2)  #
db3labels = db3.labels_  
core_samples = db3.core_sample_indices_


print("Silhouette Coefficient: %0.3f" #progress!
      % silhouette_score(X, db3labels))

# %%
db4 = DBSCAN(eps = .75, min_samples = 5).fit(xPC_3)  #
db4labels = db4.labels_  
core_samples = db4.core_sample_indices_


print("Silhouette Coefficient: %0.3f" #this is returning all zeros (which yields a killer silhouette...)
      % silhouette_score(X, db4labels))

# %%
set(db4labels) # 5 clusters here

# %%
set(db3labels) #4 clusters as well

# %%
rfc = RandomForestRegressor(n_estimators=1000) #
stratk = StratifiedKFold(y_temp, n_folds=10, shuffle=True, random_state=66)

rfc.fit(X, db4labels)
s_rfc = cross_val_score(rfc, X, db4labels, cv=stratk, n_jobs=-1).mean()

feature_importance_rfc = pd.DataFrame(rfc.feature_importances_,
                                   index = features.columns,
                                    columns=['importance']).sort_values('importance',
                                                                        ascending=False)
feature_importance_rfc.head(35) #first time running this, i kepy federalized and public use categories in, and they dominated the clustering, so i removed them

# %%
from sklearn.grid_search import GridSearchCV

eps_vals = [0.1, 0.3, 0.5, 0.75, .9, 1.25, 1.5, 2, 3]
min_samples = [3,5,6,7,8,9,10,11,12, 15]

gs = GridSearchCV(db3, {'eps': eps_vals, 'min_samples': min_samples}, verbose=False, cv=stratk)
# dbgs2labels = gs.labels_
gs.fit(xPC_3, score=silhouette_score(X, gs.labels_))
gs.best_params_

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(30, 20))
plt.scatter(X_2d[:,0],X_2d[:,1])
plt.title('t-SNE')
plt.xlabel('')
plt.ylabel('')
plt.xlim([-25,25])
plt.ylim([-25,25]) #4 clusters here?


for i, label in enumerate(db4labels['airport']):
    graph.annotate(label, (X_2d.iloc[i,0],X_2d.iloc[i,1]))

# %%
print(len(X_2d), len(db4labels))

# %%
X_2d = pd.DataFrame(X_2d)
db4labels = pd.DataFrame(db4labels)


plotdf = X_2d.merge(db4labels, how='left', left_index=1, right_index=1)
# plotdf = pd.merge(X_2d, db4labels, how='left', left_index=1, right_index=1)

plotdf.columns = ['x1', 'x2', 'label']

plt.figure(figsize=(30, 20))
sns.lmplot('x1','x2', data=plotdf, hue='label', legend=1, fit_reg=0)
plt.title('t-SNE')

# %%
labels_pca

labels_pca = pd.DataFrame(labels_pca)


plotdf2 = X_2d.merge(labels_pca, how='left', left_index=1, right_index=1)
# plotdf = pd.merge(X_2d, db4labels, how='left', left_index=1, right_index=1)

plotdf2.columns = ['x1', 'x2', 'label']

plt.figure(figsize=(30, 20))
sns.lmplot('x1','x2', data=plotdf2, hue='label', legend=1, fit_reg=0)
plt.title('t-SNE')

# %%
#tree/ random forest model predicting df['percent on-time airport departures'] and extract feature importance

# %% [markdown]
# ### Part 7: Write an analysis plan of your findings

# %% [markdown]
# Create a writeup on the interpretation of findings including an executive summary with conclusions and next steps. Put it on your blog, and include the link here.

# %% [markdown]
# Which operational features are most correlated with delays?

# %% [markdown]
# What should the airport's next steps be?

# %% [markdown]
# ### Bonus: Copy your Database to AWS

# %% [markdown]
# Make sure to properly document all of the features of your dataset

# %% [markdown]
# ### Bonus: Create a 3-Dimensional Plot of your new dataset with PCA applied
