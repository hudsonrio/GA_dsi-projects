# %% [markdown]
# # Project 7
#
# In this project, you will implement the the clustering techniques that you've learned this week.
#
# #### Step 1: Load the python libraries that you will need for this project

# %%
import pandas as pd 
import matplotlib as plt
import numpy as np
import sklearn
import psycopg2 as psy
import os 
import matplotlib.pyplot as plt
import numpy as np
import math
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA 
from sklearn.cluster import KMeans
from sklearn import metrics
from matplotlib import *
import sys
from pylab import *
from matplotlib import offsetbox
from sklearn import (manifold, datasets, decomposition, ensemble,
                     discriminant_analysis, random_projection)
from sklearn import metrics
from sklearn.cross_validation import cross_val_score, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, BaggingRegressor

# %matplotlib inline

os.getcwd()
# Out:
# '/Users/HudsonCavanagh/GA_dsi-projects/projects/7th'

# %% [markdown]
# #### Step 2: Examine your data

# %%
airports = pd.read_csv('/Users/HudsonCavanagh/Documents/airports.csv')
ops = pd.read_csv('/Users/HudsonCavanagh/Documents/Airport_operations.csv')
cancelations = pd.read_csv('/Users/HudsonCavanagh/Documents/airport_cancellations.csv')

airports.head()
# Out:
#     Key LocID                   AP_NAME                                ALIAS  \
# 0  3443   STX           HENRY E ROHLSEN        Henry E Rohlsen Int'l Airport
# 1  5088   X64                  PATILLAS                                  NaN
# 2  2886   PSE                 MERCEDITA                 Aeropuerto Mercedita
# 3  2879   VQS  ANTONIO RIVERA RODRIGUEZ  Aeropuerto Antonio Rivera Rodr�guez
# 4  2883   X63                   HUMACAO       Aeropuerto Regional De Humacao
#
#   Facility Type FAA REGION            COUNTY             CITY STATE  \
# 0       Airport        ASO  -VIRGIN ISLANDS-    CHRISTIANSTED    VI
# 1       Airport        ASO            #NAME?         PATILLAS    PR
# 2       Airport        ASO            #NAME?            PONCE    PR
# 3       Airport        ASO            #NAME?  ISLA DE VIEQUES    PR
# 4       Airport        ASO            #NAME?          HUMACAO    PR
#
#       AP Type   Latitude  Longitude Boundary Data Available
# 0  Public Use  17.701556 -64.801722                     Yes
# 1  Public Use  17.982189 -66.019330                      No
# 2  Public Use  18.008306 -66.563028                     Yes
# 3  Public Use  18.134811 -65.493617                     Yes
# 4  Public Use  18.138017 -65.800718                     Yes

# %%
airports['AP Type'].value_counts() # way more public use than federal/ commercial (95%)
# Out:
# Public Use                4876
# Federalized/Commercial     288
# Name: AP Type, dtype: int64

# %%
print(len(ops), len(cancelations))
# Out:
# (841, 805)

# %%
ops['str_year'] = ops['year'].apply(lambda x: str(int(x)))
ops['airport_year'] = ops['airport'] + ops['str_year']
ops['airport_year']
# Out:
# 0      ABQ2004
# 1      ABQ2005
# 2      ABQ2006
# 3      ABQ2007
# 4      ABQ2008
# 5      ABQ2009
# 6      ABQ2010
# 7      ABQ2011
# 8      ABQ2012
# 9      ABQ2013
# 10     ABQ2014
# 11     ANC2004
# 12     ANC2005
# 13     ANC2006
# 14     ANC2007
# 15     ANC2008
# 16     ANC2009
# 17     ANC2010
# 18     ANC2011
# 19     ANC2012
# 20     ANC2013
# 21     ANC2014
# 22     ATL2004
# 23     ATL2005
# 24     ATL2006
# 25     ATL2007
# 26     ATL2008
# 27     ATL2009
# 28     ATL2010
# 29     ATL2011
#         ...
# 811    TPA2007
# 812    TPA2008
# 813    TPA2009
# 814    TPA2010
# 815    TPA2011
# 816    TPA2012
# 817    TPA2013
# 818    TPA2014
# 819    TUS2004
# 820    TUS2005
# 821    TUS2006
# 822    TUS2007
# 823    TUS2008
# 824    TUS2009
# 825    TUS2010
# 826    TUS2011
# 827    TUS2012
# 828    TUS2013
# 829    TUS2014
# 830    VNY2004
# 831    VNY2005
# 832    VNY2006
# 833    VNY2007
# 834    VNY2008
# 835    VNY2009
# 836    VNY2010
# 837    VNY2011
# 838    VNY2012
# 839    VNY2013
# 840    VNY2014
# Name: airport_year, dtype: object

# %%
cancelations

cancelations['str_year'] = cancelations['Year'].apply(lambda x: str(int(x)))
cancelations['airport_year'] = cancelations['Airport'] + cancelations['str_year']
cancelations['airport_year']
# Out:
# 0      ABQ2004
# 1      ABQ2005
# 2      ABQ2006
# 3      ABQ2007
# 4      ABQ2008
# 5      ABQ2009
# 6      ABQ2010
# 7      ABQ2011
# 8      ABQ2012
# 9      ABQ2013
# 10     ABQ2014
# 11     ANC2004
# 12     ANC2005
# 13     ANC2006
# 14     ANC2007
# 15     ANC2008
# 16     ANC2009
# 17     ANC2010
# 18     ANC2011
# 19     ANC2012
# 20     ANC2013
# 21     ANC2014
# 22     ATL2004
# 23     ATL2005
# 24     ATL2006
# 25     ATL2007
# 26     ATL2008
# 27     ATL2009
# 28     ATL2010
# 29     ATL2011
#         ...
# 775    SWF2007
# 776    SWF2008
# 777    SWF2009
# 778    SWF2010
# 779    SWF2011
# 780    SWF2012
# 781    SWF2013
# 782    SWF2014
# 783    TPA2004
# 784    TPA2005
# 785    TPA2006
# 786    TPA2007
# 787    TPA2008
# 788    TPA2009
# 789    TPA2010
# 790    TPA2011
# 791    TPA2012
# 792    TPA2013
# 793    TPA2014
# 794    TUS2004
# 795    TUS2005
# 796    TUS2006
# 797    TUS2007
# 798    TUS2008
# 799    TUS2009
# 800    TUS2010
# 801    TUS2011
# 802    TUS2012
# 803    TUS2013
# 804    TUS2014
# Name: airport_year, dtype: object

# %%
ops.head()
# Out:
#   airport  year  departures for metric computation  \
# 0     ABQ  2004                              53971
# 1     ABQ  2005                              51829
# 2     ABQ  2006                              49682
# 3     ABQ  2007                              53255
# 4     ABQ  2008                              49589
#
#    arrivals for metric computation  percent on-time gate departures  \
# 0                            53818                           0.8030
# 1                            51877                           0.8140
# 2                            51199                           0.7983
# 3                            53611                           0.8005
# 4                            49512                           0.8103
#
#    percent on-time airport departures  percent on-time gate arrivals  \
# 0                              0.7809                         0.7921
# 1                              0.7922                         0.8001
# 2                              0.7756                         0.7746
# 3                              0.7704                         0.7647
# 4                              0.7844                         0.7875
#
#    average_gate_departure_delay  average_taxi_out_time  \
# 0                         10.38                   9.89
# 1                          9.60                   9.79
# 2                         10.84                   9.89
# 3                         11.29                  10.34
# 4                         10.79                  10.41
#
#    average taxi out delay  average airport departure delay  \
# 0                    2.43                            12.10
# 1                    2.29                            11.20
# 2                    2.16                            12.33
# 3                    2.40                            12.95
# 4                    2.41                            12.32
#
#    average airborne delay  average taxi in delay  average block delay  \
# 0                    2.46                   0.83                 2.55
# 1                    2.26                   0.89                 2.34
# 2                    2.12                   0.84                 2.66
# 3                    2.19                   1.29                 3.06
# 4                    1.82                   1.03                 2.79
#
#    average gate arrival delay str_year airport_year
# 0                       10.87     2004      ABQ2004
# 1                       10.24     2005      ABQ2005
# 2                       11.82     2006      ABQ2006
# 3                       12.71     2007      ABQ2007
# 4                       11.48     2008      ABQ2008

# %%
df = pd.merge(ops, cancelations, how='left', on='airport_year')
df = pd.merge(df, airports,how='left', left_on='airport', right_on='LocID')
df.head()

df.drop(['str_year_x', 'str_year_y', 'Airport', 'Year', 'airport_year'], axis=1, inplace=1)

num_port = {}
for i,v in enumerate(set(df['airport'])):
    num_port[v] = i

df['airport_num'] = df['airport'].apply(lambda x: num_port[x])
# df['airport_num'].value_counts() #58 and 73 don't have 11
# df[df['airport_num']==58] #no 2004-2007 data for these airports. 
# df[df['airport_num']==73]

# %%
df.head()
# Out:
#   airport  year  departures for metric computation  \
# 0     ABQ  2004                              53971
# 1     ABQ  2005                              51829
# 2     ABQ  2006                              49682
# 3     ABQ  2007                              53255
# 4     ABQ  2008                              49589
#
#    arrivals for metric computation  percent on-time gate departures  \
# 0                            53818                           0.8030
# 1                            51877                           0.8140
# 2                            51199                           0.7983
# 3                            53611                           0.8005
# 4                            49512                           0.8103
#
#    percent on-time airport departures  percent on-time gate arrivals  \
# 0                              0.7809                         0.7921
# 1                              0.7922                         0.8001
# 2                              0.7756                         0.7746
# 3                              0.7704                         0.7647
# 4                              0.7844                         0.7875
#
#    average_gate_departure_delay  average_taxi_out_time  \
# 0                         10.38                   9.89
# 1                          9.60                   9.79
# 2                         10.84                   9.89
# 3                         11.29                  10.34
# 4                         10.79                  10.41
#
#    average taxi out delay     ...       Facility Type  FAA REGION      COUNTY  \
# 0                    2.43     ...             Airport         ASW  BERNALILLO
# 1                    2.29     ...             Airport         ASW  BERNALILLO
# 2                    2.16     ...             Airport         ASW  BERNALILLO
# 3                    2.40     ...             Airport         ASW  BERNALILLO
# 4                    2.41     ...             Airport         ASW  BERNALILLO
#
#           CITY  STATE                 AP Type   Latitude   Longitude  \
# 0  ALBUQUERQUE     NM  Federalized/Commercial  35.040194 -106.609194
# 1  ALBUQUERQUE     NM  Federalized/Commercial  35.040194 -106.609194
# 2  ALBUQUERQUE     NM  Federalized/Commercial  35.040194 -106.609194
# 3  ALBUQUERQUE     NM  Federalized/Commercial  35.040194 -106.609194
# 4  ALBUQUERQUE     NM  Federalized/Commercial  35.040194 -106.609194
#
#    Boundary Data Available  airport_num
# 0                      Yes           44
# 1                      Yes           44
# 2                      Yes           44
# 3                      Yes           44
# 4                      Yes           44
#
# [5 rows x 33 columns]

# %%
df.isnull().sum() #last 4 from cancelations have nulls
# Out:
# airport                                0
# year                                   0
# departures for metric computation      0
# arrivals for metric computation        0
# percent on-time gate departures        0
# percent on-time airport departures     0
# percent on-time gate arrivals          0
# average_gate_departure_delay           0
# average_taxi_out_time                  0
# average taxi out delay                 0
# average airport departure delay        0
# average airborne delay                 0
# average taxi in delay                  0
# average block delay                    0
# average gate arrival delay             0
# Departure Cancellations               42
# Arrival Cancellations                 42
# Departure Diversions                  42
# Arrival Diversions                    42
# Key                                    0
# LocID                                  0
# AP_NAME                                0
# ALIAS                                  0
# Facility Type                          0
# FAA REGION                             0
# COUNTY                                 0
# CITY                                   0
# STATE                                  0
# AP Type                                0
# Latitude                               0
# Longitude                              0
# Boundary Data Available                0
# airport_num                            0
# dtype: int64

# %%
# df[df.isnull().any(axis=1)] #prints the nan rows
df['airport'][df.isnull().any(axis=1)].unique() #prints the names of the airports I'm dropping
#gary near chicago in IN, ventura california, rockford in chicago, TEB in NJ, VNY in LA, CA. Doesn't seem like I'm losing a ton by dropping these

df.dropna(axis=0, how='any', inplace=1)
len(df)
# Out:
# 799

# %%
import seaborn as sns

df['diff_gate_airport_departures'] = df['percent on-time gate departures'] - df['percent on-time airport departures']
df['diff_gate_airport_departures']

sns.distplot(df['percent on-time gate departures'], color="blue")
sns.distplot(df['percent on-time airport departures'], color="green")
sns.distplot(df['percent on-time gate arrivals'], color="red")
sns.distplot(df['diff_gate_airport_departures'], color="purple")

# %%
# df['Departure Cancellations'].value_counts()

# %% [markdown]
# ### Intro: Write a problem statement / aim for this project

# %% [markdown]
# ### Part 1: Create a PostgreSQL database

# %% [markdown]
# #### 1. Let's create a database where we can house our airport data

# %%
#Will return to this later in week
from sqlalchemy import create_engine
from sqlalchemy.engine.url import URL
import psycopg2


# %load_ext sql

# df1 = df

# df1.columns = [c.lower().replace(' ','') for c in df1.columns] #postgres doesn't like capitals or spaces

# engine = create_engine('postgresql://localhost:5432')
# df1.to_sql('airport_ops', engine)

# %% [markdown]
# Load our csv files into tables

# %% [markdown]
# Join airport_cancellations.csv and airports.csv into one table

# %%
#done above

# %% [markdown]
# Query the database for our intial data

# %%
# %%sql postgresql://localhost:5432/
#
# SELECT * FROM airport_ops;
# Out:
# ERROR: Cell magic `%%sql` not found.

# %% [markdown]
# #### 1.2 What are the risks and assumptions of our data?

# %% [markdown]
# ### Part 2: Exploratory Data Analysis

# %% [markdown]
# #### 2.1 Plot and Describe the Data

# %%
df.columns
# Out:
# Index([u'airport', u'year', u'departures for metric computation',
#        u'arrivals for metric computation', u'percent on-time gate departures',
#        u'percent on-time airport departures', u'percent on-time gate arrivals',
#        u'average_gate_departure_delay', u'average_taxi_out_time',
#        u'average taxi out delay', u'average airport departure delay',
#        u'average airborne delay', u'average taxi in delay',
#        u'average block delay', u'average gate arrival delay',
#        u'Departure Cancellations', u'Arrival Cancellations',
#        u'Departure Diversions', u'Arrival Diversions', u'Key', u'LocID',
#        u'AP_NAME', u'ALIAS', u'Facility Type', u'FAA REGION', u'COUNTY',
#        u'CITY', u'STATE', u'AP Type', u'Latitude', u'Longitude',
#        u'Boundary Data Available', u'airport_num',
#        u'diff_gate_airport_departures'],
#       dtype='object')

# %%
# df.describe().columns#


# orig_index(['year', 'departures for metric computation',
#        'arrivals for metric computation', 'percent on-time gate departures',
#        'percent on-time airport departures', 'percent on-time gate arrivals',
#        'average_gate_departure_delay', 'average_taxi_out_time',
#        'average taxi out delay', 'average airport departure delay',
#        'average airborne delay', 'average taxi in delay',
#        'average block delay', 'average gate arrival delay',
#        'Departure Cancellations', 'Arrival Cancellations',
#        'Departure Diversions', 'Arrival Diversions', 'Key', 'Latitude',
#        'Longitude', 'airport_num', 'diff_gate_airport_departures'],
#       dtype='object')

# %%
decade_agg_ap = pd.pivot_table(df, index='airport')
grouped_years = pd.pivot_table(df, index='year')

# %%
import seaborn as sns

# sns.pairplot(decade_agg_ap.describe().iloc[:,10:-1])

# %%
# sns.pairplot(grouped_years.describe().iloc[:,10:-1])

# %%
sns.pairplot(df.describe().iloc[:,4:12])

# %% [markdown]
# #### Are there any unique values?

# %%
grouped_years['Year'] = grouped_years.index
grouped_years
# Out:
#       Arrival Cancellations  Arrival Diversions  Departure Cancellations  \
# year
# 2004            1487.070423          160.887324              1439.000000
# 2005            1546.422535          164.169014              1501.323944
# 2006            1384.486111          193.097222              1344.069444
# 2007            1781.567568          196.918919              1732.513514
# 2008            1542.216216          195.851351              1495.324324
# 2009            1011.739726          170.835616               969.205479
# 2010            1292.123288          170.287671              1247.931507
# 2011            1328.150685          161.342466              1293.068493
# 2012             906.575342          137.575342               878.356164
# 2013            1059.931507          157.479452              1021.369863
# 2014            1413.902778          163.458333              1372.652778
#
#       Departure Diversions          Key   Latitude  Longitude  airport_num  \
# year
# 2004            160.676056  1735.281690  36.396961 -94.574346    37.633803
# 2005            166.140845  1735.281690  36.396961 -94.574346    37.633803
# 2006            186.819444  1727.361111  36.477495 -94.498275    37.777778
# 2007            190.891892  1697.729730  36.471686 -95.161801    38.527027
# 2008            196.594595  1697.729730  36.471686 -95.161801    38.527027
# 2009            180.054795  1705.027397  36.393279 -95.244877    38.397260
# 2010            179.849315  1705.027397  36.393279 -95.244877    38.397260
# 2011            171.013699  1712.534247  36.502794 -94.832411    38.479452
# 2012            147.904110  1712.534247  36.502794 -94.832411    38.479452
# 2013            164.698630  1712.534247  36.502794 -94.832411    38.479452
# 2014            171.111111  1720.138889  36.423730 -94.912067    38.347222
#
#       arrivals for metric computation  average airborne delay  ...   \
# year                                                           ...
# 2004                    118353.070423                3.390986  ...
# 2005                    126686.000000                3.322394  ...
# 2006                    121796.638889                3.242500  ...
# 2007                    120772.243243                3.346486  ...
# 2008                    115291.175676                3.144595  ...
# 2009                    108056.849315                2.884658  ...
# 2010                    107772.767123                2.734384  ...
# 2011                    107818.452055                2.580137  ...
# 2012                    106035.589041                2.242877  ...
# 2013                    105086.273973                2.218767  ...
# 2014                    105779.638889                2.539722  ...
#
#       average taxi in delay  average taxi out delay  \
# year
# 2004               1.253803                4.015915
# 2005               1.516197                4.023662
# 2006               1.458333                4.166389
# 2007               1.657838                4.469730
# 2008               1.461216                4.015270
# 2009               1.379452                3.606301
# 2010               1.407260                3.393562
# 2011               1.291918                3.153836
# 2012               1.325068                3.009315
# 2013               1.382740                3.463699
# 2014               1.416944                3.201667
#
#       average_gate_departure_delay  average_taxi_out_time  \
# year
# 2004                     11.955493              13.886197
# 2005                     12.728732              13.810563
# 2006                     13.125833              14.144444
# 2007                     14.282297              14.573108
# 2008                     13.453243              14.359730
# 2009                     11.664384              13.968767
# 2010                     12.170685              13.668767
# 2011                     12.714658              13.477397
# 2012                     11.884932              13.302877
# 2013                     13.333425              13.752192
# 2014                     14.446806              13.640556
#
#       departures for metric computation  diff_gate_airport_departures  \
# year
# 2004                      118986.211268                      0.053428
# 2005                      127418.563380                      0.053628
# 2006                      122675.000000                      0.057726
# 2007                      121056.864865                      0.066832
# 2008                      115622.216216                      0.057545
# 2009                      108484.246575                      0.051338
# 2010                      108230.835616                      0.049179
# 2011                      108212.575342                      0.043723
# 2012                      106332.890411                      0.041678
# 2013                      105445.739726                      0.050770
# 2014                      106147.680556                      0.047785
#
#       percent on-time airport departures  percent on-time gate arrivals  \
# year
# 2004                            0.733166                       0.768585
# 2005                            0.718992                       0.758573
# 2006                            0.710628                       0.748257
# 2007                            0.691212                       0.731392
# 2008                            0.719423                       0.755453
# 2009                            0.751647                       0.789962
# 2010                            0.742793                       0.784225
# 2011                            0.743247                       0.780868
# 2012                            0.756963                       0.797562
# 2013                            0.721893                       0.767186
# 2014                            0.706613                       0.753465
#
#       percent on-time gate departures  Year
# year
# 2004                         0.786594  2004
# 2005                         0.772620  2005
# 2006                         0.768354  2006
# 2007                         0.758045  2007
# 2008                         0.776968  2008
# 2009                         0.802985  2009
# 2010                         0.791973  2010
# 2011                         0.786970  2011
# 2012                         0.798641  2012
# 2013                         0.772663  2013
# 2014                         0.754397  2014
#
# [11 rows x 23 columns]

# %% [markdown]
# ### Part 3: Data Mining

# %% [markdown]
# #### 3.1 Create Dummy Variables

# %%
#Goal analysis:
#1: df - airport-years, find patterns
#2: decade_agg_ap - by airport over entire decade
#3: grouped_years - by year to see trends over time

# %% [markdown]
# #### 3.2 Format and Clean the Data

# %% [markdown]
# ### Part 4: Define the Data

# %% [markdown]
# #### 4.1 Confirm that the dataset has a normal distribution. How can you tell?

# %%
sns.distplot(df['percent on-time gate arrivals'], color='blue')
sns.distplot(df.iloc[:,4], color= 'orange')

# %%
# sns.distplot(df.iloc[:,4])

# %%
sns.distplot(df.iloc[:,7], color='red')
sns.distplot(df.iloc[:,8], color='green')

# %%
sns.distplot(df.iloc[:,8])

# %% [markdown]
# #### 4.2 Find correlations in the data

# %%
# variables for analysis:
#1: df - airport-years, find patterns
#2: decade_agg_ap - by airport over entire decade
#3: grouped_years

# %%
sns.distplot(decade_agg_ap['percent on-time gate arrivals'])

# %%
sns.regplot(grouped_years['Year'], grouped_years['percent on-time gate arrivals'])
#slightly positive trend in terms of ontime gate arrivals

# %%
sns.regplot(grouped_years['Year'], grouped_years.iloc[:,8])
#slight decrease in aavg. arrival delay

# %%
sns.regplot(grouped_years['Year'], grouped_years.iloc[:,11])
#slight decrease in aavg. arrival delay

# %%
import matplotlib as plt

decade_agg_ap['airport'] = decade_agg_ap.index
# decade_agg_ap
plt.style.use('fivethirtyeight')

# fig, ax = plt.subplots(figsize=(16,16))
decade_agg_ap.sort_values(by=['percent on-time gate departures'],axis=0, inplace=1)


# sns.barplot(decade_agg_ap['percent on-time gate arrivals'],decade_agg_ap['airport'], hue=decade_agg_ap['Arrival Cancellations'])
sns.barplot(decade_agg_ap['percent on-time gate departures'],decade_agg_ap['airport'],)
fig = plt.pyplot.gcf()
fig.set_size_inches(20, 16)
fig.savefig('test2png.png', dpi=100)

# %%
decade_agg_ap.head()
# Out:
#          Arrival Cancellations  Arrival Diversions  Departure Cancellations  \
# airport
# HPN                 284.454545           76.090909               331.454545
# SDF                 284.000000           27.000000               323.181818
# PBI                 304.272727           45.272727               322.090909
# HOU                 967.000000          184.818182               975.000000
# MDW                1115.000000          362.363636              1148.000000
#
#          Departure Diversions   Key   Latitude  Longitude  airport_num  \
# airport
# HPN                 27.454545  2502  41.066944 -73.707556           47
# SDF                 46.727273  1437  38.174086 -85.736499           67
# PBI                 90.909091   843  26.683167 -80.095583           53
# HOU                116.909091  3341  29.645419 -95.278889           46
# MDW                171.909091  1163  41.785972 -87.752417           65
#
#          arrivals for metric computation  average airborne delay   ...     \
# airport                                                            ...
# HPN                         31924.090909                3.964545   ...
# SDF                         68087.181818                3.060000   ...
# PBI                         39139.090909                2.418182   ...
# HOU                         63293.454545                3.277273   ...
# MDW                        108581.545455                3.883636   ...
#
#          average taxi out delay  average_gate_departure_delay  \
# airport
# HPN                    3.388182                     21.885455
# SDF                    2.612727                     14.926364
# PBI                    2.568182                     16.015455
# HOU                    2.119091                     15.410000
# MDW                    3.616364                     15.556364
#
#          average_taxi_out_time  departures for metric computation  \
# airport
# HPN                  13.815455                       31627.272727
# SDF                  12.387273                       68559.181818
# PBI                  12.881818                       40257.818182
# HOU                   9.195455                       63264.363636
# MDW                  11.877273                      108642.000000
#
#          diff_gate_airport_departures  percent on-time airport departures  \
# airport
# HPN                          0.042545                            0.540991
# SDF                          0.042436                            0.655100
# PBI                          0.028973                            0.671573
# HOU                          0.024145                            0.680509
# MDW                          0.053700                            0.655382
#
#          percent on-time gate arrivals  percent on-time gate departures  year  \
# airport
# HPN                           0.583164                         0.583536  2009
# SDF                           0.720500                         0.697536  2009
# PBI                           0.678582                         0.700545  2009
# HOU                           0.759064                         0.704655  2009
# MDW                           0.770682                         0.709082  2009
#
#          airport
# airport
# HPN          HPN
# SDF          SDF
# PBI          PBI
# HOU          HOU
# MDW          MDW
#
# [5 rows x 24 columns]

# %%
decade_agg_ap_short = decade_agg_ap[-20:] #df['20130102':'20130104']
decade_agg_ap_short.head(25)
# Out:
#          Arrival Cancellations  Arrival Diversions  Departure Cancellations  \
# airport
# IAH                2501.181818          778.363636              2289.454545
# MCI                 658.454545          118.636364               735.636364
# MSP                1909.818182          263.636364              1729.090909
# SJU                 211.090909           43.000000               247.727273
# BDL                 455.363636           37.181818               509.363636
# DCA                2349.909091          211.000000              2468.363636
# TPA                 583.090909          138.727273               638.272727
# CVG                2300.181818          136.454545              1922.000000
# RSW                 229.181818           57.181818               257.272727
# SAN                 865.181818          233.363636              1008.363636
# CLE                1060.090909          102.454545              1063.000000
# SMF                 449.750000           40.125000               489.250000
# TUS                 143.090909           28.090909               168.818182
# PDX                 454.090909           65.545455               441.818182
# SEA                 824.181818          155.454545               770.636364
# SLC                1324.090909          145.909091               993.363636
# LGB                  94.545455           51.545455               100.818182
# OXR                  24.571429            0.142857                29.285714
# HNL                 305.909091           57.727273               308.636364
# OGG                 125.818182           24.636364               156.090909
#
#          Departure Diversions   Key   Latitude   Longitude  airport_num  \
# airport
# IAH                495.636364  3185  29.984444  -95.341444           36
# MCI                121.181818  1892  39.297605  -94.713906           60
# MSP                289.909091  1791  44.881972  -93.221778            9
# SJU                 69.909091  2885  18.439295  -66.002004           43
# BDL                 66.545455   755  41.939145  -72.683371           40
# DCA                164.363636   769  38.851916  -77.037699           23
# TPA                176.636364   864  27.975472  -82.533250           71
# CVG                179.272727  1418  39.048837  -84.667822           13
# RSW                 73.272727   857  26.536167  -81.755167           75
# SAN                155.909091   650  32.733556 -117.189667           18
# CLE                143.272727  2527  41.409417  -81.854694           27
# SMF                 83.250000   644  38.695444 -121.590778           58
# TUS                 50.090909   474  32.116083 -110.941028            2
# PDX                102.181818  2775  45.588709 -122.596869           38
# SEA                235.909091  3520  47.449889 -122.311778           24
# SLC                351.818182  3377  40.788388 -111.977773           55
# LGB                 26.727273   582  33.817754 -118.151733           62
# OXR                  0.571429   617  34.200806 -119.207222           42
# HNL                 46.272727   975  21.318681 -157.922429            8
# OGG                 26.272727   976  20.898650 -156.430458           74
#
#          arrivals for metric computation  average airborne delay   ...     \
# airport                                                            ...
# IAH                        261806.636364                2.902727   ...
# MCI                         74033.909091                2.551818   ...
# MSP                        216655.272727                4.205455   ...
# SJU                         47202.909091                1.613636   ...
# BDL                         45482.000000                2.860909   ...
# DCA                        137316.363636                3.709091   ...
# TPA                         92243.000000                1.890000   ...
# CVG                        128746.727273                3.117273   ...
# RSW                         34532.727273                2.260909   ...
# SAN                         94611.909091                2.381818   ...
# CLE                         99315.090909                3.125455   ...
# SMF                         53313.375000                1.990000   ...
# TUS                         24825.545455                1.890000   ...
# PDX                        101588.000000                2.282727   ...
# SEA                        161423.181818                3.350909   ...
# SLC                        151255.818182                3.167273   ...
# LGB                         15139.636364                2.146364   ...
# OXR                          1696.142857                1.507143   ...
# HNL                         92935.545455                2.183636   ...
# OGG                         29570.363636                2.122727   ...
#
#          average taxi out delay  average_gate_departure_delay  \
# airport
# IAH                    5.839091                     11.768182
# MCI                    2.524545                     11.907273
# MSP                    5.154545                     11.031818
# SJU                    2.297273                     11.699091
# BDL                    3.106364                     11.766364
# DCA                    4.722727                     12.090909
# TPA                    2.635455                     11.470909
# CVG                    3.467273                     11.438182
# RSW                    2.365455                     11.667273
# SAN                    3.529091                     10.310000
# CLE                    3.721818                     11.634545
# SMF                    2.022500                     10.212500
# TUS                    2.370000                     10.241818
# PDX                    2.007273                      9.434545
# SEA                    3.176364                      9.290000
# SLC                    5.184545                      8.915455
# LGB                    2.405455                      9.276364
# OXR                    2.041429                      6.238571
# HNL                    1.842727                      8.035455
# OGG                    1.236364                      7.066364
#
#          average_taxi_out_time  departures for metric computation  \
# airport
# IAH                  18.168182                      262574.454545
# MCI                  11.370909                       73786.818182
# MSP                  17.403636                      217164.272727
# SJU                  13.848182                       48738.000000
# BDL                  13.052727                       45903.090909
# DCA                  15.682727                      137145.181818
# TPA                  12.034545                       92314.636364
# CVG                  14.961818                      128916.636364
# RSW                  12.425455                       34521.545455
# SAN                  13.279091                       94522.181818
# CLE                  14.329091                       99621.454545
# SMF                  10.361250                       53184.875000
# TUS                  10.786364                       24757.181818
# PDX                  11.001818                      101724.727273
# SEA                  14.515455                      161461.272727
# SLC                  17.539091                      155351.181818
# LGB                  13.370000                       14980.545455
# OXR                   9.072857                        1734.857143
# HNL                  12.859091                       91753.363636
# OGG                   8.190000                       30094.454545
#
#          diff_gate_airport_departures  percent on-time airport departures  \
# airport
# IAH                          0.100591                            0.703855
# MCI                          0.026600                            0.778018
# MSP                          0.085064                            0.720027
# SJU                          0.028227                            0.778364
# BDL                          0.041945                            0.765327
# DCA                          0.070718                            0.737127
# TPA                          0.027400                            0.780527
# CVG                          0.050618                            0.757318
# RSW                          0.024255                            0.787027
# SAN                          0.040682                            0.774464
# CLE                          0.050345                            0.766745
# SMF                          0.021512                            0.798175
# TUS                          0.024036                            0.797364
# PDX                          0.019609                            0.808109
# SEA                          0.040255                            0.796391
# SLC                          0.080145                            0.757336
# LGB                          0.020491                            0.821027
# OXR                          0.016429                            0.855229
# HNL                          0.016536                            0.859873
# OGG                          0.007073                            0.881027
#
#          percent on-time gate arrivals  percent on-time gate departures  \
# airport
# IAH                           0.793264                         0.804445
# MCI                           0.769364                         0.804618
# MSP                           0.804673                         0.805091
# SJU                           0.778173                         0.806591
# BDL                           0.761436                         0.807273
# DCA                           0.812000                         0.807845
# TPA                           0.782609                         0.807927
# CVG                           0.813627                         0.807936
# RSW                           0.765136                         0.811282
# SAN                           0.785136                         0.815145
# CLE                           0.788145                         0.817091
# SMF                           0.793025                         0.819688
# TUS                           0.761673                         0.821400
# PDX                           0.814727                         0.827718
# SEA                           0.810909                         0.836645
# SLC                           0.825409                         0.837482
# LGB                           0.807164                         0.841518
# OXR                           0.833457                         0.871657
# HNL                           0.849836                         0.876409
# OGG                           0.864709                         0.888100
#
#            year  airport
# airport
# IAH      2009.0      IAH
# MCI      2009.0      MCI
# MSP      2009.0      MSP
# SJU      2009.0      SJU
# BDL      2009.0      BDL
# DCA      2009.0      DCA
# TPA      2009.0      TPA
# CVG      2009.0      CVG
# RSW      2009.0      RSW
# SAN      2009.0      SAN
# CLE      2009.0      CLE
# SMF      2010.5      SMF
# TUS      2009.0      TUS
# PDX      2009.0      PDX
# SEA      2009.0      SEA
# SLC      2009.0      SLC
# LGB      2009.0      LGB
# OXR      2007.0      OXR
# HNL      2009.0      HNL
# OGG      2009.0      OGG
#
# [20 rows x 24 columns]

# %%
# sns.barplot(decade_agg_ap['percent on-time gate arrivals'],decade_agg_ap['airport'], hue=decade_agg_ap['Arrival Cancellations'])
sns.axes_style()
sns.set_context("notebook", font_scale=2, rc={"lines.linewidth": 4})

ax = sns.barplot(data=decade_agg_ap_short, y='percent on-time airport departures', x='airport',hue='average_gate_departure_delay', palette='plasma', orient='v')
ax.legend_.remove()

fig = plt.pyplot.gcf()
fig.set_size_inches(16, 14)
# ax.legend_.remove()

# plt.xlim([0.7,1.0])
fig.savefig('most_delayed.png', dpi=100)

# %% [markdown]
# create buckets for departures (or use previously counted values)

# %%
# # sns.barplot(decade_agg_ap['percent on-time gate arrivals'],decade_agg_ap['airport'], hue=decade_agg_ap['Arrival Cancellations'])
# sns.barplot(data=decade_agg_ap_short, y='percenton-timegatedepartures', x='airport', hue='percenton-timegatearrivals', palette='plasma')
# fig = plt.pyplot.gcf()
# fig.set_size_inches(16, 12)
# # plt.xlim([0.7,1.0])
# fig.savefig('most_delayed.png', dpi=100)

# %% [markdown]
# #### 4.3 What is the value of understanding correlations before PCA?

# %% [markdown]
# Answer: When reducing the dimensionality of the underlying dataset, we lose relative feature importance and, therefore, interpretability. Additionally, although it is a matter of preference and is specific to the methodology of a given context, by including variables that are highly correlated with one another, we may be over-emphasizing the dimension of the shared "underlying factor" that is influencing multiple features (in contrast, this may also provide precision, depending on the context of the problem.

# %% [markdown]
# #### 4.4 Validate your findings using statistical analysis

# %%
df.head()
# Out:
#   airport  year  departures for metric computation  \
# 0     ABQ  2004                              53971
# 1     ABQ  2005                              51829
# 2     ABQ  2006                              49682
# 3     ABQ  2007                              53255
# 4     ABQ  2008                              49589
#
#    arrivals for metric computation  percent on-time gate departures  \
# 0                            53818                           0.8030
# 1                            51877                           0.8140
# 2                            51199                           0.7983
# 3                            53611                           0.8005
# 4                            49512                           0.8103
#
#    percent on-time airport departures  percent on-time gate arrivals  \
# 0                              0.7809                         0.7921
# 1                              0.7922                         0.8001
# 2                              0.7756                         0.7746
# 3                              0.7704                         0.7647
# 4                              0.7844                         0.7875
#
#    average_gate_departure_delay  average_taxi_out_time  \
# 0                         10.38                   9.89
# 1                          9.60                   9.79
# 2                         10.84                   9.89
# 3                         11.29                  10.34
# 4                         10.79                  10.41
#
#    average taxi out delay              ...               FAA REGION  \
# 0                    2.43              ...                      ASW
# 1                    2.29              ...                      ASW
# 2                    2.16              ...                      ASW
# 3                    2.40              ...                      ASW
# 4                    2.41              ...                      ASW
#
#        COUNTY         CITY  STATE                 AP Type   Latitude  \
# 0  BERNALILLO  ALBUQUERQUE     NM  Federalized/Commercial  35.040194
# 1  BERNALILLO  ALBUQUERQUE     NM  Federalized/Commercial  35.040194
# 2  BERNALILLO  ALBUQUERQUE     NM  Federalized/Commercial  35.040194
# 3  BERNALILLO  ALBUQUERQUE     NM  Federalized/Commercial  35.040194
# 4  BERNALILLO  ALBUQUERQUE     NM  Federalized/Commercial  35.040194
#
#     Longitude  Boundary Data Available  airport_num  \
# 0 -106.609194                      Yes           44
# 1 -106.609194                      Yes           44
# 2 -106.609194                      Yes           44
# 3 -106.609194                      Yes           44
# 4 -106.609194                      Yes           44
#
#    diff_gate_airport_departures
# 0                        0.0221
# 1                        0.0218
# 2                        0.0227
# 3                        0.0301
# 4                        0.0259
#
# [5 rows x 34 columns]

# %%
df['delay_score'] = ((1-df['percent on-time airport departures'])-df['percent on-time gate arrivals'])*(df['average airport departure delay']-df['average gate arrival delay'])

# %%
df['net_lateness_percent'] = ((1-df['percent on-time airport departures'])-(1-df['percent on-time gate arrivals']))

# %%
df['avg_delay_late_control'] = (df['average airport departure delay']+df['average airborne delay']+df['average taxi out delay']-df['average gate arrival delay'])

# %%
df['avg_delay_late_control']
# Out:
# 0       6.12
# 1       5.51
# 2       4.79
# 3       4.83
# 4       5.07
# 5       4.81
# 6       5.06
# 7       6.03
# 8       6.11
# 9       5.76
# 10      5.41
# 11      7.38
# 12      7.05
# 13      6.19
# 14      6.85
# 15      5.82
# 16      5.33
# 17      4.09
# 18      7.25
# 19      7.05
# 20      6.54
# 21      6.94
# 22     19.78
# 23     16.07
# 24     21.24
# 25     20.25
# 26     19.00
# 27     17.98
# 28     17.01
# 29     15.62
#        ...
# 789     6.04
# 790     5.23
# 791     5.69
# 792     2.37
# 793     1.85
# 794     1.59
# 795     3.05
# 796     3.58
# 808     4.86
# 809     6.62
# 810     6.18
# 811     5.20
# 812     4.76
# 813     4.80
# 814     6.45
# 815     4.76
# 816     4.30
# 817     4.72
# 818     5.73
# 819     5.02
# 820     4.60
# 821     3.30
# 822     3.55
# 823     2.47
# 824     2.97
# 825     1.99
# 826     2.45
# 827     2.99
# 828     3.30
# 829     2.58
# Name: avg_delay_late_control, dtype: float64

# %%
df['net_cancelations']= df['Departure Cancellations'] - df['Arrival Cancellations']
df['net_diversions']= df['Departure Diversions'] - df['Arrival Diversions']

# %%
sns.distplot(df['delay_score'])

# %% [markdown]
# Based on the above plot (where the more positive, the better performance) it appears that delays

# %% [markdown]
# #### 4.5 How can you improve your overall analysis?

# %% [markdown]
# Answer:

# %% [markdown]
# ### Part 5: Perform a PCA

# %% [markdown]
# #### 5.1 Conduct the PCA

# %%
df['delay_score']

df['samples'] = ((df['departures for metric computation'] + df['arrivals for metric computation'])/2)
sns.distplot(df['samples'])

# %%
df[df['samples']>100] # all these super low samples are commercial, let's leave them in and hope we differentiate
#also, its clear that AP type is really important - let's make dummies for those
# Out:
#     airport  year  departures for metric computation  \
# 0       ABQ  2004                              53971
# 1       ABQ  2005                              51829
# 2       ABQ  2006                              49682
# 3       ABQ  2007                              53255
# 4       ABQ  2008                              49589
# 5       ABQ  2009                              42550
# 6       ABQ  2010                              42302
# 7       ABQ  2011                              42283
# 8       ABQ  2012                              39105
# 9       ABQ  2013                              35277
# 10      ABQ  2014                              33292
# 11      ANC  2004                              16503
# 12      ANC  2005                              72043
# 13      ANC  2006                              75708
# 14      ANC  2007                              78741
# 15      ANC  2008                              76606
# 16      ANC  2009                              67252
# 17      ANC  2010                              73089
# 18      ANC  2011                              72556
# 19      ANC  2012                              70322
# 20      ANC  2013                              69984
# 21      ANC  2014                              71099
# 22      ATL  2004                             477323
# 23      ATL  2005                             484570
# 24      ATL  2006                             483334
# 25      ATL  2007                             491826
# 26      ATL  2008                             482903
# 27      ATL  2009                             479957
# 28      ATL  2010                             469542
# 29      ATL  2011                             454954
# ..      ...   ...                                ...
# 789     SWF  2007                               9634
# 790     SWF  2008                               8096
# 791     SWF  2009                               5068
# 792     SWF  2010                               4840
# 793     SWF  2011                               5546
# 794     SWF  2012                               5546
# 795     SWF  2013                               4935
# 796     SWF  2014                               4863
# 808     TPA  2004                             100556
# 809     TPA  2005                             111899
# 810     TPA  2006                             106426
# 811     TPA  2007                             107523
# 812     TPA  2008                             100289
# 813     TPA  2009                              83888
# 814     TPA  2010                              82346
# 815     TPA  2011                              81837
# 816     TPA  2012                              80605
# 817     TPA  2013                              80603
# 818     TPA  2014                              79489
# 819     TUS  2004                               7498
# 820     TUS  2005                              29803
# 821     TUS  2006                              29332
# 822     TUS  2007                              32136
# 823     TUS  2008                              30267
# 824     TUS  2009                              24475
# 825     TUS  2010                              24995
# 826     TUS  2011                              25149
# 827     TUS  2012                              23583
# 828     TUS  2013                              22502
# 829     TUS  2014                              22589
#
#      arrivals for metric computation  percent on-time gate departures  \
# 0                              53818                           0.8030
# 1                              51877                           0.8140
# 2                              51199                           0.7983
# 3                              53611                           0.8005
# 4                              49512                           0.8103
# 5                              42704                           0.8341
# 6                              42169                           0.8144
# 7                              42297                           0.8072
# 8                              39107                           0.8219
# 9                              34989                           0.7710
# 10                             33137                           0.7451
# 11                             15511                           0.7109
# 12                             67034                           0.7394
# 13                             69995                           0.7771
# 14                             73323                           0.7838
# 15                             72479                           0.7972
# 16                             63135                           0.8112
# 17                             68125                           0.7992
# 18                             66845                           0.8276
# 19                             66453                           0.8442
# 20                             65469                           0.8432
# 21                             66704                           0.8288
# 22                            473249                           0.7596
# 23                            480171                           0.7413
# 24                            478735                           0.7150
# 25                            486799                           0.7167
# 26                            478627                           0.7696
# 27                            475882                           0.7775
# 28                            465911                           0.7961
# 29                            453734                           0.8008
# ..                               ...                              ...
# 789                             9418                           0.7162
# 790                             7907                           0.7456
# 791                             4975                           0.7129
# 792                             4819                           0.7519
# 793                             5444                           0.7034
# 794                             5474                           0.7495
# 795                             4873                           0.7400
# 796                             4871                           0.7027
# 808                           100312                           0.8245
# 809                           111953                           0.7996
# 810                           106040                           0.8129
# 811                           107579                           0.7903
# 812                           100528                           0.7983
# 813                            84140                           0.8154
# 814                            82582                           0.8121
# 815                            81897                           0.8296
# 816                            80523                           0.8322
# 817                            79946                           0.7997
# 818                            79173                           0.7726
# 819                             7501                           0.7757
# 820                            29761                           0.7868
# 821                            30490                           0.8098
# 822                            32102                           0.8152
# 823                            30337                           0.8354
# 824                            24528                           0.8507
# 825                            25088                           0.8502
# 826                            25165                           0.8458
# 827                            23679                           0.8599
# 828                            22090                           0.8145
# 829                            22340                           0.7914
#
#      percent on-time airport departures  percent on-time gate arrivals  \
# 0                                0.7809                         0.7921
# 1                                0.7922                         0.8001
# 2                                0.7756                         0.7746
# 3                                0.7704                         0.7647
# 4                                0.7844                         0.7875
# 5                                0.8147                         0.8224
# 6                                0.7907                         0.8047
# 7                                0.7758                         0.8022
# 8                                0.7940                         0.8177
# 9                                0.7402                         0.7554
# 10                               0.7148                         0.7320
# 11                               0.6770                         0.6502
# 12                               0.7061                         0.6955
# 13                               0.7455                         0.7110
# 14                               0.7457                         0.7196
# 15                               0.7698                         0.7573
# 16                               0.7952                         0.8264
# 17                               0.7760                         0.8045
# 18                               0.8050                         0.8292
# 19                               0.8235                         0.8521
# 20                               0.8228                         0.8631
# 21                               0.8074                         0.8600
# 22                               0.5757                         0.7370
# 23                               0.6216                         0.7337
# 24                               0.5324                         0.7205
# 25                               0.5713                         0.7446
# 26                               0.6071                         0.7559
# 27                               0.5900                         0.7335
# 28                               0.6405                         0.7956
# 29                               0.6730                         0.8068
# ..                                  ...                            ...
# 789                              0.6583                         0.6277
# 790                              0.7155                         0.6920
# 791                              0.6687                         0.6476
# 792                              0.7192                         0.6559
# 793                              0.6918                         0.6275
# 794                              0.7467                         0.6955
# 795                              0.6987                         0.6483
# 796                              0.6955                         0.6843
# 808                              0.8023                         0.7921
# 809                              0.7656                         0.7696
# 810                              0.7871                         0.7869
# 811                              0.7620                         0.7542
# 812                              0.7684                         0.7672
# 813                              0.7875                         0.7965
# 814                              0.7775                         0.7988
# 815                              0.8054                         0.8044
# 816                              0.8096                         0.8080
# 817                              0.7750                         0.7774
# 818                              0.7454                         0.7536
# 819                              0.7586                         0.7124
# 820                              0.7666                         0.7493
# 821                              0.7793                         0.7422
# 822                              0.7827                         0.7412
# 823                              0.8086                         0.7703
# 824                              0.8278                         0.7965
# 825                              0.8293                         0.7926
# 826                              0.8216                         0.7795
# 827                              0.8336                         0.7965
# 828                              0.7914                         0.7628
# 829                              0.7715                         0.7351
#
#      average_gate_departure_delay  average_taxi_out_time  \
# 0                           10.38                   9.89
# 1                            9.60                   9.79
# 2                           10.84                   9.89
# 3                           11.29                  10.34
# 4                           10.79                  10.41
# 5                            9.24                   9.88
# 6                           10.25                   9.95
# 7                           10.81                  10.50
# 8                           10.55                  10.27
# 9                           12.56                  10.77
# 10                          14.30                  10.64
# 11                          21.45                  12.41
# 12                          18.36                  12.19
# 13                          15.56                  12.84
# 14                          15.69                  13.19
# 15                          13.45                  13.44
# 16                          15.10                  12.49
# 17                          17.77                  11.97
# 18                          14.56                  11.89
# 19                          10.01                  11.71
# 20                           9.18                  12.03
# 21                          11.33                  11.33
# 22                          13.59                  20.45
# 23                          15.50                  18.52
# 24                          16.20                  20.38
# 25                          16.77                  19.67
# 26                          13.86                  20.60
# 27                          13.20                  21.84
# 28                          12.82                  21.26
# 29                          12.20                  20.33
# ..                            ...                    ...
# 789                         17.40                  13.76
# 790                         16.07                  13.37
# 791                         16.71                  14.65
# 792                         14.95                  14.09
# 793                         17.80                  13.17
# 794                         14.40                  12.31
# 795                         14.62                  14.03
# 796                         16.78                  12.42
# 808                          9.85                  11.88
# 809                         11.39                  12.17
# 810                         10.78                  12.13
# 811                         12.55                  12.03
# 812                         12.39                  12.19
# 813                         10.86                  12.05
# 814                         11.02                  12.45
# 815                         10.60                  11.93
# 816                         10.51                  11.69
# 817                         11.90                  11.86
# 818                         14.33                  12.00
# 819                         14.09                   9.98
# 820                         11.53                   9.87
# 821                         10.49                  10.58
# 822                         10.62                  11.10
# 823                          9.51                  10.94
# 824                          8.41                  10.70
# 825                          8.27                  10.48
# 826                          8.76                  11.06
# 827                          8.10                  11.19
# 828                         10.55                  11.43
# 829                         12.33                  11.32
#
#      average taxi out delay    ...      Longitude  Boundary Data Available  \
# 0                      2.43    ...    -106.609194                      Yes
# 1                      2.29    ...    -106.609194                      Yes
# 2                      2.16    ...    -106.609194                      Yes
# 3                      2.40    ...    -106.609194                      Yes
# 4                      2.41    ...    -106.609194                      Yes
# 5                      1.89    ...    -106.609194                      Yes
# 6                      2.05    ...    -106.609194                      Yes
# 7                      2.51    ...    -106.609194                      Yes
# 8                      2.32    ...    -106.609194                      Yes
# 9                      2.64    ...    -106.609194                      Yes
# 10                     2.41    ...    -106.609194                      Yes
# 11                     2.92    ...    -149.998194                      Yes
# 12                     2.78    ...    -149.998194                      Yes
# 13                     2.54    ...    -149.998194                      Yes
# 14                     2.29    ...    -149.998194                      Yes
# 15                     1.86    ...    -149.998194                      Yes
# 16                     1.55    ...    -149.998194                      Yes
# 17                     1.79    ...    -149.998194                      Yes
# 18                     1.66    ...    -149.998194                      Yes
# 19                     1.52    ...    -149.998194                      Yes
# 20                     1.51    ...    -149.998194                      Yes
# 21                     1.33    ...    -149.998194                      Yes
# 22                     8.73    ...     -84.427864                      Yes
# 23                     7.26    ...     -84.427864                      Yes
# 24                     9.63    ...     -84.427864                      Yes
# 25                     8.28    ...     -84.427864                      Yes
# 26                     9.01    ...     -84.427864                      Yes
# 27                     9.73    ...     -84.427864                      Yes
# 28                     8.61    ...     -84.427864                      Yes
# 29                     7.52    ...     -84.427864                      Yes
# ..                      ...    ...            ...                      ...
# 789                    3.84    ...     -74.104833                      Yes
# 790                    2.42    ...     -74.104833                      Yes
# 791                    3.02    ...     -74.104833                      Yes
# 792                    2.46    ...     -74.104833                      Yes
# 793                    1.30    ...     -74.104833                      Yes
# 794                    0.83    ...     -74.104833                      Yes
# 795                    2.70    ...     -74.104833                      Yes
# 796                    0.65    ...     -74.104833                      Yes
# 808                    2.39    ...     -82.533250                      Yes
# 809                    3.12    ...     -82.533250                      Yes
# 810                    2.87    ...     -82.533250                      Yes
# 811                    2.78    ...     -82.533250                      Yes
# 812                    2.85    ...     -82.533250                      Yes
# 813                    2.59    ...     -82.533250                      Yes
# 814                    3.03    ...     -82.533250                      Yes
# 815                    2.42    ...     -82.533250                      Yes
# 816                    2.19    ...     -82.533250                      Yes
# 817                    2.36    ...     -82.533250                      Yes
# 818                    2.39    ...     -82.533250                      Yes
# 819                    2.31    ...    -110.941028                      Yes
# 820                    2.15    ...    -110.941028                      Yes
# 821                    2.56    ...    -110.941028                      Yes
# 822                    2.82    ...    -110.941028                      Yes
# 823                    2.42    ...    -110.941028                      Yes
# 824                    2.17    ...    -110.941028                      Yes
# 825                    2.01    ...    -110.941028                      Yes
# 826                    2.58    ...    -110.941028                      Yes
# 827                    2.59    ...    -110.941028                      Yes
# 828                    2.43    ...    -110.941028                      Yes
# 829                    2.03    ...    -110.941028                      Yes
#
#      airport_num  diff_gate_airport_departures  delay_score  \
# 0             44                        0.0221    -0.704790
# 1             44                        0.0218    -0.568608
# 2             44                        0.0227    -0.280602
# 3             44                        0.0301    -0.128424
# 4             44                        0.0259    -0.480396
# 5             44                        0.0194    -0.751778
# 6             44                        0.0237    -0.803790
# 7             44                        0.0314    -1.121320
# 8             44                        0.0279    -1.455846
# 9             44                        0.0308    -0.753312
# 10            44                        0.0303    -0.567436
# 11            61                        0.0339    -0.140696
# 12            61                        0.0333    -0.248992
# 13            61                        0.0316     0.292160
# 14            61                        0.0381     0.265221
# 15            61                        0.0274     0.616707
# 16            61                        0.0160     0.043512
# 17            61                        0.0232     0.841725
# 18            61                        0.0226    -1.059114
# 19            61                        0.0207    -1.128252
# 20            61                        0.0204    -1.118017
# 21            61                        0.0214    -1.014448
# 22             5                        0.1839    -1.891835
# 23             5                        0.1197    -1.623721
# 24             5                        0.1826    -1.997910
# 25             5                        0.1454    -2.555631
# 26             5                        0.1625    -2.134440
# 27             5                        0.1875    -1.598090
# 28             5                        0.1556    -2.503214
# 29             5                        0.1278    -2.730062
# ..           ...                           ...          ...
# 789           17                        0.0579     0.082940
# 790           17                        0.0301    -0.040750
# 791           17                        0.0442     0.053771
# 792           17                        0.0327     1.117798
# 793           17                        0.0116     0.753548
# 794           17                        0.0028     0.866712
# 795           17                        0.0413     0.742580
# 796           17                        0.0072    -0.037980
# 808           71                        0.0222    -0.136712
# 809           71                        0.0340    -0.492384
# 810           71                        0.0258    -0.476420
# 811           71                        0.0283    -0.118726
# 812           71                        0.0299    -0.326716
# 813           71                        0.0279    -0.659920
# 814           71                        0.0346    -0.899028
# 815           71                        0.0242    -0.414664
# 816           71                        0.0226    -0.358208
# 817           71                        0.0247    -0.403252
# 818           71                        0.0272    -0.548900
# 819            2                        0.0171    -0.160140
# 820            2                        0.0202    -0.015477
# 821            2                        0.0305     0.714455
# 822            2                        0.0325     0.801567
# 823            2                        0.0268     0.914662
# 824            2                        0.0229     0.636786
# 825            2                        0.0209     1.032354
# 826            2                        0.0242     0.961760
# 827            2                        0.0263     0.730916
# 828            2                        0.0231     0.443360
# 829            2                        0.0199     0.653514
#
#      net_lateness_percent  avg_delay_late_control  net_cancelations  \
# 0                  0.0112                    6.12                 7
# 1                  0.0079                    5.51                31
# 2                 -0.0010                    4.79                63
# 3                 -0.0057                    4.83                62
# 4                  0.0031                    5.07                33
# 5                  0.0077                    4.81                30
# 6                  0.0140                    5.06                45
# 7                  0.0264                    6.03                51
# 8                  0.0237                    6.11                56
# 9                  0.0152                    5.76                20
# 10                 0.0172                    5.41                41
# 11                -0.0268                    7.38               -59
# 12                -0.0106                    7.05               -60
# 13                -0.0345                    6.19               -69
# 14                -0.0261                    6.85               -64
# 15                -0.0125                    5.82               -87
# 16                 0.0312                    5.33               -67
# 17                 0.0285                    4.09               -55
# 18                 0.0242                    7.25               -74
# 19                 0.0286                    7.05               -68
# 20                 0.0403                    6.54               -43
# 21                 0.0526                    6.94               -51
# 22                 0.1613                   19.78              -563
# 23                 0.1121                   16.07              -643
# 24                 0.1881                   21.24              -677
# 25                 0.1733                   20.25              -994
# 26                 0.1488                   19.00              -875
# 27                 0.1435                   17.98              -979
# 28                 0.1551                   17.01             -1081
# 29                 0.1338                   15.62              -929
# ..                    ...                     ...               ...
# 789               -0.0306                    6.04                17
# 790               -0.0235                    5.23                12
# 791               -0.0211                    5.69                11
# 792               -0.0633                    2.37                13
# 793               -0.0643                    1.85                 2
# 794               -0.0512                    1.59                 2
# 795               -0.0504                    3.05                 4
# 796               -0.0112                    3.58                 6
# 808               -0.0102                    4.86               151
# 809                0.0040                    6.62                25
# 810               -0.0002                    6.18                71
# 811               -0.0078                    5.20                50
# 812               -0.0012                    4.76                73
# 813                0.0090                    4.80                42
# 814                0.0213                    6.45                54
# 815               -0.0010                    4.76                45
# 816               -0.0016                    4.30                39
# 817                0.0024                    4.72                25
# 818                0.0082                    5.73                32
# 819               -0.0462                    5.02                23
# 820               -0.0173                    4.60                25
# 821               -0.0371                    3.30                32
# 822               -0.0415                    3.55                44
# 823               -0.0383                    2.47                32
# 824               -0.0313                    2.97                17
# 825               -0.0367                    1.99                34
# 826               -0.0421                    2.45                21
# 827               -0.0371                    2.99                10
# 828               -0.0286                    3.30                22
# 829               -0.0364                    2.58                23
#
#      net_diversions   samples
# 0                25   53894.5
# 1                28   51853.0
# 2               -53   50440.5
# 3                62   53433.0
# 4                37   49550.5
# 5                48   42627.0
# 6                21   42235.5
# 7                16   42290.0
# 8                 5   39106.0
# 9                16   35133.0
# 10               29   33214.5
# 11               43   16007.0
# 12               43   69538.5
# 13               38   72851.5
# 14               39   76032.0
# 15               40   74542.5
# 16                4   65193.5
# 17               52   70607.0
# 18               51   69700.5
# 19               42   68387.5
# 20               25   67726.5
# 21               46   68901.5
# 22              -35  475286.0
# 23             -290  482370.5
# 24              126  481034.5
# 25             -125  489312.5
# 26              -90  480765.0
# 27              -52  477919.5
# 28               26  467726.5
# 29               91  454344.0
# ..              ...       ...
# 789              -2    9526.0
# 790              -2    8001.5
# 791               1    5021.5
# 792              -7    4829.5
# 793              -1    5495.0
# 794               2    5510.0
# 795               1    4904.0
# 796              -8    4867.0
# 808              15  100434.0
# 809             109  111926.0
# 810               8  106233.0
# 811              65  107551.0
# 812              12  100408.5
# 813              99   84014.0
# 814              17   82464.0
# 815              39   81867.0
# 816              -1   80564.0
# 817              34   80274.5
# 818              20   79331.0
# 819              28    7499.5
# 820              10   29782.0
# 821              17   29911.0
# 822              43   32119.0
# 823              43   30302.0
# 824              10   24501.5
# 825               7   25041.5
# 826              15   25157.0
# 827               9   23631.0
# 828              44   22296.0
# 829              16   22464.5
#
# [799 rows x 40 columns]

# %%
df['AP Type'].value_counts() #definitely worth including, values for all 799 rows
# Out:
# Federalized/Commercial    748
# Public Use                 51
# Name: AP Type, dtype: int64

# %%
len(df[df['samples']>100])
# Out:
# 799

# %%
ap_type_dums = pd.get_dummies(df['AP Type'])
df = pd.concat([df,ap_type_dums], axis = 1)

# ['samples', 'Public Use', 'Ferderalized/Commercial']

# %%
ap_type_dums
# Out:
#      Federalized/Commercial  Public Use
# 0                         1           0
# 1                         1           0
# 2                         1           0
# 3                         1           0
# 4                         1           0
# 5                         1           0
# 6                         1           0
# 7                         1           0
# 8                         1           0
# 9                         1           0
# 10                        1           0
# 11                        1           0
# 12                        1           0
# 13                        1           0
# 14                        1           0
# 15                        1           0
# 16                        1           0
# 17                        1           0
# 18                        1           0
# 19                        1           0
# 20                        1           0
# 21                        1           0
# 22                        1           0
# 23                        1           0
# 24                        1           0
# 25                        1           0
# 26                        1           0
# 27                        1           0
# 28                        1           0
# 29                        1           0
# ..                      ...         ...
# 789                       1           0
# 790                       1           0
# 791                       1           0
# 792                       1           0
# 793                       1           0
# 794                       1           0
# 795                       1           0
# 796                       1           0
# 808                       1           0
# 809                       1           0
# 810                       1           0
# 811                       1           0
# 812                       1           0
# 813                       1           0
# 814                       1           0
# 815                       1           0
# 816                       1           0
# 817                       1           0
# 818                       1           0
# 819                       1           0
# 820                       1           0
# 821                       1           0
# 822                       1           0
# 823                       1           0
# 824                       1           0
# 825                       1           0
# 826                       1           0
# 827                       1           0
# 828                       1           0
# 829                       1           0
#
# [799 rows x 2 columns]

# %%
from sklearn import preprocessing



unscaled_x = df.loc[:,['year','percent on-time gate departures','percent on-time airport departures', 'percent on-time gate arrivals','average_gate_departure_delay', 'average_taxi_out_time','average taxi out delay', 'average airport departure delay','average airborne delay', 'average taxi in delay','average block delay', 'average gate arrival delay', 'Latitude','Longitude', 'net_cancelations', 'net_diversions','samples', 'Public Use', 'Federalized/Commercial']]

X_orig = preprocessing.StandardScaler().fit_transform(unscaled_x)
X_orig = pd.DataFrame(X_orig, columns=unscaled_x.columns)

y = df['airport_num']
y_temp = df['delay_score']

# %%
rfc_cv = RandomForestRegressor(n_estimators=1000) #
stratk = StratifiedKFold(y_temp, n_folds=10, shuffle=True, random_state=66)

rfc_cv.fit(X_orig, y_temp)
s_rfc = cross_val_score(rfc_cv, X_orig, y_temp, cv=stratk, n_jobs=-1).mean()
s_rfc
# Out:
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:516: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of labels for any class cannot be less than n_folds=10.
#   % (min_labels, self.n_folds)), Warning)
# 0.89533604710903669

# %%
feature_importances_rfc = pd.DataFrame(rfc_cv.feature_importances_,
                                   index = X_orig.columns,
                                    columns=['importance']).sort_values('importance',
                                                                        ascending=False)
feature_importances_rfc.head(35)
# Out:
#                                     importance
# samples                               0.363583
# average gate arrival delay            0.098508
# Longitude                             0.098475
# percent on-time gate arrivals         0.095014
# percent on-time airport departures    0.086439
# average airport departure delay       0.068592
# average block delay                   0.032691
# average_gate_departure_delay          0.031154
# average taxi out delay                0.022272
# average taxi in delay                 0.018166
# Latitude                              0.017772
# percent on-time gate departures       0.013704
# average airborne delay                0.013370
# year                                  0.012278
# average_taxi_out_time                 0.011661
# net_cancelations                      0.008878
# net_diversions                        0.006991
# Public Use                            0.000228
# Federalized/Commercial                0.000224

# %%
#because federal v. public airports are not predictive at all on the amount of lateness, seems like I should focus my analysis on non-public airports
#Looking online, I was unable to find a clear difference between 2 groups, so dropping as features (airports seem to be divided in other ways online)

# removed: 'Public Use', 'Federalized/Commercial'

features = df.loc[:,['year','avg_delay_late_control', 'net_lateness_percent', 'Latitude','Longitude', 'net_cancelations', 'net_diversions','samples']]
X = preprocessing.StandardScaler().fit_transform(features)
X = pd.DataFrame(X, columns=features.columns)

# %%
from sklearn.decomposition import PCA

pca_2 = PCA(n_components=2)
xPC_2 = pca_2.fit_transform(X) # Use the eigenvectors to transform xStand onto new axes
print pca_2.fit(X).components_# eigenvectors
# Out:
# [[ 0.04403301 -0.51738054 -0.5164958  -0.14685512 -0.17392922  0.36223268
#    0.20287415 -0.489308  ]
#  [-0.01221021  0.21764529  0.11837381  0.13092501  0.60358192  0.56268371
#   -0.35331277 -0.33996135]]

# %%
from sklearn.decomposition import PCA

pca_3 = PCA(n_components=3)
xPC_3 = pca_3.fit_transform(X) # Use the eigenvectors to transform xStand onto new axes
print pca_3.fit(X).components_# eigenvectors
# Out:
# [[ 0.04403301 -0.51738054 -0.5164958  -0.14685512 -0.17392922  0.36223268
#    0.20287415 -0.489308  ]
#  [-0.01221021  0.21764529  0.11837381  0.13092501  0.60358192  0.56268371
#   -0.35331277 -0.33996135]
#  [ 0.54643499 -0.00291863  0.05305829  0.66450567  0.12728359 -0.02252715
#    0.48607349 -0.06357118]]

# %%
df_pca_2 = pd.DataFrame(xPC_2, columns=['PC1','PC2'])
# len(df_pca_2) #799, as expected
df_pca_labeled_full = pd.merge(df_pca_2, df, left_index=1, right_index=1)
df_pca_labeled = df_pca_labeled_full.iloc[:,:3]
df_pca_labeled.head()
# Out:
#         PC1       PC2 airport
# 0  1.024396 -0.239258     ABQ
# 1  1.190435 -0.208007     ABQ
# 2  1.296620  0.063480     ABQ
# 3  1.519790 -0.285393     ABQ
# 4  1.351652 -0.260115     ABQ

# %%
df_pca_3 = pd.DataFrame(xPC_3, columns=['PC1','PC2', 'PC3']) #for use in analysis
df_pca3_labeled_full = pd.merge(df_pca_3, df, left_index=1, right_index=1)
df_pca3_labeled = df_pca3_labeled_full.iloc[:,:4]
df_pca_3.head()
# Out:
#         PC1       PC2       PC3
# 0  1.024396 -0.239258 -0.995192
# 1  1.190435 -0.208007 -0.814328
# 2  1.296620  0.063480 -0.964968
# 3  1.519790 -0.285393 -0.353155
# 4  1.351652 -0.260115 -0.261957

# %%
df_pca3_labeled.head() #for visualizations later
# Out:
#         PC1       PC2       PC3 airport
# 0  1.024396 -0.239258 -0.995192     ABQ
# 1  1.190435 -0.208007 -0.814328     ABQ
# 2  1.296620  0.063480 -0.964968     ABQ
# 3  1.519790 -0.285393 -0.353155     ABQ
# 4  1.351652 -0.260115 -0.261957     ABQ

# %%
# sns.regplot(data=df_pca_2,x='PC1', y='PC2')
# plt.style.use('fivethirtyeight')

# %%
kmeans = KMeans(n_clusters=5)
clusters = kmeans.fit(X)
labels = kmeans.labels_
centroids = kmeans.cluster_centers_
metrics.silhouette_score(X, labels, metric='euclidean')
# Out:
# 0.18142944759840757

# %%
kmeans3 = KMeans(n_clusters=3)
clusters3 = kmeans3.fit(X)
labels3 = kmeans3.labels_
centroids3 = kmeans3.cluster_centers_
metrics.silhouette_score(X, labels3, metric='euclidean')
# Out:
# 0.19455856807973365

# %%
kmeans10 = KMeans(n_clusters=10)
clusters10 = kmeans10.fit(X)
labels10 = kmeans10.labels_
centroids10 = kmeans10.cluster_centers_
metrics.silhouette_score(X, labels10, metric='euclidean')
# Out:
# 0.22388563545301784

# %%
#now assessing PCA results

kmeans3pca = KMeans(n_clusters=4)
clusters3pca = kmeans3pca.fit(df_pca_2)
labels3pca = kmeans3pca.labels_
centroids3pca = kmeans3pca.cluster_centers_
metrics.silhouette_score(df_pca_2, labels3pca, metric='euclidean')
# Out:
# 0.37044037571894661

# %%
kmeans4 = KMeans(n_clusters=4)
clusters4 = kmeans4.fit(df_pca_2)
labels4 = kmeans4.labels_
centroids4 = kmeans4.cluster_centers_
metrics.silhouette_score(df_pca_2, labels4, metric='euclidean')
# Out:
# 0.37044037571894661

# %%
kmeans_pca = KMeans(n_clusters=5)
clusters_pca = kmeans_pca.fit(df_pca_2)
labels_pca = kmeans_pca.labels_
centroids_pca = kmeans_pca.cluster_centers_
metrics.silhouette_score(df_pca_2, labels_pca, metric='euclidean')
# Out:
# 0.39642807743482894

# %%
kmeans6 = KMeans(n_clusters=6)
clusters6 = kmeans6.fit(df_pca_2)
labels6 = kmeans6.labels_
centroids6 = kmeans6.cluster_centers_
metrics.silhouette_score(df_pca_2, labels6, metric='euclidean')
# Out:
# 0.37365601938634452

# %%
df_pca_2['cluster'] = pd.Series(clusters_pca.labels_)
plt.style.use('fivethirtyeight')

graph = df_pca_2.plot(kind='scatter', x='PC2', y='PC1', figsize=(16,8))

for i, airport in enumerate(df_pca_labeled['airport']):
    graph.annotate(airport, (df_pca_2.iloc[i].PC2, df_pca_2.iloc[i].PC1))

# %% [markdown]
# Stopping Point: Future Analysis
#
# Next, I will implement:
#
# heirarchical clustering
# random forest classification (with feature importance to inform other analysis)
# t-SNE (to see if more obvious clusters emerge)
#
# Then, next goal is to determine number of clusters -- especially if unclear above (using the full dataset). I will do 2 methods and compare them:
#
# DBscan (grid-search optimized w/ silouette score)
#
# Once I have determined my number of clusters, I will perform the following on both PCA and full(scaled) features:
#
# Finally, try to visualize best clusters with best siluette

# %% [markdown]
# ### Part 6: Additional Analysis
# Include any other models you'd like to run here. These can include regressions, classifications, or clusters.

# %%
#heirarchical

from sklearn import cluster, metrics
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from scipy.cluster.hierarchy import dendrogram, linkage, cophenet, fcluster
from scipy.spatial.distance import pdist

Z = linkage(X, 'ward')
c, coph_dists = cophenet(Z, pdist(X))
c
# Out:
# 0.51670764816028125

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot') 
# %matplotlib inline


plt.figure(figsize=(30, 10))
plt.title('Dendrogram')
plt.xlabel('Index Numbers')
plt.ylabel('Distance')
dendrogram(
    Z,
    leaf_rotation=90.,  
    leaf_font_size=8.,
    truncate_mode='lastp')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-98038165f09b> in <module>()
#      14     leaf_rotation=90.,
#      15     leaf_font_size=8.,
# ---> 16     truncate_mode='lastp')
#      17
#      18 plt.show()
#
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/scipy/cluster/hierarchy.pyc in dendrogram(Z, p, truncate_mode, color_threshold, get_leaves, orientation, labels, count_sort, distance_sort, show_leaf_counts, no_plot, no_labels, leaf_font_size, leaf_rotation, leaf_label_func, show_contracted, link_color_func, ax, above_threshold_color)
#    2302                          contraction_marks=contraction_marks,
#    2303                          ax=ax,
# -> 2304                          above_threshold_color=above_threshold_color)
#    2305
#    2306     return R
#
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/scipy/cluster/hierarchy.pyc in _plot_dendrogram(icoords, dcoords, ivl, p, n, mh, orientation, no_labels, color_list, leaf_font_size, leaf_rotation, contraction_marks, ax, above_threshold_color)
#    1892
#    1893     if trigger_redraw:
# -> 1894         matplotlib.pylab.draw_if_interactive()
#    1895
#    1896
#
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/IPython/utils/decorators.pyc in wrapper(*args, **kw)
#      41     def wrapper(*args,**kw):
#      42         wrapper.called = False
# ---> 43         out = func(*args,**kw)
#      44         wrapper.called = True
#      45         return out
#
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/matplotlib/backends/backend_macosx.pyc in draw_if_interactive()
#     248         figManager =  Gcf.get_active()
#     249         if figManager is not None:
# --> 250             figManager.canvas.invalidate()
#     251
#     252
#
# AttributeError: 'FigureCanvasAgg' object has no attribute 'invalidate'

# %%
#looks like 3 clusters will be reasonable given the above visualization. What does t-SNE think?
#this confirms the Kmeans silouettes scores

# %%
#edited plit imbedding

def plot_embedding(X, title=None):
    x_min, x_max = np.min(X, 0), np.max(X, 0)
    X = (X - x_min) / (x_max - x_min)

    fig = plt.figure(figsize=(15,8))
    ax = plt.subplot(111)
    for i in range(X.shape[0]):
        plt.text(X[i, 0], X[i, 1], str(df_pca_labeled['airport'][i]),
                 color=plt.cm.Set1(y[i] / 10.),
                 fontdict={'weight': 'bold', 'size': 9})

    if hasattr(offsetbox, 'AnnotationBbox'):
        # only print thumbnails with matplotlib > 1.0
        shown_images = np.array([[1., 1.]])  # just something big
        for i in range(df_pca_labeled['airport'].shape[0]):
            dist = np.sum((X[i] - shown_images) ** 2, 1)
            if np.min(dist) < 4e-3:
                # don't show points that are too close
                continue
            shown_images = np.r_[shown_images, [X[i]]]
            imagebox = offsetbox.AnnotationBbox(
                offsetbox.OffsetImage(df_pca_labeled['airport'][i], cmap=plt.cm.gray_r),
                X[i])
            ax.add_artist(imagebox)
    plt.xticks([]), plt.yticks([])
    if title is not None:
        plt.title(title)

# %%
def scatter_basic(x):
    # We choose a color palette with seaborn.
    palette = sns.color_palette("GnBu_d")

    # We create a scatter plot.
    plt.style.use('fivethirtyeight')
    f = plt.figure(figsize=(8, 8))
    ax = plt.subplot(aspect='equal')
    sc = ax.scatter(x[:,0], x[:,1], lw=0, s=40)
    plt.xlim(-25, 25)
    plt.ylim(-25, 25)
    ax.axis('off')
    ax.axis('tight')
    plt.show()


    return f, ax, sc

# %%
# original version of plot_embedding
# def plot_embedding(X, title=None):
#     x_min, x_max = np.min(X, 0), np.max(X, 0)
#     X = (X - x_min) / (x_max - x_min)

#     fig = plt.figure(figsize=(15,8))
#     ax = plt.subplot(111)
#     for i in range(X.shape[0]):
#         plt.text(X[i, 0], X[i, 1], str(df['airport_num'][i]),
#                  color=plt.cm.Set1(y[i] / 10.),
#                  fontdict={'weight': 'bold', 'size': 9})

#     if hasattr(offsetbox, 'AnnotationBbox'):
#         # only print thumbnails with matplotlib > 1.0
#         shown_images = np.array([[1., 1.]])  # just something big
#         for i in range(df['airport_num'].shape[0]):
#             dist = np.sum((X[i] - shown_images) ** 2, 1)
#             if np.min(dist) < 4e-3:
#                 # don't show points that are too close
#                 continue
#             shown_images = np.r_[shown_images, [X[i]]]
#             imagebox = offsetbox.AnnotationBbox(
#                 offsetbox.OffsetImage(df['airport_num'][i], cmap=plt.cm.gray_r),
#                 X[i])
#             ax.add_artist(imagebox)
#     plt.xticks([]), plt.yticks([])
#     if title is not None:
#         plt.title(title)

# %%
# t-SNE 
from time import time
from scipy.cluster import hierarchy


print("Computing t-SNE embedding")
tsne = manifold.TSNE(n_components=2, init='pca', random_state=5)
X_tsne = tsne.fit_transform(X)
scatter_basic(X_tsne)

#this plot seems to support more than three groupings

# %%
X.iloc[220:244,:]

# %%
#t-SNE resources for troubleshooting visualization errors: https://indico.io/blog/visualizing-with-t-sne/
#https://gist.github.com/lukemetz/be6123c7ee3b366e333a

# %%
from tsne import bh_sne
X_2d = bh_sne(X)
plt.style.use('fivethirtyeight')
plt.figure(figsize=(30, 10))
plt.scatter(X_2d[:,0],X_2d[:,1])
plt.title('t-SNE')
plt.xlabel('')
plt.ylabel('')
# plt.plot(X_2d)
# plt.show()

# %%
X_2d[1,1]

# %%
X_2d = bh_sne(X)
plt.style.use('fivethirtyeight')
plt.figure(figsize=(30, 10))
plt.scatter(X_2d[:,0],X_2d[:,1])
plt.title('t-SNE')
plt.xlabel('')
plt.ylabel('')

for i, airport in enumerate(df_pca_labeled['airport']):
    graph.annotate(airport, (X_2d[i,1], X_2d[i,0]))

# %%
# Isomap 
n_neighbors = 6
X_iso = manifold.Isomap(n_neighbors, n_components=2).fit_transform(X)
scatter_basic(X_iso)

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(30, 20))
plt.scatter(X_2d[:,0],X_2d[:,1])
plt.title('t-SNE')
plt.xlabel('')
plt.ylabel('')
plt.xlim([-25,25])
plt.ylim([-25,25]) #4 clusters here?

# %%
from sklearn.cluster import DBSCAN, KMeans

db1 = DBSCAN(eps = 1, min_samples = 5).fit(X)  
db1labels = db1.labels_  
core_samples = db1.core_sample_indices_

db1labels #too many

# %%
from sklearn.metrics import silhouette_score

print("Silhouette Coefficient: %0.3f" #what does negative mean???
      % silhouette_score(X, db1labels))

# %%
db2 = DBSCAN(eps = 3, min_samples = 10).fit(X)  #
db2labels = db2.labels_  
core_samples = db2.core_sample_indices_


print("Silhouette Coefficient: %0.3f" #this is returning all zeros (which yields a killer silhouette...)
      % silhouette_score(X, db2labels))

# %%
set(db2labels) #too few

# %%
db3 = DBSCAN(eps = 1, min_samples = 10).fit(xPC_2)  #
db3labels = db3.labels_  
core_samples = db3.core_sample_indices_


print("Silhouette Coefficient: %0.3f" #progress!
      % silhouette_score(X, db3labels))

# %%
db4 = DBSCAN(eps = .75, min_samples = 5).fit(xPC_3)  #
db4labels = db4.labels_  
core_samples = db4.core_sample_indices_


print("Silhouette Coefficient: %0.3f" #this is returning all zeros (which yields a killer silhouette...)
      % silhouette_score(X, db4labels))

# %%
set(db4labels) # 5 clusters here

# %%
set(db3labels) #4 clusters as well

# %%
rfc = RandomForestRegressor(n_estimators=1000) #
stratk = StratifiedKFold(y_temp, n_folds=10, shuffle=True, random_state=66)

rfc.fit(X, db4labels)
s_rfc = cross_val_score(rfc, X, db4labels, cv=stratk, n_jobs=-1).mean()

feature_importance_rfc = pd.DataFrame(rfc.feature_importances_,
                                   index = features.columns,
                                    columns=['importance']).sort_values('importance',
                                                                        ascending=False)
feature_importance_rfc.head(35) #first time running this, i kepy federalized and public use categories in, and they dominated the clustering, so i removed them

# %%
from sklearn.grid_search import GridSearchCV

eps_vals = [0.1, 0.3, 0.5, 0.75, .9, 1.25, 1.5, 2, 3]
min_samples = [3,5,6,7,8,9,10,11,12, 15]

gs = GridSearchCV(db3, {'eps': eps_vals, 'min_samples': min_samples}, verbose=False, cv=stratk)
# dbgs2labels = gs.labels_
gs.fit(xPC_3, score=silhouette_score(X, gs.labels_))
gs.best_params_

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(30, 20))
plt.scatter(X_2d[:,0],X_2d[:,1])
plt.title('t-SNE')
plt.xlabel('')
plt.ylabel('')
plt.xlim([-25,25])
plt.ylim([-25,25]) #4 clusters here?


for i, label in enumerate(db4labels['airport']):
    graph.annotate(label, (X_2d.iloc[i,0],X_2d.iloc[i,1]))

# %%
print(len(X_2d), len(db4labels))

# %%
X_2d = pd.DataFrame(X_2d)
db4labels = pd.DataFrame(db4labels)


plotdf = X_2d.merge(db4labels, how='left', left_index=1, right_index=1)
# plotdf = pd.merge(X_2d, db4labels, how='left', left_index=1, right_index=1)

plotdf.columns = ['x1', 'x2', 'label']

plt.figure(figsize=(30, 20))
sns.lmplot('x1','x2', data=plotdf, hue='label', legend=1, fit_reg=0)
plt.title('t-SNE')

# %%
labels_pca

labels_pca = pd.DataFrame(labels_pca)


plotdf2 = X_2d.merge(labels_pca, how='left', left_index=1, right_index=1)
# plotdf = pd.merge(X_2d, db4labels, how='left', left_index=1, right_index=1)

plotdf2.columns = ['x1', 'x2', 'label']

plt.figure(figsize=(30, 20))
sns.lmplot('x1','x2', data=plotdf2, hue='label', legend=1, fit_reg=0)
plt.title('t-SNE')

# %%
#tree/ random forest model predicting df['percent on-time airport departures'] and extract feature importance

# %% [markdown]
# ### Part 7: Write an analysis plan of your findings

# %% [markdown]
# Create a writeup on the interpretation of findings including an executive summary with conclusions and next steps. Put it on your blog, and include the link here.

# %% [markdown]
# Which operational features are most correlated with delays?

# %% [markdown]
# What should the airport's next steps be?

# %% [markdown]
# ### Bonus: Copy your Database to AWS

# %% [markdown]
# Make sure to properly document all of the features of your dataset

# %% [markdown]
# ### Bonus: Create a 3-Dimensional Plot of your new dataset with PCA applied
