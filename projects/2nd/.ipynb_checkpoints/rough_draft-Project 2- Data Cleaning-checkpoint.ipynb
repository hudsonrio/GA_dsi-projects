# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os 
import random

# %matplotlib inline

os.getcwd()
# Out:
# '/Users/HudsonCavanagh/dsi-projects/projects/2nd'

# %%
dis = pd.read_csv("/Users/HudsonCavanagh/dsi-projects/projects/2nd/billboard.csv")
bb = pd.DataFrame(dis)
bb.head()
# Out:
#    year      artist.inverted                                  track  \
# 0  2000      Destiny's Child               Independent Women Part I
# 1  2000              Santana                           Maria, Maria
# 2  2000        Savage Garden                     I Knew I Loved You
# 3  2000              Madonna                                  Music
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)
#
#          time genre        date.entered         date.peaked  x1st.week  \
# 0  3,38,00 AM  Rock  September 23, 2000   November 18, 2000         78
# 1  4,18,00 AM  Rock   February 12, 2000       April 8, 2000         15
# 2  4,07,00 AM  Rock    October 23, 1999    January 29, 2000         71
# 3  3,45,00 AM  Rock     August 12, 2000  September 16, 2000         41
# 4  3,38,00 AM  Rock      August 5, 2000    October 14, 2000         57
#
#   x2nd.week x3rd.week    ...     x67th.week x68th.week x69th.week x70th.week  \
# ...

# %%
bb.head()

"""
Things to clean from billboard
dates as values
names of artists
genre(value_count())
* (missing values)
any addl columns you might want
--> num weeks on charts
--> peak chart position
"""
# Out:
# '\nThings to clean from billboard\ndates as values\nnames of artists\ngenre(value_count())\n* (missing values)\nany addl columns you might want\n--> num weeks on charts\n--> peak chart position\n'

# %%
#based on this wikipedia article (https://en.wikipedia.org/wiki/Rock_and_roll) I'M NOT combining the two
#"Rock and roll" can refer either to the first wave of music that originated in the US in the 1950s 
#prior to its development into "rock music", or more broadly to rock music and culture.[8] 

#HOWEVER, clearly rock'n'roll is supposed to be rock

#g = len(bb["genre"])
#genre_freq = genres.apply((lambda x/ g))
#genres["Normalized"]= genres/len(genres)
#was trying to normalize these results, but moving on
# Out:
# Rock           103
# Country         74
# Rap             58
# Rock'n'roll     34
# R&B             13
# Name: genre, dtype: int64

# %%
#converted datetime column


bb["peak_date"]


#def date_cleaner1(v, infer_datetime_format=True):
    #v.to_datetime
        
#def date_cleaner2(v):
   # parser.parse(v)

#df['col'] = pd.to_datetime(df['col'])
#bb["peak_date2"] = bb["date.peaked"].apply(date_cleaner2)
#dt = parser.parse("Aug 28 1999 12:00AM")
#date_object = datetime.strptime('Jun 1 2005  1:33PM', '%b %d %Y %I:%M%p')
# Out:
# 0     2000-11-18
# 1     2000-04-08
# 2     2000-01-29
# 3     2000-09-16
# 4     2000-10-14
# 5     2000-08-26
# 6     2000-03-18
# 7     2000-06-24
# 8     2000-08-12
# 9     2000-03-04
# 10    2000-07-29
# 11    2000-01-15
# 12    2000-07-15
# 13    2000-11-11
# 14    2000-06-17
# 15    2000-07-22
# 16    2000-02-19
# 17    2000-04-22
# 18    2000-12-02
# 19    2000-12-30
# 20    2000-05-06
# 21    2000-06-03
# 22    2000-09-30
# 23    2000-08-19
# 24    2000-11-11
# 25    2000-05-20
# 26    2000-07-01
# 27    2000-01-08
# 28    2000-07-01
# 29    2000-02-12
#          ...
# 287   2000-09-09
# 288   2000-09-16
# 289   2000-07-22
# 290   2000-02-05
# 291   2000-03-11
# 292   2000-06-17
# 293   2000-04-15
# 294   2000-08-26
# 295   2000-01-15
# 296   2000-01-22
# 297   2000-12-02
# 298   2000-05-20
# 299   2000-06-17
# 300   2000-05-06
# 301   2000-04-01
# 302   2000-09-16
# 303   2000-09-16
# 304   2000-07-29
# 305   2000-11-18
# 306   2000-12-23
# 307   2000-03-11
# ...

# %%
#scrap AM
#replace , with .






"""
def time_clean(val):
    for i in val:
        return str(i[0:7].replace(',', '.', inplace=True))

bb["time"] = time_clean(bb["time"])
bb["track_length"] = pd.to_timedelta(bb["time"])


#bb['track_length'].head()
"""
# Out:
# '\ndef time_clean(val):\n    for i in val:\n        return str(i[0:7].replace(\',\', \'.\', inplace=True))\n\nbb["time"] = time_clean(bb["time"])\nbb["track_length"] = pd.to_timedelta(bb["time"])\n\n\n#bb[\'track_length\'].head()\n'

# %%
bb['track_length']
# Out:
# 0     03:38:00
# 1     04:18:00
# 2     04:07:00
# 3     03:45:00
# 4     03:38:00
# 5     04:17:00
# 6     04:31:00
# 7     03:36:00
# 8     03:52:00
# 9     04:25:00
# 10    03:10:00
# 11    03:18:00
# 12    04:01:00
# 13    03:52:00
# 14    04:03:00
# 15    04:12:00
# 16    04:14:00
# 17    04:04:00
# 18    03:50:00
# 19    03:43:00
# 20    04:21:00
# 21    03:50:00
# 22    03:24:00
# 23    03:48:00
# 24    03:53:00
# 25    04:05:00
# 26    04:00:00
# 27    04:16:00
# 28    04:57:00
# 29    04:34:00
#         ...
# 287   03:15:00
# 288   03:44:00
# 289   03:48:00
# 290   04:08:00
# 291   04:11:00
# 292   03:54:00
# 293   04:02:00
# 294   04:10:00
# 295   03:47:00
# 296   03:23:00
# 297   04:14:00
# 298   03:46:00
# 299   05:10:00
# 300   04:43:00
# 301   04:01:00
# 302   02:58:00
# 303   04:17:00
# 304   03:44:00
# 305   04:16:00
# 306   05:02:00
# 307   04:02:00
# 308   04:24:00
# 309   04:06:00
# 310   04:00:00
# 311   03:33:00
# 312   03:04:00
# 313   03:58:00
# 314   03:30:00
# ...

# %%
      
        

bb.head(20)
# Out:
#     year      artist.inverted                                  track  \
# 0   2000      Destiny's Child               Independent Women Part I
# 1   2000              Santana                           Maria, Maria
# 2   2000        Savage Garden                     I Knew I Loved You
# 3   2000              Madonna                                  Music
# 4   2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)
# 5   2000                Janet                  Doesn't Really Matter
# 6   2000      Destiny's Child                            Say My Name
# 7   2000    Iglesias, Enrique                            Be With You
# 8   2000                Sisqo                             Incomplete
# 9   2000             Lonestar                                 Amazed
# 10  2000               N'Sync                       It's Gonna Be Me
# 11  2000  Aguilera, Christina                      What A Girl Wants
# 12  2000     Vertical Horizon                    Everything You Want
# ...

# %%
def empty_replace(value):
    if value == '*':
        return np.nan
    else:
        return value      
    
def time_clean1(val):
    return val[0:7].replace(',', ':')


dis = pd.read_csv("/Users/HudsonCavanagh/dsi-projects/projects/2nd/billboard.csv")
bb = pd.DataFrame(dis)

genres = bb["genre"].value_counts() #genres works
genres.head()
bb["peak_date"] = pd.to_datetime(bb["date.peaked"])
bb["time"] = (bb["time"]).apply(time_clean1)
bb["track_length"] = pd.to_timedelta(bb["time"])
bb = bb.applymap(empty_replace)
bb['genre'].replace("Rock'n'roll", "Rock", inplace=True)  
bb.groupby(['artist.inverted','genre', 'track'])
bb['time_on_bb100'] = bb.iloc[:,7:83].count(axis=1)
bb['avg_on_bb100'] = bb.iloc[:,7:83].mean(axis=1)
bb['peak_rank'] = bb.iloc[:,7:83].max(axis=1)
#bb['date_fell_off'] = bb["peak_date"] + bb['Time_on_bb100']

bb.drop(bb.columns[7:83], axis=1, inplace=True)
bb.drop(bb.columns[3], axis=1, inplace=True)


bb.head(100)


#bb.groupby(['artist.inverted'],axis=0, as_index=True, sort=True)['Time_on_bb100']['avg_on_bb100']['peak_rank']

        
#this doesn't work, just erases all values, moving on for now
#def plus_t(value):
   # if '+' in str(value):
    #    return value.replace("+", "t")
   # if "'" in str(value):
    #    return value.replace("'", "\'")
# Out:
#     year      artist.inverted                                  track    genre  \
# 0   2000      Destiny's Child               Independent Women Part I     Rock
# 1   2000              Santana                           Maria, Maria     Rock
# 2   2000        Savage Garden                     I Knew I Loved You     Rock
# 3   2000              Madonna                                  Music     Rock
# 4   2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)     Rock
# 5   2000                Janet                  Doesn't Really Matter     Rock
# 6   2000      Destiny's Child                            Say My Name     Rock
# 7   2000    Iglesias, Enrique                            Be With You    Latin
# 8   2000                Sisqo                             Incomplete     Rock
# 9   2000             Lonestar                                 Amazed  Country
# 10  2000               N'Sync                       It's Gonna Be Me     Rock
# ...

# %%
#this isn't working, going to move on 

"""

def reorder(n):
    for a in n.split(', ')
        return a[1] + ' ' + a[0]
    
bb["artist.inverted"] = bb["artist.inverted"].astype('str')
bb['artist'] = bb["artist.inverted"].apply(reorder)
"""

        #(' '.join((n.split(', ')[::-1]))
    #[" ".join(n.replace(","," ").split()[::-1]) for n in namelist]
         #from http://stackoverflow.com/questions/15704943/switch-lastname-firstname-to-firstname-lastname-inside-list
    #for lname, fname in s.split(" ,"):
      #  replace(s, fname + ", " + lname )
        
#print(pd.DataFrame(reorder(bb['artist.inverted'])))
# Out:
#   File "<ipython-input-26-1f5eff550095>", line 4
#     for a in n.split(', ')
#                           ^
# SyntaxError: invalid syntax

# %%
#this whole box was a failure



#Create columns to summarize
#--> num weeks on charts
#--> peak chart position

#didn't get this to work, trying pivot_table
 #trying to only take billboard columns
#charts['Time_on_bb100'] = charts[7:].apply(lambda x: len(x) , axis=1)
#charts['avg_on_bb100'] = charts[7:].apply(lambda x: np.mean(x), axis=1)      
#print(charts);


#bb.pivot_table(dis, index=bb['artist.inverted'], columns=[7:],aggfunc=(np.mean, len))


#for h in bb.colums:
    #if h[0] == 'x':
     #   if

# %%
#time on the charts, counting NaN with count oriented row-wise


bb.head()
# Out:
#    year      artist.inverted                                  track  \
# 0  2000      Destiny's Child               Independent Women Part I
# 1  2000              Santana                           Maria, Maria
# 2  2000        Savage Garden                     I Knew I Loved You
# 3  2000              Madonna                                  Music
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)
#
#          time genre        date.entered         date.peaked  x1st.week  \
# 0  3,38,00 AM  Rock  September 23, 2000   November 18, 2000         78
# 1  4,18,00 AM  Rock   February 12, 2000       April 8, 2000         15
# 2  4,07,00 AM  Rock    October 23, 1999    January 29, 2000         71
# 3  3,45,00 AM  Rock     August 12, 2000  September 16, 2000         41
# 4  3,38,00 AM  Rock      August 5, 2000    October 14, 2000         57
#
#   x2nd.week x3rd.week     ...      x69th.week x70th.week x71st.week  \
# ...

# %%
#yet to do:
#- highest chart position
#time column to song length
#chart of success v. song track title
#calculate the date each song fell off the charts (date entered + weeks on charts)
#pivot of genre & length/ height on charts
#scatter of time on bb v. avg ranking on bb
#avg ranking v. week 1 (or any other week)
