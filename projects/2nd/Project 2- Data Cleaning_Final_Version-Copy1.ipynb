# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os 
import random

# %matplotlib inline

os.getcwd()
dis = pd.read_csv("/Users/HudsonCavanagh/dsi-projects/projects/2nd/billboard.csv")
bb = pd.DataFrame(dis)
type(bb)
# Out:
# pandas.core.frame.DataFrame

# %%
def empty_replace(value):
    if value == '*':
        return np.nan
    else:
        return value      
    
def time_clean1(val):
    return val[0:7].replace(',', ':')


# bb_str.iloc[1:,7:83].apply(pd.convert_objects(convert_numeric=True))
# #print(type(bb['x2nd.week'][2]))

bb['time_on_bb100'] = bb.iloc[:,7:83].count(axis=1)

bb.head()
genres = bb["genre"].value_counts() #genres works
bb["peak_date"] = pd.to_datetime(bb["date.peaked"])
bb["entered_date"] = pd.to_datetime(bb["date.entered"])
bb["time"] = (bb["time"]).apply(time_clean1)
bb["track_length"] = pd.to_timedelta(bb["time"])
bb = bb.applymap(empty_replace)
bb.iloc[:,7:83] = bb.iloc[:,7:83].applymap(lambda x: float(x))
bb['genre'].replace("Rock'n'roll", "Rock", inplace=True)  
bb.groupby(['artist.inverted','genre', 'track'])
bb['weeks_on_bb100'] = bb.iloc[:,7:83].count(axis=1)
bb['avg_on_bb100'] = bb.iloc[:,7:83].mean(axis=1)
bb['peak_rank'] = bb.iloc[:,7:83].apply(np.min,axis=1) #had previously used max, this is returning weirdly  idxmax
bb['worst_rank'] = bb.iloc[:,7:83].max(axis=1) #had previously used max
bb['bb_ratio'] = bb['time_on_bb100']/ (bb['avg_on_bb100'])
#create column that combined avg_on_bb100, and time to convert to $
#can use dollars to evaluate track length, or time on x axis(peak date) to see if things are 'getting better'
bb.drop(bb.columns[7:83], axis=1, inplace=True)
bb.drop(bb.columns[5], axis=1, inplace=True)
bb.drop(bb.columns[3], axis=1, inplace=True)
bb.drop(bb.columns[4], axis=1, inplace=True)
bb.rename(columns={'artist.inverted': 'artist'}, inplace=1) 
bb.head()
# Out:
#    year               artist                                  track genre  \
# 0  2000      Destiny's Child               Independent Women Part I  Rock
# 1  2000              Santana                           Maria, Maria  Rock
# 2  2000        Savage Garden                     I Knew I Loved You  Rock
# 3  2000              Madonna                                  Music  Rock
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  Rock
#
#    time_on_bb100  peak_date entered_date  track_length  weeks_on_bb100  \
# 0             76 2000-11-18   2000-09-23      03:38:00              28
# 1             75 2000-04-08   2000-02-12      04:18:00              26
# 2             76 2000-01-29   1999-10-23      04:07:00              33
# 3             73 2000-09-16   2000-08-12      03:45:00              24
# 4             73 2000-10-14   2000-08-05      03:38:00              21
#
#    avg_on_bb100  peak_rank  worst_rank  bb_ratio
# 0     14.821429          1          78  5.127711
# 1     10.500000          1          48  7.142857
# 2     17.363636          1          71  4.376963
# 3     13.458333          1          44  5.424149
# 4     19.952381          1          57  3.658711

# %%
#pivot_table by artist so we can see their total time on the chart and rank them by that valuye
#run scatter of song length to how long it was 'big'
art_track_view = pd.pivot_table(bb, index=['artist','track'], values=['peak_rank', 'bb_ratio'], aggfunc=(np.mean), margins=1).sort_values(by="bb_ratio", ascending=0)
print(art_track_view)


#pd.pivot_table(df,index=["Manager","Rep"],values=["Price"],aggfunc=[np.mean,len])
# Out:
#                                                                     bb_ratio  \
# artist                       track
# Santana                      Maria, Maria                           7.142857
# Madonna                      Music                                  5.424149
# Destiny's Child              Independent Women Part I               5.127711
# N'Sync                       Bye Bye Bye                            5.118902
# Elliott, Missy "Misdemeanor" Hot Boyz                               5.093023
# Iglesias, Enrique            Be With You                            4.605678
# Aaliyah                      Try Again                              4.562852
# Savage Garden                I Knew I Loved You                     4.376963
# Houston, Whitney             My Love Is Your Love                   4.256000
# Pink                         There U Go                             4.080537
# matchbox twenty              Bent                                   4.077029
# Sisqo                        Thong Song                             3.962756
# Mya                          Case Of The Ex (Whatcha Gonna Do)      3.870968
# N'Sync                       This I Promise You                     3.823529
# Aguilera, Christina          What A Girl Wants                      3.784017
# Ruff Endz                    No More                                3.764479
# Janet                        Doesn't Really Matter                  3.759657
# Aguilera, Christina          Come On Over Baby (All I Want Is You)  3.658711
# Destiny's Child              Say My Name                            3.640719
# Braxton, Toni                He Wasn't Man Enough                   3.619048
# Joe                          I Wanna Know                           3.584137
# Vertical Horizon             Everything You Want                    3.544937
# Blaque                       Bring It All To Me                     3.520767
# Gray, Macy                   I Try                                  3.507692
# Pink                         Most Girls                             3.489796
# Sonique                      It Feels So Good                       3.435028
# N'Sync                       It's Gonna Be Me                       3.413284
# Destiny's Child              Jumpin' Jumpin'                        3.313351
# Hill, Faith                  Breathe                                3.301639
# Anthony, Marc                You Sang To Me                         3.238349
# ...                                                                      ...
# Moore, Chante                Straight Up                            0.792521
# Madison Avenue               Don't Call Me Baby                     0.787911
# Limp Bizkit                  Re-Arranged                            0.787298
# Juvenile                     U Understand                           0.783542
# Funkmaster Flex              Do You                                 0.780153
# Tamar                        If You Don't Wanna Love Me             0.779359
# Spencer, Tracie              Still In My Heart                      0.779359
# Levert, Gerald               Baby U Are                             0.778252
# Nu Flavor                    3 Little Words                         0.772941
# Anastacia                    I'm Outta Love                         0.771127
# Price, Kelly                 Love Sets You Free                     0.766404
# En Vogue                     Riddle                                 0.766404
# Diffie, Joe                  The Quittin' Kind                      0.761739
# Trina                        Pull Over                              0.756477
# Herndon, Ty                  No Mercy                               0.755498
# A*Teens                      Dancing Queen                          0.752577
# Hart, Beth                   L.A. Song                              0.751286
# De La Soul                   All Good?                              0.750000
# Sheist, Shade                Where I Wanna Be                       0.746421
# Ghostface Killah             Cherchez LaGhost                       0.744898
# Braxton, Toni                Spanish Guitar                         0.744898
# Larrieux, Amel               Get Up                                 0.744898
# Tuesday                      I Know                                 0.744898
# Master P                     Souljas                                0.744898
# Lil' Mo                      Ta Da                                  0.743814
# LL Cool J                    Imagine That                           0.741117
# Smith, Will                  Freakin' It                            0.737374
# Eastsidaz, The               Got Beef                               0.737374
# Fragma                       Toca's Miracle                         0.737374
# Zombie Nation                Kernkraft 400                          0.737374
#
#                                                                     peak_rank
# artist                       track
# Santana                      Maria, Maria                                   1
# Madonna                      Music                                          1
# Destiny's Child              Independent Women Part I                       1
# N'Sync                       Bye Bye Bye                                    4
# Elliott, Missy "Misdemeanor" Hot Boyz                                       5
# Iglesias, Enrique            Be With You                                    1
# Aaliyah                      Try Again                                      1
# Savage Garden                I Knew I Loved You                             1
# Houston, Whitney             My Love Is Your Love                           4
# Pink                         There U Go                                     7
# matchbox twenty              Bent                                           1
# Sisqo                        Thong Song                                     3
# Mya                          Case Of The Ex (Whatcha Gonna Do)              2
# N'Sync                       This I Promise You                             5
# Aguilera, Christina          What A Girl Wants                              1
# Ruff Endz                    No More                                        5
# Janet                        Doesn't Really Matter                          1
# Aguilera, Christina          Come On Over Baby (All I Want Is You)          1
# Destiny's Child              Say My Name                                    1
# Braxton, Toni                He Wasn't Man Enough                           2
# Joe                          I Wanna Know                                   4
# Vertical Horizon             Everything You Want                            1
# Blaque                       Bring It All To Me                             5
# Gray, Macy                   I Try                                          5
# Pink                         Most Girls                                     4
# Sonique                      It Feels So Good                               8
# N'Sync                       It's Gonna Be Me                               1
# Destiny's Child              Jumpin' Jumpin'                                3
# Hill, Faith                  Breathe                                        2
# Anthony, Marc                You Sang To Me                                 2
# ...                                                                       ...
# Moore, Chante                Straight Up                                   83
# Madison Avenue               Don't Call Me Baby                            88
# Limp Bizkit                  Re-Arranged                                   88
# Juvenile                     U Understand                                  83
# Funkmaster Flex              Do You                                        91
# Tamar                        If You Don't Wanna Love Me                    89
# Spencer, Tracie              Still In My Heart                             88
# Levert, Gerald               Baby U Are                                    89
# Nu Flavor                    3 Little Words                                89
# Anastacia                    I'm Outta Love                                92
# Price, Kelly                 Love Sets You Free                            91
# En Vogue                     Riddle                                        92
# Diffie, Joe                  The Quittin' Kind                             90
# Trina                        Pull Over                                     93
# Herndon, Ty                  No Mercy                                      92
# A*Teens                      Dancing Queen                                 95
# Hart, Beth                   L.A. Song                                     90
# De La Soul                   All Good?                                     96
# Sheist, Shade                Where I Wanna Be                              95
# Ghostface Killah             Cherchez LaGhost                              98
# Braxton, Toni                Spanish Guitar                                98
# Larrieux, Amel               Get Up                                        97
# Tuesday                      I Know                                        98
# Master P                     Souljas                                       98
# Lil' Mo                      Ta Da                                         95
# LL Cool J                    Imagine That                                  98
# Smith, Will                  Freakin' It                                   99
# Eastsidaz, The               Got Beef                                      99
# Fragma                       Toca's Miracle                                99
# Zombie Nation                Kernkraft 400                                 99
#
# [318 rows x 2 columns]

# %%
track_view = pd.pivot_table(bb, index=['track', 'artist'], values=['peak_rank', 'bb_ratio'], aggfunc=(np.mean), margins=1).sort_values(by=['bb_ratio'], ascending=0)
print(track_view)
#works! at least for bb_score
# Out:
#                                                                     bb_ratio  \
# track                                 artist
# Maria, Maria                          Santana                       7.142857
# Music                                 Madonna                       5.424149
# Independent Women Part I              Destiny's Child               5.127711
# Bye Bye Bye                           N'Sync                        5.118902
# Hot Boyz                              Elliott, Missy "Misdemeanor"  5.093023
# Be With You                           Iglesias, Enrique             4.605678
# Try Again                             Aaliyah                       4.562852
# I Knew I Loved You                    Savage Garden                 4.376963
# My Love Is Your Love                  Houston, Whitney              4.256000
# There U Go                            Pink                          4.080537
# Bent                                  matchbox twenty               4.077029
# Thong Song                            Sisqo                         3.962756
# Case Of The Ex (Whatcha Gonna Do)     Mya                           3.870968
# This I Promise You                    N'Sync                        3.823529
# What A Girl Wants                     Aguilera, Christina           3.784017
# No More                               Ruff Endz                     3.764479
# Doesn't Really Matter                 Janet                         3.759657
# Come On Over Baby (All I Want Is You) Aguilera, Christina           3.658711
# Say My Name                           Destiny's Child               3.640719
# He Wasn't Man Enough                  Braxton, Toni                 3.619048
# I Wanna Know                          Joe                           3.584137
# Everything You Want                   Vertical Horizon              3.544937
# Bring It All To Me                    Blaque                        3.520767
# I Try                                 Gray, Macy                    3.507692
# Most Girls                            Pink                          3.489796
# It Feels So Good                      Sonique                       3.435028
# It's Gonna Be Me                      N'Sync                        3.413284
# Jumpin' Jumpin'                       Destiny's Child               3.313351
# Breathe                               Hill, Faith                   3.301639
# You Sang To Me                        Anthony, Marc                 3.238349
# ...                                                                      ...
# Straight Up                           Moore, Chante                 0.792521
# Don't Call Me Baby                    Madison Avenue                0.787911
# Re-Arranged                           Limp Bizkit                   0.787298
# U Understand                          Juvenile                      0.783542
# Do You                                Funkmaster Flex               0.780153
# If You Don't Wanna Love Me            Tamar                         0.779359
# Still In My Heart                     Spencer, Tracie               0.779359
# Baby U Are                            Levert, Gerald                0.778252
# 3 Little Words                        Nu Flavor                     0.772941
# I'm Outta Love                        Anastacia                     0.771127
# Riddle                                En Vogue                      0.766404
# Love Sets You Free                    Price, Kelly                  0.766404
# The Quittin' Kind                     Diffie, Joe                   0.761739
# Pull Over                             Trina                         0.756477
# No Mercy                              Herndon, Ty                   0.755498
# Dancing Queen                         A*Teens                       0.752577
# L.A. Song                             Hart, Beth                    0.751286
# All Good?                             De La Soul                    0.750000
# Where I Wanna Be                      Sheist, Shade                 0.746421
# Cherchez LaGhost                      Ghostface Killah              0.744898
# Souljas                               Master P                      0.744898
# Spanish Guitar                        Braxton, Toni                 0.744898
# Get Up                                Larrieux, Amel                0.744898
# I Know                                Tuesday                       0.744898
# Ta Da                                 Lil' Mo                       0.743814
# Imagine That                          LL Cool J                     0.741117
# Kernkraft 400                         Zombie Nation                 0.737374
# Freakin' It                           Smith, Will                   0.737374
# Got Beef                              Eastsidaz, The                0.737374
# Toca's Miracle                        Fragma                        0.737374
#
#                                                                     peak_rank
# track                                 artist
# Maria, Maria                          Santana                               1
# Music                                 Madonna                               1
# Independent Women Part I              Destiny's Child                       1
# Bye Bye Bye                           N'Sync                                4
# Hot Boyz                              Elliott, Missy "Misdemeanor"          5
# Be With You                           Iglesias, Enrique                     1
# Try Again                             Aaliyah                               1
# I Knew I Loved You                    Savage Garden                         1
# My Love Is Your Love                  Houston, Whitney                      4
# There U Go                            Pink                                  7
# Bent                                  matchbox twenty                       1
# Thong Song                            Sisqo                                 3
# Case Of The Ex (Whatcha Gonna Do)     Mya                                   2
# This I Promise You                    N'Sync                                5
# What A Girl Wants                     Aguilera, Christina                   1
# No More                               Ruff Endz                             5
# Doesn't Really Matter                 Janet                                 1
# Come On Over Baby (All I Want Is You) Aguilera, Christina                   1
# Say My Name                           Destiny's Child                       1
# He Wasn't Man Enough                  Braxton, Toni                         2
# I Wanna Know                          Joe                                   4
# Everything You Want                   Vertical Horizon                      1
# Bring It All To Me                    Blaque                                5
# I Try                                 Gray, Macy                            5
# Most Girls                            Pink                                  4
# It Feels So Good                      Sonique                               8
# It's Gonna Be Me                      N'Sync                                1
# Jumpin' Jumpin'                       Destiny's Child                       3
# Breathe                               Hill, Faith                           2
# You Sang To Me                        Anthony, Marc                         2
# ...                                                                       ...
# Straight Up                           Moore, Chante                        83
# Don't Call Me Baby                    Madison Avenue                       88
# Re-Arranged                           Limp Bizkit                          88
# U Understand                          Juvenile                             83
# Do You                                Funkmaster Flex                      91
# If You Don't Wanna Love Me            Tamar                                89
# Still In My Heart                     Spencer, Tracie                      88
# Baby U Are                            Levert, Gerald                       89
# 3 Little Words                        Nu Flavor                            89
# I'm Outta Love                        Anastacia                            92
# Riddle                                En Vogue                             92
# Love Sets You Free                    Price, Kelly                         91
# The Quittin' Kind                     Diffie, Joe                          90
# Pull Over                             Trina                                93
# No Mercy                              Herndon, Ty                          92
# Dancing Queen                         A*Teens                              95
# L.A. Song                             Hart, Beth                           90
# All Good?                             De La Soul                           96
# Where I Wanna Be                      Sheist, Shade                        95
# Cherchez LaGhost                      Ghostface Killah                     98
# Souljas                               Master P                             98
# Spanish Guitar                        Braxton, Toni                        98
# Get Up                                Larrieux, Amel                       97
# I Know                                Tuesday                              98
# Ta Da                                 Lil' Mo                              95
# Imagine That                          LL Cool J                            98
# Kernkraft 400                         Zombie Nation                        99
# Freakin' It                           Smith, Will                          99
# Got Beef                              Eastsidaz, The                       99
# Toca's Miracle                        Fragma                               99
#
# [318 rows x 2 columns]

# %% [markdown]
# This is a printout of all the songs that made it to #1
#
# What A Girl Wants                                  Aguilera, Christina  3.784017
# Independent Women Part I                           Destiny's Child      5.127711
# It's Gonna Be Me                                   N'Sync               3.413284
# Be With You                                        Iglesias, Enrique    4.605678
# Say My Name                                        Destiny's Child      3.640719
# Incomplete                                         Sisqo                3.085443
# Come On Over Baby (All I Want Is You)              Aguilera, Christina  3.658711
# With Arms Wide Open                                Creed                2.246541
# Bent                                               matchbox twenty      4.077029
# Try Again                                          Aaliyah              4.562852
# Music                                              Madonna              5.424149
# I Knew I Loved You                                 Savage Garden        4.376963
# Maria, Maria                                       Santana              7.142857
# Doesn't Really Matter                              Janet                3.759657
# Everything You Want                                Vertical Horizon     3.544937
# Thank God I Found You                              Carey, Mariah        1.972973
# Amazed                                             Lonestar             2.731293

# %%
artist_view = pd.pivot_table(bb, index=['artist'], values=['peak_rank', 'bb_ratio'], aggfunc=(np.mean), margins=1).sort_values(by=['bb_ratio'], ascending=0)
print(artist_view)
#works! at least for bb_score
#peak_rank is the average of the highest point that those artists songs reached
# Out:
#                               bb_ratio  peak_rank
# artist
# Santana                       7.142857   1.000000
# Elliott, Missy "Misdemeanor"  5.093023   5.000000
# N'Sync                        4.118572   3.333333
# matchbox twenty               4.077029   1.000000
# Destiny's Child               4.027260   1.666667
# Pink                          3.785166   5.500000
# Ruff Endz                     3.764479   5.000000
# Janet                         3.759657   1.000000
# Madonna                       3.560912  15.000000
# Blaque                        3.520767   5.000000
# Gray, Macy                    3.507692   5.000000
# Aguilera, Christina           3.489070   1.666667
# Sonique                       3.435028   8.000000
# Dion, Celine                  3.057471   6.000000
# Aaliyah                       2.982675  18.000000
# Savage Garden                 2.972585  12.500000
# Mumba, Samantha               2.909420   4.000000
# Iglesias, Enrique             2.900048  16.500000
# Dream                         2.826029   2.000000
# Vertical Horizon              2.758955  12.000000
# Sisqo                         2.741557  14.666667
# Jordan, Montell               2.672527   4.000000
# Smash Mouth                   2.606952  11.000000
# Next                          2.589527   7.000000
# BBMak                         2.480000  13.000000
# Nelly                         2.460952   7.000000
# Mya                           2.446183  26.000000
# Eiffel 65                     2.377850   6.000000
# Ja Rule                       2.343499  11.000000
# Everclear                     2.340458  11.000000
# ...                                ...        ...
# Hollister, Dave               0.813370  84.000000
# Clark, Terri                  0.812616  75.000000
# 2Ge+her                       0.811111  87.000000
# Trick Daddy                   0.810293  83.000000
# Cam'ron                       0.807522  83.000000
# Carter, Torrey                0.805994  86.000000
# Moore, Chante                 0.792521  83.000000
# Madison Avenue                0.787911  88.000000
# Juvenile                      0.783542  83.000000
# Funkmaster Flex               0.780153  91.000000
# Spencer, Tracie               0.779359  88.000000
# Tamar                         0.779359  89.000000
# Nu Flavor                     0.772941  89.000000
# Anastacia                     0.771127  92.000000
# En Vogue                      0.766404  92.000000
# Trina                         0.756477  93.000000
# Herndon, Ty                   0.755498  92.000000
# A*Teens                       0.752577  95.000000
# Hart, Beth                    0.751286  90.000000
# De La Soul                    0.750000  96.000000
# Sheist, Shade                 0.746421  95.000000
# Tuesday                       0.744898  98.000000
# Master P                      0.744898  98.000000
# Ghostface Killah              0.744898  98.000000
# Larrieux, Amel                0.744898  97.000000
# Lil' Mo                       0.743814  95.000000
# LL Cool J                     0.741117  98.000000
# Fragma                        0.737374  99.000000
# Zombie Nation                 0.737374  99.000000
# Smith, Will                   0.737374  99.000000
#
# [229 rows x 2 columns]

# %%
harv_lang = pd.read_csv("/Users/HudsonCavanagh/dsi-projects/projects/2nd/inquirer_basic.csv")
#downloaded from http://www.wjh.harvard.edu/~inquirer/spreadsheet_guide.htm
lang = pd.DataFrame(harv_lang)

lang.head()
#transform post and nega into lists that I can reference
# Out:
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2902: DtypeWarning: Columns (63,108,109,110,176) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          Entry Source Positiv  Negativ Pstv Affil  Ngtv Hostile Strong Power  \
# 0            A  H4Lvd     NaN      NaN  NaN   NaN   NaN     NaN    NaN   NaN
# 1      ABANDON  H4Lvd     NaN  Negativ  NaN   NaN  Ngtv     NaN    NaN   NaN
# 2  ABANDONMENT     H4     NaN  Negativ  NaN   NaN   NaN     NaN    NaN   NaN
# 3        ABATE  H4Lvd     NaN  Negativ  NaN   NaN   NaN     NaN    NaN   NaN
# 4    ABATEMENT    Lvd     NaN      NaN  NaN   NaN   NaN     NaN    NaN   NaN
#
#                          ...                         Anomie NegAff PosAff  \
# 0                        ...                            NaN    NaN    NaN
# 1                        ...                            NaN    NaN    NaN
# 2                        ...                            NaN    NaN    NaN
# 3                        ...                            NaN    NaN    NaN
# 4                        ...                            NaN    NaN    NaN
#
#   SureLw   If NotLw TimeSpc FormLw  Othtags  \
# 0    NaN  NaN   NaN     NaN    NaN  DET ART
# 1    NaN  NaN   NaN     NaN    NaN     SUPV
# 2    NaN  NaN   NaN     NaN    NaN     Noun
# 3    NaN  NaN   NaN     NaN    NaN     SUPV
# 4    NaN  NaN   NaN     NaN    NaN     Noun
#
#                                              Defined
# 0  | article: Indefinite singular article--some o...
# 1                                                  |
# 2                                                  |
# 3                                                  |
# 4                                                NaN
#
# [5 rows x 186 columns]

# %%
def null_checker(series):
    null_list = []
    for i in range(len(series)):
        if pd.isnull(series[i]) == True:
            null_list.append(series[i])
    print("Null %:", (len(null_list)*100)/len(series))
    
    
print("Positiv:", lang['Positiv'].value_counts(), 
      "Negativ:", lang['Negativ'].value_counts())
# Out:
# ('Positiv:', Positiv    1915
# Name: Positiv, dtype: int64, 'Negativ:', Negativ    2291
# Name: Negativ, dtype: int64)

# %%
#Creating a list of positive words

positive_words = []
for i in range(len(lang['Positiv'])):
    if lang['Positiv'][i] == 'Positiv':
        positive_words.append(lang['Entry'][i].split('#')[0]) #cleaning symbols and numbers denoting multiple definitions?

        
print(positive_words)
# Out:
# ['ABIDE', 'ABILITY', 'ABLE', 'ABOUND', 'ABSOLVE', 'ABSORBENT', 'ABSORPTION', 'ABUNDANCE', 'ABUNDANT', 'ACCEDE', 'ACCENTUATE', 'ACCEPT', 'ACCEPTABLE', 'ACCEPTANCE', 'ACCESSIBLE', 'ACCESSION', 'ACCLAIM', 'ACCLAMATION', 'ACCOLADE', 'ACCOMMODATE', 'ACCOMMODATION', 'ACCOMPANIMENT', 'ACCOMPLISH', 'ACCOMPLISHMENT', 'ACCORD', 'ACCORD', 'ACCORD', 'ACCORDANCE', 'ACCOUNTABLE', 'ACCRUE', 'ACCURACY', 'ACCURATE', 'ACCURATENESS', 'ACHIEVE', 'ACHIEVEMENT', 'ACKNOWLEDGEMENT', 'ACQUAINT', 'ACQUAINTANCE', 'ACQUIT', 'ACQUITTAL', 'ACTUAL', 'ACTUAL', 'ACTUALITY', 'ADAMANT', 'ADAPTABILITY', 'ADAPTABLE', 'ADAPTATION', 'ADAPTIVE', 'ADEPT', 'ADEPTNESS', 'ADEQUATE', 'ADHERENCE', 'ADHERENT', 'ADHESION', 'ADHESIVE', 'ADJUNCT', 'ADJUST', 'ADJUSTABLE', 'ADJUSTMENT', 'ADMIRABLE', 'ADMIRATION', 'ADMIRE', 'ADMIRER', 'ADMIT', 'ADMIT', 'ADMIT', 'ADMITTANCE', 'ADORABLE', 'ADORE', 'ADORN', 'ADORNMENT', 'ADROIT', 'ADROITLY', 'ADULATION', 'ADULT', 'ADVANCE', 'ADVANCE', 'ADVANCE', 'ADVANCEMENT', 'ADVANTAGE', 'ADVANTAGEOUS', 'ADVENT', 'ADVENTURESOME', 'ADVENTUROUS', 'ADVISABLE', 'ADVOCACY', 'AFFABILITY', 'AFFABLE', 'AFFECTION', 'AFFECTIONATE', 'AFFILIATE', 'AFFILIATION', 'AFFINITY', 'AFFIRM', 'AFFIRMATION', 'AFFIRMATIVE', 'AFFIX', 'AFFLUENCE', 'AFFLUENT', 'AFLOAT', 'AGGREGATE', 'AGGREGATION', 'AGILE', 'AGILITY', 'AGREEABLE', 'AGREEMENT', 'AID', 'AID', 'ALERTNESS', 'ALIGHT', 'ALIVE', 'ALLEGIANCE', 'ALLEVIATE', 'ALLIANCE', 'ALLIED', 'ALLIES', 'ALLOW', 'ALLOWABLE', 'ALLOWANCE', 'ALLURE', 'ALLY', 'ALMIGHTY', 'ALTRUISTIC', 'AMAZEMENT', 'AMAZING', 'AMELIORATE', 'AMENABLE', 'AMENITY', 'AMIABILITY', 'AMIABLE', 'AMICABLE', 'AMNESTY', 'AMOUR', 'AMPLE', 'AMPLIFY', 'AMPLY', 'AMUSE', 'AMUSEMENT', 'ANGEL', 'ANGELIC', 'ANOINT', 'APOCALYPSE', 'APPEAL', 'APPEASE', 'APPEND', 'APPLAUD', 'APPLAUSE', 'APPOINT', 'APPOINT', 'APPRECIABLE', 'APPRECIATE', 'APPRECIATION', 'APPRECIATIVE', 'APPREHEND', 'APPROACH', 'APPROACH', 'APPROPRIATE', 'APPROVAL', 'APPROVE', 'APPROVE', 'APT', 'APTITUDE', 'ARBITER', 'ARBITRATE', 'ARBITRATION', 'ARDENT', 'ARISEN', 'ARISTOCRACY', 'ARISTOCRAT', 'ARISTOCRATIC', 'ARREST', 'ART', 'ART', 'ASCRIBE', 'ASPIRATION', 'ASPIRE', 'ASSENT', 'ASSERTION', 'ASSET', 'ASSIST', 'ASSIST', 'ASSISTANCE', 'ASSISTANT', 'ASSOCIATE', 'ASSOCIATE', 'ASSOCIATE', 'ASSOCIATION', 'ASSOCIATION', 'ASSURANCE', 'ASSURE', 'ASSURE', 'ASSURE', 'ASSUREDLY', 'ASTOUND', 'ASTUTE', 'ATHLETIC', 'ATTACHMENT', 'ATTAIN', 'ATTAINMENT', 'ATTEND', 'ATTENDANCE', 'ATTENTIVE', 'ATTRACT', 'ATTRACTION', 'ATTRACTIVE', 'ATTRACTIVENESS', 'ATTUNE', 'AUDIBLE', 'AUGMENT', 'AUGMENTATION', 'AUSPICIOUS', 'AUTHENTIC', 'AUTHENTICITY', 'AUTHORITATIVE', 'AUTHORITY', 'AUTONOMOUS', 'AVAILABILITY', 'AVID', 'AWARD', 'AWARD', 'AWARE', 'AWARENESS', 'BACK', 'BACK', 'BACKBONE', 'BACKER', 'BACKING', 'BALL', 'BALL', 'BALMY', 'BAPTISM', 'BAPTIZE', 'BARGAIN', 'BASIC', 'BASIC', 'BEACON', 'BEAUTEOUS', 'BEAUTIFY', 'BEAUTY', 'BEFIT', 'BEFITTING', 'BEFRIEND', 'BEHALF', 'BELOVED', 'BENEFACTOR', 'BENEFICENT', 'BENEFICIAL', 'BENEFICIARY', 'BENEFIT', 'BENEFIT', 'BENEFIT', 'BENEVOLENCE', 'BENEVOLENT', 'BENIGN', 'BEQUEATH', 'BEST', 'BESTOW', 'BETROTH', 'BETROTHAL', 'BETTER', 'BETTER', 'BLAMELESS', 'BLESS', 'BLESS', 'BLESS', 'BLISS', 'BLISSFUL', 'BLITHE', 'BLOOM', 'BLOSSOM', 'BOARD', 'BOLDNESS', 'BOLSTER', 'BONNY', 'BONUS', 'BOOM', 'BOOST', 'BOOST', 'BOUNDLESS', 'BOUNTIFUL', 'BRAINY', 'BRAVE', 'BRAVERY', 'BREADWINNER', 'BRIGHT', 'BRIGHTNESS', 'BRILLIANCE', 'BRILLIANT', 'BROTHERHOOD', 'BROTHERLY', 'BUOYANT', 'BUY', 'CALL', 'CALM', 'CALM', 'CALM', 'CALMNESS', 'CANDID', 'CANDOR', 'CAPABILITY', 'CAPABLE', 'CAPITALIZE', 'CAPTIVATION', 'CARE', 'CARE', 'CAREFREE', 'CAREFUL', 'CARESS', 'CARESS', 'CASUAL', 'CEASELESS', 'CELEBRATE', 'CELEBRATION', 'CELEBRITY', 'CEREMONIAL', 'CHAMP', 'CHAMPION', 'CHAMPIONSHIP', 'CHARISMA', 'CHARITABLE', 'CHARITY', 'CHARM', 'CHARM', 'CHASTE', 'CHEER', 'CHEERFUL', 'CHEERY', 'CHERISH', 'CHERISH', 'CHERUB', 'CHIC', 'CHIVALROUS', 'CHIVALRY', 'CHOSEN', 'CHUM', 'CIVIL', 'CIVILITY', 'CIVILIZATION', 'CIVILIZE', 'CIVILIZE', 'CLARIFY', 'CLAR ...

# %%
#negative words

negative_words = []
for i in range(len(lang['Negativ'])):
    if lang['Negativ'][i] == 'Negativ':
        negative_words.append(lang['Entry'][i].split('#')[0]) #cleaning definitions

        
print(negative_words)
# Out:
# ['ABANDON', 'ABANDONMENT', 'ABATE', 'ABDICATE', 'ABHOR', 'ABJECT', 'ABNORMAL', 'ABOLISH', 'ABOMINABLE', 'ABRASIVE', 'ABRUPT', 'ABSCOND', 'ABSENCE', 'ABSENT', 'ABSENT-MINDED', 'ABSENTEE', 'ABSURD', 'ABSURDITY', 'ABUSE', 'ABUSE', 'ABYSS', 'ACCIDENT', 'ACCOST', 'ACCURSED', 'ACCUSATION', 'ACCUSE', 'ACCUSE', 'ACHE', 'ACRIMONIOUS', 'ACRIMONY', 'ADDICT', 'ADDICTION', 'ADMONISH', 'ADMONITION', 'ADULTERATE', 'ADULTERATION', 'ADULTERY', 'ADVERSARY', 'ADVERSE', 'ADVERSITY', 'AFFECTATION', 'AFFLICT', 'AFFLICTION', 'AFRAID', 'AGAINST', 'AGGRAVATE', 'AGGRAVATION', 'AGGRESSION', 'AGGRESSIVE', 'AGGRESSIVENESS', 'AGGRESSOR', 'AGGRIEVE', 'AGHAST', 'AGITATE', 'AGITATION', 'AGITATOR', 'AGONIZE', 'AGONY', 'AIL', 'AILMENT', 'AIMLESS', 'ALARM', 'ALARMING', 'ALAS', 'ALIBI', 'ALIEN', 'ALIENATE', 'ALIENATION', 'ALLEGATION', 'ALLEGE', 'ALOOF', 'ALTERCATION', 'AMBIGUITY', 'AMBIGUOUS', 'AMBIVALENT', 'AMBUSH', 'AMBUSH', 'AMISS', 'AMPUTATE', 'ANARCHIST', 'ANARCHY', 'ANGER', 'ANGER', 'ANGRY', 'ANGUISH', 'ANIMOSITY', 'ANNIHILATE', 'ANNIHILATION', 'ANNOY', 'ANNOYANCE', 'ANOMALOUS', 'ANOMALY', 'ANTAGONISM', 'ANTAGONIST', 'ANTAGONISTIC', 'ANTAGONIZE', 'ANTI-SOCIAL', 'ANTIPATHY', 'ANTIQUATED', 'ANTITRUST', 'ANXIETY', 'ANXIOUS', 'ANXIOUS', 'ANXIOUSNESS', 'APATHETIC', 'APATHY', 'APPALL', 'APPALL', 'APPREHENSION', 'APPREHENSIVE', 'ARBITRARY', 'ARDUOUS', 'ARGUE', 'ARGUMENT', 'ARREST', 'ARREST', 'ARROGANCE', 'ARROGANT', 'ARTIFICIAL', 'ASHAMED', 'ASSAIL', 'ASSAILANT', 'ASSASSIN', 'ASSASSINATE', 'ASSAULT', 'ASSAULT', 'ASTRAY', 'ASUNDER', 'ATROCIOUS', 'ATROPHY', 'ATTACK', 'ATTACK', 'ATTACK', 'AUDACIOUS', 'AUDACITY', 'AUSTERE', 'AUTOCRAT', 'AUTOCRATIC', 'AVARICE', 'AVARICIOUS', 'AVENGE', 'AVERSION', 'AVERT', 'AVOID', 'AVOIDANCE', 'AWFUL', 'AWKWARD', 'AWKWARDNESS', 'AX', 'BABBLE', 'BACKWARD', 'BACKWARDNESS', 'BAD', 'BADLY', 'BAFFLE', 'BAFFLEMENT', 'BAIL', 'BAIT', 'BALK', 'BANAL', 'BANDIT', 'BANE', 'BANISH', 'BANISH', 'BANISHMENT', 'BANKRUPT', 'BANKRUPTCY', 'BAR', 'BARBARIAN', 'BARBAROUS', 'BARREN', 'BARRIER', 'BASHFUL', 'BASTARD', 'BATTLE', 'BATTLE', 'BATTLEFIELD', 'BEASTLY', 'BEAT', 'BEAT', 'BEAT', 'BEG', 'BEGGAR', 'BEHEAD', 'BELATED', 'BELIE', 'BELITTLE', 'BELLIGERENT', 'BELT', 'BEREAVE', 'BEREAVEMENT', 'BEREFT', 'BERSERK', 'BESEECH', 'BESET', 'BESIEGE', 'BETRAY', 'BETRAYAL', 'BEWARE', 'BEWILDER', 'BEWILDERMENT', 'BIT', 'BITCHY', 'BITE', 'BITE', 'BITE', 'BITTER', 'BITTERNESS', 'BIZARRE', 'BLACKMAIL', 'BLAH', 'BLAME', 'BLAME', 'BLAND', 'BLAST', 'BLAST', 'BLATANT', 'BLEAK', 'BLEMISH', 'BLIND', 'BLIND', 'BLIND', 'BLIND', 'BLINDNESS', 'BLOCK', 'BLOCK', 'BLOCKHEAD', 'BLOODSHED', 'BLOODTHIRSTY', 'BLOODY', 'BLOW', 'BLOW', 'BLUNDER', 'BLUNT', 'BLUR', 'BLURT', 'BOARD', 'BOAST', 'BOASTFUL', 'BOGUS', 'BOISTEROUS', 'BOLT', 'BOMB', 'BOMB', 'BOMBARD', 'BOMBARDMENT', 'BONDAGE', 'BOOT', 'BORE', 'BORE', 'BORE', 'BOREDOM', 'BOTHER', 'BOTHER', 'BOTHERSOME', 'BOUND', 'BOUT', 'BOX', 'BRAG', 'BRANDISH', 'BRAT', 'BRAVADO', 'BRAWL', 'BRAZEN', 'BREACH', 'BREAK', 'BREAK', 'BREAK', 'BREAKDOWN', 'BRIBE', 'BRISTLE', 'BRITTLE', 'BROKE', 'BROKE', 'BROKE', 'BROKE', 'BROKEN-HEARTED', 'BROOD', 'BRUISE', 'BRUSQUE', 'BRUTALITY', 'BRUTE', 'BRUTISH', 'BUCKLE', 'BUG', 'BULLET', 'BUM', 'BUNGLE', 'BURDEN', 'BURDEN', 'BURDENSOME', 'BURGLAR', 'BURGLARY', 'BURN', 'BURN', 'BURN', 'BURN', 'BURY', 'BUSYBODY', 'BUTCHERY', 'CALAMITY', 'CALLOUS', 'CANCEL', 'CANCELLATION', 'CANCER', 'CANNIBAL', 'CANNON', 'CAPITAL', 'CAPITULATE', 'CAPRICIOUS', 'CAPSIZE', 'CAPTIVE', 'CAPTURE', 'CAPTURE', 'CAREEN', 'CARELESS', 'CARELESSNESS', 'CASUALTY', 'CATACLYSM', 'CATASTROPHE', 'CATCH', 'CAVE', 'CENSOR', 'CENSORSHIP', 'CENSURE', 'CHAFE', 'CHALLENGE', 'CHALLENGE', 'CHAOS', 'CHAOTIC', 'CHARGE', 'CHARGE', 'CHARGE', 'CHARGE', 'CHASE', 'CHASE', 'CHASTISE', 'CHEAP', 'CHEAPEN', 'CHEATER', 'CHIDE', 'CHILDISH', 'CHOKE', 'CHOKE', 'CHORE', 'CHRONIC', 'CIRCLE', 'CLAMOR', 'CLAMOROUS', 'CLASH', 'CLATTER', 'CLIQUE', 'CLOG', 'CLOSE', 'CLOSE', 'CLUB', 'CLUB', 'CLUMSY', 'CLUTTER', 'COARSE', 'COARSENESS', 'COCKINESS', 'COCKY', 'COERCE', 'COERCION', 'COERC ...

# %%
bb['track_pos'] = np.NaN
bb['track_pos'].fillna(0, inplace=True)

bb['track_neg'] = np.NaN
bb['track_neg'].fillna(0, inplace=True)

for i in range(len(bb['track'])):
    for h in bb['track'][i].split():  
        if any(h in s for s in positive_words):
            bb.ix[i,'track_pos'] += 1
    for c in bb['track'][i].split():
        if any(c in q for q in negative_words):
            bb.ix[i,'track_neg'] += -1

print(bb['track_pos'],bb['track_neg'])

#the output here is that each track has a negativity and positive score
# Out:
# (0      1
# 1      0
# 2      2
# 3      0
# 4      1
# 5      0
# 6      0
# 7      0
# 8      0
# 9      0
# 10     0
# 11     1
# 12     0
# 13     0
# 14     0
# 15     0
# 16     1
# 17     0
# 18     0
# 19     1
# 20     0
# 21     0
# 22     0
# 23     0
# 24     0
# 25     0
# 26     1
# 27     0
# 28     1
# 29     0
#       ..
# 287    0
# 288    0
# 289    0
# 290    0
# 291    0
# 292    0
# 293    0
# 294    1
# 295    0
# 296    0
# 297    0
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# 303    0
# 304    0
# 305    1
# 306    0
# 307    0
# 308    0
# 309    1
# 310    0
# 311    0
# 312    0
# 313    0
# 314    0
# 315    0
# 316    0
# Name: track_pos, dtype: float64, 0     -1
# 1      0
# 2     -2
# 3      0
# 4     -1
# 5      0
# 6      0
# 7      0
# 8      0
# 9      0
# 10     0
# 11    -1
# 12     0
# 13     0
# 14     0
# 15     0
# 16    -1
# 17     0
# 18     0
# 19    -1
# 20     0
# 21     0
# 22     0
# 23     0
# 24     0
# 25     0
# 26    -1
# 27     0
# 28    -1
# 29     0
#       ..
# 287    0
# 288    0
# 289    0
# 290    0
# 291    0
# 292    0
# 293    0
# 294   -1
# 295    0
# 296    0
# 297    0
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# 303    0
# 304    0
# 305   -1
# 306    0
# 307    0
# 308    0
# 309   -1
# 310    0
# 311    0
# 312    0
# 313    0
# 314    0
# 315    0
# 316    0
# Name: track_neg, dtype: float64)

# %%
#track positivity v. duration (negativity as color?)
#track negativity v. duration
#ibid v. avg position
#ibid v. bb_ratio
#track len v. positivity/ neg
#-ttest on positive v. negative titled songs

# bb['weeks_on_bb100'] 
# bb['avg_on_bb100'] 
# bb['peak_rank']
# bb['worst_rank']
# bb['bb_ratio']
bb.head(100)
# Out:
#     year               artist                                  track    genre  \
# 0   2000      Destiny's Child               Independent Women Part I     Rock
# 1   2000              Santana                           Maria, Maria     Rock
# 2   2000        Savage Garden                     I Knew I Loved You     Rock
# 3   2000              Madonna                                  Music     Rock
# 4   2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)     Rock
# 5   2000                Janet                  Doesn't Really Matter     Rock
# 6   2000      Destiny's Child                            Say My Name     Rock
# 7   2000    Iglesias, Enrique                            Be With You    Latin
# 8   2000                Sisqo                             Incomplete     Rock
# 9   2000             Lonestar                                 Amazed  Country
# 10  2000               N'Sync                       It's Gonna Be Me     Rock
# 11  2000  Aguilera, Christina                      What A Girl Wants     Rock
# 12  2000     Vertical Horizon                    Everything You Want     Rock
# 13  2000                Creed                    With Arms Wide Open     Rock
# 14  2000              Aaliyah                              Try Again     Rock
# 15  2000      matchbox twenty                                   Bent     Rock
# 16  2000        Carey, Mariah                  Thank God I Found You     Rock
# 17  2000          Hill, Faith                                Breathe      Rap
# 18  2000                  Mya      Case Of The Ex (Whatcha Gonna Do)     Rock
# 19  2000                Dream                         He Loves U Not     Rock
# 20  2000        Braxton, Toni                   He Wasn't Man Enough     Rock
# 21  2000        Anthony, Marc                         You Sang To Me    Latin
# 22  2000                  98�     Give Me Just One Night (Una Noche)     Rock
# 23  2000      Destiny's Child                        Jumpin' Jumpin'     Rock
# 24  2000         3 Doors Down                             Kryptonite     Rock
# 25  2000                Sisqo                             Thong Song     Rock
# 26  2000  Aguilera, Christina                          I Turn To You     Rock
# 27  2000     Houston, Whitney                   My Love Is Your Love     Rock
# 28  2000                  Joe                           I Wanna Know     Rock
# 29  2000      Jordan, Montell                     Get It On.. Tonite      Rap
# ..   ...                  ...                                    ...      ...
# 70  2000                Sting                            Desert Rose     Rock
# 71  2000                Jay-Z                            Big Pimpin'      Rap
# 72  2000             Kid Rock                     Only God Knows Why     Rock
# 73  2000         Foo Fighters                           Learn To Fly     Rock
# 74  2000    Dixie Chicks, The                           Goodbye Earl  Country
# 75  2000                  Guy                                Dancin'      R&B
# 76  2000          Lil Bow Wow                         Bounce With Me      Rap
# 77  2000             Westlife                         Swear It Again     Rock
# 78  2000                Train                          Meet Virginia     Rock
# 79  2000         Thomas, Carl                                 I Wish     Rock
# 80  2000               Hanson                       This Time Around  Country
# 81  2000     Simpson, Jessica           I Think I'm In Love With You      Pop
# 82  2000             Ludacris                    What's Your Fantasy      Rap
# 83  2000            Lil' Zane                             Callin' Me      Rap
# 84  2000                  M2M                  Don't Say You Love Me      Pop
# 85  2000         SoulDecision                                  Faded     Rock
# 86  2000          Brock, Chad                                   Yes!  Country
# 87  2000        Martin, Ricky                     Shake Your Bon-Bon    Latin
# 88  2000     Vertical Horizon                           You're A God     Rock
# 89  2000                Avant                              Separated     Rock
# 90  2000         Rimes, LeAnn                               Big Deal  Country
# 91  2000                  IMx                         Stay The Night      Rap
# 92  2000              Dr. Dre                       The Next Episode      Rap
# 93  2000      Spears, Britney                                  Lucky     Rock
# 94  2000        Savage Garden                         Crash And Burn     Rock
# 95  2000                Kandi                    Don't Think I'm Not     Rock
# 96  2000               Sammie                              I Like It     Rock
# 97  2000        Goo Goo Dolls                               Broadway     Rock
# 98  2000         Moore, Mandy                    I Wanna Be With You      Pop
# 99  2000              Dr. Dre                       Forgot About Dre      Rap
#
#     time_on_bb100  peak_date entered_date  track_length  weeks_on_bb100  \
# 0              76 2000-11-18   2000-09-23      03:38:00              28
# 1              75 2000-04-08   2000-02-12      04:18:00              26
# 2              76 2000-01-29   1999-10-23      04:07:00              33
# 3              73 2000-09-16   2000-08-12      03:45:00              24
# 4              73 2000-10-14   2000-08-05      03:38:00              21
# 5              73 2000-08-26   2000-06-17      04:17:00              24
# 6              76 2000-03-18   1999-12-25      04:31:00              32
# 7              73 2000-06-24   2000-04-01      03:36:00              20
# 8              75 2000-08-12   2000-06-24      03:52:00              26
# 9              73 2000-03-04   1999-06-05      04:25:00              55
# 10             74 2000-07-29   2000-05-06      03:10:00              25
# 11             73 2000-01-15   1999-11-27      03:18:00              24
# 12             76 2000-07-15   2000-01-22      04:01:00              41
# 13             76 2000-11-11   2000-05-13      03:52:00              47
# 14             76 2000-06-17   2000-03-18      04:03:00              32
# 15             76 2000-07-22   2000-04-29      04:12:00              39
# 16             73 2000-02-19   1999-12-11      04:14:00              20
# 17             76 2000-04-22   1999-11-06      04:04:00              53
# 18             76 2000-12-02   2000-08-19      03:50:00              30
# 19             76 2000-12-30   2000-09-30      03:43:00              28
# 20             76 2000-05-06   2000-03-18      04:21:00              37
# 21             76 2000-06-03   2000-02-26      03:50:00              32
# 22             73 2000-09-30   2000-08-19      03:24:00              20
# 23             76 2000-08-19   2000-05-13      03:48:00              32
# 24             76 2000-11-11   2000-04-08      03:53:00              53
# 25             76 2000-05-20   2000-01-29      04:05:00              28
# 26             73 2000-07-01   2000-04-15      04:00:00              22
# 27             76 2000-01-08   1999-09-04      04:16:00              28
# 28             76 2000-07-01   2000-01-01      04:57:00              44
# 29             76 2000-02-12   1999-10-23      04:34:00              32
# ..            ...        ...          ...           ...             ...
# 70             75 2000-08-26   2000-05-13      03:52:00              26
# 71             73 2000-07-08   2000-04-22      03:55:00              20
# 72             73 2000-04-15   2000-02-19      05:27:00              20
# 73             73 2000-01-22   1999-10-16      03:55:00              21
# 74             73 2000-05-06   2000-03-18      04:19:00              15
# 75             73 2000-01-01   1999-12-18      04:08:00              11
# 76             73 2000-09-16   2000-08-19      03:22:00              20
# 77             73 2000-07-01   2000-04-01      04:07:00              20
# 78             76 2000-01-22   1999-10-09      03:55:00              27
# 79             73 2000-05-13   2000-03-25      03:50:00              20
# 80             73 2000-05-06   2000-04-22      04:14:00               7
# 81             73 2000-08-12   2000-07-01      03:32:00              16
# 82             73 2000-12-16   2000-09-30      04:16:00              22
# 83             73 2000-09-02   2000-07-29      03:43:00              13
# 84             73 2000-01-08   1999-11-20      03:41:00              12
# 85             73 2000-09-09   2000-07-08      03:25:00              24
# 86             73 2000-07-01   2000-04-08      03:22:00              20
# 87             73 2000-02-12   1999-11-20      03:08:00              18
# 88             73 2000-11-04   2000-08-26      03:45:00              21
# 89             73 2000-05-20   2000-04-29      04:13:00              20
# 90             73 2000-01-01   1999-10-16      03:03:00              20
# 91             73 2000-01-08   1999-10-09      03:37:00              20
# 92             73 2000-07-29   2000-05-27      02:38:00              20
# 93             73 2000-09-09   2000-08-12      03:23:00              11
# 94             73 2000-05-27   2000-04-08      04:41:00              20
# 95             73 2000-10-07   2000-08-05      03:50:00              24
# 96             73 2000-04-15   2000-01-29      04:09:00              20
# 97             73 2000-07-01   2000-04-22      03:54:00              20
# 98             76 2000-08-12   2000-06-17      04:12:00              23
# 99             73 2000-03-25   2000-01-22      03:42:00              20
#
#     avg_on_bb100  peak_rank  worst_rank  bb_ratio  track_pos  track_neg
# 0      14.821429          1          78  5.127711          1         -1
# 1      10.500000          1          48  7.142857          0          0
# 2      17.363636          1          71  4.376963          2         -2
# 3      13.458333          1          44  5.424149          0          0
# 4      19.952381          1          57  3.658711          1         -1
# 5      19.416667          1          59  3.759657          0          0
# 6      20.875000          1          83  3.640719          0          0
# 7      15.850000          1          63  4.605678          0          0
# 8      24.307692          1          77  3.085443          0          0
# 9      26.727273          1          81  2.731293          0          0
# 10     21.680000          1          82  3.413284          0          0
# 11     19.291667          1          71  3.784017          1         -1
# 12     21.439024          1          70  3.544937          0          0
# 13     33.829787          1          86  2.246541          0          0
# 14     16.656250          1          59  4.562852          0          0
# 15     18.641026          1          60  4.077029          0          0
# 16     37.000000          1          89  1.972973          1         -1
# 17     23.018868          2          81  3.301639          0          0
# 18     19.633333          2          72  3.870968          0          0
# 19     26.892857          2          99  2.826029          1         -1
# 20     21.000000          2          63  3.619048          0          0
# 21     23.468750          2          77  3.238349          0          0
# 22     37.650000          2          94  1.938911          0          0
# 23     22.937500          3          74  3.313351          0          0
# 24     26.471698          3          81  2.870991          0          0
# 25     19.178571          3          74  3.962756          0          0
# 26     24.136364          3          50  3.024482          1         -1
# 27     17.857143          4          81  4.256000          0          0
# 28     21.204545          4          94  3.584137          1         -1
# 29     28.437500          4          92  2.672527          0          0
# ..           ...        ...         ...       ...        ...        ...
# 70     38.000000         17          98  1.973684          0          0
# 71     31.300000         18          69  2.332268          0          0
# 72     39.000000         19          78  1.871795          0          0
# 73     39.666667         19          80  1.840336          0          0
# 74     50.600000         19          98  1.442688          0          0
# 75     49.909091         19          94  1.462659          0          0
# 76     45.750000         20         100  1.595628          0          0
# 77     43.350000         20          96  1.683968          0          0
# 78     36.925926         20          76  2.058175          0          0
# 79     36.400000         20          75  2.005495          1         -1
# 80     51.714286         20          95  1.411602          0          0
# 81     44.875000         21          96  1.626741          1         -1
# 82     38.863636         21          89  1.878363          0          0
# 83     57.923077         21          95  1.260292          0          0
# 84     62.333333         21          98  1.171123          0          0
# 85     41.583333         22          94  1.755511          0          0
# 86     45.800000         22          90  1.593886          0          0
# 87     53.611111         22          93  1.361658          0          0
# 88     37.000000         23          64  1.972973          1         -1
# 89     32.350000         23          62  2.256569          0          0
# 90     40.800000         23          71  1.789216          0          0
# 91     49.100000         23          84  1.486762          0          0
# 92     43.250000         23          78  1.687861          0          0
# 93     48.181818         23         100  1.515094          0          0
# 94     46.550000         24          87  1.568206          0          0
# 95     37.166667         24          66  1.964126          0          0
# 96     52.850000         24          93  1.381268          1         -1
# 97     50.000000         24          87  1.460000          0          0
# 98     64.173913         24          99  1.184282          1         -1
# 99     43.250000         25          82  1.687861          0          0
#
# [100 rows x 15 columns]

# %%
avgbb_weeksbb_jointplot = sns.jointplot('avg_on_bb100', 'weeks_on_bb100', data=bb, kind='scatter', color="orange")
avgbb_weeksbb_jointplot.savefig('avgbb_weeksbb_jointplot.jpg', bbox_inches='tight')

# %%
#a t-test is better for interpreting this plot
track_pos_weeks_jointplot = sns.jointplot('track_pos', 'weeks_on_bb100', data=bb, kind='scatter', color="orange")
track_pos_weeks_jointplot.savefig('track_pos_weeks_jointplot.jpg', bbox_inches='tight')

# %%
#a t-test is better for interpreting this plot
trackpos_weeksbb_bar = sns.barplot('track_pos', 'weeks_on_bb100', data=bb, hue='track_neg', color="orange")
trackpos_weeksbb_bar.savefig('trackpos_weeksbb_bar.jpg', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-d7c373072882> in <module>()
#       1 #a t-test is better for interpreting this plot
#       2 trackpos_weeksbb_bar = sns.barplot('track_pos', 'weeks_on_bb100', data=bb, hue='track_neg', color="orange")
# ----> 3 trackpos_weeksbb_bar.savefig('trackpos_weeksbb_bar.jpg', bbox_inches='tight')
#
# AttributeError: 'AxesSubplot' object has no attribute 'savefig'

# %%
from scipy.stats import ttest_ind

#ttest sample 

cat3 = []
cat4 = []

for i, j in enumerate(bb['track_neg']):
    if j == 0:
        cat3.append(bb['bb_ratio'][i])
        
for a, b in enumerate(bb['track_neg']):
    if b < 0:
        cat4.append(bb['bb_ratio'][a])        
        

t_stata, p_vala = ttest_ind(cat3, cat4, equal_var=False)

print("T stat and P val:", t_stata, p_vala, "mean (category 3,4):", np.mean(cat3),np.mean(cat4))
# Out:
# ('T stat and P val:', -1.7604263097403956, 0.082938288605145238, 'mean (category 3,4):', 1.4969929259769781, 1.7938996183586993)

# %%
from scipy.stats import ttest_ind

#ttest for whether more positive songs have higher bb_ratio

cat1 = []
cat2 = []

for i, j in enumerate(bb['track_pos']):
    if j == 0:
        cat1.append(bb['bb_ratio'][i])
        
for a, b in enumerate(bb['track_pos']):
    if b == 1 or 2:
        cat2.append(bb['bb_ratio'][a])        
        
t_stat1, p_val1 = ttest_ind(cat1, cat2, equal_var=False)

print("T stat and P val:", t_stat1, p_val1, "mean (category 1,2):", np.mean(cat1),np.mean(cat2) )
# Out:
# ('T stat and P val:', -0.59226175594101249, 0.55391108145568058, 'mean (category 1,2):', 1.4969929259769781, 1.5456968628976389)

# %%
#a t-test is better for interpreting this plot
#note the black bars noting the standard deviation is high, because the sample for 2.0 is low (relatively few song titles had two 'negative' words)
avgbb_weeks=sns.barplot('track_neg', 'weeks_on_bb100', data=bb, hue='track_pos', color="orange")
avgbb_weeks.savefig('track_neg_weeks_bar.jpg', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-713d855b8ac4> in <module>()
#       2 #note the black bars noting the standard deviation is high, because the sample for 2.0 is low (relatively few song titles had two 'negative' words)
#       3 avgbb_weeks=sns.barplot('track_neg', 'weeks_on_bb100', data=bb, hue='track_pos', color="orange")
# ----> 4 avgbb_weeks.savefig('track_neg_weeks_bar.jpg', bbox_inches='tight')
#
# AttributeError: 'AxesSubplot' object has no attribute 'savefig'

# %%
#there is a correlation between how long songs are popular and magnitude of how popular songs are
#note that the upper left region is where the biggest hits were - the songs with lower averages prolonged duration
#those 4-5 outliars really stand out
avgbb_weeks=sns.regplot('avg_on_bb100', 'weeks_on_bb100', data=bb, color="orange")
avgbb_weeks.savefig('avgbb_weeks.jpg', bbox_inches='tight')
#there may be some phenomenon with the data that leads to the above cap at 20 weeks
#perhaps that is when some radio shows typically stop playing such songs, with the exception of some 'instant classics'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-921b6eef77b8> in <module>()
#       3 #those 4-5 outliars really stand out
#       4 avgbb_weeks=sns.regplot('avg_on_bb100', 'weeks_on_bb100', data=bb, color="orange")
# ----> 5 avgbb_weeks.savefig('avgbb_weeks.jpg', bbox_inches='tight')
#       6 #there may be some phenomenon with the data that leads to the above cap at 20 weeks
#       7 #perhaps that is when some radio shows typically stop playing such songs, with the exception of some 'instant classics'
#
# AttributeError: 'AxesSubplot' object has no attribute 'savefig'

# %%
avgbb_weeks_jitter = sns.regplot('avg_on_bb100', 'weeks_on_bb100', data=bb, color="orange", fit_reg=1, x_jitter=10, y_jitter=5)
#by jittering the scatter plot the trend is a little more clear
avgbb_weeks_jitter.savefig('xt', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-2ffd5a883ada> in <module>()
#       1 avgbb_weeks_jitter = sns.regplot('avg_on_bb100', 'weeks_on_bb100', data=bb, color="orange", fit_reg=1, x_jitter=10, y_jitter=5)
#       2 #by jittering the scatter plot the trend is a little more clear
# ----> 3 avgbb_weeks_jitter.savefig('avgbb_weeks_jitter.jpg', bbox_inches='tight')
#       4
#
# AttributeError: 'AxesSubplot' object has no attribute 'savefig'

# %%
from sklearn import linear_model
import statsmodels.api as sm

X1 = np.array(bb['track_pos'], bb['track_neg']) #should reslice this
X = sm.add_constant(X1)
ys = bb['bb_ratio']
# Fit and summarize OLS model
mod = sm.OLS(ys, X)
res = mod.fit()
OLS_reg = res.summary()
OLS_reg



#blog post: Y2K - signs that milleanials like 'negative' songs
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               bb_ratio   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     5.417
# Date:                Thu, 23 Jun 2016   Prob (F-statistic):             0.0206
# Time:                        08:46:57   Log-Likelihood:                -448.42
# No. Observations:                 317   AIC:                             900.8
# Df Residuals:                     315   BIC:                             908.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          1.4895      0.061     24.386      0.000         1.369     1.610
# x1             0.3241      0.139      2.327      0.021         0.050     0.598
# ==============================================================================
# Omnibus:                      146.943   Durbin-Watson:                   0.377
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              553.378
# Skew:                           2.067   Prob(JB):                    6.85e-121
# Kurtosis:                       7.981   Cond. No.                         2.57
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
