# %%
import pandas as pd
import numpy as np
import sklearn
import pandas as pd 
import numpy as np
import sklearn
import psycopg2 as psy
import os 
import matplotlib.pyplot as plt
import numpy as np
import math
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA 
from sklearn.cluster import KMeans
from sklearn import metrics
from matplotlib import *
import sys
from matplotlib import offsetbox
from sklearn import (manifold, datasets, decomposition, ensemble,
                     discriminant_analysis, random_projection)
from sklearn import metrics
from sklearn.cross_validation import cross_val_score, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, BaggingRegressor

# %matplotlib inline

os.getcwd()
# Out:
# '/Users/HudsonCavanagh/GA_dsi-projects/capstone'

# %%
unemp_03_14 = pd.read_csv('unemp_tot_03_14.csv')
pov_county_year_03_14 = pd.read_csv('pov_county_year_03_14.csv')
cdc_03_14 = pd.read_csv('cdc_03_14.csv')
# pop_03_14 = pd.read_csv('pop_03_14.csv') ---- still working on merging this data!
unemp_03_14 = unemp_03_14.iloc[:,1:]

unemp_03_14.head()
# Out:
#    year  county_code  nan  working_pop  employed_pop  unemployed_pop  \
# 0  2003         1001  NaN      22604.0       21462.0          1142.0
# 1  2003         1003  NaN      72299.0       68702.0          3597.0
# 2  2003         1005  NaN      10977.0       10196.0           781.0
# 3  2003         1007  NaN       8836.0        8309.0           527.0
# 4  2003         1009  NaN      25900.0       24702.0          1198.0
#
#    unemp_perc
# 0         5.1
# 1         5.0
# 2         7.1
# 3         6.0
# 4         4.6

# %%
pov_county_year_03_14 = pov_county_year_03_14.iloc[:,1:]
pov_county_year_03_14.head()
# Out:
#    year  county_code  pov_count_tot  pov_rate_tot  pov_youth_count_0-17  \
# 0  2003         1001         4926.0          10.4                1891.0
# 1  2003         1003        15753.0          10.1                5550.0
# 2  2003         1005         5717.0          22.2                2083.0
# 3  2003         1007         3383.0          16.8                1237.0
# 4  2003         1009         6503.0          11.9                2272.0
#
#    pov_youth_rate_0-17  med_hh_income
# 0                 15.1        44241.0
# 1                 15.6        41961.0
# 2                 30.5        26062.0
# 3                 23.7        32924.0
# 4                 17.3        37758.0

# %%
cdc_03_14 = cdc_03_14.iloc[:,2:]
type(cdc_03_14['population'][3])
# Out:
# numpy.float64

# %%
cdc_03_14['county_code'].value_counts()
# Out:
# 6037     386
# 4013     260
# 17031    251
# 48201    219
# 6073     207
# 42101    195
# 26163    184
# 6065     181
# 6059     178
# 36047    171
# 6071     169
# 48113    163
# 32003    154
# 36005    151
# 48029    141
# 36061    139
# 35001    137
# 53033    135
# 55079    131
# 6067     131
# 12103    126
# 39035    126
# 36081    122
# 4019     120
# 12099    119
# 12011    118
# 6085     117
# 8031     114
# 6001     112
# 49035    110
#         ...
# 45077      1
# 15009      1
# 12019      1
# 48485      1
# 56021      1
# 24013      1
# 41035      1
# 51550      1
# 33017      1
# 55139      1
# 1127       1
# 47179      1
# 21059      1
# 54109      1
# 17113      1
# 22087      1
# 5131       1
# 6025       1
# 17167      1
# 13057      1
# 54005      1
# 34035      1
# 30111      1
# 26021      1
# 26093      1
# 47059      1
# 42007      1
# 9015       1
# 51710      1
# 41033      1
# Name: county_code, dtype: int64

# %%
cdc_03_14.tail()
# Out:
#                      County  County Code Ten-Year Age Groups  \
# 14287  Milwaukee County, WI      55079.0         45-54 years
# 14288  Milwaukee County, WI      55079.0         45-54 years
# 14289  Milwaukee County, WI      55079.0         55-64 years
# 14290  Milwaukee County, WI      55079.0         55-64 years
# 14291     Racine County, WI      55101.0         45-54 years
#
#       Ten-Year Age Groups Code Gender Gender Code                       Race  \
# 14287                    45-54   Male           M  Black or African American
# 14288                    45-54   Male           M                      White
# 14289                    55-64   Male           M  Black or African American
# 14290                    55-64   Male           M                      White
# 14291                    45-54   Male           M                      White
#
#       Race Code         Hispanic Origin Hispanic Origin Code  \
# 14287    2054-5  Not Hispanic or Latino               2186-2
# 14288    2106-3  Not Hispanic or Latino               2186-2
# 14289    2054-5  Not Hispanic or Latino               2186-2
# 14290    2106-3  Not Hispanic or Latino               2186-2
# 14291    2106-3  Not Hispanic or Latino               2186-2
#
#                ...            year  pct_total_deaths deaths population  \
# 14287          ...            2003             0.045   22.0    12340.0
# 14288          ...            2003             0.074   36.0    43678.0
# 14289          ...            2003             0.023   11.0     6461.0
# 14290          ...            2003             0.020   10.0    26734.0
# 14291          ...            2003             0.023   11.0    12187.0
#
#        crude_100k  county_id  state  county_code           CTYNAME  \
# 14287  178.282010      55079     WI        55079  Milwaukee County
# 14288   82.421356      55079     WI        55079  Milwaukee County
# 14289  170.252283      55079     WI        55079  Milwaukee County
# 14290   37.405551      55079     WI        55079  Milwaukee County
# 14291   90.260113      55101     WI        55101     Racine County
#
#                pop_merge_ind
# 14287  Milwaukee County_2003
# 14288  Milwaukee County_2003
# 14289  Milwaukee County_2003
# 14290  Milwaukee County_2003
# 14291     Racine County_2003
#
# [5 rows x 24 columns]

# %%
deaths_pop = cdc_03_14.groupby(by=['year', 'county_code']).sum()
deaths_pop.reset_index(inplace=1)

#merging unemployment

deaths_pop = pd.merge(deaths_pop, unemp_03_14, how='left', left_on=['year', 'county_code'], right_on=['year', 'county_code'])

#merging poverty

deaths_pop = pd.merge(deaths_pop, pov_county_year_03_14, how='left', left_on=['year','county_code'], right_on=['year','county_code'])

#calculations that required merge

deaths_pop['perc_pop_employed'] = deaths_pop['employed_pop']/deaths_pop['population']
deaths_pop['unemp_rate'] = deaths_pop['employed_pop']/deaths_pop['working_pop']
deaths_pop['perc_pop_not_working'] = (deaths_pop['population'] -deaths_pop['working_pop'])/deaths_pop['population']
deaths_pop['pov_rate'] = deaths_pop['pov_count_tot']/ deaths_pop['population']
deaths_pop['pov_rate_youth'] = deaths_pop['pov_youth_count_0-17']/ deaths_pop['population']
deaths_pop['constant'] = 1




deaths_pop.head()
# deaths_pop.isnull().sum()
# Out:
#    year  county_code  County Code  Deaths  Population  pct_total_deaths  \
# 0  2003         1073       2146.0    26.0     54422.0             0.054
# 1  2003         2020       4040.0    24.0     34160.0             0.049
# 2  2003         4013      72234.0   591.0   1783462.0             1.212
# 3  2003         4019      36171.0   149.0    285630.0             0.308
# 4  2003         4025       4025.0    10.0     11831.0             0.020
#
#    deaths  population  crude_100k  county_id    ...     pov_rate_tot  \
# 0    26.0     54422.0   95.427762       2146    ...             14.5
# 1    24.0     34160.0  139.969440       4040    ...              8.7
# 2   591.0   1783462.0  715.153184      72234    ...             12.8
# 3   149.0    285630.0  513.516478      36171    ...             14.3
# 4    10.0     11831.0   84.523709       4025    ...             12.0
#
#    pov_youth_count_0-17  pov_youth_rate_0-17  med_hh_income  \
# 0               31787.0                 20.1        38305.0
# 1                7998.0                 10.4        55197.0
# 2              177188.0                 18.4        46376.0
# 3               48407.0                 21.7        37540.0
# 4                7613.0                 19.6        35303.0
#
#    perc_pop_employed  unemp_rate  perc_pop_not_working  pov_rate  \
# 0           5.572783    0.944680             -4.899122  1.720334
# 1           3.987910    0.936732             -3.257260  0.676464
# 2           0.929834    0.948048              0.019213  0.247740
# 3           1.423103    0.946738             -0.503165  0.444085
# 4           6.818020    0.948899             -6.185191  1.901023
#
#    pov_rate_youth  constant
# 0        0.584084         1
# 1        0.234133         1
# 2        0.099351         1
# 3        0.169474         1
# 4        0.643479         1
#
# [5 rows x 26 columns]

# %%
deaths_pop.dropna(axis=0, subset=['working_pop', 'employed_pop'], inplace=1)
deaths_pop.isnull().sum() # values where nulls
# Out:
# year                       0
# county_code                0
# County Code                0
# Deaths                     0
# Population                 0
# pct_total_deaths           0
# deaths                     0
# population                 0
# crude_100k                 0
# county_id                  0
# nan                     3104
# working_pop                0
# employed_pop               0
# unemployed_pop             0
# unemp_perc                 0
# pov_count_tot              0
# pov_rate_tot               0
# pov_youth_count_0-17       0
# pov_youth_rate_0-17        0
# med_hh_income              0
# perc_pop_employed          0
# unemp_rate                 0
# perc_pop_not_working       0
# pov_rate                   0
# pov_rate_youth             0
# constant                   0
# dtype: int64

# %%
deaths_pop.columns
# Out:
# Index([u'year', u'county_code', u'County Code', u'Deaths', u'Population',
#        u'pct_total_deaths', u'deaths', u'population', u'crude_100k',
#        u'county_id', u'nan', u'working_pop', u'employed_pop',
#        u'unemployed_pop', u'unemp_perc', u'pov_count_tot', u'pov_rate_tot',
#        u'pov_youth_count_0-17', u'pov_youth_rate_0-17', u'med_hh_income',
#        u'perc_pop_employed', u'unemp_rate', u'perc_pop_not_working',
#        u'pov_rate', u'pov_rate_youth', u'constant'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler


y = deaths_pop['crude_100k']



features = deaths_pop[['year', 'population','med_hh_income', 'perc_pop_employed', 'unemp_rate', 'perc_pop_not_working', 'pov_rate', 'pov_rate_youth', 'constant']]

X = StandardScaler().fit_transform(features)
X = pd.DataFrame(X, columns=features.columns)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import train_test_split, cross_val_score
from sklearn.cross_validation import StratifiedKFold, permutation_test_score
from sklearn.tree import DecisionTreeRegressor

stratk = StratifiedKFold(y, n_folds=10, shuffle=True, random_state=66)


dt_simple = DecisionTreeRegressor(min_samples_leaf=4, min_samples_split=6, max_depth=6)

s_dt = cross_val_score(dt_simple, X, y, cv=stratk, n_jobs=-1)

print("Decision Tree", s_dt.mean())
# Out:
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:516: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of labels for any class cannot be less than n_folds=10.
#   % (min_labels, self.n_folds)), Warning)
# ('Decision Tree', 0.57760064712292203)

# %%
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, BaggingRegressor
import seaborn as sns

rf = RandomForestRegressor()
rf_cv = RandomForestRegressor()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=50)
rf.fit(X_train, y_train)
ypred_rf = rf.predict(X_test)
s_rf_cv = cross_val_score(rf_cv, X, y, cv=stratk, n_jobs=-1)

zip(rf.feature_importances_, features.columns)
# Out:
# [(0.021101282928976679, 'year'),
#  (0.13328834655405186, 'population'),
#  (0.063103497948907503, 'med_hh_income'),
#  (0.45029569141076087, 'perc_pop_employed'),
#  (0.029050536820032936, 'unemp_rate'),
#  (0.13319154116701926, 'perc_pop_not_working'),
#  (0.079112333775205226, 'pov_rate'),
#  (0.090856769395045611, 'pov_rate_youth'),
#  (0.0, 'constant')]

# %% [markdown]
# s_rf_cv.mean()

# %%
sns.regplot(ypred_rf, y_test)

# %% [raw]
# ## Takeaways:
#
# --- still need to merge population/ demographic data by county - having a hard time creating cleaned csv
# --- it appears the greatest risk factor is a population that is not fully employed
# --- already seeing good accuracy, with further tuning this could be quite strong. Idea that these features can predict mortality seems to be well-founded
