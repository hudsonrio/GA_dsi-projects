# %%
import pandas as pd
import numpy as np
#downloaded from https://www.census.gov/2010census/csv/pop_density.csv -- state level

pop_dense = pd.read_csv('/Users/HudsonCavanagh/Dropbox/Capstone/non_cdc_data/pop_density.csv')
pop_dense.head()
# Out:
#   # POPULATION DENSITY DATA PROVIDED BY U.S. CENSUS.       Unnamed: 1  \
# 0     # DENSITY EXPRESSED AS PEOPLE PER SQUARE MILE.              NaN
# 1  # DENSITY RANKING EXPRESSED IN ORDER OF MOST D...              NaN
# 2                                    STATE_OR_REGION  1910_POPULATION
# 3                                      United States         92228531
# 4                                            Alabama          2138093
#
#         Unnamed: 2       Unnamed: 3       Unnamed: 4       Unnamed: 5  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2  1920_POPULATION  1930_POPULATION  1940_POPULATION  1950_POPULATION
# 3        106021568        123202660        132165129        151325798
# 4          2348174          2646248          2832961          3061743
#
#         Unnamed: 6       Unnamed: 7       Unnamed: 8       Unnamed: 9  \
# ...

# %%
pop_dense_cols = pop_dense.iloc[2,:]
pop_dense = pop_dense.iloc[3:,:]
pop_dense.columns = pop_dense_cols 
# pop_dense.head()
pop_dense.columns
# Out:
# Index([u'STATE_OR_REGION', u'1910_POPULATION', u'1920_POPULATION',
#        u'1930_POPULATION', u'1940_POPULATION', u'1950_POPULATION',
#        u'1960_POPULATION', u'1970_POPULATION', u'1980_POPULATION',
#        u'1990_POPULATION', u'2000_POPULATION', u'2010_POPULATION',
#        u'1910_DENSITY', u'1920_DENSITY', u'1930_DENSITY', u'1940_DENSITY',
#        u'1950_DENSITY', u'1960_DENSITY', u'1970_DENSITY', u'1980_DENSITY',
#        u'1990_DENSITY', u'2000_DENSITY', u'2010_DENSITY', u'1910_RANK',
#        u'1920_RANK', u'1930_RANK', u'1940_RANK', u'1950_RANK', u'1960_RANK',
#        u'1970_RANK', u'1980_RANK', u'1990_RANK', u'2000_RANK', u'2010_RANK'],
#       dtype='object', name=2)

# %%
def floater(item):
    item = str(item)
    item = item.replace(",", "")
    try:
        item = float(item)
    except:
        pass 
    return item

pop_dense.iloc[:,1:] = pop_dense.iloc[:,1:].applymap(lambda x: floater(x))

pop_dense['2005_dense'] = (pop_dense['2000_DENSITY'] + pop_dense['2010_DENSITY'])/2.0

# %%
type(pop_dense['2010_DENSITY'][3])
# Out:
# float

# %%
pop_dense['2005_dense']
# Out:
# 3       83.55
# 4        91.1
# 5        1.15
# 6       50.75
# 7        53.7
# 8      228.25
# 9          45
# 10      720.7
# 11     431.45
# 12    9613.55
# 13      324.3
# 14     155.35
# 15      200.2
# 16      17.35
# 17      227.4
# 18     175.35
# 19      53.45
# 20       33.9
# 21     106.15
# 22     104.15
# 23       42.2
# 24      570.2
# 25      826.7
# 26      175.3
# 27       64.2
# 28       61.9
# 29      84.25
# 30        6.5
# 31      23.05
# 32       21.4
# 33      142.5
# 34    1169.85
# 35         16
# 36     406.95
# 37     180.85
# 38        9.5
# 39     280.05
# 40       52.5
# 41      37.75
# 42      279.2
# 43    1016.05
# 44      143.7
# 45      10.35
# 46     145.95
# 47      88.05
# 48       30.4
# 49         67
# 50      190.9
# 51      94.95
# 52      76.15
# 53        102
# 54       5.45
# 55     1100.3
# Name: 2005_dense, dtype: object

# %% [markdown]
# ## Found county level data from 2010 census, below
#
# https://www.census.gov/popest/data/maps/2011/maps-county2011.csv
#
# https://www.census.gov/popest/data/maps/2009/Maps-county2009.csv
#
# -seems like the previous years follow the same url pattern
#
# for each county, add three features:
#
# - total population
# - population growth (assuming low or negative is associated with mortality)
# - population density

# %%
map_2011_dense = pd.read_csv('/Users/HudsonCavanagh/Dropbox/Capstone/non_cdc_data/maps-county2011.csv')
map_2011_dense.head(50)
# Out:
#    table with row headers in column B and column headers in rows 3 through 4 (leading dots indicate sub-parts)  \
# 0   Table 3. Cumulative Estimates of Resident Popu...
# 1                                     State FIPS Code
# 2                                                 NaN
# 3                                                 NaN
# 4                                               00000
# 5                                               01000
# 6                                               01001
# 7                                               01003
# 8                                               01005
# 9                                               01007
# 10                                              01009
# 11                                              01011
# 12                                              01013
# 13                                              01015
# 14                                              01017
# ...
