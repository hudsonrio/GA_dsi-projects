# %%
import pandas as pd
import numpy as np
import sklearn
import pandas as pd 
import numpy as np
import sklearn
import psycopg2 as psy
import os 
import matplotlib.pyplot as plt
import numpy as np
import math
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA 
from sklearn.cluster import KMeans
from sklearn import metrics
from matplotlib import *
import sys
from matplotlib import offsetbox
from sklearn import (manifold, datasets, decomposition, ensemble,
                     discriminant_analysis, random_projection)
from sklearn import metrics
from sklearn.cross_validation import cross_val_score, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, BaggingRegressor

# %matplotlib inline

os.getcwd()
# Out:
# '/Users/HudsonCavanagh/GA_dsi-projects/capstone'

# %% [markdown]
# Reading in the CSVs - Deaths are Drug-Related Deaths,

# %%
# cdc_99_03 = pd.read_csv('/Users/HudsonCavanagh/GA_dsi-projects/capstone/Opioid/CDC_Wonder/Underlying Cause of Death, 1999-2003.csv')
# cdc_04_09 = pd.read_csv('/Users/HudsonCavanagh/GA_dsi-projects/capstone/Opioid/CDC_Wonder/Underlying Cause of Death 2004-2009.csv')



cdc_1999 = pd.read_csv('/Users/HudsonCavanagh/Dropbox/Capstone/cdc_data/cdc_1999.csv', delimiter='\t', encoding='utf-8')
cdc_2000 = pd.read_csv('/Users/HudsonCavanagh/Dropbox/Capstone/cdc_data/cdc_2000.csv', delimiter='\t', encoding='utf-8')
cdc_2001 = pd.read_csv('/Users/HudsonCavanagh/Dropbox/Capstone/cdc_data/cdc_2001.csv', delimiter='\t', encoding='utf-8')
cdc_2002 = pd.read_csv('/Users/HudsonCavanagh/Dropbox/Capstone/cdc_data/cdc_2002.csv', delimiter='\t', encoding='utf-8')
cdc_2003 = pd.read_csv('/Users/HudsonCavanagh/Dropbox/Capstone/cdc_data/cdc_2003.csv', delimiter='\t', encoding='utf-8')
cdc_2004 = pd.read_csv('/Users/HudsonCavanagh/Dropbox/Capstone/cdc_data/cdc_2004.csv', delimiter='\t', encoding='utf-8')
cdc_2005 = pd.read_csv('/Users/HudsonCavanagh/Dropbox/Capstone/cdc_data/cdc_2005.csv', delimiter='\t', encoding='utf-8')
cdc_2006 = pd.read_csv('/Users/HudsonCavanagh/Dropbox/Capstone/cdc_data/cdc_2006.csv', delimiter='\t', encoding='utf-8')
cdc_2007 = pd.read_csv('/Users/HudsonCavanagh/Dropbox/Capstone/cdc_data/cdc_2007.csv', delimiter='\t', encoding='utf-8')
cdc_2008 = pd.read_csv('/Users/HudsonCavanagh/Dropbox/Capstone/cdc_data/cdc_2008.csv', delimiter='\t', encoding='utf-8')
cdc_2009 = pd.read_csv('/Users/HudsonCavanagh/Dropbox/Capstone/cdc_data/cdc_2009.csv', delimiter='\t', encoding='utf-8')
cdc_2010 = pd.read_csv('/Users/HudsonCavanagh/Dropbox/Capstone/cdc_data/cdc_2010.csv', delimiter='\t', encoding='utf-8')
cdc_2011 = pd.read_csv('/Users/HudsonCavanagh/Dropbox/Capstone/cdc_data/cdc_2011.csv', delimiter='\t', encoding='utf-8')
cdc_2012 = pd.read_csv('/Users/HudsonCavanagh/Dropbox/Capstone/cdc_data/cdc_2012.csv', delimiter='\t', encoding='utf-8')
cdc_2013 = pd.read_csv('/Users/HudsonCavanagh/Dropbox/Capstone/cdc_data/cdc_2013.csv', delimiter='\t', encoding='utf-8')
cdc_2014_a = pd.read_csv('/Users/HudsonCavanagh/Dropbox/Capstone/cdc_data/cdc_2014_a-mississip.csv', delimiter='\t', encoding='utf-8')
cdc_2014_b = pd.read_csv('/Users/HudsonCavanagh/Dropbox/Capstone/cdc_data/cdc_2014_missouri-z.csv', delimiter='\t', encoding='utf-8')

# %%
def pct_clean(thing):
    thing = str(thing)
    x = thing.replace("%", "")
    return float(x)

def disqual(entry):
    disqual_list = ['nan', 'Not Applicable', np.NaN, 'NaN']
    if entry.isnull() == True:
        return False
    elif type(entry) == float:
        return True
    elif entry in disqual_list:
        return False
    else:
        return True
    
def int_erate(num):
    str(num).replace(".", "").replace(" ", "")
#     try:
    return float(num)
#     except:
#         return num


#Workign with 2014 first, in pieces
cdc_2014_a = cdc_2014_a[cdc_2014_a['Deaths'].isnull() == False]
cdc_2014_b = cdc_2014_b[cdc_2014_b['Deaths'].isnull() == False]


cols_cdc =['Notes','County','County Code','Ten-Year Age Groups',
    'Ten-Year Age Groups Code','Gender','Gender Code', 'Race',
       'Race Code', 'Hispanic Origin', 'Hispanic Origin Code', 'Deaths',
       'Population', 'Crude Rate', '% of Total Deaths']


cdc_2014_a.columns = cols_cdc
cdc_2014_b.columns = cols_cdc

cdc_2014 = pd.concat([cdc_2014_a, cdc_2014_b], axis=0)

#succesfully merged, all dfs imported

cdc_years = (cdc_2014, cdc_2013, cdc_2012, cdc_2011, cdc_2010, cdc_2009, cdc_2008, cdc_2007, cdc_2006, cdc_2005, cdc_2004, cdc_2003, cdc_2002, cdc_2001, cdc_2000, cdc_1999)

#checking what percent of counties I am dropping below

pre_disqual = 0
post_disqual = 0

for check_pre in cdc_years:
    pre_disqual = pre_disqual + len(check_pre)

    
cdc_1999 = cdc_1999[cdc_1999['Deaths'].isnull() == False]
cdc_2000 = cdc_2000[cdc_2000['Deaths'].isnull() == False]
cdc_2001 = cdc_2001[cdc_2001['Deaths'].isnull() == False]
cdc_2002 = cdc_2002[cdc_2002['Deaths'].isnull() == False]
cdc_2003 = cdc_2003[cdc_2003['Deaths'].isnull() == False]
cdc_2004 = cdc_2004[cdc_2004['Deaths'].isnull() == False]
cdc_2005 = cdc_2005[cdc_2005['Deaths'].isnull() == False]
cdc_2006 = cdc_2006[cdc_2006['Deaths'].isnull() == False]
cdc_2007 = cdc_2007[cdc_2007['Deaths'].isnull() == False]
cdc_2008 = cdc_2008[cdc_2008['Deaths'].isnull() == False]
cdc_2009 = cdc_2009[cdc_2009['Deaths'].isnull() == False]
cdc_2010 = cdc_2010[cdc_2010['Deaths'].isnull() == False]
cdc_2011 = cdc_2011[cdc_2011['Deaths'].isnull() == False]
cdc_2012 = cdc_2012[cdc_2012['Deaths'].isnull() == False]
cdc_2013 = cdc_2013[cdc_2013['Deaths'].isnull() == False]

years = [2014,2013,2012,2011,2010,2009,2008,2007,2006,2005,2004,2003,2002,2001,2000,1999]

lista = []

for ind, ex_df in enumerate([cdc_2014, cdc_2013, cdc_2012, cdc_2011, cdc_2010, cdc_2009, cdc_2008, cdc_2007, cdc_2006, cdc_2005, cdc_2004, cdc_2003, cdc_2002, cdc_2001, cdc_2000, cdc_1999]):
    ex_df['year'] = years[ind]
    ex_df['pct_total_deaths'] = ex_df['% of Total Deaths'].apply(lambda x: pct_clean(x))
    ex_df['deaths'] = ex_df['Deaths'].apply(lambda x: float(x))
    ex_df['population'] = ex_df['Population'].apply(lambda x: pd.to_numeric(x, errors='coerce'))
    ex_df['crude_100k'] = ex_df['deaths']/(ex_df['population']/100000)
    
for check_post in cdc_years:
    post_disqual = post_disqual + len(check_post)

print(pre_disqual, post_disqual) #identical - do not appear to be dropping anything?
# Out:
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (18293, 18293)
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
###Used the following two lines to find all the remaining nulls individually, noted below

# cdc_2014['population'].isnull().sum()

# cdc_2010['population'][cdc_2010['population'].isnull()]

# cdc_1999.iloc[473,:] #new york county - White Male 45-54, Hisp = 'Not Stated'
# cdc_2000.iloc[473,:] #ibid
# cdc_2001.iloc[486,:] #null rows - kings --
# cdc_2002.iloc[579,:] #new york
# cdc_2009.iloc[1049,:] #harris county, TX

#going to drop the below rows, no way to determine if these ~10 per row deaths were hispanic or not

cdc_1999.drop(cdc_1999.index[473], inplace=1)
cdc_2000.drop(cdc_2000.index[473], inplace=1)
cdc_2001.drop(cdc_2001.index[486], inplace=1)
cdc_2002.drop(cdc_2002.index[579], inplace=1)
cdc_2009.drop(cdc_2009.index[1049], inplace=1)
# Out:
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## Important note about the above dropped data:
#
# I was forced to drop about 11 deaths per year in the nyc area, all 45-54 white, unclear if hispanic or not
# and some in harris county tx

# %%
cdc_99_14 = pd.concat([cdc_2014, cdc_2013, cdc_2012, cdc_2011, cdc_2010, cdc_2009, cdc_2008, cdc_2007, cdc_2006, cdc_2005, cdc_2004, cdc_2003, cdc_2002, cdc_2001, cdc_2000, cdc_1999], axis=0)

cdc_99_14.drop(['Notes'], inplace=1) #need to fix this to drop notes



cdc_99_14.head()
# Out:
#   Notes                County  County Code Ten-Year Age Groups  \
# 0   NaN  Jefferson County, AL       1073.0         15-24 years
# 1   NaN  Jefferson County, AL       1073.0         25-34 years
# 2   NaN  Jefferson County, AL       1073.0         25-34 years
# 3   NaN  Jefferson County, AL       1073.0         35-44 years
# 4   NaN  Jefferson County, AL       1073.0         35-44 years
#
#   Ten-Year Age Groups Code  Gender Gender Code   Race Race Code  \
# 0                    15-24    Male           M  White    2106-3
# 1                    25-34  Female           F  White    2106-3
# 2                    25-34    Male           M  White    2106-3
# 3                    35-44  Female           F  White    2106-3
# 4                    35-44    Male           M  White    2106-3
#
#           Hispanic Origin Hispanic Origin Code  Deaths Population  Crude Rate  \
# 0  Not Hispanic or Latino               2186-2    11.0      19306  Unreliable
# 1  Not Hispanic or Latino               2186-2    16.0      23590  Unreliable
# 2  Not Hispanic or Latino               2186-2    27.0      22917     117.816
# 3  Not Hispanic or Latino               2186-2    22.0      20774     105.902
# 4  Not Hispanic or Latino               2186-2    26.0      21104     123.199
#
#   % of Total Deaths  year  pct_total_deaths  deaths  population  crude_100k
# 0            0.027%  2014             0.027    11.0     19306.0   56.977106
# 1            0.039%  2014             0.039    16.0     23590.0   67.825350
# 2            0.065%  2014             0.065    27.0     22917.0  117.816468
# 3            0.053%  2014             0.053    22.0     20774.0  105.901608
# 4            0.063%  2014             0.063    26.0     21104.0  123.199393

# %%
def county_clean(code):
    code = str(code)
    code = code.split(".")[0]
    return code


def state_extract(county):
    county = str(county)
    county = county.split(",")[1]
    return county
    

cdc_99_14['county_id'] = cdc_99_14['County Code'].apply(county_clean)
cdc_99_14['state'] = cdc_99_14['County'].apply(state_extract)

cdc_99_14['state']
# Out:
# 0       AL
# 1       AL
# 2       AL
# 3       AL
# 4       AL
# 5       AL
# 6       AL
# 7       AL
# 8       AL
# 9       AL
# 10      AL
# 11      AL
# 12      AL
# 13      AL
# 14      AL
# 15      AK
# 16      AK
# 17      AZ
# 18      AZ
# 19      AZ
# 20      AZ
# 21      AZ
# 22      AZ
# 23      AZ
# 24      AZ
# 25      AZ
# 26      AZ
# 27      AZ
# 28      AZ
# 29      AZ
#       ...
# 624     WA
# 625     WA
# 626     WA
# 627     WA
# 628     WA
# 629     WA
# 630     WA
# 631     WA
# 632     WA
# 633     WA
# 634     WA
# 635     WA
# 636     WA
# 637     WA
# 638     WA
# 639     WA
# 640     WA
# 641     WA
# 642     WA
# 643     WA
# 644     WA
# 645     WI
# 646     WI
# 647     WI
# 648     WI
# 649     WI
# 650     WI
# 651     WI
# 652     WI
# 653     WI
# Name: state, dtype: object

# %%
len(cdc_99_14)
# Out:
# 17092

# %%
import seaborn as sns
cdc_99_14['total_deaths'] = (1/cdc_99_14['pct_total_deaths'])*cdc_99_14['deaths']

sns.regplot(cdc_99_14['total_deaths'], cdc_99_14['population'])

# %%
cdc_99_14['overall_death_rate'] = cdc_99_14['total_deaths']/cdc_99_14['population']
sns.regplot(cdc_99_14['overall_death_rate'],cdc_99_14['crude_100k'])

#strong correlation between overall death rate and crude rate per 100k people

# %%
from collections import defaultdict

# early_pops = defaultdict(int)

# early_pops[cdc_2003['County Code']] == cdc_2003['Population']


cdc_grouped_county_sum = cdc_99_14.groupby(by=['County'], sort=1).sum() # cant use crude_100k or pct_total_deaths on this
cdc_grouped_county_mean = cdc_99_14.groupby(by=['County'], sort=1).mean() # CAN use crude_100k or pct_total_deaths on this

cdc_grouped_county_sum.head()
# Out:
#                     County Code  Deaths    year  pct_total_deaths  deaths  \
# County
# Ada County, ID         512032.0   382.0   64264             0.720   382.0
# Adams County, CO       416052.0   729.0  104433             1.300   729.0
# Alachua County, FL      24002.0    20.0    4014             0.035    20.0
# Alameda County, CA     828138.0  2382.0  276970             4.431  2382.0
# Albany County, NY      108003.0    32.0    6039             0.071    32.0
#
#                     population   crude_100k  total_deaths  overall_death_rate
# County
# Ada County, ID        728411.0  1700.055807  17761.595550            0.788312
# Adams County, CO      930687.0  4114.295324  30103.350270            1.714104
# Alachua County, FL     20126.0   198.751517   1166.666667            0.116009
# Alameda County, CA   4430752.0  9124.246207  76937.611247            3.302389
# Albany County, NY      48277.0   200.238697   1451.425729            0.089207

# %%
cdc_grouped_county_mean.head()



#lets impute 2003 population data into each missing population file, assuming it didn't change too much in 4 years
#first test the difference between 2011, 2007 and 2003 population data to see if this is a safe assumption
#going to wait till all data merged
# Out:
#                     County Code     Deaths         year  pct_total_deaths  \
# County
# Ada County, ID          16001.0  11.937500  2008.250000          0.022500
# Adams County, CO         8001.0  14.019231  2008.326923          0.025000
# Alachua County, FL      12001.0  10.000000  2007.000000          0.017500
# Alameda County, CA       6001.0  17.260870  2007.028986          0.032109
# Albany County, NY       36001.0  10.666667  2013.000000          0.023667
#
#                        deaths    population  crude_100k  total_deaths  \
# County
# Ada County, ID      11.937500  22762.843750   53.126744    555.049861
# Adams County, CO    14.019231  17897.826923   79.121064    578.910582
# Alachua County, FL  10.000000  10063.000000   99.375759    583.333333
# Alameda County, CA  17.260870  32106.898551   66.117726    557.518922
# Albany County, NY   10.666667  16092.333333   66.746232    483.808576
#
#                     overall_death_rate
# County
# Ada County, ID                0.024635
# Adams County, CO              0.032964
# Alachua County, FL            0.058005
# Alameda County, CA            0.023930
# Albany County, NY             0.029736

# %%
import seaborn as sns

sns.regplot(cdc_grouped_county_mean['pct_total_deaths'], cdc_grouped_county_mean['crude_100k'])

# %%
sns.distplot(cdc_grouped_county_mean['crude_100k'])

#histogram visualization of the average crude rate by county, averaged over the 15 years

# %%
cdc_grouped_county_mean['crude_100k'].tail()
# Out:
# County
# Yellowstone County, MT    143.513203
# Yolo County, CA           165.860132
# York County, ME            70.137475
# York County, PA            52.008418
# York County, SC            80.945003
# Name: crude_100k, dtype: float64

# %%
cdc_grouped_county_mean = cdc_99_14.groupby(by=['year'], sort=1).mean()
sns.distplot(cdc_grouped_county_mean['crude_100k'])

# %%
sns.regplot(cdc_99_14['year'], cdc_99_14['crude_100k'])

# %% [markdown]
# ## Start using pivotables for getting demographic looks
#
# need to be able to aggregate at the county level and find
# 1)what proportion of each demographic group the population is
# 2) what proportion of deaths each demographic group represents

# %% [markdown]
# ## Begin Time Series Analysis Here - SARIMA

# %%
cdc_99_14
# Out:
#     Notes                 County  County Code Ten-Year Age Groups  \
# 0     NaN   Jefferson County, AL       1073.0         15-24 years
# 1     NaN   Jefferson County, AL       1073.0         25-34 years
# 2     NaN   Jefferson County, AL       1073.0         25-34 years
# 3     NaN   Jefferson County, AL       1073.0         35-44 years
# 4     NaN   Jefferson County, AL       1073.0         35-44 years
# 5     NaN   Jefferson County, AL       1073.0         45-54 years
# 6     NaN   Jefferson County, AL       1073.0         45-54 years
# 7     NaN   Jefferson County, AL       1073.0         55-64 years
# 8     NaN   Jefferson County, AL       1073.0         55-64 years
# 9     NaN   Jefferson County, AL       1073.0         55-64 years
# 10    NaN     Madison County, AL       1089.0         35-44 years
# 11    NaN      Mobile County, AL       1097.0         35-44 years
# 12    NaN      Mobile County, AL       1097.0         45-54 years
# 13    NaN      Mobile County, AL       1097.0         45-54 years
# 14    NaN      Mobile County, AL       1097.0         55-64 years
# 15    NaN  Anchorage Borough, AK       2020.0         45-54 years
# 16    NaN  Anchorage Borough, AK       2020.0         55-64 years
# 17    NaN    Maricopa County, AZ       4013.0         15-24 years
# 18    NaN    Maricopa County, AZ       4013.0         15-24 years
# 19    NaN    Maricopa County, AZ       4013.0         15-24 years
# 20    NaN    Maricopa County, AZ       4013.0         25-34 years
# 21    NaN    Maricopa County, AZ       4013.0         25-34 years
# 22    NaN    Maricopa County, AZ       4013.0         25-34 years
# 23    NaN    Maricopa County, AZ       4013.0         25-34 years
# 24    NaN    Maricopa County, AZ       4013.0         35-44 years
# 25    NaN    Maricopa County, AZ       4013.0         35-44 years
# 26    NaN    Maricopa County, AZ       4013.0         35-44 years
# 27    NaN    Maricopa County, AZ       4013.0         35-44 years
# 28    NaN    Maricopa County, AZ       4013.0         45-54 years
# 29    NaN    Maricopa County, AZ       4013.0         45-54 years
# ..    ...                    ...          ...                 ...
# 624   NaN        King County, WA      53033.0         15-24 years
# 625   NaN        King County, WA      53033.0         25-34 years
# 626   NaN        King County, WA      53033.0         35-44 years
# 627   NaN        King County, WA      53033.0         35-44 years
# 628   NaN        King County, WA      53033.0         45-54 years
# 629   NaN        King County, WA      53033.0         45-54 years
# 630   NaN        King County, WA      53033.0         55-64 years
# 631   NaN        King County, WA      53033.0         65-74 years
# 632   NaN        King County, WA      53033.0         65-74 years
# 633   NaN        King County, WA      53033.0         75-84 years
# 634   NaN      Kitsap County, WA      53035.0         45-54 years
# 635   NaN      Pierce County, WA      53053.0         35-44 years
# 636   NaN      Pierce County, WA      53053.0         35-44 years
# 637   NaN      Pierce County, WA      53053.0         45-54 years
# 638   NaN      Pierce County, WA      53053.0         55-64 years
# 639   NaN   Snohomish County, WA      53061.0         35-44 years
# 640   NaN   Snohomish County, WA      53061.0         45-54 years
# 641   NaN   Snohomish County, WA      53061.0         45-54 years
# 642   NaN   Snohomish County, WA      53061.0         55-64 years
# 643   NaN     Spokane County, WA      53063.0         35-44 years
# 644   NaN     Spokane County, WA      53063.0         45-54 years
# 645   NaN        Dane County, WI      55025.0         45-54 years
# 646   NaN   Milwaukee County, WI      55079.0         35-44 years
# 647   NaN   Milwaukee County, WI      55079.0         35-44 years
# 648   NaN   Milwaukee County, WI      55079.0         35-44 years
# 649   NaN   Milwaukee County, WI      55079.0         45-54 years
# 650   NaN   Milwaukee County, WI      55079.0         45-54 years
# 651   NaN   Milwaukee County, WI      55079.0         45-54 years
# 652   NaN   Milwaukee County, WI      55079.0         55-64 years
# 653   NaN    Waukesha County, WI      55133.0         35-44 years
#
#     Ten-Year Age Groups Code  Gender Gender Code  \
# 0                      15-24    Male           M
# 1                      25-34  Female           F
# 2                      25-34    Male           M
# 3                      35-44  Female           F
# 4                      35-44    Male           M
# 5                      45-54  Female           F
# 6                      45-54    Male           M
# 7                      55-64  Female           F
# 8                      55-64    Male           M
# 9                      55-64    Male           M
# 10                     35-44    Male           M
# 11                     35-44    Male           M
# 12                     45-54  Female           F
# 13                     45-54    Male           M
# 14                     55-64    Male           M
# 15                     45-54    Male           M
# 16                     55-64    Male           M
# 17                     15-24  Female           F
# 18                     15-24    Male           M
# 19                     15-24    Male           M
# 20                     25-34  Female           F
# 21                     25-34    Male           M
# 22                     25-34    Male           M
# 23                     25-34    Male           M
# 24                     35-44  Female           F
# 25                     35-44  Female           F
# 26                     35-44    Male           M
# 27                     35-44    Male           M
# 28                     45-54  Female           F
# 29                     45-54  Female           F
# ..                       ...     ...         ...
# 624                    15-24    Male           M
# 625                    25-34    Male           M
# 626                    35-44  Female           F
# 627                    35-44    Male           M
# 628                    45-54  Female           F
# 629                    45-54    Male           M
# 630                    55-64    Male           M
# 631                    65-74  Female           F
# 632                    65-74    Male           M
# 633                    75-84    Male           M
# 634                    45-54    Male           M
# 635                    35-44  Female           F
# 636                    35-44    Male           M
# 637                    45-54    Male           M
# 638                    55-64    Male           M
# 639                    35-44    Male           M
# 640                    45-54  Female           F
# 641                    45-54    Male           M
# 642                    55-64    Male           M
# 643                    35-44    Male           M
# 644                    45-54    Male           M
# 645                    45-54    Male           M
# 646                    35-44  Female           F
# 647                    35-44    Male           M
# 648                    35-44    Male           M
# 649                    45-54  Female           F
# 650                    45-54    Male           M
# 651                    45-54    Male           M
# 652                    55-64    Male           M
# 653                    35-44    Male           M
#
#                                  Race Race Code         Hispanic Origin  \
# 0                               White    2106-3  Not Hispanic or Latino
# 1                               White    2106-3  Not Hispanic or Latino
# 2                               White    2106-3  Not Hispanic or Latino
# 3                               White    2106-3  Not Hispanic or Latino
# 4                               White    2106-3  Not Hispanic or Latino
# 5                               White    2106-3  Not Hispanic or Latino
# 6                               White    2106-3  Not Hispanic or Latino
# 7                               White    2106-3  Not Hispanic or Latino
# 8           Black or African American    2054-5  Not Hispanic or Latino
# 9                               White    2106-3  Not Hispanic or Latino
# 10                              White    2106-3  Not Hispanic or Latino
# 11                              White    2106-3  Not Hispanic or Latino
# 12                              White    2106-3  Not Hispanic or Latino
# 13                              White    2106-3  Not Hispanic or Latino
# 14                              White    2106-3  Not Hispanic or Latino
# 15                              White    2106-3  Not Hispanic or Latino
# 16                              White    2106-3  Not Hispanic or Latino
# 17                              White    2106-3  Not Hispanic or Latino
# 18                              White    2106-3      Hispanic or Latino
# 19                              White    2106-3  Not Hispanic or Latino
# 20                              White    2106-3  Not Hispanic or Latino
# 21   American Indian or Alaska Native    1002-5  Not Hispanic or Latino
# 22                              White    2106-3      Hispanic or Latino
# 23                              White    2106-3  Not Hispanic or Latino
# 24                              White    2106-3      Hispanic or Latino
# 25                              White    2106-3  Not Hispanic or Latino
# 26                              White    2106-3      Hispanic or Latino
# 27                              White    2106-3  Not Hispanic or Latino
# 28          Black or African American    2054-5  Not Hispanic or Latino
# 29                              White    2106-3      Hispanic or Latino
# ..                                ...       ...                     ...
# 624                             White    2106-3  Not Hispanic or Latino
# 625                             White    2106-3  Not Hispanic or Latino
# 626                             White    2106-3  Not Hispanic or Latino
# 627                             White    2106-3  Not Hispanic or Latino
# 628                             White    2106-3  Not Hispanic or Latino
# 629                             White    2106-3  Not Hispanic or Latino
# 630                             White    2106-3  Not Hispanic or Latino
# 631                             White    2106-3  Not Hispanic or Latino
# 632                             White    2106-3  Not Hispanic or Latino
# 633                             White    2106-3  Not Hispanic or Latino
# 634                             White    2106-3  Not Hispanic or Latino
# 635                             White    2106-3  Not Hispanic or Latino
# 636                             White    2106-3  Not Hispanic or Latino
# 637                             White    2106-3  Not Hispanic or Latino
# 638                             White    2106-3  Not Hispanic or Latino
# 639                             White    2106-3  Not Hispanic or Latino
# 640                             White    2106-3  Not Hispanic or Latino
# 641                             White    2106-3  Not Hispanic or Latino
# 642                             White    2106-3  Not Hispanic or Latino
# 643                             White    2106-3  Not Hispanic or Latino
# 644                             White    2106-3  Not Hispanic or Latino
# 645                             White    2106-3  Not Hispanic or Latino
# 646                             White    2106-3  Not Hispanic or Latino
# 647         Black or African American    2054-5  Not Hispanic or Latino
# 648                             White    2106-3  Not Hispanic or Latino
# 649                             White    2106-3  Not Hispanic or Latino
# 650         Black or African American    2054-5  Not Hispanic or Latino
# 651                             White    2106-3  Not Hispanic or Latino
# 652                             White    2106-3  Not Hispanic or Latino
# 653                             White    2106-3  Not Hispanic or Latino
#
#             ...         % of Total Deaths  year pct_total_deaths deaths  \
# 0           ...                    0.027%  2014            0.027   11.0
# 1           ...                    0.039%  2014            0.039   16.0
# 2           ...                    0.065%  2014            0.065   27.0
# 3           ...                    0.053%  2014            0.053   22.0
# 4           ...                    0.063%  2014            0.063   26.0
# 5           ...                    0.046%  2014            0.046   19.0
# 6           ...                    0.078%  2014            0.078   32.0
# 7           ...                    0.029%  2014            0.029   12.0
# 8           ...                    0.024%  2014            0.024   10.0
# 9           ...                    0.080%  2014            0.080   33.0
# 10          ...                    0.024%  2014            0.024   10.0
# 11          ...                    0.027%  2014            0.027   11.0
# 12          ...                    0.024%  2014            0.024   10.0
# 13          ...                    0.024%  2014            0.024   10.0
# 14          ...                    0.048%  2014            0.048   20.0
# 15          ...                    0.029%  2014            0.029   12.0
# 16          ...                    0.029%  2014            0.029   12.0
# 17          ...                    0.024%  2014            0.024   10.0
# 18          ...                    0.034%  2014            0.034   14.0
# 19          ...                    0.048%  2014            0.048   20.0
# 20          ...                    0.078%  2014            0.078   32.0
# 21          ...                    0.024%  2014            0.024   10.0
# 22          ...                    0.053%  2014            0.053   22.0
# 23          ...                    0.172%  2014            0.172   71.0
# 24          ...                    0.024%  2014            0.024   10.0
# 25          ...                    0.114%  2014            0.114   47.0
# 26          ...                    0.078%  2014            0.078   32.0
# 27          ...                    0.237%  2014            0.237   98.0
# 28          ...                    0.024%  2014            0.024   10.0
# 29          ...                    0.029%  2014            0.029   12.0
# ..          ...                       ...   ...              ...    ...
# 624         ...                    0.026%  1999            0.026   10.0
# 625         ...                    0.051%  1999            0.051   20.0
# 626         ...                    0.057%  1999            0.057   22.0
# 627         ...                    0.142%  1999            0.142   55.0
# 628         ...                    0.062%  1999            0.062   24.0
# 629         ...                    0.170%  1999            0.170   66.0
# 630         ...                    0.057%  1999            0.057   22.0
# 631         ...                    0.033%  1999            0.033   13.0
# 632         ...                    0.041%  1999            0.041   16.0
# 633         ...                    0.028%  1999            0.028   11.0
# 634         ...                    0.031%  1999            0.031   12.0
# 635         ...                    0.028%  1999            0.028   11.0
# 636         ...                    0.062%  1999            0.062   24.0
# 637         ...                    0.062%  1999            0.062   24.0
# 638         ...                    0.031%  1999            0.031   12.0
# 639         ...                    0.049%  1999            0.049   19.0
# 640         ...                    0.031%  1999            0.031   12.0
# 641         ...                    0.067%  1999            0.067   26.0
# 642         ...                    0.026%  1999            0.026   10.0
# 643         ...                    0.039%  1999            0.039   15.0
# 644         ...                    0.036%  1999            0.036   14.0
# 645         ...                    0.041%  1999            0.041   16.0
# 646         ...                    0.031%  1999            0.031   12.0
# 647         ...                    0.033%  1999            0.033   13.0
# 648         ...                    0.070%  1999            0.070   27.0
# 649         ...                    0.031%  1999            0.031   12.0
# 650         ...                    0.054%  1999            0.054   21.0
# 651         ...                    0.082%  1999            0.082   32.0
# 652         ...                    0.054%  1999            0.054   21.0
# 653         ...                    0.026%  1999            0.026   10.0
#
#     population  crude_100k  county_id  state  total_deaths  overall_death_rate
# 0      19306.0   56.977106       1073     AL    407.407407            0.021103
# 1      23590.0   67.825350       1073     AL    410.256410            0.017391
# 2      22917.0  117.816468       1073     AL    415.384615            0.018126
# 3      20774.0  105.901608       1073     AL    415.094340            0.019981
# 4      21104.0  123.199393       1073     AL    412.698413            0.019555
# 5      23482.0   80.913040       1073     AL    413.043478            0.017590
# 6      22839.0  140.111213       1073     AL    410.256410            0.017963
# 7      25098.0   47.812575       1073     AL    413.793103            0.016487
# 8      15872.0   63.004032       1073     AL    416.666667            0.026252
# 9      23237.0  142.014890       1073     AL    412.500000            0.017752
# 10     13907.0   71.906234       1089     AL    416.666667            0.029961
# 11     14645.0   75.110959       1097     AL    407.407407            0.027819
# 12     17090.0   58.513751       1097     AL    416.666667            0.024381
# 13     16458.0   60.760724       1097     AL    416.666667            0.025317
# 14     16682.0  119.889701       1097     AL    416.666667            0.024977
# 15     13800.0   86.956522       2020     AK    413.793103            0.029985
# 16     13377.0   89.706212       2020     AK    413.793103            0.030933
# 17    128412.0    7.787434       4013     AZ    416.666667            0.003245
# 18    105472.0   13.273665       4013     AZ    411.764706            0.003904
# 19    134544.0   14.865026       4013     AZ    416.666667            0.003097
# 20    149601.0   21.390231       4013     AZ    410.256410            0.002742
# 21      6564.0  152.346130       4013     AZ    416.666667            0.063478
# 22     89859.0   24.482801       4013     AZ    415.094340            0.004619
# 23    154537.0   45.943690       4013     AZ    412.790698            0.002671
# 24     82259.0   12.156724       4013     AZ    416.666667            0.005065
# 25    145963.0   32.199941       4013     AZ    412.280702            0.002825
# 26     80350.0   39.825762       4013     AZ    410.256410            0.005106
# 27    148059.0   66.189830       4013     AZ    413.502110            0.002793
# 28     13665.0   73.179656       4013     AZ    416.666667            0.030492
# 29     61483.0   19.517590       4013     AZ    413.793103            0.006730
# ..         ...         ...        ...    ...           ...                 ...
# 624    77787.0   12.855619      53033     WA    384.615385            0.004944
# 625   108319.0   18.463981      53033     WA    392.156863            0.003620
# 626   117309.0   18.753889      53033     WA    385.964912            0.003290
# 627   121049.0   45.436146      53033     WA    387.323944            0.003200
# 628   105648.0   22.716947      53033     WA    387.096774            0.003664
# 629   104359.0   63.243228      53033     WA    388.235294            0.003720
# 630    58128.0   37.847509      53033     WA    385.964912            0.006640
# 631    39657.0   32.781098      53033     WA    393.939394            0.009934
# 632    34026.0   47.022865      53033     WA    390.243902            0.011469
# 633    23915.0   45.996237      53033     WA    392.857143            0.016427
# 634    15687.0   76.496462      53035     WA    387.096774            0.024676
# 635    46667.0   23.571260      53053     WA    392.857143            0.008418
# 636    47578.0   50.443482      53053     WA    387.096774            0.008136
# 637    39580.0   60.636685      53053     WA    387.096774            0.009780
# 638    23950.0   50.104384      53053     WA    387.096774            0.016163
# 639    48981.0   38.790551      53061     WA    387.755102            0.007916
# 640    38501.0   31.168022      53061     WA    387.096774            0.010054
# 641    38477.0   67.572836      53061     WA    388.059701            0.010085
# 642    20897.0   47.853759      53061     WA    384.615385            0.018405
# 643    30287.0   49.526199      53063     WA    384.615385            0.012699
# 644    27662.0   50.610946      53063     WA    388.888889            0.014059
# 645    27700.0   57.761733      55025     WI    390.243902            0.014088
# 646    47512.0   25.256777      55079     WI    387.096774            0.008147
# 647    14155.0   91.840339      55079     WI    393.939394            0.027830
# 648    47976.0   56.278139      55079     WI    385.714286            0.008040
# 649    42950.0   27.939464      55079     WI    387.096774            0.009013
# 650    10617.0  197.795988      55079     WI    388.888889            0.036629
# 651    42258.0   75.725306      55079     WI    390.243902            0.009235
# 652    24481.0   85.780810      55079     WI    388.888889            0.015885
# 653    30697.0   32.576473      55133     WI    384.615385            0.012529
#
# [17092 rows x 24 columns]

# %%
def accident_clean(pop):
    pop = str(pop)
    pop = pop.replace(",", "")
    try:
        return float(pop)
    except: 
        return 'error'

accidents = pd.read_csv('/Users/HudsonCavanagh/Dropbox/Capstone/cdc_data/accidents_01-14.csv')

accidents = accidents[accidents['Age Group']!='Unknown yr']
accidents['Injuries'] = accidents['Injuries'].apply(lambda x: float(x))
accidents['Population'] = accidents['Population'].apply(lambda x: accident_clean(x))



accidents['inj_rate_100k']= accidents['Injuries']/(accidents['Population']/1000000)
# accidents

# %% [markdown]
# ####  Above should be used for graphical analysis to test whether hypothesis that increase in accidents is driving pain meds perscrips

# %% [markdown]
# ## Start making demographic, state dummies
#
# 1) classify for each demographic group whether they will be above the national mean (need dummies for each demo line)
# 2) classify for each demographic group whether they will increase from year before
# 3) regression for each county crude rate (need figures for proportion of demographic groups in county_

# %%
#for merging, need to clean county code
from collections import defaultdict
# import defaultdict

def county_cleaner(county):
    county = str(county).split(".")[0]
    if len(county) == 4:
        county = '0' + county
    return county

cdc_99_14['county_code'] = cdc_99_14['County Code'].apply(county_cleaner)

# %% [markdown]
# #### Grabbing county - code conversions for later

# %%
ccodes = cdc_99_14.loc[:,['county_code', 'County']] #grabbing this 
ccodes.index=ccodes['county_code']
ccodes = ccodes.iloc[:,1:]
ccodes = ccodes.to_dict()
ccodes = ccodes['County']
ccodes['01073'] #test
# cdc_99_14.head()
# Out:
# u'Jefferson County, AL'

# %% [markdown]
# ## Decided to simplify this (at least for now)
#
# 1) Going to make two targets for model, deaths by county-year and death rate(per 100k) by county-year
# 2) Can easy go back and use, for example, white male deaths by county if of interest
# 3) Because I'm going to merge on demographic data for each county below, I don't necessarily need to retain the victims demographic for this analysis (although awesome for EDA and summary)

# %%
# cdc_99_14['year']

# %%
attempt_pivot =pd.pivot_table(cdc_99_14, values=['population', 'deaths'], index=['County','year', 'Ten-Year Age Groups Code', 'Gender Code', 'Race', 'Hispanic Origin'], aggfunc='sum', fill_value=None, margins=False, dropna=True, margins_name='All')
# attempt_pivot #this won't work because it doesn't have zero values
#need to re-merge population data onto deaths because this population data does not add up
#appears that it accurately describes the subgroup, but does not sum properly
death_rate_pivot =pd.pivot_table(cdc_99_14, values=['crude_100k'], index=['County','year'], aggfunc='mean', fill_value=None, margins=False, dropna=True, margins_name='All')

# %% [markdown]
# ## Loading population data by county
# http://www.census.gov/popest/data/counties/asrh/2015/CC-EST2015-ALLDATA.html -15

# %% [markdown]
# ## Merging Datasets
#
# For poverty and unemployment data, combine state FIPS Code and County Fips code for county code in CDC data
#
# CDC county code needs to be transformed:
# -remove float
# -add 0 at the beginning of first ten states
# -may also want to try by extracting county name from each row

# %%
cdc_99_14['CTYNAME'] = cdc_99_14['County'].apply(lambda x: x.split(",")[0].strip(" "))
cdc_99_14['year'] = cdc_99_14['year'].apply(lambda x: str(x))
cdc_99_14['pop_merge_ind'] = cdc_99_14['CTYNAME'] + "_" + cdc_99_14['year']
cdc_99_14['pop_merge_ind'][1]
# Out:
# 1    Jefferson County_2014
# 1       Greene County_2014
# 1    Jefferson County_2013
# 1    Jefferson County_2012
# 1    Jefferson County_2011
# 1    Jefferson County_2010
# 1    Jefferson County_2009
# 1    Jefferson County_2008
# 1    Jefferson County_2007
# 1    Jefferson County_2006
# 1    Jefferson County_2005
# 1    Jefferson County_2004
# 1    Jefferson County_2003
# 1    Jefferson County_2002
# 1    Jefferson County_2001
# 1    Jefferson County_2000
# 1    Jefferson County_1999
# Name: pop_merge_ind, dtype: object

# %%
death_count_pivot = pd.pivot_table(cdc_99_14, values=['deaths'], index=['CTYNAME','year'], aggfunc='sum', fill_value=None, margins=False, dropna=True, margins_name='All')

# %% [markdown]
# ### Population Dataset explanation:
# http://www.census.gov/popest/data/counties/asrh/2015/files/CC-EST2015-ALLDATA.pdf
#
# BAC_Male = black, alone or in combination

# %%
def age_grp_clean(age):
    if age == 0:
        return 'total'
    if age == 1:
        return 'age_0-4'
    if age == 2:
        return 'age_5-14'
    if age == 3:
        return 'age_5-14'
    if age == 4:
        return 'age_15-24'
    if age == 5:
        return 'age_15-24'
    if age == 6:
        return 'age_25-34'
    if age == 7:
        return 'age_25-34'
    if age == 8:
        return 'age_35-44'
    if age == 9:
        return 'age_35-44'
    if age == 10:
        return 'age_45-54'
    if age == 11:
        return 'age_45-54'
    if age == 12:
        return 'age_55-64'
    if age == 13:
        return 'age_55-64'
    if age == 14:
        return 'age_65-74'
    if age == 15:
        return 'age_65-74'
    if age == 16:
        return 'age_75-84'
    if age == 17:
        return 'age_75-84'
    if age == 18:
        return 'age_85+'
    
def year_clean(year):
    if year == 1:
        return '2010_census'
    if year == 2:
        return '2010_pop_est_base'
    if year == 3:
        return '2010'
    if year == 4:
        return '2011'
    if year == 5:
        return '2012'
    if year == 6:
        return '2013'
    if year == 7:
        return '2014'
    if year == 8:
        return '2015'
 

pop_15 = pd.read_csv("/Users/HudsonCavanagh/Dropbox/Capstone/non_cdc_data/pop_data_15.csv")
pop_15['age'] = pop_15['AGEGRP'].apply(lambda x:age_grp_clean(x))
pop_15['year'] = pop_15['YEAR'].apply(lambda x: year_clean(x))
pop_15['AGEGRP'] = pop_15['AGEGRP'].apply(lambda x: int(x))
pop_15['pop_sub_15'] = pop_15['TOT_POP'] * pop_15['AGEGRP'].apply(lambda x: 1 if x in (1,2,3) else 0)
pop_15['pop_15-34'] = pop_15['TOT_POP'] * pop_15['AGEGRP'].apply(lambda x: 1 if x in (4,5,6,7) else 0)
pop_15['pop_35-54'] = pop_15['TOT_POP'] * pop_15['AGEGRP'].apply(lambda x: 1 if x in (8,9,10,11) else 0)
pop_15['pop_55+'] = pop_15['TOT_POP'] * pop_15['AGEGRP'].apply(lambda x: 1 if x >= 12 else 0)
pop_15['pop_black'] = pop_15['BAC_MALE'] +  pop_15['BAC_FEMALE']
pop_15['pop_white'] = pop_15['WA_MALE'] +  pop_15['WA_FEMALE']
pop_15['pop_hisp'] = pop_15['H_MALE'] +  pop_15['H_FEMALE']
# pop_15['pop%_men'] = pop_15['TOT_MALE']/  pop_15['TOT_POP']
# pop_15['pop%_sub_15'] = pop_15['pop_sub_15']/ pop_15['TOT_POP']
# pop_15['pop%_15-34'] = pop_15['pop_15-34']/ pop_15['TOT_POP']
# pop_15['pop%_35-54'] = pop_15['pop_35-54']/ pop_15['TOT_POP']
# pop_15['pop%_55+'] = pop_15['pop_55+']/ pop_15['TOT_POP']
# pop_15['pop%_black'] = pop_15['pop_black']/ pop_15['TOT_POP']
# pop_15['pop_white'] = pop_15['pop_white']/ pop_15['TOT_POP']
# pop_15['pop_hisp'] = pop_15['pop_hisp']/ pop_15['TOT_POP']


pop_15['pop_merge_ind'] = pop_15['CTYNAME'] + "_" + pop_15['year']
pop_10_15 = pop_15.groupby(['CTYNAME', 'year'], axis=0).sum()

pop_10_15.head()


##pd.concat more population figures!! HERE




# pop_15
# Out:
#                                     SUMLEV  STATE  COUNTY  YEAR  AGEGRP  \
# CTYNAME          year
# Abbeville County 2010                  950    855      19    57     171
#                  2010_census           950    855      19    19     171
#                  2010_pop_est_base     950    855      19    38     171
#                  2011                  950    855      19    76     171
#                  2012                  950    855      19    95     171
#
#                                     TOT_POP  TOT_MALE  TOT_FEMALE  WA_MALE  \
# CTYNAME          year
# Abbeville County 2010                 50676     24580       26096    17508
#                  2010_census          50834     24642       26192    17550
#                  2010_pop_est_base    50832     24640       26192    17548
#                  2011                 50210     24398       25812    17374
#                  2012                 50102     24288       25814    17274
#
#                                     WA_FEMALE    ...     HAAC_FEMALE  \
# CTYNAME          year                            ...
# Abbeville County 2010                   17970    ...               0
#                  2010_census            18044    ...               0
#                  2010_pop_est_base      18046    ...               0
#                  2011                   17818    ...               0
#                  2012                   17802    ...               4
#
#                                     HNAC_MALE  HNAC_FEMALE  pop_sub_15  \
# CTYNAME          year
# Abbeville County 2010                       0            0        4696
#                  2010_census                2            0        4750
#                  2010_pop_est_base          2            0        4748
#                  2011                       0            0        4584
#                  2012                       0            0        4555
#
#                                     pop_15-34  pop_35-54  pop_55+  pop_black  \
# CTYNAME          year
# Abbeville County 2010                    5966       6721     7955      14728
#                  2010_census             5957       6774     7936      14738
#                  2010_pop_est_base       5958       6775     7935      14736
#                  2011                    5925       6536     8060      14480
#                  2012                    5964       6334     8198      14486
#
#                                     pop_white  pop_hisp
# CTYNAME          year
# Abbeville County 2010                   35478       526
#                  2010_census            35594       510
#                  2010_pop_est_base      35594       510
#                  2011                   35192       552
#                  2012                   35076       604
#
# [5 rows x 85 columns]

# %%
cdc_99_14['pop_merge_ind'] = cdc_99_14['pop_merge_ind'].apply(lambda x: str(x))
death_pop = cdc_99_14.merge(pop_10_15, how='left', left_on=['CTYNAME', 'year'], right_index=1)#WORKS!

# %%
death_pop['county_code'] = death_pop['county_code'].apply(lambda x: str(x))
deaths_pop = death_pop.groupby(by=['year', 'county_code']).sum()
deaths_pop['pop%_men'] = deaths_pop['TOT_MALE']/  deaths_pop['TOT_POP']
deaths_pop['pop%_sub_15'] = deaths_pop['pop_sub_15']/ deaths_pop['TOT_POP']
deaths_pop['pop%_15-34'] = deaths_pop['pop_15-34']/ deaths_pop['TOT_POP']
deaths_pop['pop%_35-54'] = deaths_pop['pop_35-54']/ deaths_pop['TOT_POP']
deaths_pop['pop%_55+'] = deaths_pop['pop_55+']/ deaths_pop['TOT_POP']
deaths_pop['pop%_black'] = deaths_pop['pop_black']/ deaths_pop['TOT_POP']
deaths_pop['pop%_white'] = deaths_pop['pop_white']/ deaths_pop['TOT_POP']
deaths_pop['pop%_hisp'] = deaths_pop['pop_hisp']/ deaths_pop['TOT_POP']
# deaths_pop['pop%_white'] #this works for listed years!

# %% [markdown]
# ## Loading County level unemployment data (and workforce size by county) below
#
# here is source:
#
# http://www.bls.gov/lau/#cntyaa

# %%
#Clean & merge unemployment data

def unemp_col_clean(fig):
    fig = str(fig)
    fig = fig.replace(",", "").strip(" ")
    return float(fig)

def unemp_fix(df):
    unemp_cols = ['unknown_code', 'state_code', 'cout_code', 'county_state', 'year', 'nan', 'working_pop', 'employed_pop', 'unemployed_pop', 'unemp_perc']
    df = df.iloc[3:,0:]
    df.columns= unemp_cols
    df = df[2:]
    df['county_code'] = df['state_code'] + df['cout_code']# need to clean this
    df['county_code'] = df['county_code'].apply(lambda x: str(x))
    df['working_pop'] = df['working_pop'].apply(unemp_col_clean)
    df['employed_pop'] = df['employed_pop'].apply(unemp_col_clean)
    df['unemployed_pop'] = df['unemployed_pop'].apply(unemp_col_clean)
    df['unemp_perc'] = df['unemp_perc'].apply(unemp_col_clean)
    return df

unemp_14 = pd.read_csv("/Users/HudsonCavanagh/Dropbox/Capstone/non_cdc_data/unemp_14.csv")
unemp_15 = pd.read_csv("/Users/HudsonCavanagh/Dropbox/Capstone/non_cdc_data/unemp_15.csv")



#ADD MORE UNEMP FIGURES WHEN DOWNLOADED

unemp_14 = unemp_fix(unemp_14)
unemp_15 = unemp_fix(unemp_15)


unemp_tot = pd.concat([unemp_14, unemp_15], axis=1)

# unemp_tot['county_code'] = unemp_tot['county_code'].apply(lambda x: str(x))
unemp_tot = unemp_14.groupby(by=['year', 'county_code']).sum()

deaths_pop = deaths_pop.merge(unemp_tot, how='left', left_index=1, right_index=1)
deaths_pop
# Out:
#                   County Code  Deaths  pct_total_deaths  deaths  population  \
# year county_code
# 1999 01073             4292.0    52.0             0.133    52.0    102605.0
#      01097             1097.0    10.0             0.026    10.0     19679.0
#      02020             2020.0    13.0             0.033    13.0     16365.0
#      04013            60195.0   390.0             1.005   390.0   1575758.0
#      04019            24114.0   124.0             0.320   124.0    218133.0
#      06001            48008.0   133.0             0.342   133.0    262877.0
#      06013            12026.0    33.0             0.084    33.0     97817.0
#      06019            30095.0    55.0             0.141    55.0    104417.0
#      06029            48232.0   109.0             0.281   109.0    175942.0
#      06037           175073.0  1443.0             3.717  1443.0   4580185.0
#      06059            72708.0   235.0             0.604   235.0    989789.0
#      06061             6061.0    10.0             0.026    10.0     16641.0
#      06065            54585.0   201.0             0.516   201.0    406001.0
#      06067            36402.0   104.0             0.267   104.0    302830.0
#      06071            66781.0   277.0             0.713   277.0    444667.0
#      06073            78949.0   382.0             0.983   382.0   1019985.0
#      06075            54675.0   174.0             0.447   174.0    187734.0
#      06077             6077.0    14.0             0.036    14.0     20418.0
#      06079             6079.0    17.0             0.044    17.0     15351.0
#      06081            12162.0    25.0             0.064    25.0     64357.0
#      06083             6083.0    10.0             0.026    10.0     17700.0
#      06085            42595.0   110.0             0.283   110.0    292374.0
#      06087             6087.0    16.0             0.041    16.0     16611.0
#      06097            12194.0    22.0             0.057    22.0     59277.0
#      06099            18297.0    43.0             0.110    43.0     51391.0
#      06111            18333.0    45.0             0.115    45.0     88394.0
#      08001             8001.0    15.0             0.039    15.0     22070.0
#      08005            16010.0    22.0             0.057    22.0     63821.0
#      08031            48186.0   111.0             0.285   111.0    125526.0
#      08041            24123.0    55.0             0.141    55.0     94869.0
# ...                       ...     ...               ...     ...         ...
# 2014 48439           484390.0   234.0             0.608   234.0    645577.0
#      48453           387624.0   156.0             0.406   156.0    368425.0
#      48491            48491.0    12.0             0.031    12.0     17723.0
#      49011           147033.0    33.0             0.086    33.0     54942.0
#      49035           441315.0   270.0             0.703   270.0    486237.0
#      49049           196196.0    63.0             0.164    63.0    110692.0
#      49057            98114.0    22.0             0.058    22.0     21557.0
#      51059           102118.0    30.0             0.078    30.0     84540.0
#      51710            51710.0    11.0             0.029    11.0      6329.0
#      51810            51810.0    10.0             0.026    10.0     17747.0
#      53009            53009.0    11.0             0.029    11.0      5278.0
#      53011           265055.0    79.0             0.206    79.0    127796.0
#      53015            53015.0    11.0             0.029    11.0      6807.0
#      53033           689429.0   418.0             1.088   418.0   1019507.0
#      53035           159105.0    33.0             0.086    33.0     40998.0
#      53053           371371.0   176.0             0.458   176.0    271768.0
#      53061           424488.0   166.0             0.431   166.0    306989.0
#      53063           212252.0    83.0             0.216    83.0    104280.0
#      53067            53067.0    10.0             0.026    10.0     16619.0
#      54005            54005.0    10.0             0.026    10.0      1562.0
#      54011           108022.0    25.0             0.065    25.0     11020.0
#      54039           216156.0    62.0             0.161    62.0     44560.0
#      54055            54055.0    14.0             0.036    14.0      3557.0
#      54081           108162.0    24.0             0.062    24.0      9011.0
#      55009           110018.0    20.0             0.052    20.0     28692.0
#      55025           385175.0    89.0             0.231    89.0    200129.0
#      55079           716027.0   275.0             0.715   275.0    380775.0
#      55101            55101.0    10.0             0.026    10.0     12090.0
#      55105            55105.0    10.0             0.026    10.0     10041.0
#      55133           110266.0    30.0             0.078    30.0     48986.0
#
#                    crude_100k  total_deaths  overall_death_rate   SUMLEV  \
# year county_code
# 1999 01073         212.473675   1566.326531            0.066114      NaN
#      01097          50.815590    384.615385            0.019544      NaN
#      02020          79.437825    393.939394            0.024072      NaN
#      04013         468.814895   5816.332811            0.093708      NaN
#      04019         337.272386   2326.788853            0.065612      NaN
#      06001         508.955156   3111.664887            0.128966      NaN
#      06013          67.932156    786.096257            0.016085      NaN
#      06019         278.114479   1948.884449            0.098665      NaN
#      06029         500.226017   3103.681265            0.147105      NaN
#      06037        1234.944796  11261.863382            0.132625      NaN
#      06059         324.068343   4672.137386            0.072047      NaN
#      06061          60.092543    384.615385            0.023113      NaN
#      06065         469.467168   3506.572994            0.088590      NaN
#      06067         222.753064   2336.263798            0.049733      NaN
#      06071         762.356877   4276.000092            0.142180      NaN
#      06073         581.319499   5057.129113            0.101281      NaN
#      06075        1459.071419   3502.970649            0.333758      NaN
#      06077          68.566951    388.888889            0.019046      NaN
#      06079         110.741971    386.363636            0.025169      NaN
#      06081          77.702430    781.036168            0.024308      NaN
#      06083          56.497175    384.615385            0.021730      NaN
#      06085         408.636229   2717.543339            0.111128      NaN
#      06087          96.321715    390.243902            0.023493      NaN
#      06097          74.078128    771.712159            0.026072      NaN
#      06099         273.819305   1173.344948            0.072700      NaN
#      06111         171.893394   1173.902894            0.049480      NaN
#      08001          67.965564    384.615385            0.017427      NaN
#      08005          68.891320    771.712159            0.024185      NaN
#      08031         621.747010   2341.893186            0.146494      NaN
#      08041         174.402093   1171.576540            0.037433      NaN
# ...                       ...           ...                 ...      ...
# 2014 48439         356.710058   3850.531300            0.061418   9500.0
#      48453         362.329717   3077.177107            0.068568   7600.0
#      48491          67.708627    387.096774            0.021841   2850.0
#      49011         182.843585   1151.022504            0.063731   5700.0
#      49035         514.115734   3457.434195            0.065167   8550.0
#      49049         242.063758   1536.310686            0.058012   3800.0
#      49057         204.167290    758.620690            0.070403   1900.0
#      51059          70.961271    769.841270            0.018300   1900.0
#      51710         173.803128    379.310345            0.059932    950.0
#      51810          56.347552    384.615385            0.021672    950.0
#      53009         208.412277    379.310345            0.071866    950.0
#      53011         309.917973   1917.456070            0.075113  57000.0
#      53015         161.598355    379.310345            0.055724    950.0
#      53033         632.023093   4991.960278            0.116687  24700.0
#      53035         244.415485   1151.022504            0.085997   2850.0
#      53053         451.049807   2691.867343            0.071518  33250.0
#      53061         419.890264   3082.950675            0.083791   7600.0
#      53063         323.961132   1535.213156            0.060857   3800.0
#      53067          60.172092    384.615385            0.023143   1900.0
#      54005         640.204866    384.615385            0.246233   7600.0
#      54011         454.263872    769.449715            0.139685   1900.0
#      54039         566.526324   1541.553429            0.139570   3800.0
#      54055         393.590104    388.888889            0.109331   7600.0
#      54081         533.200788    774.193548            0.172000   1900.0
#      55009         139.526760    769.230769            0.053664  17100.0
#      55025         310.219175   2696.756280            0.094787   6650.0
#      55079        1042.694344   4995.913806            0.210127  12350.0
#      55101          82.712986    384.615385            0.031813    950.0
#      55105          99.591674    384.615385            0.038304   2850.0
#      55133         124.250289    769.841270            0.032273   1900.0
#
#                     STATE     ...      pop%_35-54  pop%_55+  pop%_black  \
# year county_code              ...
# 1999 01073            NaN     ...             NaN       NaN         NaN
#      01097            NaN     ...             NaN       NaN         NaN
#      02020            NaN     ...             NaN       NaN         NaN
#      04013            NaN     ...             NaN       NaN         NaN
#      04019            NaN     ...             NaN       NaN         NaN
#      06001            NaN     ...             NaN       NaN         NaN
#      06013            NaN     ...             NaN       NaN         NaN
#      06019            NaN     ...             NaN       NaN         NaN
#      06029            NaN     ...             NaN       NaN         NaN
#      06037            NaN     ...             NaN       NaN         NaN
#      06059            NaN     ...             NaN       NaN         NaN
#      06061            NaN     ...             NaN       NaN         NaN
#      06065            NaN     ...             NaN       NaN         NaN
#      06067            NaN     ...             NaN       NaN         NaN
#      06071            NaN     ...             NaN       NaN         NaN
#      06073            NaN     ...             NaN       NaN         NaN
#      06075            NaN     ...             NaN       NaN         NaN
#      06077            NaN     ...             NaN       NaN         NaN
#      06079            NaN     ...             NaN       NaN         NaN
#      06081            NaN     ...             NaN       NaN         NaN
#      06083            NaN     ...             NaN       NaN         NaN
#      06085            NaN     ...             NaN       NaN         NaN
#      06087            NaN     ...             NaN       NaN         NaN
#      06097            NaN     ...             NaN       NaN         NaN
#      06099            NaN     ...             NaN       NaN         NaN
#      06111            NaN     ...             NaN       NaN         NaN
#      08001            NaN     ...             NaN       NaN         NaN
#      08005            NaN     ...             NaN       NaN         NaN
#      08031            NaN     ...             NaN       NaN         NaN
#      08041            NaN     ...             NaN       NaN         NaN
# ...                   ...     ...             ...       ...         ...
# 2014 48439         9120.0     ...        0.138027  0.105393    0.171643
#      48453         7296.0     ...        0.142168  0.093550    0.098165
#      48491         2128.0     ...        0.149461  0.113756    0.068451
#      49011         3876.0     ...        0.121810  0.092864    0.020680
#      49035         8379.0     ...        0.127678  0.098403    0.026596
#      49049         3724.0     ...        0.101883  0.068551    0.011957
#      49057         1862.0     ...        0.121792  0.107243    0.023023
#      51059         1938.0     ...        0.148721  0.119623    0.110511
#      51710          969.0     ...        0.109198  0.100788    0.447406
#      51810          969.0     ...        0.131821  0.118922    0.220609
#      53009         1007.0     ...        0.104977  0.218728    0.016458
#      53011        33345.0     ...        0.136562  0.128751    0.112007
#      53015         1007.0     ...        0.124993  0.162610    0.016035
#      53033        24947.0     ...        0.144482  0.122003    0.083110
#      53035         3021.0     ...        0.123457  0.151967    0.044047
#      53053        25270.0     ...        0.131126  0.125513    0.096267
#      53061         8056.0     ...        0.143370  0.125601    0.043332
#      53063         4028.0     ...        0.124127  0.139437    0.032373
#      53067         1596.0     ...        0.129111  0.143083    0.049229
#      54005         3686.0     ...        0.130703  0.123666    0.056101
#      54011         2052.0     ...        0.119187  0.149932    0.063784
#      54039         4104.0     ...        0.129071  0.167882    0.089045
#      54055         5206.0     ...        0.133180  0.147546    0.152386
#      54081         2052.0     ...        0.128207  0.165191    0.091600
#      55009        11438.0     ...        0.130183  0.141266    0.033018
#      55025         7315.0     ...        0.128251  0.119183    0.067263
#      55079        13585.0     ...        0.125284  0.119571    0.288806
#      55101         1045.0     ...        0.135715  0.143008    0.131563
#      55105         2147.0     ...        0.132262  0.143801    0.061204
#      55133         2090.0     ...        0.139537  0.157298    0.019606
#
#                   pop%_white  pop%_hisp  nan  working_pop  employed_pop  \
# year county_code
# 1999 01073               NaN        NaN  NaN          NaN           NaN
#      01097               NaN        NaN  NaN          NaN           NaN
#      02020               NaN        NaN  NaN          NaN           NaN
#      04013               NaN        NaN  NaN          NaN           NaN
#      04019               NaN        NaN  NaN          NaN           NaN
#      06001               NaN        NaN  NaN          NaN           NaN
#      06013               NaN        NaN  NaN          NaN           NaN
#      06019               NaN        NaN  NaN          NaN           NaN
#      06029               NaN        NaN  NaN          NaN           NaN
#      06037               NaN        NaN  NaN          NaN           NaN
#      06059               NaN        NaN  NaN          NaN           NaN
#      06061               NaN        NaN  NaN          NaN           NaN
#      06065               NaN        NaN  NaN          NaN           NaN
#      06067               NaN        NaN  NaN          NaN           NaN
#      06071               NaN        NaN  NaN          NaN           NaN
#      06073               NaN        NaN  NaN          NaN           NaN
#      06075               NaN        NaN  NaN          NaN           NaN
#      06077               NaN        NaN  NaN          NaN           NaN
#      06079               NaN        NaN  NaN          NaN           NaN
#      06081               NaN        NaN  NaN          NaN           NaN
#      06083               NaN        NaN  NaN          NaN           NaN
#      06085               NaN        NaN  NaN          NaN           NaN
#      06087               NaN        NaN  NaN          NaN           NaN
#      06097               NaN        NaN  NaN          NaN           NaN
#      06099               NaN        NaN  NaN          NaN           NaN
#      06111               NaN        NaN  NaN          NaN           NaN
#      08001               NaN        NaN  NaN          NaN           NaN
#      08005               NaN        NaN  NaN          NaN           NaN
#      08031               NaN        NaN  NaN          NaN           NaN
#      08041               NaN        NaN  NaN          NaN           NaN
# ...                      ...        ...  ...          ...           ...
# 2014 48439          0.751842   0.278636  NaN     990723.0      941059.0
#      48453          0.807211   0.338092  NaN     644341.0      618059.0
#      48491          0.860743   0.168554  NaN     255327.0      244204.0
#      49011          0.928975   0.089045  NaN     156266.0      150671.0
#      49035          0.885196   0.177807  NaN     577159.0      555908.0
#      49049          0.935389   0.112113  NaN     255870.0      246942.0
#      49057          0.928827   0.177385  NaN     115180.0      110118.0
#      51059          0.666651   0.162685  NaN     622185.0      596248.0
#      51710          0.492870   0.074184  NaN     112466.0      105312.0
#      51810          0.686135   0.077786  NaN     232635.0      221183.0
#      53009          0.878392   0.058637  NaN      26711.0       24478.0
#      53011          0.767243   0.235132  NaN     209174.0      194498.0
#      53015          0.919033   0.084392  NaN      43571.0       40078.0
#      53033          0.699817   0.094066  NaN    1161113.0     1106290.0
#      53035          0.833659   0.072417  NaN     113480.0      106574.0
#      53053          0.776752   0.096390  NaN     385100.0      358258.0
#      53061          0.802125   0.097023  NaN     396624.0      375709.0
#      53063          0.897524   0.052362  NaN     225213.0      209642.0
#      53067          0.817336   0.083063  NaN     123254.0      115313.0
#      54005          0.901717   0.049255  NaN       8441.0        7658.0
#      54011          0.913237   0.013953  NaN      42217.0       39896.0
#      54039          0.888520   0.010828  NaN      88848.0       83617.0
#      54055          0.769809   0.102674  NaN      22254.0       20551.0
#      54081          0.887378   0.014753  NaN      31272.0       29030.0
#      55009          0.909359   0.073409  NaN     138636.0      131911.0
#      55025          0.859685   0.062490  NaN     306147.0      294796.0
#      55079          0.652087   0.142573  NaN     479375.0      446333.0
#      55101          0.841517   0.124824  NaN      99994.0       93383.0
#      55105          0.912286   0.079061  NaN      82406.0       77345.0
#      55133          0.935784   0.045642  NaN     220880.0      211075.0
#
#                   unemployed_pop  unemp_perc
# year county_code
# 1999 01073                   NaN         NaN
#      01097                   NaN         NaN
#      02020                   NaN         NaN
#      04013                   NaN         NaN
#      04019                   NaN         NaN
#      06001                   NaN         NaN
#      06013                   NaN         NaN
#      06019                   NaN         NaN
#      06029                   NaN         NaN
#      06037                   NaN         NaN
#      06059                   NaN         NaN
#      06061                   NaN         NaN
#      06065                   NaN         NaN
#      06067                   NaN         NaN
#      06071                   NaN         NaN
#      06073                   NaN         NaN
#      06075                   NaN         NaN
#      06077                   NaN         NaN
#      06079                   NaN         NaN
#      06081                   NaN         NaN
#      06083                   NaN         NaN
#      06085                   NaN         NaN
#      06087                   NaN         NaN
#      06097                   NaN         NaN
#      06099                   NaN         NaN
#      06111                   NaN         NaN
#      08001                   NaN         NaN
#      08005                   NaN         NaN
#      08031                   NaN         NaN
#      08041                   NaN         NaN
# ...                          ...         ...
# 2014 48439               49664.0         5.0
#      48453               26282.0         4.1
#      48491               11123.0         4.4
#      49011                5595.0         3.6
#      49035               21251.0         3.7
#      49049                8928.0         3.5
#      49057                5062.0         4.4
#      51059               25937.0         4.2
#      51710                7154.0         6.4
#      51810               11452.0         4.9
#      53009                2233.0         8.4
#      53011               14676.0         7.0
#      53015                3493.0         8.0
#      53033               54823.0         4.7
#      53035                6906.0         6.1
#      53053               26842.0         7.0
#      53061               20915.0         5.3
#      53063               15571.0         6.9
#      53067                7941.0         6.4
#      54005                 783.0         9.3
#      54011                2321.0         5.5
#      54039                5231.0         5.9
#      54055                1703.0         7.7
#      54081                2242.0         7.2
#      55009                6725.0         4.9
#      55025               11351.0         3.7
#      55079               33042.0         6.9
#      55101                6611.0         6.6
#      55105                5061.0         6.1
#      55133                9805.0         4.4
#
# [3791 rows x 106 columns]

# %% [markdown]
# ## Loading Poverty Data by COunty
#
# http://www.census.gov/did/www/saipe/data/statecounty/data/2014.html

# %%
pov_14 = pd.read_csv("/Users/HudsonCavanagh/Dropbox/Capstone/non_cdc_data/pov_14.csv")

def pov_col_clean(fig):
    fig = str(fig)
    fig = fig.replace(",", "").strip(" ")
    try:
        return float(fig)
    except: 
        return 0.0


def pov_clean(df):
    correct_pov_cols = ['State FIPS Code',
 'County FIPS Code',
 'Postal Code',
 'Name',
 'Poverty Estimate, All Ages',
 '90% CI Lower Bound',
 '90% CI Upper Bound',
 'Poverty Percent, All Ages',
 '90% CI Lower Bound',
 '90% CI Upper Bound',
 'Poverty Estimate, Age 0-17',
 '90% CI Lower Bound',
 '90% CI Upper Bound',
 'Poverty Percent, Age 0-17',
 '90% CI Lower Bound',
 '90% CI Upper Bound',
 'Poverty Estimate, Age 5-17 in Families',
 '90% CI Lower Bound',
 '90% CI Upper Bound',
 'Poverty Percent, Age 5-17 in Families',
 '90% CI Lower Bound',
 '90% CI Upper Bound',
 'Median Household Income',
 '90% CI Lower Bound',
 '90% CI Upper Bound',
 'Poverty Estimate, Age 0-4',
 '90% CI Lower Bound',
 '90% CI Upper Bound',
 'Poverty Percent, Age 0-4',
 '90% CI Lower Bound',
 '90% CI Upper Bound']
    df = df.iloc[2:,:]
    pov_cols = df.iloc[0]
    df = df.iloc[1:,:]
    df.columns = correct_pov_cols
    df['county_code'] = df['State FIPS Code'] + df['County FIPS Code']
    df['county_code'] = df['county_code'].apply(lambda x: str(x))
    df['pov_count_tot'] = df['Poverty Estimate, All Ages'].apply(lambda x: pov_col_clean(x))
    df['pov_rate_tot'] = df['Poverty Percent, All Ages'].apply(lambda x: pov_col_clean(x))
    df['pov_rate_tot'] = df['Poverty Percent, All Ages'].apply(lambda x: pov_col_clean(x))
    df['pov_youth_count_0-17'] = df['Poverty Estimate, Age 0-17'].apply(lambda x: pov_col_clean(x))
    df['pov_youth_rate_0-17'] = df['Poverty Percent, Age 0-17'].apply(lambda x: pov_col_clean(x))
    df['med_hh_income'] = df['Median Household Income'].apply(lambda x: pov_col_clean(x))
    return df


pov_14 = pov_clean(pov_14)
pov_14['year'] = '2014'



# pov_99_14 = pd.concat([pov_14], axis=1) #insert more loaded data here

pov_county_year = pov_14.groupby(by=['year', 'county_code']).mean()
pov_county_year
# Out:
#                   pov_count_tot  pov_rate_tot  pov_youth_count_0-17  \
# year county_code
# 2014 00000           48208387.0          15.5            15686012.0
#      01000             905682.0          19.2              298682.0
#      01001               7204.0          13.1                2505.0
#      01003              25696.0          13.0                8637.0
#      01005               5943.0          25.4                2137.0
#      01007               3666.0          18.1                1237.0
#      01009              10000.0          17.5                3241.0
#      01011               3179.0          35.1                 980.0
#      01013               4988.0          25.0                1735.0
#      01015              23114.0          20.5                7080.0
#      01017               7170.0          21.3                2255.0
#      01019               4768.0          18.6                1462.0
#      01021               7874.0          18.1                2896.0
#      01023               3293.0          25.0                 867.0
#      01025               6137.0          24.9                1881.0
#      01027               2592.0          19.5                 835.0
#      01029               2527.0          17.0                 854.0
#      01031               8407.0          16.8                2974.0
#      01033               9022.0          16.7                2949.0
#      01035               3846.0          30.6                1103.0
#      01037               1976.0          18.8                 568.0
#      01039               7778.0          20.8                2493.0
#      01041               2929.0          21.2                 873.0
#      01043              13809.0          17.2                4219.0
#      01045              10865.0          22.4                3869.0
#      01047              14470.0          35.2                5134.0
#      01049              16856.0          24.0                6314.0
#      01051              10867.0          14.4                3808.0
#      01053               8639.0          25.1                2588.0
#      01055              19291.0          19.0                6606.0
# ...                         ...           ...                   ...
#      55131               7761.0           5.9                2200.0
#      55133              22536.0           5.8                6337.0
#      55135               5228.0          10.4                1667.0
#      55137               3184.0          13.9                 979.0
#      55139              19505.0          12.1                5340.0
#      55141               8201.0          11.3                2725.0
#      56000              63860.0          11.2               18580.0
#      56001               8547.0          24.0                 930.0
#      56003               1251.0          10.7                 437.0
#      56005               3391.0           7.1                1218.0
#      56007               1851.0          12.3                 522.0
#      56009               1299.0           9.3                 429.0
#      56011                602.0           8.4                 192.0
#      56013               5558.0          14.0                2061.0
#      56015               1762.0          14.3                 500.0
#      56017                513.0          10.9                 162.0
#      56019                824.0           9.7                 218.0
#      56021              10165.0          10.8                3168.0
#      56023               1656.0           9.0                 607.0
#      56025               8262.0          10.4                2596.0
#      56027                326.0          14.7                  74.0
#      56029               3049.0          10.8                 921.0
#      56031               1130.0          13.0                 346.0
#      56033               2890.0           9.9                 827.0
#      56035                675.0           6.8                 178.0
#      56037               4346.0           9.8                1416.0
#      56039               1751.0           7.7                 411.0
#      56041               2081.0          10.0                 775.0
#      56043               1030.0          12.6                 312.0
#      56045                901.0          13.2                 280.0
#
#                   pov_youth_rate_0-17  med_hh_income
# year county_code
# 2014 00000                       21.7        53657.0
#      01000                       27.4        42917.0
#      01001                       18.1        54366.0
#      01003                       19.8        49626.0
#      01005                       38.1        34971.0
#      01007                       26.8        39546.0
#      01009                       24.1        45567.0
#      01011                       43.1        26580.0
#      01013                       36.7        32512.0
#      01015                       28.1        41123.0
#      01017                       31.6        34116.0
#      01019                       27.9        38013.0
#      01021                       27.6        41450.0
#      01023                       31.9        35049.0
#      01025                       33.7        36620.0
#      01027                       28.9        35940.0
#      01029                       24.8        40418.0
#      01031                       25.0        46931.0
#      01033                       25.3        43057.0
#      01035                       41.2        29101.0
#      01037                       29.0        34679.0
#      01039                       30.2        36149.0
#      01041                       28.0        34445.0
#      01043                       23.5        39922.0
#      01045                       33.5        41940.0
#      01047                       49.5        26602.0
#      01049                       36.5        36241.0
#      01051                       20.7        54298.0
#      01053                       31.6        37077.0
#      01055                       29.5        39904.0
# ...                               ...            ...
#      55131                        7.3        69346.0
#      55133                        7.3        76584.0
#      55135                       15.6        52850.0
#      55137                       22.1        46835.0
#      55139                       15.5        52711.0
#      55141                       17.3        51003.0
#      56000                       13.7        58291.0
#      56001                       15.2        42838.0
#      56003                       14.6        50437.0
#      56005                        9.2        79358.0
#      56007                       14.0        58225.0
#      56009                       12.5        63166.0
#      56011                       11.3        59701.0
#      56013                       20.2        48624.0
#      56015                       19.0        45721.0
#      56017                       16.7        44427.0
#      56019                       11.7        51434.0
#      56021                       14.2        57192.0
#      56023                       12.2        63575.0
#      56025                       13.6        57427.0
#      56027                       18.2        45251.0
#      56029                       15.7        55354.0
#      56031                       19.3        49713.0
#      56033                       13.1        54716.0
#      56035                        7.5        77222.0
#      56037                       11.9        72604.0
#      56039                        9.5        75348.0
#      56041                       12.6        56800.0
#      56043                       16.2        50802.0
#      56045                       18.4        55520.0
#
# [3194 rows x 5 columns]

# %%
deaths_pop = deaths_pop.merge(pov_county_year, how='left', left_index=1, right_index=1)

deaths_pop.describe() #looks like 2014 is fully ready to go!
# Out:
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#         County Code       Deaths  pct_total_deaths       deaths    population  \
# count  3.791000e+03  3791.000000       3791.000000  3791.000000  3.791000e+03
# mean   1.147802e+05    93.632815          0.171661    93.632815  1.918840e+05
# std    1.351437e+05   155.466277          0.293220   155.466277  4.315559e+05
# min    1.003000e+03    10.000000          0.014000    10.000000  1.196000e+03
# 25%    3.403900e+04    15.000000          0.031000    15.000000  2.330550e+04
# 50%    6.615300e+04    43.000000          0.076000    43.000000  7.440400e+04
# 75%    1.360800e+05   111.500000          0.197000   111.500000  1.986935e+05
# max    1.060422e+06  1812.000000          4.154000  1812.000000  5.645514e+06
#
#         crude_100k  total_deaths  overall_death_rate         SUMLEV  \
# count  3791.000000   3791.000000         3791.000000    1467.000000
# mean    295.998997   2572.465088            0.104293   18067.484663
# std     280.080667   2579.630907            0.089973   34941.793092
# min      17.160583    379.310345            0.006129     950.000000
# 25%     101.650869    714.285714            0.044443            NaN
# 50%     199.418164   1663.793103            0.080898            NaN
# 75%     396.842907   3531.794363            0.135667            NaN
# max    2566.462631  24358.380442            0.832616  288800.000000
#
#                STATE      ...        nan   working_pop  employed_pop  \
# count    1467.000000      ...        0.0  3.280000e+02  3.280000e+02
# mean    10181.111793      ...        NaN  3.136101e+05  2.941326e+05
# std     20323.434388      ...        NaN  4.126416e+05  3.835409e+05
# min        38.000000      ...        NaN  8.441000e+03  7.658000e+03
# 25%              NaN      ...        NaN           NaN           NaN
# 50%              NaN      ...        NaN           NaN           NaN
# 75%              NaN      ...        NaN           NaN           NaN
# max    182666.000000      ...        NaN  5.025850e+06  4.611509e+06
#
#        unemployed_pop  unemp_perc  pov_count_tot  pov_rate_tot  \
# count      328.000000  328.000000   3.280000e+02    328.000000
# mean     19477.503049    6.257927   9.367411e+04     14.825610
# std      30047.212840    1.448145   1.489013e+05      4.991309
# min        783.000000    3.000000   5.172000e+03      5.000000
# 25%               NaN         NaN            NaN           NaN
# 50%               NaN         NaN            NaN           NaN
# 75%               NaN         NaN            NaN           NaN
# max     414341.000000   11.600000   1.863025e+06     35.800000
#
#        pov_youth_count_0-17  pov_youth_rate_0-17  med_hh_income
# count            328.000000           328.000000     328.000000
# mean           30489.628049            20.653049   56719.618902
# std            50486.736456             7.478683   14120.178067
# min             1458.000000             5.600000   29497.000000
# 25%                     NaN                  NaN            NaN
# 50%                     NaN                  NaN            NaN
# 75%                     NaN                  NaN            NaN
# max           605129.000000            45.500000  110507.000000
#
# [8 rows x 111 columns]

# %% [markdown]
# #### Readding the county name

# %%
deaths_pop.reset_index(inplace=1)
#note -- ccodes is the dict I created above to reapply the name of every row
deaths_pop['county_name'] = deaths_pop['county_code'].apply(lambda x: ccodes[x])
deaths_pop['county_name']
# Out:
# 0             Jefferson County, AL
# 1                Mobile County, AL
# 2            Anchorage Borough, AK
# 3              Maricopa County, AZ
# 4                  Pima County, AZ
# 5               Alameda County, CA
# 6          Contra Costa County, CA
# 7                Fresno County, CA
# 8                  Kern County, CA
# 9           Los Angeles County, CA
# 10               Orange County, CA
# 11               Placer County, CA
# 12            Riverside County, CA
# 13           Sacramento County, CA
# 14       San Bernardino County, CA
# 15            San Diego County, CA
# 16        San Francisco County, CA
# 17          San Joaquin County, CA
# 18      San Luis Obispo County, CA
# 19            San Mateo County, CA
# 20        Santa Barbara County, CA
# 21          Santa Clara County, CA
# 22           Santa Cruz County, CA
# 23               Sonoma County, CA
# 24           Stanislaus County, CA
# 25              Ventura County, CA
# 26                Adams County, CO
# 27             Arapahoe County, CO
# 28               Denver County, CO
# 29              El Paso County, CO
#                    ...
# 3761            Tarrant County, TX
# 3762             Travis County, TX
# 3763         Williamson County, TX
# 3764              Davis County, UT
# 3765          Salt Lake County, UT
# 3766               Utah County, UT
# 3767              Weber County, UT
# 3768            Fairfax County, VA
# 3769              Norfolk city, VA
# 3770       Virginia Beach city, VA
# 3771            Clallam County, WA
# 3772              Clark County, WA
# 3773            Cowlitz County, WA
# 3774               King County, WA
# 3775             Kitsap County, WA
# 3776             Pierce County, WA
# 3777          Snohomish County, WA
# 3778            Spokane County, WA
# 3779           Thurston County, WA
# 3780              Boone County, WV
# 3781             Cabell County, WV
# 3782            Kanawha County, WV
# 3783             Mercer County, WV
# 3784            Raleigh County, WV
# 3785              Brown County, WI
# 3786               Dane County, WI
# 3787          Milwaukee County, WI
# 3788             Racine County, WI
# 3789               Rock County, WI
# 3790           Waukesha County, WI
# Name: county_name, dtype: object

# %% [markdown]
# ## Creating two models below, with crude_100k (w/o pop) and deaths (w/ pop)  as targets

# %%
#deaths is target


y = deaths_pop['deaths']
deaths_pop
deaths_pop['working_proportion_pop'] = deaths_pop['working_pop']/deaths_pop['population']
deaths_pop['employed_proportion_pop'] = deaths_pop['employed_pop']/deaths_pop['population']


#features = # write here

# working_popemployed_pop	unemployed_pop	unemp_perc	pov_count_tot	pov_rate_tot	pov_youth_count_0-17	pov_youth_rate_0-17	med_hh_income	county_name
# Out:
#       year county_code  County Code  Deaths  pct_total_deaths  deaths  \
# 0     1999       01073       4292.0    52.0             0.133    52.0
# 1     1999       01097       1097.0    10.0             0.026    10.0
# 2     1999       02020       2020.0    13.0             0.033    13.0
# 3     1999       04013      60195.0   390.0             1.005   390.0
# 4     1999       04019      24114.0   124.0             0.320   124.0
# 5     1999       06001      48008.0   133.0             0.342   133.0
# 6     1999       06013      12026.0    33.0             0.084    33.0
# 7     1999       06019      30095.0    55.0             0.141    55.0
# 8     1999       06029      48232.0   109.0             0.281   109.0
# 9     1999       06037     175073.0  1443.0             3.717  1443.0
# 10    1999       06059      72708.0   235.0             0.604   235.0
# 11    1999       06061       6061.0    10.0             0.026    10.0
# 12    1999       06065      54585.0   201.0             0.516   201.0
# 13    1999       06067      36402.0   104.0             0.267   104.0
# 14    1999       06071      66781.0   277.0             0.713   277.0
# 15    1999       06073      78949.0   382.0             0.983   382.0
# 16    1999       06075      54675.0   174.0             0.447   174.0
# 17    1999       06077       6077.0    14.0             0.036    14.0
# 18    1999       06079       6079.0    17.0             0.044    17.0
# 19    1999       06081      12162.0    25.0             0.064    25.0
# 20    1999       06083       6083.0    10.0             0.026    10.0
# 21    1999       06085      42595.0   110.0             0.283   110.0
# 22    1999       06087       6087.0    16.0             0.041    16.0
# 23    1999       06097      12194.0    22.0             0.057    22.0
# 24    1999       06099      18297.0    43.0             0.110    43.0
# 25    1999       06111      18333.0    45.0             0.115    45.0
# 26    1999       08001       8001.0    15.0             0.039    15.0
# 27    1999       08005      16010.0    22.0             0.057    22.0
# 28    1999       08031      48186.0   111.0             0.285   111.0
# 29    1999       08041      24123.0    55.0             0.141    55.0
# ...    ...         ...          ...     ...               ...     ...
# 3761  2014       48439     484390.0   234.0             0.608   234.0
# 3762  2014       48453     387624.0   156.0             0.406   156.0
# 3763  2014       48491      48491.0    12.0             0.031    12.0
# 3764  2014       49011     147033.0    33.0             0.086    33.0
# 3765  2014       49035     441315.0   270.0             0.703   270.0
# 3766  2014       49049     196196.0    63.0             0.164    63.0
# 3767  2014       49057      98114.0    22.0             0.058    22.0
# 3768  2014       51059     102118.0    30.0             0.078    30.0
# 3769  2014       51710      51710.0    11.0             0.029    11.0
# 3770  2014       51810      51810.0    10.0             0.026    10.0
# 3771  2014       53009      53009.0    11.0             0.029    11.0
# 3772  2014       53011     265055.0    79.0             0.206    79.0
# 3773  2014       53015      53015.0    11.0             0.029    11.0
# 3774  2014       53033     689429.0   418.0             1.088   418.0
# 3775  2014       53035     159105.0    33.0             0.086    33.0
# 3776  2014       53053     371371.0   176.0             0.458   176.0
# 3777  2014       53061     424488.0   166.0             0.431   166.0
# 3778  2014       53063     212252.0    83.0             0.216    83.0
# 3779  2014       53067      53067.0    10.0             0.026    10.0
# 3780  2014       54005      54005.0    10.0             0.026    10.0
# 3781  2014       54011     108022.0    25.0             0.065    25.0
# 3782  2014       54039     216156.0    62.0             0.161    62.0
# 3783  2014       54055      54055.0    14.0             0.036    14.0
# 3784  2014       54081     108162.0    24.0             0.062    24.0
# 3785  2014       55009     110018.0    20.0             0.052    20.0
# 3786  2014       55025     385175.0    89.0             0.231    89.0
# 3787  2014       55079     716027.0   275.0             0.715   275.0
# 3788  2014       55101      55101.0    10.0             0.026    10.0
# 3789  2014       55105      55105.0    10.0             0.026    10.0
# 3790  2014       55133     110266.0    30.0             0.078    30.0
#
#       population   crude_100k  total_deaths  overall_death_rate  \
# 0       102605.0   212.473675   1566.326531            0.066114
# 1        19679.0    50.815590    384.615385            0.019544
# 2        16365.0    79.437825    393.939394            0.024072
# 3      1575758.0   468.814895   5816.332811            0.093708
# 4       218133.0   337.272386   2326.788853            0.065612
# 5       262877.0   508.955156   3111.664887            0.128966
# 6        97817.0    67.932156    786.096257            0.016085
# 7       104417.0   278.114479   1948.884449            0.098665
# 8       175942.0   500.226017   3103.681265            0.147105
# 9      4580185.0  1234.944796  11261.863382            0.132625
# 10      989789.0   324.068343   4672.137386            0.072047
# 11       16641.0    60.092543    384.615385            0.023113
# 12      406001.0   469.467168   3506.572994            0.088590
# 13      302830.0   222.753064   2336.263798            0.049733
# 14      444667.0   762.356877   4276.000092            0.142180
# 15     1019985.0   581.319499   5057.129113            0.101281
# 16      187734.0  1459.071419   3502.970649            0.333758
# 17       20418.0    68.566951    388.888889            0.019046
# 18       15351.0   110.741971    386.363636            0.025169
# 19       64357.0    77.702430    781.036168            0.024308
# 20       17700.0    56.497175    384.615385            0.021730
# 21      292374.0   408.636229   2717.543339            0.111128
# 22       16611.0    96.321715    390.243902            0.023493
# 23       59277.0    74.078128    771.712159            0.026072
# 24       51391.0   273.819305   1173.344948            0.072700
# 25       88394.0   171.893394   1173.902894            0.049480
# 26       22070.0    67.965564    384.615385            0.017427
# 27       63821.0    68.891320    771.712159            0.024185
# 28      125526.0   621.747010   2341.893186            0.146494
# 29       94869.0   174.402093   1171.576540            0.037433
# ...          ...          ...           ...                 ...
# 3761    645577.0   356.710058   3850.531300            0.061418
# 3762    368425.0   362.329717   3077.177107            0.068568
# 3763     17723.0    67.708627    387.096774            0.021841
# 3764     54942.0   182.843585   1151.022504            0.063731
# 3765    486237.0   514.115734   3457.434195            0.065167
# 3766    110692.0   242.063758   1536.310686            0.058012
# 3767     21557.0   204.167290    758.620690            0.070403
# 3768     84540.0    70.961271    769.841270            0.018300
# 3769      6329.0   173.803128    379.310345            0.059932
# 3770     17747.0    56.347552    384.615385            0.021672
# 3771      5278.0   208.412277    379.310345            0.071866
# 3772    127796.0   309.917973   1917.456070            0.075113
# 3773      6807.0   161.598355    379.310345            0.055724
# 3774   1019507.0   632.023093   4991.960278            0.116687
# 3775     40998.0   244.415485   1151.022504            0.085997
# 3776    271768.0   451.049807   2691.867343            0.071518
# 3777    306989.0   419.890264   3082.950675            0.083791
# 3778    104280.0   323.961132   1535.213156            0.060857
# 3779     16619.0    60.172092    384.615385            0.023143
# 3780      1562.0   640.204866    384.615385            0.246233
# 3781     11020.0   454.263872    769.449715            0.139685
# 3782     44560.0   566.526324   1541.553429            0.139570
# 3783      3557.0   393.590104    388.888889            0.109331
# 3784      9011.0   533.200788    774.193548            0.172000
# 3785     28692.0   139.526760    769.230769            0.053664
# 3786    200129.0   310.219175   2696.756280            0.094787
# 3787    380775.0  1042.694344   4995.913806            0.210127
# 3788     12090.0    82.712986    384.615385            0.031813
# 3789     10041.0    99.591674    384.615385            0.038304
# 3790     48986.0   124.250289    769.841270            0.032273
#
#                  ...              working_pop  employed_pop  unemployed_pop  \
# 0                ...                      NaN           NaN             NaN
# 1                ...                      NaN           NaN             NaN
# 2                ...                      NaN           NaN             NaN
# 3                ...                      NaN           NaN             NaN
# 4                ...                      NaN           NaN             NaN
# 5                ...                      NaN           NaN             NaN
# 6                ...                      NaN           NaN             NaN
# 7                ...                      NaN           NaN             NaN
# 8                ...                      NaN           NaN             NaN
# 9                ...                      NaN           NaN             NaN
# 10               ...                      NaN           NaN             NaN
# 11               ...                      NaN           NaN             NaN
# 12               ...                      NaN           NaN             NaN
# 13               ...                      NaN           NaN             NaN
# 14               ...                      NaN           NaN             NaN
# 15               ...                      NaN           NaN             NaN
# 16               ...                      NaN           NaN             NaN
# 17               ...                      NaN           NaN             NaN
# 18               ...                      NaN           NaN             NaN
# 19               ...                      NaN           NaN             NaN
# 20               ...                      NaN           NaN             NaN
# 21               ...                      NaN           NaN             NaN
# 22               ...                      NaN           NaN             NaN
# 23               ...                      NaN           NaN             NaN
# 24               ...                      NaN           NaN             NaN
# 25               ...                      NaN           NaN             NaN
# 26               ...                      NaN           NaN             NaN
# 27               ...                      NaN           NaN             NaN
# 28               ...                      NaN           NaN             NaN
# 29               ...                      NaN           NaN             NaN
# ...              ...                      ...           ...             ...
# 3761             ...                 990723.0      941059.0         49664.0
# 3762             ...                 644341.0      618059.0         26282.0
# 3763             ...                 255327.0      244204.0         11123.0
# 3764             ...                 156266.0      150671.0          5595.0
# 3765             ...                 577159.0      555908.0         21251.0
# 3766             ...                 255870.0      246942.0          8928.0
# 3767             ...                 115180.0      110118.0          5062.0
# 3768             ...                 622185.0      596248.0         25937.0
# 3769             ...                 112466.0      105312.0          7154.0
# 3770             ...                 232635.0      221183.0         11452.0
# 3771             ...                  26711.0       24478.0          2233.0
# 3772             ...                 209174.0      194498.0         14676.0
# 3773             ...                  43571.0       40078.0          3493.0
# 3774             ...                1161113.0     1106290.0         54823.0
# 3775             ...                 113480.0      106574.0          6906.0
# 3776             ...                 385100.0      358258.0         26842.0
# 3777             ...                 396624.0      375709.0         20915.0
# 3778             ...                 225213.0      209642.0         15571.0
# 3779             ...                 123254.0      115313.0          7941.0
# 3780             ...                   8441.0        7658.0           783.0
# 3781             ...                  42217.0       39896.0          2321.0
# 3782             ...                  88848.0       83617.0          5231.0
# 3783             ...                  22254.0       20551.0          1703.0
# 3784             ...                  31272.0       29030.0          2242.0
# 3785             ...                 138636.0      131911.0          6725.0
# 3786             ...                 306147.0      294796.0         11351.0
# 3787             ...                 479375.0      446333.0         33042.0
# 3788             ...                  99994.0       93383.0          6611.0
# 3789             ...                  82406.0       77345.0          5061.0
# 3790             ...                 220880.0      211075.0          9805.0
#
#       unemp_perc  pov_count_tot  pov_rate_tot  pov_youth_count_0-17  \
# 0            NaN            NaN           NaN                   NaN
# 1            NaN            NaN           NaN                   NaN
# 2            NaN            NaN           NaN                   NaN
# 3            NaN            NaN           NaN                   NaN
# 4            NaN            NaN           NaN                   NaN
# 5            NaN            NaN           NaN                   NaN
# 6            NaN            NaN           NaN                   NaN
# 7            NaN            NaN           NaN                   NaN
# 8            NaN            NaN           NaN                   NaN
# 9            NaN            NaN           NaN                   NaN
# 10           NaN            NaN           NaN                   NaN
# 11           NaN            NaN           NaN                   NaN
# 12           NaN            NaN           NaN                   NaN
# 13           NaN            NaN           NaN                   NaN
# 14           NaN            NaN           NaN                   NaN
# 15           NaN            NaN           NaN                   NaN
# 16           NaN            NaN           NaN                   NaN
# 17           NaN            NaN           NaN                   NaN
# 18           NaN            NaN           NaN                   NaN
# 19           NaN            NaN           NaN                   NaN
# 20           NaN            NaN           NaN                   NaN
# 21           NaN            NaN           NaN                   NaN
# 22           NaN            NaN           NaN                   NaN
# 23           NaN            NaN           NaN                   NaN
# 24           NaN            NaN           NaN                   NaN
# 25           NaN            NaN           NaN                   NaN
# 26           NaN            NaN           NaN                   NaN
# 27           NaN            NaN           NaN                   NaN
# 28           NaN            NaN           NaN                   NaN
# 29           NaN            NaN           NaN                   NaN
# ...          ...            ...           ...                   ...
# 3761         5.0       291534.0          15.2              113228.0
# 3762         4.1       188959.0          16.7               60561.0
# 3763         4.4        37898.0           7.8               13119.0
# 3764         3.6        23606.0           7.2                9070.0
# 3765         3.7       128385.0          11.9               45911.0
# 3766         3.5        69472.0          12.6               21222.0
# 3767         4.4        29322.0          12.3               10722.0
# 3768         4.2        75137.0           6.7               23301.0
# 3769         6.4        49728.0          23.4               15559.0
# 3770         4.9        37886.0           8.6               12569.0
# 3771         8.4        11518.0          16.2                3267.0
# 3772         7.0        44213.0           9.9               15179.0
# 3773         8.0        20701.0          20.6                6118.0
# 3774         4.7       230750.0          11.3               58351.0
# 3775         6.1        27550.0          11.2                7473.0
# 3776         7.0       106432.0          13.1               34165.0
# 3777         5.3        73930.0           9.9               22598.0
# 3778         6.9        76910.0          16.3               21892.0
# 3779         6.4        31197.0          11.9                9031.0
# 3780         9.3         5172.0          22.1                1458.0
# 3781         5.5        20377.0          21.9                5054.0
# 3782         5.9        31400.0          16.8                9744.0
# 3783         7.7        12413.0          20.5                3889.0
# 3784         7.2        13163.0          17.7                4006.0
# 3785         4.9        29879.0          12.0               10184.0
# 3786         3.7        67242.0          13.4               15265.0
# 3787         6.9       205183.0          22.0               73980.0
# 3788         6.6        24966.0          13.1                8596.0
# 3789         6.1        23554.0          14.9                8892.0
# 3790         4.4        22536.0           5.8                6337.0
#
#       pov_youth_rate_0-17  med_hh_income                 county_name
# 0                     NaN            NaN        Jefferson County, AL
# 1                     NaN            NaN           Mobile County, AL
# 2                     NaN            NaN       Anchorage Borough, AK
# 3                     NaN            NaN         Maricopa County, AZ
# 4                     NaN            NaN             Pima County, AZ
# 5                     NaN            NaN          Alameda County, CA
# 6                     NaN            NaN     Contra Costa County, CA
# 7                     NaN            NaN           Fresno County, CA
# 8                     NaN            NaN             Kern County, CA
# 9                     NaN            NaN      Los Angeles County, CA
# 10                    NaN            NaN           Orange County, CA
# 11                    NaN            NaN           Placer County, CA
# 12                    NaN            NaN        Riverside County, CA
# 13                    NaN            NaN       Sacramento County, CA
# 14                    NaN            NaN   San Bernardino County, CA
# 15                    NaN            NaN        San Diego County, CA
# 16                    NaN            NaN    San Francisco County, CA
# 17                    NaN            NaN      San Joaquin County, CA
# 18                    NaN            NaN  San Luis Obispo County, CA
# 19                    NaN            NaN        San Mateo County, CA
# 20                    NaN            NaN    Santa Barbara County, CA
# 21                    NaN            NaN      Santa Clara County, CA
# 22                    NaN            NaN       Santa Cruz County, CA
# 23                    NaN            NaN           Sonoma County, CA
# 24                    NaN            NaN       Stanislaus County, CA
# 25                    NaN            NaN          Ventura County, CA
# 26                    NaN            NaN            Adams County, CO
# 27                    NaN            NaN         Arapahoe County, CO
# 28                    NaN            NaN           Denver County, CO
# 29                    NaN            NaN          El Paso County, CO
# ...                   ...            ...                         ...
# 3761                 21.7        58127.0          Tarrant County, TX
# 3762                 23.1        61779.0           Travis County, TX
# 3763                 10.0        73098.0       Williamson County, TX
# 3764                  8.3        70797.0            Davis County, UT
# 3765                 15.1        62536.0        Salt Lake County, UT
# 3766                 11.0        60957.0             Utah County, UT
# 3767                 15.4        59293.0            Weber County, UT
# 3768                  8.7       110507.0          Fairfax County, VA
# 3769                 31.7        42567.0            Norfolk city, VA
# 3770                 12.4        67676.0     Virginia Beach city, VA
# 3771                 26.2        47185.0          Clallam County, WA
# 3772                 13.6        61747.0            Clark County, WA
# 3773                 26.8        44235.0          Cowlitz County, WA
# 3774                 13.6        75738.0             King County, WA
# 3775                 14.4        61898.0           Kitsap County, WA
# 3776                 17.5        60397.0           Pierce County, WA
# 3777                 13.1        71890.0        Snohomish County, WA
# 3778                 20.5        50083.0          Spokane County, WA
# 3779                 15.6        61653.0         Thurston County, WA
# 3780                 28.4        37625.0            Boone County, WV
# 3781                 27.0        34887.0           Cabell County, WV
# 3782                 25.8        43936.0          Kanawha County, WV
# 3783                 31.0        35046.0           Mercer County, WV
# 3784                 25.0        40270.0          Raleigh County, WV
# 3785                 16.6        54141.0            Brown County, WI
# 3786                 14.3        61937.0             Dane County, WI
# 3787                 32.2        42946.0        Milwaukee County, WI
# 3788                 18.8        54782.0           Racine County, WI
# 3789                 23.7        51237.0             Rock County, WI
# 3790                  7.3        76584.0         Waukesha County, WI
#
# [3791 rows x 114 columns]

# %%
#crude rate is target


y = deaths_pop['crude_100k']
deaths_pop
features = ['population']
