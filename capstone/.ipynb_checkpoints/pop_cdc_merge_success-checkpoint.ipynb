# %%
import pandas as pd

pop_03 = pd.read_csv("/Users/HudsonCavanagh/Dropbox/Capstone/csv_output/pop_03_output.csv")
pop_03.head()
# Out:
#    Unnamed: 0  year  county_code   SEX  AGEGRP  population_age_sex  ORIGIN  \
# 0           0  2003         1001  3591   32319          11793600.0    3591
# 1           1  2003         1003  3591   32319          38180268.0    3591
# 2           2  2003         1005  3591   32319           7205688.0    3591
# 3           3  2003         1007  3591   32319           5392548.0    3591
# 4           4  2003         1009  3591   32319          13471164.0    3591
#
#     RACE  population_race_hisp   sex    ...      age_group  pop_sub_15  \
# 0  10773            21340800.0  3591    ...          32319   1372644.0
# 1  10773            69088104.0  3591    ...          32319   3701502.0
# 2  10773            13038864.0  3591    ...          32319    707742.0
# 3  10773             9757944.0  3591    ...          32319    558306.0
# 4  10773            24376392.0  3591    ...          32319   1423044.0
#
#    pop_15-34  pop_35-54    pop_55+   pop_male   pop_white  pop_black  \
# ...

# %%
pop_03.tail()
# Out:
#       Unnamed: 0  year  county_code   SEX  AGEGRP  population_age_sex  ORIGIN  \
# 3138        3138  2003        56037  3591   32319           9437400.0    3591
# 3139        3139  2003        56039  3591   32319           4804632.0    3591
# 3140        3140  2003        56041  3591   32319           4908960.0    3591
# 3141        3141  2003        56043  3591   32319           2009952.0    3591
# 3142        3142  2003        56045  3591   32319           1665720.0    3591
#
#        RACE  population_race_hisp   sex    ...      age_group  pop_sub_15  \
# 3138  10773            17077200.0  3591    ...          32319   1023750.0
# 3139  10773             8694096.0  3591    ...          32319    373338.0
# 3140  10773             8882880.0  3591    ...          32319    611604.0
# 3141  10773             3637056.0  3591    ...          32319    199962.0
# 3142  10773             3014160.0  3591    ...          32319    140994.0
#
# ...

# %%
pop_15 = pd.read_csv("/Users/HudsonCavanagh/Dropbox/Capstone/csv_output/pop_10_15_output.csv")
pop_15.head()
# Out:
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2902: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  year  county_code  SUMLEV  YEAR  AGEGRP  TOT_POP  TOT_MALE  \
# 0           0  2010         1001     950    57     171   109320     53236
# 1           1  2010         1003     950    57     171   366386    179218
# 2           2  2010         1005     950    57     171    54682     29026
# 3           3  2010         1007     950    57     171    45722     24512
# 4           4  2010         1009     950    57     171   114746     56752
#
#    TOT_FEMALE  WA_MALE    ...      HNAC_MALE  HNAC_FEMALE  pop_sub_15  \
# 0       56084    42602    ...             38           22       11824
# 1      187168   157352    ...             84           74       34792
# ...

# %%
cdc = pd.read_csv("/Users/HudsonCavanagh/Dropbox/Capstone/csv_output/cdc_03_14.csv")

cdc.head()
# Out:
#    Unnamed: 0  Notes                County  County Code Ten-Year Age Groups  \
# 0           0    NaN  Jefferson County, AL       1073.0         15-24 years
# 1           1    NaN  Jefferson County, AL       1073.0         25-34 years
# 2           2    NaN  Jefferson County, AL       1073.0         25-34 years
# 3           3    NaN  Jefferson County, AL       1073.0         35-44 years
# 4           4    NaN  Jefferson County, AL       1073.0         35-44 years
#
#   Ten-Year Age Groups Code  Gender Gender Code   Race Race Code  \
# 0                    15-24    Male           M  White    2106-3
# 1                    25-34  Female           F  White    2106-3
# 2                    25-34    Male           M  White    2106-3
# 3                    35-44  Female           F  White    2106-3
# 4                    35-44    Male           M  White    2106-3
#
#            ...            year pct_total_deaths  deaths  population  \
# ...

# %%
deaths_pop = pd.merge(cdc, pop_03, how='left', left_on=['year','county_code'], right_on=['year','county_code'])
deaths_pop[deaths_pop['year']==2003]
# Out:
#        Unnamed: 0_x  Notes                 County  County Code  \
# 13412             0    NaN   Jefferson County, AL       1073.0
# 13413             1    NaN   Jefferson County, AL       1073.0
# 13414             2    NaN  Anchorage Borough, AK       2020.0
# 13415             3    NaN  Anchorage Borough, AK       2020.0
# 13416             4    NaN    Maricopa County, AZ       4013.0
# 13417             5    NaN    Maricopa County, AZ       4013.0
# 13418             6    NaN    Maricopa County, AZ       4013.0
# 13419             7    NaN    Maricopa County, AZ       4013.0
# 13420             8    NaN    Maricopa County, AZ       4013.0
# 13421             9    NaN    Maricopa County, AZ       4013.0
# 13422            10    NaN    Maricopa County, AZ       4013.0
# 13423            11    NaN    Maricopa County, AZ       4013.0
# 13424            12    NaN    Maricopa County, AZ       4013.0
# 13425            13    NaN    Maricopa County, AZ       4013.0
# ...
